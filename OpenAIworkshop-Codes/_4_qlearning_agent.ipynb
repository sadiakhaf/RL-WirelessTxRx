# %%
#   ____                            _____     _____                   __          __        _        _                 
#  / __ \                     /\   |_   _|   / ____|                  \ \        / /       | |      | |                
# | |  | |_ __   ___ _ __    /  \    | |    | |  __ _   _ _ __ ___     \ \  /\  / /__  _ __| | _____| |__   ___  _ __  
# | |  | | '_ \ / _ \ '_ \  / /\ \   | |    | | |_ | | | | '_ ` _ \     \ \/  \/ / _ \| '__| |/ / __| '_ \ / _ \| '_ \ 
# | |__| | |_) |  __/ | | |/ ____ \ _| |_   | |__| | |_| | | | | | |     \  /\  / (_) | |  |   <\__ \ | | | (_) | |_) |
#  \____/| .__/ \___|_| |_/_/    \_\_____|   \_____|\__, |_| |_| |_|      \/  \/ \___/|_|  |_|\_\___/_| |_|\___/| .__/ 
#        | |                                         __/ |                                                      | |    
#        |_|                                        |___/                                                       |_|

# %%
# !pip install gym
#!pip install torch==1.5.0+cpu -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (0.17.2)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym) (1.18.5)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)

# %%
import json
from itertools import count

import gym
from gym import spaces

import torch
from torch import Tensor

import random
from random import randint

from typing import Dict, List, Optional, Callable, Any, Tuple, Union, Type

import pathlib

# %%
class RxQLearningAgent:
  def __init__(
    self, lr: float, gamma: float, act_space: spaces.Discrete,
    obs_space: spaces.Discrete, eps_fn_steps: int
  ):
    assert obs_space.dtype == int  # compatibility assertion

    self.lr = lr  # learning rate
    self.gamma = gamma  # gamma parameter
    self.qtable: Dict[int, Tensor] = dict()  # Q-table with time-step as keys for a 1D Q-table (with number frequences)
    self.n_actions = act_space.n  # number of actions

    self.eps_fn_steps = eps_fn_steps  # number of steps (episodes) in epsilon log-space
    self.eps_fn: Callable[[int], float] = build_epsilon_fn(eps_fn_steps)  # build our epsilon function
    self.episode_i: Optional[int] = None  # keep track of the episode number (e.g. for epsilon)
    self.eps: Optional[float] = None  # epsilon value as a property of our agent

  def act(self, o: int, eps: Optional[float] = None) -> int:  # function to choose action, with optinal epsilon argument
    if eps is None:
      eps = self.eps  # not epsilon as argument, use agent's current epsilon value

    if o not in self.qtable:
      self.qtable[o] = torch.zeros(self.n_actions)  # add new Q-table for new obs, Q-values are zero

    if random.uniform(1.0, 0.0) < eps:  # epsilon-greedy condition for exploration
      return self.explore(o)  # exploring random action

    return self.qtable[o].argmax().item()  # return frequency with highest Q-value

  def explore(self, o: int) -> int:  # action-space exploration
    return randint(0, self.n_actions - 1)  # random action

  def update(self, o: int, a: int, r: float, o_prime: int) -> float:  # agent update function (e.g. Q-learning update)
    if o not in self.qtable:
      self.qtable[o] = torch.zeros(self.n_actions)  # add new Q-table for new obs, Q-values are zero

    if o_prime not in self.qtable:
      self.qtable[o_prime] = torch.zeros(self.n_actions)  # add new Q-table for new obs, Q-values are zero

    old_o_a_value = self.qtable[o][a].item()  # keep old Q-values to compute delta update

    td_target = r + self.gamma * self.qtable[o_prime].max().item()  # compute Temporal-Difference target (e.i [r + gamma * Q(o', a_max)])
    self.qtable[o][a] += self.lr * (td_target - self.qtable[o][a].item())  # update Q-table (e.i. Q(o, s) <- Q(o, s) + lr * [TD-target - Q(o, a)])

    return self.qtable[o][a].item() - old_o_a_value  # return delta update to training loop

  def episode_reset(self, o: int, episode_i: int) -> int:  # reset agent for a new episode
    self.episode_i = episode_i  # current episode number
    self.eps = self.eps_fn(episode_i)  # epsilon w.r.t. episode number
    return self.act(o, self.eps)  # act upon initial observation

  def save_to_file(self, path: str, overwrite: bool = False):  # save agent state to file
    file = pathlib.Path(path)  # file path
    if not overwrite and file.exists():  # exception if file exist and overwrite is false
      raise FileExistsError()

    # agent state as a python dictionary
    agent_state: Dict[str, Any] = {
      'gamma': self.gamma, 'n_actions': self.n_actions,
      'qtable': {k: v.tolist() for k, v in self.qtable.items()}
    }

    with file.open('w') as f:  # open file to write in it
      json.dump(agent_state, f)  # write agent state in file

  def load_from_file(self, path: str):  # load agent state from compatible saved state
    file = pathlib.Path(path)  # file path
    if not file.exists():
      return  # file does not exists

    with file.open('r') as f:  # open file to read it
      agent_state = json.load(f)  # load agent state from file

    self.gamma = agent_state['gamma']  # set gamma to loaded value
    self.n_actions = agent_state['n_actions']  # set number of actions from loaded value
    # set Q-table from loaded values
    self.qtable = {
      int(k): torch.tensor(v) for k, v in agent_state['qtable'].items()
    }

# %%
class TxWirelessGym(gym.Env):
  def __init__(self, n_freqs: int, horizon: int):
    super(TxWirelessGym, self).__init__()  # initialize gym.Env base class
    self.action_space: spaces.Discrete = spaces.Discrete(n_freqs)  # action space {0, 1, ..., n_freqs - 1}
    self.observation_space: spaces.Discrete = spaces.Discrete(horizon + 1)  # observation space {0, 1, ..., horizon}
    self.hor = horizon  # gym horizon to know when we are DONE
    self.tx_freq = torch.randint(n_freqs, size=(horizon,))  # random Tx frequencies w.r.t. time-step
    self.t = 0  # initial time-step / observation 

  def step(self, action: int):  # step function to interact with the gym
    if self.t < self.hor:  # non-terminal observation, horizon not reached
      r = float(action == self.tx_freq[self.t])  # float(True) = 1.0 if Tx and Rx frequencies are the same
    else:  # gym horizon reached
      r = 0.0
    self.t += 1  # increment our time-step / observation
    o = self.t  # observation that will return
    done = (self.t == self.hor)  # is terminal gym state reached
    return o, r, done, {}  # gyms always returns <obs, reward, terminal obs reached, debug/info dictionary>

  def reset(self):  # reset our gym for a new episode
    self.t = 0  # initial time-step
    o = self.t  # initial observation
    return o

  def render(self, mode='human'):  # gym visual rendering (e.g. text, image, plot, 3D frame, etc.)
    a_r = []
    for freq in range(self.action_space.n):  # try every freqs
      if self.t < self.hor:
        a_r.append(float(freq == self.tx_freq[self.t]))  # float(True) = 1.0 if Tx and Rx frequencies are the same
      else:
        a_r.append(0.0)
    # print all action-reward for this time-step
    print(
      't={o:2}, tx_freq:{tx_freq}, tx_rewards:{action_rewards}'.format(
        o=self.t, tx_freq=[i for i in range(len(a_r)) if a_r[i] == 1.0],
        action_rewards=a_r
      )
    )

# %%
def build_epsilon_fn(steps: int) -> Callable[[int], float]:  # epsilon function builder
  log_epsilon_space = torch.logspace(1.0, -1.0, steps=steps, base=10.0) / 10.0  # epsilon log-space {1.0, ..., 0.0}

  def epsilon_fn(episode_i: int):  # epsilon function
    if episode_i >= steps:  # max step reached
      return 0.0
    return log_epsilon_space[episode_i].item()  # return epsilon value

  return epsilon_fn  # return our function as an callable object

# %%
random.seed(1234)  # python random number generator seed
torch.manual_seed(1234)  # pytorch random number generator seed

n_freqs = 10  # number of frequencies
horizon = 15  # horizon of our gym (episodes)

gym_env = TxWirelessGym(n_freqs, horizon)  # our gym environment

lr = 0.15  # learning rate
gamma = 0.0  # gamma parameter
eps_fn_steps = 300  # number of steps (episodes) in epsilon log-space
# initialize our Rx agent with learning parameters and gym parameters
agent = RxQLearningAgent(
  lr, gamma, gym_env.action_space, gym_env.observation_space, eps_fn_steps
)

#agent.load_from_file('rx_agent_1.json')  # load previously saved agent

show_verbose = True  # print information for debugging
render_gym = False  # render gym

# print simulation parameters
print(
  'model: {{n_freqs={n_freqs}, horizon={horizon}}}, '
  'agent: {{lr={lr}, gamma={gamma}, eps_fn_steps={eps_fn_steps}}}'.format(
    n_freqs=gym_env.action_space.n, horizon=horizon, lr=lr, gamma=gamma,
    eps_fn_steps=eps_fn_steps
  )
)

running_len = 5  # length of our running training data
running_delta = []  # running delta (e.g. the last running_len delta update)
running_acc = []  # running accuracy (e.g. the last running_len accuracy)

for episode_i in count():  # training loop
  if show_verbose:
    print('starting episode {episode_i}...'.format(episode_i=episode_i))

  delta_update: List[float] = []  # delta update of our Q-table
  n_successes: int = 0  # number of optimal actions (actions with maximum reward)
  cumul_r: float = 0.0  # cumulative reward

  o = gym_env.reset()  # reset gym for new episode
  a = agent.episode_reset(o, episode_i)  # reset agent with initial gym observation and episode number

  for t in count():  # episode loop
    if render_gym:
      gym_env.render()  # show gym rendering
    o_prime, r, done, _ = gym_env.step(a)  # interact with the gym, get environment transition
    
    delta_update.append(agent.update(o, a, r, o_prime))  # update agent with transition, get delta update
    cumul_r += r  # add reward to cumulative reward
    n_successes += int(r > 0.0)  # success if optimal action-reward of 1.0

    if show_verbose:   # show transition of our model (e.i. <o, a, r, o'>)
      print(
        'transition=<{o}, {a}, {r}, {o_prime}>,'
        ' delta_update={delta}'.format(
          o=o, a=a, r=r, o_prime=o_prime, delta=delta_update[-1]
        )
      )

    o = o_prime  # increment to next observation (e.g. next observation)
    a = agent.act(o)  #  act upon next observation
    if done:
      break  # terminal gym observation reached, out of horizon

  # strip running data because we reached running length
  if len(running_acc) >= running_len or len(running_delta) >= running_len:
    running_acc.pop(0)  # delete oldest running accuracy
    running_delta.pop(0)  # delete oldest running update delta

  running_acc.append(n_successes / horizon)  # add latest accuracy to running data
  running_delta.append(sum(delta_update))  # add latest update delta to running data

  # show episode results
  print(
    'episode {episode_i}: cumul_reward={cumul_r}, accuracy:{acc:0.5}, '
    'cumul_delta={cumul_delta:0.5}, eps={eps:0.5}'.format(
      episode_i=episode_i, cumul_r=cumul_r, acc=running_acc[-1],
      cumul_delta=running_delta[-1], eps=agent.eps
    )
  )

  # training stop conditions
  if (
    all([acc == 1.0 for acc in running_acc])  # all running accuracy are maximized
    and all([delta < 0.0001 for delta in running_delta])  # all running delta update a lower than 0.0001
    and episode_i >= running_len  # running data have reached running length
  ) or episode_i >= eps_fn_steps + running_len:  # epsilon was 0 for all running data (nothing will change)
    break  # exit training loop

agent.save_to_file('rx_agent_1.json')  # save agent state to file
gym_env.close()  # close gym environment
# Out:
# model: {n_freqs=10, horizon=15}, agent: {lr=0.15, gamma=0.0, eps_fn_steps=300}
# starting episode 0...
# transition=<0, 7, 0.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.15000000596046448
# transition=<2, 9, 0.0, 3>, delta_update=0.0
# transition=<3, 1, 0.0, 4>, delta_update=0.0
# transition=<4, 5, 0.0, 5>, delta_update=0.0
# transition=<5, 0, 0.0, 6>, delta_update=0.0
# transition=<6, 0, 0.0, 7>, delta_update=0.0
# transition=<7, 9, 0.0, 8>, delta_update=0.0
# transition=<8, 7, 0.0, 9>, delta_update=0.0
# transition=<9, 2, 0.0, 10>, delta_update=0.0
# transition=<10, 0, 0.0, 11>, delta_update=0.0
# transition=<11, 3, 0.0, 12>, delta_update=0.0
# transition=<12, 8, 0.0, 13>, delta_update=0.0
# transition=<13, 1, 0.0, 14>, delta_update=0.0
# transition=<14, 1, 0.0, 15>, delta_update=0.0
# episode 0: cumul_reward=1.0, accuracy:0.066667, cumul_delta=0.15, eps=1.0
# starting episode 1...
# transition=<0, 8, 0.0, 1>, delta_update=0.0
# transition=<1, 4, 0.0, 2>, delta_update=0.0
# transition=<2, 5, 0.0, 3>, delta_update=0.0
# transition=<3, 3, 0.0, 4>, delta_update=0.0
# transition=<4, 8, 0.0, 5>, delta_update=0.0
# transition=<5, 8, 0.0, 6>, delta_update=0.0
# transition=<6, 5, 0.0, 7>, delta_update=0.0
# transition=<7, 7, 0.0, 8>, delta_update=0.0
# transition=<8, 2, 0.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.15000000596046448
# transition=<10, 1, 0.0, 11>, delta_update=0.0
# transition=<11, 2, 0.0, 12>, delta_update=0.0
# transition=<12, 5, 0.0, 13>, delta_update=0.0
# transition=<13, 8, 0.0, 14>, delta_update=0.0
# transition=<14, 4, 0.0, 15>, delta_update=0.0
# episode 1: cumul_reward=1.0, accuracy:0.066667, cumul_delta=0.15, eps=0.98472
# starting episode 2...
# transition=<0, 0, 0.0, 1>, delta_update=0.0
# transition=<1, 2, 0.0, 2>, delta_update=0.0
# transition=<2, 2, 0.0, 3>, delta_update=0.0
# transition=<3, 7, 0.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.15000000596046448
# transition=<5, 7, 0.0, 6>, delta_update=0.0
# transition=<6, 7, 0.0, 7>, delta_update=0.0
# transition=<7, 7, 0.0, 8>, delta_update=0.0
# transition=<8, 9, 0.0, 9>, delta_update=0.0
# transition=<9, 7, 0.0, 10>, delta_update=0.0
# transition=<10, 8, 0.0, 11>, delta_update=0.0
# transition=<11, 4, 0.0, 12>, delta_update=0.0
# transition=<12, 2, 0.0, 13>, delta_update=0.0
# transition=<13, 1, 0.0, 14>, delta_update=0.0
# transition=<14, 1, 0.0, 15>, delta_update=0.0
# episode 2: cumul_reward=1.0, accuracy:0.066667, cumul_delta=0.15, eps=0.96967
# starting episode 3...
# transition=<0, 4, 0.0, 1>, delta_update=0.0
# transition=<1, 5, 0.0, 2>, delta_update=0.0
# transition=<2, 2, 0.0, 3>, delta_update=0.0
# transition=<3, 4, 0.0, 4>, delta_update=0.0
# transition=<4, 5, 0.0, 5>, delta_update=0.0
# transition=<5, 7, 0.0, 6>, delta_update=0.0
# transition=<6, 1, 0.0, 7>, delta_update=0.0
# transition=<7, 0, 0.0, 8>, delta_update=0.0
# transition=<8, 0, 0.0, 9>, delta_update=0.0
# transition=<9, 1, 0.0, 10>, delta_update=0.0
# transition=<10, 5, 0.0, 11>, delta_update=0.0
# transition=<11, 7, 0.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.15000000596046448
# transition=<13, 6, 0.0, 14>, delta_update=0.0
# transition=<14, 1, 0.0, 15>, delta_update=0.0
# episode 3: cumul_reward=1.0, accuracy:0.066667, cumul_delta=0.15, eps=0.95485
# starting episode 4...
# transition=<0, 5, 1.0, 1>, delta_update=0.15000000596046448
# transition=<1, 3, 0.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.15000000596046448
# transition=<3, 9, 0.0, 4>, delta_update=0.0
# transition=<4, 0, 0.0, 5>, delta_update=0.0
# transition=<5, 8, 0.0, 6>, delta_update=0.0
# transition=<6, 8, 0.0, 7>, delta_update=0.0
# transition=<7, 2, 0.0, 8>, delta_update=0.0
# transition=<8, 9, 0.0, 9>, delta_update=0.0
# transition=<9, 2, 0.0, 10>, delta_update=0.0
# transition=<10, 1, 0.0, 11>, delta_update=0.0
# transition=<11, 2, 0.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.1274999976158142
# transition=<13, 1, 0.0, 14>, delta_update=0.0
# transition=<14, 2, 0.0, 15>, delta_update=0.0
# episode 4: cumul_reward=3.0, accuracy:0.2, cumul_delta=0.4275, eps=0.94025
# starting episode 5...
# transition=<0, 5, 1.0, 1>, delta_update=0.1274999976158142
# transition=<1, 6, 0.0, 2>, delta_update=0.0
# transition=<2, 4, 0.0, 3>, delta_update=0.0
# transition=<3, 4, 0.0, 4>, delta_update=0.0
# transition=<4, 9, 0.0, 5>, delta_update=0.0
# transition=<5, 8, 0.0, 6>, delta_update=0.0
# transition=<6, 4, 0.0, 7>, delta_update=0.0
# transition=<7, 6, 0.0, 8>, delta_update=0.0
# transition=<8, 4, 0.0, 9>, delta_update=0.0
# transition=<9, 6, 0.0, 10>, delta_update=0.0
# transition=<10, 4, 0.0, 11>, delta_update=0.0
# transition=<11, 9, 0.0, 12>, delta_update=0.0
# transition=<12, 5, 0.0, 13>, delta_update=0.0
# transition=<13, 7, 0.0, 14>, delta_update=0.0
# transition=<14, 7, 0.0, 15>, delta_update=0.0
# episode 5: cumul_reward=1.0, accuracy:0.066667, cumul_delta=0.1275, eps=0.92588
# starting episode 6...
# transition=<0, 5, 1.0, 1>, delta_update=0.10837498307228088
# transition=<1, 4, 0.0, 2>, delta_update=0.0
# transition=<2, 7, 0.0, 3>, delta_update=0.0
# transition=<3, 7, 0.0, 4>, delta_update=0.0
# transition=<4, 9, 0.0, 5>, delta_update=0.0
# transition=<5, 9, 0.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.15000000596046448
# transition=<7, 9, 0.0, 8>, delta_update=0.0
# transition=<8, 7, 0.0, 9>, delta_update=0.0
# transition=<9, 7, 0.0, 10>, delta_update=0.0
# transition=<10, 1, 0.0, 11>, delta_update=0.0
# transition=<11, 9, 0.0, 12>, delta_update=0.0
# transition=<12, 7, 0.0, 13>, delta_update=0.0
# transition=<13, 9, 0.0, 14>, delta_update=0.0
# transition=<14, 9, 0.0, 15>, delta_update=0.0
# episode 6: cumul_reward=2.0, accuracy:0.13333, cumul_delta=0.25837, eps=0.91173
# starting episode 7...
# transition=<0, 4, 0.0, 1>, delta_update=0.0
# transition=<1, 9, 0.0, 2>, delta_update=0.0
# transition=<2, 4, 0.0, 3>, delta_update=0.0
# transition=<3, 8, 0.0, 4>, delta_update=0.0
# transition=<4, 4, 0.0, 5>, delta_update=0.0
# transition=<5, 9, 0.0, 6>, delta_update=0.0
# transition=<6, 3, 0.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.15000000596046448
# transition=<8, 7, 0.0, 9>, delta_update=0.0
# transition=<9, 8, 0.0, 10>, delta_update=0.0
# transition=<10, 8, 0.0, 11>, delta_update=0.0
# transition=<11, 3, 0.0, 12>, delta_update=0.0
# transition=<12, 2, 0.0, 13>, delta_update=0.0
# transition=<13, 6, 0.0, 14>, delta_update=0.0
# transition=<14, 9, 0.0, 15>, delta_update=0.0
# episode 7: cumul_reward=1.0, accuracy:0.066667, cumul_delta=0.15, eps=0.8978
# starting episode 8...
# transition=<0, 5, 1.0, 1>, delta_update=0.09211874008178711
# transition=<1, 6, 0.0, 2>, delta_update=0.0
# transition=<2, 1, 0.0, 3>, delta_update=0.0
# transition=<3, 4, 0.0, 4>, delta_update=0.0
# transition=<4, 7, 0.0, 5>, delta_update=0.0
# transition=<5, 3, 0.0, 6>, delta_update=0.0
# transition=<6, 1, 0.0, 7>, delta_update=0.0
# transition=<7, 0, 0.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.15000000596046448
# transition=<9, 3, 0.0, 10>, delta_update=0.0
# transition=<10, 7, 0.0, 11>, delta_update=0.0
# transition=<11, 2, 0.0, 12>, delta_update=0.0
# transition=<12, 9, 0.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.15000000596046448
# transition=<14, 3, 1.0, 15>, delta_update=0.15000000596046448
# episode 8: cumul_reward=4.0, accuracy:0.26667, cumul_delta=0.54212, eps=0.88407
# starting episode 9...
# transition=<0, 6, 0.0, 1>, delta_update=0.0
# transition=<1, 5, 0.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.1274999976158142
# transition=<3, 9, 0.0, 4>, delta_update=0.0
# transition=<4, 9, 0.0, 5>, delta_update=0.0
# transition=<5, 0, 0.0, 6>, delta_update=0.0
# transition=<6, 5, 0.0, 7>, delta_update=0.0
# transition=<7, 6, 0.0, 8>, delta_update=0.0
# transition=<8, 9, 0.0, 9>, delta_update=0.0
# transition=<9, 5, 0.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.15000000596046448
# transition=<11, 8, 0.0, 12>, delta_update=0.0
# transition=<12, 6, 0.0, 13>, delta_update=0.0
# transition=<13, 0, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.1274999976158142
# episode 9: cumul_reward=3.0, accuracy:0.2, cumul_delta=0.405, eps=0.87056
# starting episode 10...
# transition=<0, 5, 1.0, 1>, delta_update=0.07830095291137695
# transition=<1, 3, 0.0, 2>, delta_update=0.0
# transition=<2, 0, 0.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.15000000596046448
# transition=<4, 6, 1.0, 5>, delta_update=0.1274999976158142
# transition=<5, 0, 0.0, 6>, delta_update=0.0
# transition=<6, 3, 0.0, 7>, delta_update=0.0
# transition=<7, 9, 0.0, 8>, delta_update=0.0
# transition=<8, 2, 0.0, 9>, delta_update=0.0
# transition=<9, 2, 0.0, 10>, delta_update=0.0
# transition=<10, 4, 0.0, 11>, delta_update=0.0
# transition=<11, 0, 0.0, 12>, delta_update=0.0
# transition=<12, 9, 0.0, 13>, delta_update=0.0
# transition=<13, 9, 0.0, 14>, delta_update=0.0
# transition=<14, 4, 0.0, 15>, delta_update=0.0
# episode 10: cumul_reward=3.0, accuracy:0.2, cumul_delta=0.3558, eps=0.85726
# starting episode 11...
# transition=<0, 0, 0.0, 1>, delta_update=0.0
# transition=<1, 9, 0.0, 2>, delta_update=0.0
# transition=<2, 1, 0.0, 3>, delta_update=0.0
# transition=<3, 0, 0.0, 4>, delta_update=0.0
# transition=<4, 8, 0.0, 5>, delta_update=0.0
# transition=<5, 5, 0.0, 6>, delta_update=0.0
# transition=<6, 5, 0.0, 7>, delta_update=0.0
# transition=<7, 4, 0.0, 8>, delta_update=0.0
# transition=<8, 2, 0.0, 9>, delta_update=0.0
# transition=<9, 2, 0.0, 10>, delta_update=0.0
# transition=<10, 8, 0.0, 11>, delta_update=0.0
# transition=<11, 3, 0.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.10837498307228088
# transition=<13, 2, 1.0, 14>, delta_update=0.1274999976158142
# transition=<14, 9, 0.0, 15>, delta_update=0.0
# episode 11: cumul_reward=2.0, accuracy:0.13333, cumul_delta=0.23587, eps=0.84415
# starting episode 12...
# transition=<0, 9, 0.0, 1>, delta_update=0.0
# transition=<1, 7, 0.0, 2>, delta_update=0.0
# transition=<2, 5, 0.0, 3>, delta_update=0.0
# transition=<3, 8, 0.0, 4>, delta_update=0.0
# transition=<4, 9, 0.0, 5>, delta_update=0.0
# transition=<5, 9, 0.0, 6>, delta_update=0.0
# transition=<6, 7, 0.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.1274999976158142
# transition=<8, 4, 0.0, 9>, delta_update=0.0
# transition=<9, 1, 0.0, 10>, delta_update=0.0
# transition=<10, 4, 0.0, 11>, delta_update=0.0
# transition=<11, 5, 0.0, 12>, delta_update=0.0
# transition=<12, 3, 0.0, 13>, delta_update=0.0
# transition=<13, 7, 0.0, 14>, delta_update=0.0
# transition=<14, 7, 0.0, 15>, delta_update=0.0
# episode 12: cumul_reward=1.0, accuracy:0.066667, cumul_delta=0.1275, eps=0.83125
# starting episode 13...
# transition=<0, 7, 0.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.1274999976158142
# transition=<2, 9, 0.0, 3>, delta_update=0.0
# transition=<3, 2, 0.0, 4>, delta_update=0.0
# transition=<4, 3, 0.0, 5>, delta_update=0.0
# transition=<5, 2, 0.0, 6>, delta_update=0.0
# transition=<6, 5, 0.0, 7>, delta_update=0.0
# transition=<7, 0, 0.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.1274999976158142
# transition=<9, 6, 0.0, 10>, delta_update=0.0
# transition=<10, 4, 0.0, 11>, delta_update=0.0
# transition=<11, 6, 0.0, 12>, delta_update=0.0
# transition=<12, 2, 0.0, 13>, delta_update=0.0
# transition=<13, 6, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.10837498307228088
# episode 13: cumul_reward=3.0, accuracy:0.2, cumul_delta=0.36337, eps=0.81855
# starting episode 14...
# transition=<0, 5, 1.0, 1>, delta_update=0.06655579805374146
# transition=<1, 9, 0.0, 2>, delta_update=0.0
# transition=<2, 3, 0.0, 3>, delta_update=0.0
# transition=<3, 9, 0.0, 4>, delta_update=0.0
# transition=<4, 8, 0.0, 5>, delta_update=0.0
# transition=<5, 8, 0.0, 6>, delta_update=0.0
# transition=<6, 6, 0.0, 7>, delta_update=0.0
# transition=<7, 9, 0.0, 8>, delta_update=0.0
# transition=<8, 3, 0.0, 9>, delta_update=0.0
# transition=<9, 2, 0.0, 10>, delta_update=0.0
# transition=<10, 6, 0.0, 11>, delta_update=0.0
# transition=<11, 9, 0.0, 12>, delta_update=0.0
# transition=<12, 8, 0.0, 13>, delta_update=0.0
# transition=<13, 5, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.09211874008178711
# episode 14: cumul_reward=2.0, accuracy:0.13333, cumul_delta=0.15867, eps=0.80604
# starting episode 15...
# transition=<0, 5, 1.0, 1>, delta_update=0.05657243728637695
# transition=<1, 1, 1.0, 2>, delta_update=0.10837498307228088
# transition=<2, 1, 0.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.1274999976158142
# transition=<4, 6, 1.0, 5>, delta_update=0.10837498307228088
# transition=<5, 7, 0.0, 6>, delta_update=0.0
# transition=<6, 3, 0.0, 7>, delta_update=0.0
# transition=<7, 8, 0.0, 8>, delta_update=0.0
# transition=<8, 8, 0.0, 9>, delta_update=0.0
# transition=<9, 1, 0.0, 10>, delta_update=0.0
# transition=<10, 0, 0.0, 11>, delta_update=0.0
# transition=<11, 8, 0.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.09211874008178711
# transition=<13, 2, 1.0, 14>, delta_update=0.10837498307228088
# transition=<14, 8, 0.0, 15>, delta_update=0.0
# episode 15: cumul_reward=6.0, accuracy:0.4, cumul_delta=0.60132, eps=0.79372
# starting episode 16...
# transition=<0, 7, 0.0, 1>, delta_update=0.0
# transition=<1, 5, 0.0, 2>, delta_update=0.0
# transition=<2, 4, 0.0, 3>, delta_update=0.0
# transition=<3, 6, 0.0, 4>, delta_update=0.0
# transition=<4, 7, 0.0, 5>, delta_update=0.0
# transition=<5, 5, 0.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.1274999976158142
# transition=<7, 3, 0.0, 8>, delta_update=0.0
# transition=<8, 1, 0.0, 9>, delta_update=0.0
# transition=<9, 2, 0.0, 10>, delta_update=0.0
# transition=<10, 8, 0.0, 11>, delta_update=0.0
# transition=<11, 6, 0.0, 12>, delta_update=0.0
# transition=<12, 3, 0.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.09211874008178711
# transition=<14, 5, 0.0, 15>, delta_update=0.0
# episode 16: cumul_reward=2.0, accuracy:0.13333, cumul_delta=0.21962, eps=0.78159
# starting episode 17...
# transition=<0, 0, 0.0, 1>, delta_update=0.0
# transition=<1, 5, 0.0, 2>, delta_update=0.0
# transition=<2, 3, 0.0, 3>, delta_update=0.0
# transition=<3, 0, 0.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.09211874008178711
# transition=<5, 7, 0.0, 6>, delta_update=0.0
# transition=<6, 0, 0.0, 7>, delta_update=0.0
# transition=<7, 7, 0.0, 8>, delta_update=0.0
# transition=<8, 9, 0.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.1274999976158142
# transition=<10, 9, 0.0, 11>, delta_update=0.0
# transition=<11, 7, 0.0, 12>, delta_update=0.0
# transition=<12, 0, 0.0, 13>, delta_update=0.0
# transition=<13, 9, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.07830095291137695
# episode 17: cumul_reward=3.0, accuracy:0.2, cumul_delta=0.29792, eps=0.76964
# starting episode 18...
# transition=<0, 3, 0.0, 1>, delta_update=0.0
# transition=<1, 3, 0.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.10837498307228088
# transition=<3, 6, 0.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.07830095291137695
# transition=<5, 9, 0.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.10837498307228088
# transition=<7, 5, 1.0, 8>, delta_update=0.10837498307228088
# transition=<8, 3, 0.0, 9>, delta_update=0.0
# transition=<9, 8, 0.0, 10>, delta_update=0.0
# transition=<10, 2, 0.0, 11>, delta_update=0.0
# transition=<11, 8, 0.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.07830095291137695
# transition=<13, 4, 0.0, 14>, delta_update=0.0
# transition=<14, 0, 0.0, 15>, delta_update=0.0
# episode 18: cumul_reward=5.0, accuracy:0.33333, cumul_delta=0.48173, eps=0.75788
# starting episode 19...
# transition=<0, 0, 0.0, 1>, delta_update=0.0
# transition=<1, 4, 0.0, 2>, delta_update=0.0
# transition=<2, 3, 0.0, 3>, delta_update=0.0
# transition=<3, 7, 0.0, 4>, delta_update=0.0
# transition=<4, 4, 0.0, 5>, delta_update=0.0
# transition=<5, 9, 0.0, 6>, delta_update=0.0
# transition=<6, 4, 0.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.09211874008178711
# transition=<8, 4, 0.0, 9>, delta_update=0.0
# transition=<9, 0, 0.0, 10>, delta_update=0.0
# transition=<10, 5, 0.0, 11>, delta_update=0.0
# transition=<11, 9, 0.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.06655579805374146
# transition=<13, 2, 1.0, 14>, delta_update=0.07830095291137695
# transition=<14, 3, 1.0, 15>, delta_update=0.06655579805374146
# episode 19: cumul_reward=4.0, accuracy:0.26667, cumul_delta=0.30353, eps=0.74629
# starting episode 20...
# transition=<0, 0, 0.0, 1>, delta_update=0.0
# transition=<1, 6, 0.0, 2>, delta_update=0.0
# transition=<2, 9, 0.0, 3>, delta_update=0.0
# transition=<3, 1, 0.0, 4>, delta_update=0.0
# transition=<4, 1, 0.0, 5>, delta_update=0.0
# transition=<5, 6, 0.0, 6>, delta_update=0.0
# transition=<6, 5, 0.0, 7>, delta_update=0.0
# transition=<7, 9, 0.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.10837498307228088
# transition=<9, 7, 0.0, 10>, delta_update=0.0
# transition=<10, 6, 0.0, 11>, delta_update=0.0
# transition=<11, 9, 0.0, 12>, delta_update=0.0
# transition=<12, 5, 0.0, 13>, delta_update=0.0
# transition=<13, 8, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.05657243728637695
# episode 20: cumul_reward=2.0, accuracy:0.13333, cumul_delta=0.16495, eps=0.73489
# starting episode 21...
# transition=<0, 5, 1.0, 1>, delta_update=0.048086583614349365
# transition=<1, 2, 0.0, 2>, delta_update=0.0
# transition=<2, 1, 0.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.10837498307228088
# transition=<4, 9, 0.0, 5>, delta_update=0.0
# transition=<5, 1, 0.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.09211874008178711
# transition=<7, 9, 0.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.09211874008178711
# transition=<9, 9, 1.0, 10>, delta_update=0.10837498307228088
# transition=<10, 1, 0.0, 11>, delta_update=0.0
# transition=<11, 7, 0.0, 12>, delta_update=0.0
# transition=<12, 2, 0.0, 13>, delta_update=0.0
# transition=<13, 0, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.048086583614349365
# episode 21: cumul_reward=6.0, accuracy:0.4, cumul_delta=0.49716, eps=0.72366
# starting episode 22...
# transition=<0, 4, 0.0, 1>, delta_update=0.0
# transition=<1, 9, 0.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.09211874008178711
# transition=<3, 5, 1.0, 4>, delta_update=0.09211874008178711
# transition=<4, 5, 0.0, 5>, delta_update=0.0
# transition=<5, 1, 0.0, 6>, delta_update=0.0
# transition=<6, 3, 0.0, 7>, delta_update=0.0
# transition=<7, 4, 0.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.07830095291137695
# transition=<9, 9, 1.0, 10>, delta_update=0.09211874008178711
# transition=<10, 8, 0.0, 11>, delta_update=0.0
# transition=<11, 9, 0.0, 12>, delta_update=0.0
# transition=<12, 6, 0.0, 13>, delta_update=0.0
# transition=<13, 0, 0.0, 14>, delta_update=0.0
# transition=<14, 1, 0.0, 15>, delta_update=0.0
# episode 22: cumul_reward=4.0, accuracy:0.26667, cumul_delta=0.35466, eps=0.7126
# starting episode 23...
# transition=<0, 5, 1.0, 1>, delta_update=0.040873587131500244
# transition=<1, 5, 0.0, 2>, delta_update=0.0
# transition=<2, 0, 0.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.07830095291137695
# transition=<4, 2, 0.0, 5>, delta_update=0.0
# transition=<5, 9, 0.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.07830095291137695
# transition=<7, 5, 1.0, 8>, delta_update=0.07830095291137695
# transition=<8, 8, 0.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.07830095291137695
# transition=<10, 3, 1.0, 11>, delta_update=0.1274999976158142
# transition=<11, 6, 0.0, 12>, delta_update=0.0
# transition=<12, 0, 0.0, 13>, delta_update=0.0
# transition=<13, 5, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.040873587131500244
# episode 23: cumul_reward=7.0, accuracy:0.46667, cumul_delta=0.52245, eps=0.7017
# starting episode 24...
# transition=<0, 3, 0.0, 1>, delta_update=0.0
# transition=<1, 2, 0.0, 2>, delta_update=0.0
# transition=<2, 7, 0.0, 3>, delta_update=0.0
# transition=<3, 6, 0.0, 4>, delta_update=0.0
# transition=<4, 7, 0.0, 5>, delta_update=0.0
# transition=<5, 6, 0.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.06655579805374146
# transition=<7, 5, 1.0, 8>, delta_update=0.06655579805374146
# transition=<8, 5, 1.0, 9>, delta_update=0.06655579805374146
# transition=<9, 9, 1.0, 10>, delta_update=0.06655579805374146
# transition=<10, 4, 0.0, 11>, delta_update=0.0
# transition=<11, 3, 0.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.05657243728637695
# transition=<13, 2, 1.0, 14>, delta_update=0.06655579805374146
# transition=<14, 7, 0.0, 15>, delta_update=0.0
# episode 24: cumul_reward=6.0, accuracy:0.4, cumul_delta=0.38935, eps=0.69098
# starting episode 25...
# transition=<0, 0, 0.0, 1>, delta_update=0.0
# transition=<1, 0, 0.0, 2>, delta_update=0.0
# transition=<2, 3, 0.0, 3>, delta_update=0.0
# transition=<3, 3, 0.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.06655579805374146
# transition=<5, 4, 1.0, 6>, delta_update=0.15000000596046448
# transition=<6, 2, 1.0, 7>, delta_update=0.05657243728637695
# transition=<7, 6, 0.0, 8>, delta_update=0.0
# transition=<8, 7, 0.0, 9>, delta_update=0.0
# transition=<9, 0, 0.0, 10>, delta_update=0.0
# transition=<10, 9, 0.0, 11>, delta_update=0.0
# transition=<11, 3, 0.0, 12>, delta_update=0.0
# transition=<12, 5, 0.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.05657243728637695
# transition=<14, 5, 0.0, 15>, delta_update=0.0
# episode 25: cumul_reward=4.0, accuracy:0.26667, cumul_delta=0.3297, eps=0.68042
# starting episode 26...
# transition=<0, 6, 0.0, 1>, delta_update=0.0
# transition=<1, 4, 0.0, 2>, delta_update=0.0
# transition=<2, 9, 0.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.06655579805374146
# transition=<4, 3, 0.0, 5>, delta_update=0.0
# transition=<5, 2, 0.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.048086583614349365
# transition=<7, 9, 0.0, 8>, delta_update=0.0
# transition=<8, 2, 0.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.05657243728637695
# transition=<10, 3, 1.0, 11>, delta_update=0.10837498307228088
# transition=<11, 9, 0.0, 12>, delta_update=0.0
# transition=<12, 3, 0.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.048086583614349365
# transition=<14, 5, 0.0, 15>, delta_update=0.0
# episode 26: cumul_reward=5.0, accuracy:0.33333, cumul_delta=0.32768, eps=0.67002
# starting episode 27...
# transition=<0, 2, 0.0, 1>, delta_update=0.0
# transition=<1, 8, 0.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.07830095291137695
# transition=<3, 4, 0.0, 4>, delta_update=0.0
# transition=<4, 7, 0.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.1274999976158142
# transition=<6, 7, 0.0, 7>, delta_update=0.0
# transition=<7, 0, 0.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.05657243728637695
# transition=<9, 9, 1.0, 10>, delta_update=0.048086583614349365
# transition=<10, 3, 1.0, 11>, delta_update=0.09211874008178711
# transition=<11, 9, 0.0, 12>, delta_update=0.0
# transition=<12, 9, 0.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.040873587131500244
# transition=<14, 3, 1.0, 15>, delta_update=0.034742534160614014
# episode 27: cumul_reward=7.0, accuracy:0.46667, cumul_delta=0.47819, eps=0.65978
# starting episode 28...
# transition=<0, 4, 0.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.09211874008178711
# transition=<2, 7, 0.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.05657243728637695
# transition=<4, 6, 1.0, 5>, delta_update=0.05657243728637695
# transition=<5, 7, 0.0, 6>, delta_update=0.0
# transition=<6, 1, 0.0, 7>, delta_update=0.0
# transition=<7, 2, 0.0, 8>, delta_update=0.0
# transition=<8, 0, 0.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.040873587131500244
# transition=<10, 3, 1.0, 11>, delta_update=0.07830095291137695
# transition=<11, 9, 0.0, 12>, delta_update=0.0
# transition=<12, 1, 0.0, 13>, delta_update=0.0
# transition=<13, 0, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.02953118085861206
# episode 28: cumul_reward=6.0, accuracy:0.4, cumul_delta=0.35397, eps=0.64969
# starting episode 29...
# transition=<0, 5, 1.0, 1>, delta_update=0.034742534160614014
# transition=<1, 1, 1.0, 2>, delta_update=0.07830095291137695
# transition=<2, 6, 1.0, 3>, delta_update=0.06655579805374146
# transition=<3, 4, 0.0, 4>, delta_update=0.0
# transition=<4, 7, 0.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.10837498307228088
# transition=<6, 2, 1.0, 7>, delta_update=0.040873587131500244
# transition=<7, 5, 1.0, 8>, delta_update=0.05657243728637695
# transition=<8, 5, 1.0, 9>, delta_update=0.048086583614349365
# transition=<9, 8, 0.0, 10>, delta_update=0.0
# transition=<10, 8, 0.0, 11>, delta_update=0.0
# transition=<11, 4, 0.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.048086583614349365
# transition=<13, 2, 1.0, 14>, delta_update=0.034742534160614014
# transition=<14, 3, 1.0, 15>, delta_update=0.02510148286819458
# episode 29: cumul_reward=10.0, accuracy:0.66667, cumul_delta=0.54144, eps=0.63976
# starting episode 30...
# transition=<0, 8, 0.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.06655579805374146
# transition=<2, 6, 1.0, 3>, delta_update=0.05657243728637695
# transition=<3, 6, 0.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.048086583614349365
# transition=<5, 6, 0.0, 6>, delta_update=0.0
# transition=<6, 1, 0.0, 7>, delta_update=0.0
# transition=<7, 2, 0.0, 8>, delta_update=0.0
# transition=<8, 4, 0.0, 9>, delta_update=0.0
# transition=<9, 0, 0.0, 10>, delta_update=0.0
# transition=<10, 6, 0.0, 11>, delta_update=0.0
# transition=<11, 3, 0.0, 12>, delta_update=0.0
# transition=<12, 8, 0.0, 13>, delta_update=0.0
# transition=<13, 1, 0.0, 14>, delta_update=0.0
# transition=<14, 8, 0.0, 15>, delta_update=0.0
# episode 30: cumul_reward=3.0, accuracy:0.2, cumul_delta=0.17121, eps=0.62999
# starting episode 31...
# transition=<0, 5, 1.0, 1>, delta_update=0.02953118085861206
# transition=<1, 1, 1.0, 2>, delta_update=0.05657243728637695
# transition=<2, 0, 0.0, 3>, delta_update=0.0
# transition=<3, 3, 0.0, 4>, delta_update=0.0
# transition=<4, 1, 0.0, 5>, delta_update=0.0
# transition=<5, 8, 0.0, 6>, delta_update=0.0
# transition=<6, 3, 0.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.048086583614349365
# transition=<8, 5, 1.0, 9>, delta_update=0.040873587131500244
# transition=<9, 1, 0.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.06655579805374146
# transition=<11, 5, 0.0, 12>, delta_update=0.0
# transition=<12, 5, 0.0, 13>, delta_update=0.0
# transition=<13, 0, 0.0, 14>, delta_update=0.0
# transition=<14, 8, 0.0, 15>, delta_update=0.0
# episode 31: cumul_reward=5.0, accuracy:0.33333, cumul_delta=0.24162, eps=0.62036
# starting episode 32...
# transition=<0, 5, 1.0, 1>, delta_update=0.02510148286819458
# transition=<1, 1, 1.0, 2>, delta_update=0.048086583614349365
# transition=<2, 6, 1.0, 3>, delta_update=0.048086583614349365
# transition=<3, 6, 0.0, 4>, delta_update=0.0
# transition=<4, 0, 0.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.09211874008178711
# transition=<6, 0, 0.0, 7>, delta_update=0.0
# transition=<7, 9, 0.0, 8>, delta_update=0.0
# transition=<8, 9, 0.0, 9>, delta_update=0.0
# transition=<9, 6, 0.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.05657243728637695
# transition=<11, 9, 0.0, 12>, delta_update=0.0
# transition=<12, 3, 0.0, 13>, delta_update=0.0
# transition=<13, 0, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.021336257457733154
# episode 32: cumul_reward=6.0, accuracy:0.4, cumul_delta=0.2913, eps=0.61088
# starting episode 33...
# transition=<0, 5, 1.0, 1>, delta_update=0.021336257457733154
# transition=<1, 6, 0.0, 2>, delta_update=0.0
# transition=<2, 8, 0.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.048086583614349365
# transition=<4, 1, 0.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.07830095291137695
# transition=<6, 1, 0.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.040873587131500244
# transition=<8, 0, 0.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.034742534160614014
# transition=<10, 3, 1.0, 11>, delta_update=0.048086583614349365
# transition=<11, 9, 0.0, 12>, delta_update=0.0
# transition=<12, 5, 0.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.02953118085861206
# transition=<14, 8, 0.0, 15>, delta_update=0.0
# episode 33: cumul_reward=7.0, accuracy:0.46667, cumul_delta=0.30096, eps=0.60154
# starting episode 34...
# transition=<0, 7, 0.0, 1>, delta_update=0.0
# transition=<1, 5, 0.0, 2>, delta_update=0.0
# transition=<2, 9, 0.0, 3>, delta_update=0.0
# transition=<3, 9, 0.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.040873587131500244
# transition=<5, 4, 1.0, 6>, delta_update=0.06655579805374146
# transition=<6, 7, 0.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.034742534160614014
# transition=<8, 1, 0.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.02953118085861206
# transition=<10, 1, 0.0, 11>, delta_update=0.0
# transition=<11, 9, 0.0, 12>, delta_update=0.0
# transition=<12, 7, 0.0, 13>, delta_update=0.0
# transition=<13, 9, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.01813584566116333
# episode 34: cumul_reward=5.0, accuracy:0.33333, cumul_delta=0.18984, eps=0.59235
# starting episode 35...
# transition=<0, 0, 0.0, 1>, delta_update=0.0
# transition=<1, 5, 0.0, 2>, delta_update=0.0
# transition=<2, 1, 0.0, 3>, delta_update=0.0
# transition=<3, 0, 0.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.034742534160614014
# transition=<5, 4, 1.0, 6>, delta_update=0.05657243728637695
# transition=<6, 2, 1.0, 7>, delta_update=0.034742534160614014
# transition=<7, 5, 1.0, 8>, delta_update=0.02953118085861206
# transition=<8, 1, 0.0, 9>, delta_update=0.0
# transition=<9, 3, 0.0, 10>, delta_update=0.0
# transition=<10, 8, 0.0, 11>, delta_update=0.0
# transition=<11, 5, 0.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.040873587131500244
# transition=<13, 7, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.015415430068969727
# episode 35: cumul_reward=6.0, accuracy:0.4, cumul_delta=0.21188, eps=0.58329
# starting episode 36...
# transition=<0, 5, 1.0, 1>, delta_update=0.01813584566116333
# transition=<1, 1, 1.0, 2>, delta_update=0.040873587131500244
# transition=<2, 4, 0.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.040873587131500244
# transition=<4, 6, 1.0, 5>, delta_update=0.02953118085861206
# transition=<5, 2, 0.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.02953118085861206
# transition=<7, 8, 0.0, 8>, delta_update=0.0
# transition=<8, 1, 0.0, 9>, delta_update=0.0
# transition=<9, 5, 0.0, 10>, delta_update=0.0
# transition=<10, 7, 0.0, 11>, delta_update=0.0
# transition=<11, 7, 0.0, 12>, delta_update=0.0
# transition=<12, 6, 0.0, 13>, delta_update=0.0
# transition=<13, 4, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.013103127479553223
# episode 36: cumul_reward=6.0, accuracy:0.4, cumul_delta=0.17205, eps=0.57438
# starting episode 37...
# transition=<0, 5, 1.0, 1>, delta_update=0.015415430068969727
# transition=<1, 8, 0.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.040873587131500244
# transition=<3, 2, 0.0, 4>, delta_update=0.0
# transition=<4, 7, 0.0, 5>, delta_update=0.0
# transition=<5, 8, 0.0, 6>, delta_update=0.0
# transition=<6, 3, 0.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.02510148286819458
# transition=<8, 8, 0.0, 9>, delta_update=0.0
# transition=<9, 6, 0.0, 10>, delta_update=0.0
# transition=<10, 1, 0.0, 11>, delta_update=0.0
# transition=<11, 3, 0.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.034742534160614014
# transition=<13, 6, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.011137664318084717
# episode 37: cumul_reward=5.0, accuracy:0.33333, cumul_delta=0.12727, eps=0.5656
# starting episode 38...
# transition=<0, 2, 0.0, 1>, delta_update=0.0
# transition=<1, 3, 0.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.034742534160614014
# transition=<3, 5, 1.0, 4>, delta_update=0.034742534160614014
# transition=<4, 6, 1.0, 5>, delta_update=0.02510148286819458
# transition=<5, 4, 1.0, 6>, delta_update=0.048086583614349365
# transition=<6, 2, 1.0, 7>, delta_update=0.02510148286819458
# transition=<7, 5, 1.0, 8>, delta_update=0.021336257457733154
# transition=<8, 5, 1.0, 9>, delta_update=0.034742534160614014
# transition=<9, 6, 0.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.040873587131500244
# transition=<11, 3, 0.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.02953118085861206
# transition=<13, 2, 1.0, 14>, delta_update=0.02510148286819458
# transition=<14, 7, 0.0, 15>, delta_update=0.0
# episode 38: cumul_reward=10.0, accuracy:0.66667, cumul_delta=0.31936, eps=0.55695
# starting episode 39...
# transition=<0, 5, 1.0, 1>, delta_update=0.013103127479553223
# transition=<1, 1, 1.0, 2>, delta_update=0.034742534160614014
# transition=<2, 5, 0.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.02953118085861206
# transition=<4, 6, 1.0, 5>, delta_update=0.021336257457733154
# transition=<5, 4, 1.0, 6>, delta_update=0.040873587131500244
# transition=<6, 7, 0.0, 7>, delta_update=0.0
# transition=<7, 4, 0.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.02953118085861206
# transition=<9, 6, 0.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.034742534160614014
# transition=<11, 9, 0.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.02510148286819458
# transition=<13, 2, 1.0, 14>, delta_update=0.021336257457733154
# transition=<14, 5, 0.0, 15>, delta_update=0.0
# episode 39: cumul_reward=9.0, accuracy:0.6, cumul_delta=0.2503, eps=0.54844
# starting episode 40...
# transition=<0, 5, 1.0, 1>, delta_update=0.011137664318084717
# transition=<1, 1, 1.0, 2>, delta_update=0.02953118085861206
# transition=<2, 8, 0.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.02510148286819458
# transition=<4, 6, 1.0, 5>, delta_update=0.01813584566116333
# transition=<5, 4, 1.0, 6>, delta_update=0.034742534160614014
# transition=<6, 2, 1.0, 7>, delta_update=0.021336257457733154
# transition=<7, 5, 1.0, 8>, delta_update=0.01813584566116333
# transition=<8, 5, 1.0, 9>, delta_update=0.02510148286819458
# transition=<9, 0, 0.0, 10>, delta_update=0.0
# transition=<10, 1, 0.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.15000000596046448
# transition=<12, 4, 1.0, 13>, delta_update=0.021336257457733154
# transition=<13, 2, 1.0, 14>, delta_update=0.01813584566116333
# transition=<14, 3, 1.0, 15>, delta_update=0.009467005729675293
# episode 40: cumul_reward=12.0, accuracy:0.8, cumul_delta=0.38216, eps=0.54006
# starting episode 41...
# transition=<0, 5, 1.0, 1>, delta_update=0.009467005729675293
# transition=<1, 5, 0.0, 2>, delta_update=0.0
# transition=<2, 5, 0.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.021336257457733154
# transition=<4, 6, 1.0, 5>, delta_update=0.015415430068969727
# transition=<5, 6, 0.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.01813584566116333
# transition=<7, 7, 0.0, 8>, delta_update=0.0
# transition=<8, 2, 0.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.02510148286819458
# transition=<10, 0, 0.0, 11>, delta_update=0.0
# transition=<11, 3, 0.0, 12>, delta_update=0.0
# transition=<12, 8, 0.0, 13>, delta_update=0.0
# transition=<13, 9, 0.0, 14>, delta_update=0.0
# transition=<14, 2, 0.0, 15>, delta_update=0.0
# episode 41: cumul_reward=5.0, accuracy:0.33333, cumul_delta=0.089456, eps=0.53181
# starting episode 42...
# transition=<0, 5, 1.0, 1>, delta_update=0.008046984672546387
# transition=<1, 3, 0.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.02953118085861206
# transition=<3, 5, 1.0, 4>, delta_update=0.01813584566116333
# transition=<4, 3, 0.0, 5>, delta_update=0.0
# transition=<5, 1, 0.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.015415430068969727
# transition=<7, 5, 1.0, 8>, delta_update=0.015415430068969727
# transition=<8, 6, 0.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.021336257457733154
# transition=<10, 3, 1.0, 11>, delta_update=0.02953118085861206
# transition=<11, 5, 0.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.01813584566116333
# transition=<13, 2, 1.0, 14>, delta_update=0.015415430068969727
# transition=<14, 3, 1.0, 15>, delta_update=0.008046984672546387
# episode 42: cumul_reward=10.0, accuracy:0.66667, cumul_delta=0.17901, eps=0.52368
# starting episode 43...
# transition=<0, 9, 0.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.02510148286819458
# transition=<2, 6, 1.0, 3>, delta_update=0.02510148286819458
# transition=<3, 8, 0.0, 4>, delta_update=0.0
# transition=<4, 5, 0.0, 5>, delta_update=0.0
# transition=<5, 9, 0.0, 6>, delta_update=0.0
# transition=<6, 9, 0.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.013103127479553223
# transition=<8, 5, 1.0, 9>, delta_update=0.021336257457733154
# transition=<9, 9, 1.0, 10>, delta_update=0.01813584566116333
# transition=<10, 3, 1.0, 11>, delta_update=0.02510148286819458
# transition=<11, 5, 0.0, 12>, delta_update=0.0
# transition=<12, 1, 0.0, 13>, delta_update=0.0
# transition=<13, 4, 0.0, 14>, delta_update=0.0
# transition=<14, 6, 0.0, 15>, delta_update=0.0
# episode 43: cumul_reward=6.0, accuracy:0.4, cumul_delta=0.12788, eps=0.51567
# starting episode 44...
# transition=<0, 3, 0.0, 1>, delta_update=0.0
# transition=<1, 8, 0.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.021336257457733154
# transition=<3, 9, 0.0, 4>, delta_update=0.0
# transition=<4, 4, 0.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.02953118085861206
# transition=<6, 2, 1.0, 7>, delta_update=0.013103127479553223
# transition=<7, 6, 0.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.01813584566116333
# transition=<9, 9, 1.0, 10>, delta_update=0.015415430068969727
# transition=<10, 5, 0.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.1274999976158142
# transition=<12, 4, 1.0, 13>, delta_update=0.015415430068969727
# transition=<13, 2, 1.0, 14>, delta_update=0.013103127479553223
# transition=<14, 3, 1.0, 15>, delta_update=0.006839931011199951
# episode 44: cumul_reward=9.0, accuracy:0.6, cumul_delta=0.26038, eps=0.50779
# starting episode 45...
# transition=<0, 5, 1.0, 1>, delta_update=0.006839931011199951
# transition=<1, 1, 1.0, 2>, delta_update=0.021336257457733154
# transition=<2, 3, 0.0, 3>, delta_update=0.0
# transition=<3, 8, 0.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.013103127479553223
# transition=<5, 5, 0.0, 6>, delta_update=0.0
# transition=<6, 0, 0.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.011137664318084717
# transition=<8, 4, 0.0, 9>, delta_update=0.0
# transition=<9, 7, 0.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.021336257457733154
# transition=<11, 0, 0.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.013103127479553223
# transition=<13, 9, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.005813896656036377
# episode 45: cumul_reward=7.0, accuracy:0.46667, cumul_delta=0.09267, eps=0.50003
# starting episode 46...
# transition=<0, 5, 1.0, 1>, delta_update=0.005813896656036377
# transition=<1, 1, 1.0, 2>, delta_update=0.01813584566116333
# transition=<2, 6, 1.0, 3>, delta_update=0.01813584566116333
# transition=<3, 9, 0.0, 4>, delta_update=0.0
# transition=<4, 5, 0.0, 5>, delta_update=0.0
# transition=<5, 7, 0.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.011137664318084717
# transition=<7, 5, 1.0, 8>, delta_update=0.009467005729675293
# transition=<8, 5, 1.0, 9>, delta_update=0.015415430068969727
# transition=<9, 9, 1.0, 10>, delta_update=0.013103127479553223
# transition=<10, 3, 1.0, 11>, delta_update=0.01813584566116333
# transition=<11, 9, 0.0, 12>, delta_update=0.0
# transition=<12, 8, 0.0, 13>, delta_update=0.0
# transition=<13, 4, 0.0, 14>, delta_update=0.0
# transition=<14, 5, 0.0, 15>, delta_update=0.0
# episode 46: cumul_reward=8.0, accuracy:0.53333, cumul_delta=0.10934, eps=0.49239
# starting episode 47...
# transition=<0, 5, 1.0, 1>, delta_update=0.004941821098327637
# transition=<1, 4, 0.0, 2>, delta_update=0.0
# transition=<2, 8, 0.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.015415430068969727
# transition=<4, 2, 0.0, 5>, delta_update=0.0
# transition=<5, 1, 0.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.009467005729675293
# transition=<7, 8, 0.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.013103127479553223
# transition=<9, 9, 1.0, 10>, delta_update=0.011137664318084717
# transition=<10, 8, 0.0, 11>, delta_update=0.0
# transition=<11, 7, 0.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.011137664318084717
# transition=<13, 0, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.004941821098327637
# episode 47: cumul_reward=7.0, accuracy:0.46667, cumul_delta=0.070145, eps=0.48486
# starting episode 48...
# transition=<0, 8, 0.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.015415430068969727
# transition=<2, 9, 0.0, 3>, delta_update=0.0
# transition=<3, 8, 0.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.011137664318084717
# transition=<5, 4, 1.0, 6>, delta_update=0.02510148286819458
# transition=<6, 4, 0.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.008046984672546387
# transition=<8, 5, 1.0, 9>, delta_update=0.011137664318084717
# transition=<9, 8, 0.0, 10>, delta_update=0.0
# transition=<10, 7, 0.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.10837498307228088
# transition=<12, 4, 1.0, 13>, delta_update=0.009467005729675293
# transition=<13, 2, 1.0, 14>, delta_update=0.011137664318084717
# transition=<14, 4, 0.0, 15>, delta_update=0.0
# episode 48: cumul_reward=8.0, accuracy:0.53333, cumul_delta=0.19982, eps=0.47745
# starting episode 49...
# transition=<0, 6, 0.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.013103127479553223
# transition=<2, 0, 0.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.013103127479553223
# transition=<4, 6, 1.0, 5>, delta_update=0.009467005729675293
# transition=<5, 4, 1.0, 6>, delta_update=0.021336257457733154
# transition=<6, 2, 1.0, 7>, delta_update=0.008046984672546387
# transition=<7, 5, 1.0, 8>, delta_update=0.006839931011199951
# transition=<8, 9, 0.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.009467005729675293
# transition=<10, 3, 1.0, 11>, delta_update=0.015415430068969727
# transition=<11, 1, 1.0, 12>, delta_update=0.09211874008178711
# transition=<12, 4, 1.0, 13>, delta_update=0.008046984672546387
# transition=<13, 2, 1.0, 14>, delta_update=0.009467005729675293
# transition=<14, 3, 1.0, 15>, delta_update=0.004200577735900879
# episode 49: cumul_reward=12.0, accuracy:0.8, cumul_delta=0.21061, eps=0.47015
# starting episode 50...
# transition=<0, 5, 1.0, 1>, delta_update=0.004200577735900879
# transition=<1, 7, 0.0, 2>, delta_update=0.0
# transition=<2, 2, 0.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.011137664318084717
# transition=<4, 6, 1.0, 5>, delta_update=0.008046984672546387
# transition=<5, 9, 0.0, 6>, delta_update=0.0
# transition=<6, 6, 0.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.005813896656036377
# transition=<8, 3, 0.0, 9>, delta_update=0.0
# transition=<9, 3, 0.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.013103127479553223
# transition=<11, 1, 1.0, 12>, delta_update=0.07830095291137695
# transition=<12, 5, 0.0, 13>, delta_update=0.0
# transition=<13, 3, 0.0, 14>, delta_update=0.0
# transition=<14, 8, 0.0, 15>, delta_update=0.0
# episode 50: cumul_reward=6.0, accuracy:0.4, cumul_delta=0.1206, eps=0.46297
# starting episode 51...
# transition=<0, 4, 0.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.011137664318084717
# transition=<2, 1, 0.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.009467005729675293
# transition=<4, 2, 0.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.01813584566116333
# transition=<6, 2, 1.0, 7>, delta_update=0.006839931011199951
# transition=<7, 5, 1.0, 8>, delta_update=0.004941821098327637
# transition=<8, 5, 1.0, 9>, delta_update=0.009467005729675293
# transition=<9, 9, 1.0, 10>, delta_update=0.008046984672546387
# transition=<10, 5, 0.0, 11>, delta_update=0.0
# transition=<11, 2, 0.0, 12>, delta_update=0.0
# transition=<12, 2, 0.0, 13>, delta_update=0.0
# transition=<13, 4, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0035704970359802246
# episode 51: cumul_reward=8.0, accuracy:0.53333, cumul_delta=0.071607, eps=0.45589
# starting episode 52...
# transition=<0, 4, 0.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.009467005729675293
# transition=<2, 6, 1.0, 3>, delta_update=0.015415430068969727
# transition=<3, 5, 1.0, 4>, delta_update=0.008046984672546387
# transition=<4, 6, 1.0, 5>, delta_update=0.006839931011199951
# transition=<5, 4, 1.0, 6>, delta_update=0.015415430068969727
# transition=<6, 2, 1.0, 7>, delta_update=0.005813896656036377
# transition=<7, 5, 1.0, 8>, delta_update=0.004200577735900879
# transition=<8, 4, 0.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.006839931011199951
# transition=<10, 3, 1.0, 11>, delta_update=0.011137664318084717
# transition=<11, 4, 0.0, 12>, delta_update=0.0
# transition=<12, 8, 0.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.008046984672546387
# transition=<14, 8, 0.0, 15>, delta_update=0.0
# episode 52: cumul_reward=10.0, accuracy:0.66667, cumul_delta=0.091224, eps=0.44893
# starting episode 53...
# transition=<0, 5, 1.0, 1>, delta_update=0.0035704970359802246
# transition=<1, 1, 1.0, 2>, delta_update=0.008046984672546387
# transition=<2, 8, 0.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.006839931011199951
# transition=<4, 6, 1.0, 5>, delta_update=0.005813896656036377
# transition=<5, 5, 0.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.004941821098327637
# transition=<7, 4, 0.0, 8>, delta_update=0.0
# transition=<8, 8, 0.0, 9>, delta_update=0.0
# transition=<9, 6, 0.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.009467005729675293
# transition=<11, 7, 0.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.006839931011199951
# transition=<13, 8, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0030348896980285645
# episode 53: cumul_reward=8.0, accuracy:0.53333, cumul_delta=0.048555, eps=0.44206
# starting episode 54...
# transition=<0, 5, 1.0, 1>, delta_update=0.0030348896980285645
# transition=<1, 2, 0.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.013103127479553223
# transition=<3, 1, 0.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.004941821098327637
# transition=<5, 8, 0.0, 6>, delta_update=0.0
# transition=<6, 5, 0.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0035704970359802246
# transition=<8, 5, 1.0, 9>, delta_update=0.008046984672546387
# transition=<9, 9, 1.0, 10>, delta_update=0.005813896656036377
# transition=<10, 3, 1.0, 11>, delta_update=0.008046984672546387
# transition=<11, 4, 0.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.005813896656036377
# transition=<13, 2, 1.0, 14>, delta_update=0.006839931011199951
# transition=<14, 1, 0.0, 15>, delta_update=0.0
# episode 54: cumul_reward=9.0, accuracy:0.6, cumul_delta=0.059212, eps=0.43531
# starting episode 55...
# transition=<0, 5, 1.0, 1>, delta_update=0.0025796890258789062
# transition=<1, 3, 0.0, 2>, delta_update=0.0
# transition=<2, 4, 0.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.005813896656036377
# transition=<4, 6, 1.0, 5>, delta_update=0.004200577735900879
# transition=<5, 4, 1.0, 6>, delta_update=0.013103127479553223
# transition=<6, 5, 0.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0030348896980285645
# transition=<8, 5, 1.0, 9>, delta_update=0.006839931011199951
# ...
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 5, 0.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 6, 0.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 212: cumul_reward=13.0, accuracy:0.86667, cumul_delta=0.0, eps=0.038189
# starting episode 213...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 213: cumul_reward=15.0, accuracy:1.0, cumul_delta=0.0, eps=0.037605
# starting episode 214...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 214: cumul_reward=15.0, accuracy:1.0, cumul_delta=0.0, eps=0.037031
# starting episode 215...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 215: cumul_reward=15.0, accuracy:1.0, cumul_delta=0.0, eps=0.036465
# starting episode 216...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 216: cumul_reward=15.0, accuracy:1.0, cumul_delta=0.0, eps=0.035907
# starting episode 217...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 8, 0.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 217: cumul_reward=14.0, accuracy:0.93333, cumul_delta=0.0, eps=0.035359
# starting episode 218...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 218: cumul_reward=15.0, accuracy:1.0, cumul_delta=0.0, eps=0.034818
# starting episode 219...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 5, 0.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 219: cumul_reward=14.0, accuracy:0.93333, cumul_delta=0.0, eps=0.034286
# starting episode 220...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 7, 0.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 220: cumul_reward=14.0, accuracy:0.93333, cumul_delta=0.0, eps=0.033762
# starting episode 221...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 6, 0.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 221: cumul_reward=14.0, accuracy:0.93333, cumul_delta=0.0, eps=0.033246
# starting episode 222...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 222: cumul_reward=15.0, accuracy:1.0, cumul_delta=0.0, eps=0.032738
# starting episode 223...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 223: cumul_reward=15.0, accuracy:1.0, cumul_delta=0.0, eps=0.032237
# starting episode 224...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 224: cumul_reward=15.0, accuracy:1.0, cumul_delta=0.0, eps=0.031745
# starting episode 225...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 2, 0.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 225: cumul_reward=14.0, accuracy:0.93333, cumul_delta=0.0, eps=0.03126
# starting episode 226...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 226: cumul_reward=15.0, accuracy:1.0, cumul_delta=0.0, eps=0.030782
# starting episode 227...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 2, 0.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 227: cumul_reward=14.0, accuracy:0.93333, cumul_delta=0.0, eps=0.030311
# starting episode 228...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 228: cumul_reward=15.0, accuracy:1.0, cumul_delta=0.0, eps=0.029848
# starting episode 229...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 229: cumul_reward=15.0, accuracy:1.0, cumul_delta=0.0, eps=0.029392
# starting episode 230...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 230: cumul_reward=15.0, accuracy:1.0, cumul_delta=0.0, eps=0.028943
# starting episode 231...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 231: cumul_reward=15.0, accuracy:1.0, cumul_delta=0.0, eps=0.0285
# starting episode 232...
# transition=<0, 5, 1.0, 1>, delta_update=0.0
# transition=<1, 1, 1.0, 2>, delta_update=0.0
# transition=<2, 6, 1.0, 3>, delta_update=0.0
# transition=<3, 5, 1.0, 4>, delta_update=0.0
# transition=<4, 6, 1.0, 5>, delta_update=0.0
# transition=<5, 4, 1.0, 6>, delta_update=0.0
# transition=<6, 2, 1.0, 7>, delta_update=0.0
# transition=<7, 5, 1.0, 8>, delta_update=0.0
# transition=<8, 5, 1.0, 9>, delta_update=0.0
# transition=<9, 9, 1.0, 10>, delta_update=0.0
# transition=<10, 3, 1.0, 11>, delta_update=0.0
# transition=<11, 1, 1.0, 12>, delta_update=0.0
# transition=<12, 4, 1.0, 13>, delta_update=0.0
# transition=<13, 2, 1.0, 14>, delta_update=0.0
# transition=<14, 3, 1.0, 15>, delta_update=0.0
# episode 232: cumul_reward=15.0, accuracy:1.0, cumul_delta=0.0, eps=0.028065
