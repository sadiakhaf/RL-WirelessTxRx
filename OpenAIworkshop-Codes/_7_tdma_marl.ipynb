# %%
#   ____                            _____     _____                   __          __        _        _                 
#  / __ \                     /\   |_   _|   / ____|                  \ \        / /       | |      | |                
# | |  | |_ __   ___ _ __    /  \    | |    | |  __ _   _ _ __ ___     \ \  /\  / /__  _ __| | _____| |__   ___  _ __  
# | |  | | '_ \ / _ \ '_ \  / /\ \   | |    | | |_ | | | | '_ ` _ \     \ \/  \/ / _ \| '__| |/ / __| '_ \ / _ \| '_ \ 
# | |__| | |_) |  __/ | | |/ ____ \ _| |_   | |__| | |_| | | | | | |     \  /\  / (_) | |  |   <\__ \ | | | (_) | |_) |
#  \____/| .__/ \___|_| |_/_/    \_\_____|   \_____|\__, |_| |_| |_|      \/  \/ \___/|_|  |_|\_\___/_| |_|\___/| .__/ 
#        | |                                         __/ |                                                      | |    
#        |_|                                        |___/                                                       |_|

# %% [markdown]
# # 10 minutes break ?

# %%
# !pip install gym
#!pip install torch==1.5.0+cpu -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (0.17.2)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym) (1.18.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)

# %%
import json
import pathlib
import random
from itertools import count
from random import randint

import gym
from gym import spaces

from typing import Optional, Dict, Tuple, Callable, Any, List

import collections

import torch
from torch import Tensor

# %%
class MultiAgentTDMAGym(gym.Env):
  NO_ACTION = 0  # no action on sub-frame
  UPLINK_ACTION = 1  # use sub-frame as up-link role (user [Tx] --> base-station [Rx])
  DOWNLINK_ACTION = 2  # use sub-frame as down-link role (base-station [Tx] --> user [Rx])

  BASE_STATION_AGENT = 0  # base-station agent type value
  USER_AGENT = 1  # user agent type value
  JAMMER_AGENT = 2  # jammer agent type value

  def __init__(
      self, n_freqs: int, n_subframes: int, horizon: int,
      use_jammer: bool = True
  ):
    super(MultiAgentTDMAGym, self).__init__()  # initialize gym.Env base class
    if n_subframes % 2 != 0:  # since a link is separated in up and down link we need even number of subframe
      raise ValueError('n_subframes must be an even number')

    self.freq_act_space = spaces.Discrete(n_freqs)  # frequency action space
    self.sf_act_space = spaces.MultiDiscrete([3] * n_subframes)  # sub-frames action space
    self.time_step_obs_space = spaces.Discrete(horizon + 1)  # time-step action space

    # multi-agent action space dict includes frequency and sub-frames action for each type
    self.action_space = spaces.Dict(
      {
        'user': spaces.Dict(
          {'freq': self.freq_act_space, 'subframes': self.sf_act_space}  # frequency and subframes user agent action space
        ),
        'base_station': spaces.Dict(
          {'freq': self.freq_act_space, 'subframes': self.sf_act_space}  # frequency and subframes base-station agent action space
        ),
        'jammer': spaces.Dict(
          {'freq': self.freq_act_space, 'subframes': self.sf_act_space}  # frequency and subframes jammer agent action space
        )
      }
    )
    # multi-agent observation space, different space for all agent type 
    self.observation_space = spaces.Dict(
      {
        'user': spaces.Dict(
          {
            'time_step': self.time_step_obs_space,  # time-step observation, including terminal time-step
            'last_a': self.action_space['user'],  # last action done by the agent
            'last_success': spaces.MultiDiscrete([2] * n_subframes)  # what sub-frames received an acknowledgement
          }
        ),
        'base_station': spaces.Dict(
          {'time_step': self.time_step_obs_space}  # time-step observation, including terminal time-step
        ),
        'jammer': spaces.Dict(
          {
            'time_step': self.time_step_obs_space,  # time-step observation, including terminal time-step
            'last_a': self.action_space['jammer'],  # last action done by the agent
          }
        )
      }
    )
    self.reward_range = 0.0, float(n_subframes)  # action-reward range between 0 and the number of sub-frames

    self.use_jammer = use_jammer  # tell the gym to consider jammer agent
    self.hor = horizon  # gym horizon to know when we are DONE
    self.t = 0  # initial time-step / observation

  def step(self, action: Dict) -> Tuple[
    Dict, Dict[str, float], bool, Dict
  ]:
    if self.t >= self.hor:  # terminal state reached
      return collections.OrderedDict(), {}, True, {}  # return terminal empty transition

    assert self.action_space['user'].contains(action['user'])  # assert user action is within user action space
    assert self.action_space['base_station'].contains(action['base_station'])  # assert base-station action is within action space
    assert self.action_space['jammer'].contains(action['jammer'])  # assert jammer action is within action space

    bs_a = action['base_station']  # base-station action
    j_a = action['jammer']  # jammer action
    u_a = action['user']  # user action

    if bs_a['freq'] == u_a['freq']:  # base-station and user agents have the same frequency
      if u_a['freq'] == j_a['freq'] and self.use_jammer:  # base-station, user and jammer have the same frequency, jammer is considered
        sf_success = [
          int(
            bs_sf == u_sf and u_sf != self.NO_ACTION and  # base-station and user have same sub-frames role
            (u_sf != j_sf or j_sf == self.NO_ACTION)    # jammer must not have same role for user and base-station successes
          ) for bs_sf, u_sf, j_sf in zip(
            bs_a['subframes'], u_a['subframes'], j_a['subframes']  # for all sub-frames
          )
        ]
      else:  # jammer is no considered, base-station and user have the same frequency
        sf_success = [
          int(bs_sf == u_sf and u_sf != self.NO_ACTION)  # action sub-frames role is correct w.r.t. the base-station's sub-frames
          for bs_sf, u_sf in zip(bs_a['subframes'], u_a['subframes'])
        ]
    else:
      sf_success = [0] * len(self.sf_act_space.nvec)  # wrong frequency, no sub-frames successes

    self.t += 1  # increment our time-step / observation
    o = collections.OrderedDict(
      user=collections.OrderedDict(
        time_step=self.t, last_a=bs_a, last_success=sf_success   # user obs: time-step, last action, last successes
      ),
      base_station=collections.OrderedDict(time_step=self.t),  # base-station obs: only time-step
      jammer=collections.OrderedDict(time_step=self.t, last_a=j_a)  # jammer obs: time-step and last action
    )
    assert self.observation_space.contains(o)  # assert obs is within observation space

    r = {
      'base_station': float(sum(sf_success)),  # sum successes to give the reward
      'user': float(sum(sf_success)),  # sum successes to give the reward
      'jammer': 0.0  # jammer always a reward of 0
    }
    return o, r, False, {}  # gyms always returns <obs, reward, if terminal obs reached, debug/info dictionary>

  def reset(self) -> Dict:  # reset our gym for a new episode
    self.t = 0  # initial time-step
    o = collections.OrderedDict( 
      base_station=collections.OrderedDict(time_step=self.t),
      user=collections.OrderedDict(time_step=self.t),
      jammer=collections.OrderedDict(time_step=self.t)
    )
    return o  # initial observation, only the time-step

  def render(self, mode='human'):  # gym visual rendering (e.g. text, image, plot, 3D frame, etc.)
    pass

# %%
class TDMABaseStationAgent:

  def __init__(self, gym_env: MultiAgentTDMAGym):
    self.act_space = gym_env.action_space['base_station']  # base-station action space from gym
    self.obs_space = gym_env.observation_space['base_station']  # base-station observation space from gym

    horizon = self.obs_space['time_step'].n  # horizon to know when we are DONE
    n_freqs = self.act_space['freq'].n  # number of frequencies to use as base-station
    n_subframes = len(self.act_space['subframes'].nvec)  # number of sub-frames to use as base-station

    self.freq_sf: Dict[int, Tuple[int, Tensor]] = dict()  # frequency and sub-frames role assignation w.r.t. to time-step
    for t in range(horizon):  # do not include terminal state
      freq = randint(0, n_freqs - 1)  # choose random frequency to do Tx
      ul_subframes = random.sample(range(n_subframes), k=n_subframes // 2)  # choose which sub-frames will be used as up-link
      dl_subframes = [
        sf for sf in range(n_subframes) if sf not in ul_subframes  # choose the rest of sub-frames as down-link
      ]
      sf = torch.zeros(n_subframes, dtype=torch.int)  # initialize sub-frames roles
      sf.fill_(gym_env.NO_ACTION)  # set all sub-frames to no-action
      sf[ul_subframes] = gym_env.UPLINK_ACTION  # set all up-link sub-frames to uplink-action value
      sf[dl_subframes] = gym_env.DOWNLINK_ACTION  # set all down-link sub-frames to downlink-action value
      self.freq_sf[t] = freq, sf  # set sub-frames role w.r.t. time-step

    terminal_sf = torch.zeros(n_subframes, dtype=torch.int)  # terminal observation sub-frames
    terminal_sf.fill_(gym_env.NO_ACTION)  # set terminal observation sub-frames value to no-action
    self.freq_sf[horizon] = 0, terminal_sf  # frequency 0 with no-action sub-frames

  def act(self, o: Dict) -> Dict:  # choose action based on observation
    a = collections.OrderedDict(
      freq=self.freq_sf[o['time_step']][0],   # frequency for current time-step observation
      subframes=self.freq_sf[o['time_step']][1].tolist()  # sub-frames role for current time-step observation
    )
    return a  # return base-station action

  def episode_reset(self, o: Dict, episode_i: int) -> Dict:  # reset agent for a new episode
    return self.act(o)  # choose action based on initial observation

# %%
class TDMAJammerAgent:

  def __init__(self, gym_env: MultiAgentTDMAGym):
    self.act_space = gym_env.action_space['jammer']  # jammer action space
    self.obs_space = gym_env.observation_space['jammer']  # jammer observation space
    self.ul_jamming_act = gym_env.UPLINK_ACTION  # jamming up-link action value
    self.dl_jamming_act = gym_env.DOWNLINK_ACTION  # jamming down-link action value
    self.no_jamming_act = gym_env.NO_ACTION  # no jamming action value
    self.n_subframes = len(self.act_space['subframes'].nvec)  # number of subframes

  def act(self, o: Dict, eps: Optional[float] = None) -> Dict:  # choose jamming action
    rand_sf_jamming = random.sample(
      range(self.n_subframes), k=self.n_subframes // 2  # select which sub-frames half will be jam 
    )
    sf_act = []
    for i in range(self.n_subframes):  # for all sub-frames
      if i in rand_sf_jamming:  # sub-frames selected for jamming
        sf_act.append(
          random.choice([self.ul_jamming_act, self.dl_jamming_act])  # randomly choose between up-link and down-link jamming
        )
      else:  # sub-frame is not selected for jamming
        sf_act.append(self.no_jamming_act)  # no jamming action
    a = collections.OrderedDict(
      freq=randint(0, self.act_space['freq'].n - 1),  # choose random frequency to do jamming
      subframes=sf_act
    )
    return a  # random jamming action

  def episode_reset(self, o: Dict, episode_i: int) -> Dict:  # reset agent for a new episode
    return self.act(o)  # choose jamming action

# %%
def build_epsilon_fn(steps: int) -> Callable[[int], float]:  # epsilon function builder
  log_epsilon_space = torch.logspace(1.0, -1.0, steps=steps, base=10.0) / 10.0  # epsilon log-space {1.0, ..., 0.0}

  def epsilon_fn(episode_i: int):  # epsilon function
    if episode_i >= steps:  # max step reached
      return 0.0
    return log_epsilon_space[episode_i].item()  # return epsilon value

  return epsilon_fn  # return our function as an callable object

# %%
class TDMAUserAgent:

  def __init__(
      self, lr: float, gamma: float, gym_env: MultiAgentTDMAGym,
      eps_fn_steps: int
  ):
    self.act_space = gym_env.action_space['user']  # user action space from gym environment
    self.obs_space = gym_env.observation_space['user']  # user observation space

    self.lr = lr  # learning rate
    self.gamma = gamma  # gamma parameter
    self.qtable: Dict[str, Tensor] = dict()  # Q-table with observation encoded as text string as keys for a 3D Q-table
    self.qtable_dims: Tuple[int, int, int] = (   # 3D Q-table dimensions (n_freqs X n_subframes x n_roles)
      self.act_space['freq'].n,
      self.act_space['subframes'].nvec.size,
      self.act_space['subframes'].nvec.max()
    )

    self.eps_fn_steps = eps_fn_steps  # number of steps (episodes) in epsilon log-space
    self.eps_fn: Callable[[int], float] = build_epsilon_fn(eps_fn_steps)  # build our epsilon function
    self.episode_i: Optional[int] = None  # keep track of the episode number (e.g. for epsilon)
    self.eps: Optional[float] = None  # epsilon value as a property of our agent

  def act(self, o: Dict, eps: Optional[float] = None) -> Dict:  # choose action
    if eps is None:
      eps = self.eps  # not epsilon as argument, use agent's current epsilon value

    o_enc = self.encode_obs(o)  # encode obs to a string "{time_step}:{freq}:{subframes}:{successes}"
    if o_enc not in self.qtable:
      self.qtable[o_enc] = torch.zeros(self.qtable_dims)  # add new Q-table for new obs, Q-values are zero

    if random.uniform(1.0, 0.0) < eps:  # epsilon-greedy condition for exploration
      return self.explore(o)  # exploring random action

    max_sf_values, max_sf_indices = self.qtable[o_enc].max(dim=2)  # get values and index of best actions for all sub-frame Q-values
    max_freq = max_sf_values.sum(dim=1).argmax()  # get frequency with the best Q-values for all sub-frames

    if max_sf_indices.ndimension() > 1:  # multiple equal maximums
      max_sf_indices = max_sf_indices[max_freq]  # if Q-value equality occurs, take random one

    return collections.OrderedDict(
      freq=int(max_freq), subframes=max_sf_indices.tolist(),  # create and return action with best Q-values
    )

  def explore(self, o: Dict) -> Dict:  # action-space exploration
    rand_a = collections.OrderedDict(
      freq=randint(0, self.act_space['freq'].n - 1),  # random frequency
      subframes=[
        randint(0, n - 1) for n in self.act_space['subframes'].nvec  # random role action for each sub-frame
      ]
    )
    return rand_a  # random action

  def update(
      self, o: Dict, a: Dict, r: float, o_prime: Dict  # agent update function (e.g. Q-learning update)
  ) -> float:
    o_enc = self.encode_obs(o)  # encode obs to a string "{time_step}:{freq}:{subframes}:{successes}"
    o_prime_enc = self.encode_obs(o_prime)  # encode obs to a string "{time_step}:{freq}:{subframes}:{successes}"

    if o_enc not in self.qtable:
      self.qtable[o_enc] = torch.zeros(self.qtable_dims)  # add new Q-table for new obs, Q-values are zero

    if o_prime_enc not in self.qtable:
      self.qtable[o_prime_enc] = torch.zeros(self.qtable_dims)  # add new Q-table for new obs, Q-values are zero

    a_inds = a['freq'], range(len(a['subframes'])), a['subframes']  # get Q-table indices of action
    a_vals = self.qtable[o_enc][a_inds]  # TD-source (e.i. TD-error = [TD-target - TD-source]), also old Q-values to compute delta update

    max_prime_sf_vals, _ = self.qtable[o_prime_enc].max(dim=2)  # get values and index of best actions for all sub-frame Q-values
    a_prime_val = max_prime_sf_vals[max_prime_sf_vals.sum(dim=1).argmax()]  # get frequency with the best Q-values for all sub-frames

    last_success = torch.tensor(o_prime['last_success'])  # last success for credit assignment of the update

    td_target = (r + self.gamma * a_prime_val) * last_success  # compute Temporal-Difference target (e.i [r + gamma * Q(o', a_max)])
    self.qtable[o_enc][a_inds] += (
        self.lr * (td_target - a_vals) * last_success  # update Q-table (e.i. Q(o, s) <- Q(o, s) + lr * [TD-target - Q(o, a)])
    )

    delta_update = float(sum(self.qtable[o_enc][a_inds] - a_vals))  # compute delta update
    return delta_update  # return delta update to training loop

  def episode_reset(self, o: Dict, episode_i: int) -> Dict:  # reset agent for a new episode
    self.episode_i = episode_i  # current episode number
    self.eps = self.eps_fn(episode_i)  # epsilon w.r.t. episode number
    return self.act(o, self.eps)  # act upon initial observation

  def save_to_file(self, path: str, overwrite: bool):  # save agent state to file
    file = pathlib.Path(path)  # file path
    if not overwrite and file.exists():  # exception if file exist and overwrite is false
      raise FileExistsError()

    # agent state as a python dictionary
    agent_state: Dict[str, Any] = {
      'gamma': self.gamma,
      'act_space': {
        'n_freq': self.act_space['freq'].n,
        'subframes_nvec': [
          int(n) for n in self.act_space['subframes'].nvec
        ]
      },
      'obs_space': {
        'n_time_step': self.obs_space['time_step'].n
      },
      'qtable': {k: v.tolist() for k, v in self.qtable.items()}
    }

    with file.open('w') as f:  # open file to write in it
      json.dump(agent_state, f)  # write agent state in file

  def load_from_file(self, path: str):  # load agent state from compatible saved state
    file = pathlib.Path(path)  # file path
    if not file.exists():
      return  # file does not exists

    with file.open('r') as f:  # open file to read it
      agent_state = json.load(f)  # load agent state from file

    self.gamma = agent_state['gamma']  # set gamma to loaded value
    self.qtable = {
      k: torch.tensor(v) for k, v in agent_state['qtable'].items()  # set number of actions from loaded value
    }

    assert self.act_space['freq'].n == agent_state['act_space']['n_freq']  # assert compatiblity
    assert [int(n) for n in self.act_space['subframes'].nvec] == (
      agent_state['act_space']['subframes_nvec']  # assert compatiblity
    )
    assert self.obs_space['time_step'].n == (
      agent_state['obs_space']['n_time_step']  # assert compatiblity
    )

  @staticmethod
  def encode_obs(o: Dict) -> str:  # encoding observation to a string to use it as Q-table key
    encoded = '{time_step}:{last_a}:{last_success}'.format(
      time_step=o['time_step'] if 'time_step' in o else '',
      last_a=(
        TDMAUserAgent.encode_act(o['last_a']) if 'last_a' in o else ''
      ),
      last_success=o['last_success'] if 'last_success' in o else ''
    ).replace(' ', '')
    return encoded  # return encoded observation as string

  @staticmethod
  def encode_act(a: Dict) -> str:  # encoding action to a string to use it as part of Q-table key
    encoded = '{freq}:{sf}'.format(
      freq=a['freq'], sf=a['subframes']
    ).replace(' ', '')
    return encoded  # return encoded action as string

# %%
random.seed(1234)  # python random number generator seed
torch.manual_seed(1234)  # pytorch random number generator seed

n_freqs = 10  # number of frequencies
n_subframes = 8  # number of sub-frames within a time-step frame
horizon = 15  # horizon of our gym (episodes)

gym_env = MultiAgentTDMAGym(
  n_freqs, n_subframes, horizon, use_jammer=False  # our MARL gym environment
)

lr = 0.15  # learning rate
gamma = 0.0  # gamma parameter
eps_fn_steps = 3000  # number of steps (episodes) in epsilon log-space

# contain all agents inside a key-value dictionary
agents = {
  'user': TDMAUserAgent(lr, gamma, gym_env, eps_fn_steps),  # initialize user agent
  'bs': TDMABaseStationAgent(gym_env),  # initialize base-station agent
  'jam': TDMAJammerAgent(gym_env)  # initialize jammer agent
}

# agents['user'].load_from_file('tdma_user_agent_1.json')

show_verbose = False  # print information for debugging
render_gym = False  # render gym

# print simulation parameters
print(
  'model: {{n_freqs={n_freqs}, n_subframes:{n_subframes},'
  ' horizon={horizon}}}, '
  'agent: {{lr={lr}, gamma={gamma}, eps_fn_steps={eps_fn_steps}}}'.format(
    n_freqs=n_freqs, n_subframes=n_subframes, horizon=horizon, lr=lr,
    gamma=gamma, eps_fn_steps=eps_fn_steps
  )
)

running_len = 5  # length of our running training data
running_delta = []  # running delta (e.g. the last running_len delta update)
running_acc = []  # running accuracy (e.g. the last running_len accuracy)

for episode_i in count():  # user agent training loop
  if show_verbose:
    print('starting episode {episode_i}...'.format(episode_i=episode_i))

  delta_update: List[float] = []  # delta update of our Q-table
  n_successes: int = 0  # number of optimal actions (actions with maximum reward)
  cumul_r: float = 0.0  # cumulative reward

  o = gym_env.reset()  # reset gym for new episode
  a = collections.OrderedDict(
    base_station=agents['bs'].episode_reset(o['base_station'], episode_i),  # reset base-station agent
    user=agents['user'].episode_reset(o['user'], episode_i),  # reset user agent with initial observation
    jammer=agents['jam'].episode_reset(o['jammer'], episode_i)  # reset jammer agent
  )

  for t in count():  # episode loop
    if render_gym:
      gym_env.render()  # show gym rendering
    o_prime, r, done, _ = gym_env.step(a)  # interact with the gym, get environment transition
    if done:
      break  # terminal gym observation reached, out of horizon

    delta_update.append(
      agents['user'].update(
        o['user'], a['user'], r['user'], o_prime['user']  # update user agent with transition, get delta update
      )
    )
    cumul_r += r['user']  # add user reward to cumulative user reward
    n_successes += int(r['user'] == 1.0 * n_subframes)  # success if optimal action-reward of 1.0 * number of sub-frames

    if show_verbose:  # show transition of our model (e.i. <o, a, r, o'>)
      print(
        'user_transition={{o={o}, a={a}, r={r}, o_prime={o_prime}}},'
        ' delta_update={delta}'.format(
          o=agents['user'].encode_obs(o['user']),
          a=agents['user'].encode_act(a['user']),
          r=r['user'],
          o_prime=agents['user'].encode_obs(o_prime['user']),
          delta=delta_update[-1]
        )
      )

    o = o_prime  # increment to next observation (e.g. next observation)
    a = collections.OrderedDict(
      base_station=agents['bs'].act(o['base_station']),  # base-station acts upon next observation
      user=agents['user'].act(o['user']),  # user acts upun next observation
      jammer=agents['jam'].act(o['jammer'])  # jammer acts upun next observation
    )

  # strip running data because we reached running length
  if len(running_acc) >= running_len or len(running_delta) >= running_len:
    running_acc.pop(0)  # delete oldest running accuracy
    running_delta.pop(0)  # delete oldest running update delta

  running_acc.append(n_successes / horizon)  # add latest accuracy to running data
  running_delta.append(sum(delta_update))  # add latest update delta to running data

  # show episode results
  print(
    'episode {episode_i}: cumul_reward={cumul_r}, accuracy:{acc:0.5}, '
    'cumul_delta={cumul_delta:0.5}, eps={eps:0.5}'.format(
      episode_i=episode_i, cumul_r=cumul_r, acc=running_acc[-1],
      cumul_delta=running_delta[-1], eps=agents['user'].eps
    )
  )

  # training stop conditions
  if (
      all([acc == 1.0 for acc in running_acc])  # all running accuracy are maximized
      and all([delta < 0.0001 for delta in running_delta])  # all running delta update a lower than 0.0001
      and episode_i >= running_len  # running data have reached running length
  ) or episode_i >= eps_fn_steps + running_len:  # epsilon was 0 for all running data (nothing will change)
    break  # exit training loop

agents['user'].save_to_file('tdma_user_agent_1.json', overwrite=True)  # save agent state to file
gym_env.close()  # close gym environment
# Out:
# model: {n_freqs=10, n_subframes:8, horizon=15}, agent: {lr=0.15, gamma=0.0, eps_fn_steps=3000}
# episode 0: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=1.0
# episode 1: cumul_reward=10.0, accuracy:0.0, cumul_delta=5.1, eps=0.99847
# episode 2: cumul_reward=3.0, accuracy:0.0, cumul_delta=1.35, eps=0.99693
# episode 3: cumul_reward=6.0, accuracy:0.0, cumul_delta=3.0, eps=0.9954
# episode 4: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.99388
# episode 5: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.99235
# episode 6: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.99083
# episode 7: cumul_reward=2.0, accuracy:0.0, cumul_delta=0.3, eps=0.98931
# episode 8: cumul_reward=5.0, accuracy:0.0, cumul_delta=2.235, eps=0.98779
# episode 9: cumul_reward=9.0, accuracy:0.0, cumul_delta=4.35, eps=0.98627
# episode 10: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.98476
# episode 11: cumul_reward=3.0, accuracy:0.0, cumul_delta=1.35, eps=0.98325
# episode 12: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.98174
# episode 13: cumul_reward=3.0, accuracy:0.0, cumul_delta=1.26, eps=0.98024
# episode 14: cumul_reward=12.0, accuracy:0.0, cumul_delta=4.8, eps=0.97873
# episode 15: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.0825, eps=0.97723
# episode 16: cumul_reward=2.0, accuracy:0.0, cumul_delta=0.6, eps=0.97573
# episode 17: cumul_reward=7.0, accuracy:0.0, cumul_delta=3.66, eps=0.97423
# episode 18: cumul_reward=7.0, accuracy:0.0, cumul_delta=2.85, eps=0.97274
# episode 19: cumul_reward=4.0, accuracy:0.0, cumul_delta=2.0535, eps=0.97125
# episode 20: cumul_reward=11.0, accuracy:0.0, cumul_delta=6.9225, eps=0.96976
# episode 21: cumul_reward=15.0, accuracy:0.0, cumul_delta=8.1525, eps=0.96827
# episode 22: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.96678
# episode 23: cumul_reward=6.0, accuracy:0.0, cumul_delta=3.765, eps=0.9653
# episode 24: cumul_reward=6.0, accuracy:0.0, cumul_delta=2.5875, eps=0.96382
# episode 25: cumul_reward=5.0, accuracy:0.0, cumul_delta=2.55, eps=0.96234
# episode 26: cumul_reward=12.0, accuracy:0.0, cumul_delta=7.767, eps=0.96086
# episode 27: cumul_reward=12.0, accuracy:0.0, cumul_delta=9.3634, eps=0.95939
# episode 28: cumul_reward=6.0, accuracy:0.0, cumul_delta=5.0884, eps=0.95792
# episode 29: cumul_reward=9.0, accuracy:0.0, cumul_delta=3.5145, eps=0.95645
# episode 30: cumul_reward=3.0, accuracy:0.0, cumul_delta=1.17, eps=0.95498
# episode 31: cumul_reward=11.0, accuracy:0.0, cumul_delta=6.657, eps=0.95351
# episode 32: cumul_reward=8.0, accuracy:0.066667, cumul_delta=8.8721, eps=0.95205
# episode 33: cumul_reward=9.0, accuracy:0.0, cumul_delta=5.3672, eps=0.95059
# episode 34: cumul_reward=13.0, accuracy:0.0, cumul_delta=7.4342, eps=0.94913
# episode 35: cumul_reward=11.0, accuracy:0.0, cumul_delta=5.8736, eps=0.94767
# episode 36: cumul_reward=5.0, accuracy:0.0, cumul_delta=1.4017, eps=0.94622
# episode 37: cumul_reward=2.0, accuracy:0.0, cumul_delta=0.5325, eps=0.94477
# episode 38: cumul_reward=12.0, accuracy:0.066667, cumul_delta=7.8412, eps=0.94332
# episode 39: cumul_reward=15.0, accuracy:0.0, cumul_delta=8.9246, eps=0.94187
# episode 40: cumul_reward=23.0, accuracy:0.13333, cumul_delta=16.434, eps=0.94043
# episode 41: cumul_reward=23.0, accuracy:0.0, cumul_delta=17.584, eps=0.93898
# episode 42: cumul_reward=10.0, accuracy:0.066667, cumul_delta=7.7003, eps=0.93754
# episode 43: cumul_reward=17.0, accuracy:0.066667, cumul_delta=12.586, eps=0.9361
# episode 44: cumul_reward=11.0, accuracy:0.066667, cumul_delta=6.8838, eps=0.93467
# episode 45: cumul_reward=5.0, accuracy:0.0, cumul_delta=0.96478, eps=0.93323
# episode 46: cumul_reward=3.0, accuracy:0.0, cumul_delta=0.56492, eps=0.9318
# episode 47: cumul_reward=9.0, accuracy:0.0, cumul_delta=4.4217, eps=0.93037
# episode 48: cumul_reward=7.0, accuracy:0.0, cumul_delta=6.6978, eps=0.92894
# episode 49: cumul_reward=8.0, accuracy:0.066667, cumul_delta=8.6434, eps=0.92752
# episode 50: cumul_reward=17.0, accuracy:0.13333, cumul_delta=14.339, eps=0.9261
# episode 51: cumul_reward=3.0, accuracy:0.0, cumul_delta=0.22714, eps=0.92467
# episode 52: cumul_reward=27.0, accuracy:0.066667, cumul_delta=16.749, eps=0.92326
# episode 53: cumul_reward=14.0, accuracy:0.0, cumul_delta=7.5012, eps=0.92184
# episode 54: cumul_reward=14.0, accuracy:0.0, cumul_delta=8.5746, eps=0.92042
# episode 55: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.91901
# episode 56: cumul_reward=10.0, accuracy:0.0, cumul_delta=4.6103, eps=0.9176
# episode 57: cumul_reward=17.0, accuracy:0.066667, cumul_delta=12.368, eps=0.91619
# episode 58: cumul_reward=12.0, accuracy:0.066667, cumul_delta=7.5743, eps=0.91479
# episode 59: cumul_reward=14.0, accuracy:0.0, cumul_delta=9.8562, eps=0.91338
# episode 60: cumul_reward=18.0, accuracy:0.066667, cumul_delta=8.3192, eps=0.91198
# episode 61: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.91058
# episode 62: cumul_reward=28.0, accuracy:0.0, cumul_delta=15.094, eps=0.90919
# episode 63: cumul_reward=8.0, accuracy:0.0, cumul_delta=2.3096, eps=0.90779
# episode 64: cumul_reward=12.0, accuracy:0.066667, cumul_delta=8.2276, eps=0.9064
# episode 65: cumul_reward=6.0, accuracy:0.0, cumul_delta=0.78567, eps=0.90501
# episode 66: cumul_reward=19.0, accuracy:0.066667, cumul_delta=12.092, eps=0.90362
# episode 67: cumul_reward=13.0, accuracy:0.0, cumul_delta=7.8031, eps=0.90223
# episode 68: cumul_reward=23.0, accuracy:0.13333, cumul_delta=13.94, eps=0.90085
# episode 69: cumul_reward=23.0, accuracy:0.066667, cumul_delta=14.785, eps=0.89947
# episode 70: cumul_reward=2.0, accuracy:0.0, cumul_delta=0.11637, eps=0.89809
# episode 71: cumul_reward=10.0, accuracy:0.0, cumul_delta=6.1892, eps=0.89671
# episode 72: cumul_reward=19.0, accuracy:0.066667, cumul_delta=8.1123, eps=0.89533
# episode 73: cumul_reward=2.0, accuracy:0.0, cumul_delta=-0.16803, eps=0.89396
# episode 74: cumul_reward=23.0, accuracy:0.13333, cumul_delta=14.462, eps=0.89259
# episode 75: cumul_reward=9.0, accuracy:0.0, cumul_delta=2.4577, eps=0.89122
# episode 76: cumul_reward=25.0, accuracy:0.066667, cumul_delta=15.088, eps=0.88985
# episode 77: cumul_reward=14.0, accuracy:0.066667, cumul_delta=5.1325, eps=0.88848
# episode 78: cumul_reward=3.0, accuracy:0.0, cumul_delta=0.3936, eps=0.88712
# episode 79: cumul_reward=4.0, accuracy:0.0, cumul_delta=0.45956, eps=0.88576
# episode 80: cumul_reward=27.0, accuracy:0.2, cumul_delta=17.42, eps=0.8844
# episode 81: cumul_reward=16.0, accuracy:0.066667, cumul_delta=7.9997, eps=0.88304
# episode 82: cumul_reward=7.0, accuracy:0.0, cumul_delta=3.9155, eps=0.88169
# episode 83: cumul_reward=15.0, accuracy:0.066667, cumul_delta=11.45, eps=0.88034
# episode 84: cumul_reward=15.0, accuracy:0.066667, cumul_delta=7.524, eps=0.87898
# episode 85: cumul_reward=11.0, accuracy:0.066667, cumul_delta=5.7725, eps=0.87764
# episode 86: cumul_reward=16.0, accuracy:0.13333, cumul_delta=10.215, eps=0.87629
# episode 87: cumul_reward=18.0, accuracy:0.13333, cumul_delta=6.7462, eps=0.87494
# episode 88: cumul_reward=16.0, accuracy:0.13333, cumul_delta=6.5928, eps=0.8736
# episode 89: cumul_reward=21.0, accuracy:0.13333, cumul_delta=11.35, eps=0.87226
# episode 90: cumul_reward=10.0, accuracy:0.066667, cumul_delta=3.7389, eps=0.87092
# episode 91: cumul_reward=8.0, accuracy:0.066667, cumul_delta=2.6498, eps=0.86959
# episode 92: cumul_reward=14.0, accuracy:0.066667, cumul_delta=3.6494, eps=0.86825
# episode 93: cumul_reward=41.0, accuracy:0.26667, cumul_delta=16.866, eps=0.86692
# episode 94: cumul_reward=31.0, accuracy:0.13333, cumul_delta=17.242, eps=0.86559
# episode 95: cumul_reward=16.0, accuracy:0.13333, cumul_delta=7.2182, eps=0.86426
# episode 96: cumul_reward=8.0, accuracy:0.066667, cumul_delta=3.5508, eps=0.86294
# episode 97: cumul_reward=16.0, accuracy:0.13333, cumul_delta=5.0449, eps=0.86161
# episode 98: cumul_reward=25.0, accuracy:0.13333, cumul_delta=4.2299, eps=0.86029
# episode 99: cumul_reward=33.0, accuracy:0.2, cumul_delta=13.933, eps=0.85897
# episode 100: cumul_reward=18.0, accuracy:0.0, cumul_delta=2.0208, eps=0.85765
# episode 101: cumul_reward=26.0, accuracy:0.2, cumul_delta=7.842, eps=0.85634
# episode 102: cumul_reward=16.0, accuracy:0.13333, cumul_delta=8.1326, eps=0.85502
# episode 103: cumul_reward=26.0, accuracy:0.2, cumul_delta=11.19, eps=0.85371
# episode 104: cumul_reward=25.0, accuracy:0.2, cumul_delta=6.5983, eps=0.8524
# episode 105: cumul_reward=14.0, accuracy:0.066667, cumul_delta=6.5257, eps=0.85109
# episode 106: cumul_reward=25.0, accuracy:0.13333, cumul_delta=8.7636, eps=0.84979
# episode 107: cumul_reward=23.0, accuracy:0.13333, cumul_delta=8.8443, eps=0.84848
# episode 108: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.84718
# episode 109: cumul_reward=24.0, accuracy:0.2, cumul_delta=10.966, eps=0.84588
# episode 110: cumul_reward=32.0, accuracy:0.13333, cumul_delta=5.7741, eps=0.84458
# episode 111: cumul_reward=8.0, accuracy:0.066667, cumul_delta=2.7817, eps=0.84329
# episode 112: cumul_reward=20.0, accuracy:0.13333, cumul_delta=7.7816, eps=0.84199
# episode 113: cumul_reward=21.0, accuracy:0.066667, cumul_delta=3.8038, eps=0.8407
# episode 114: cumul_reward=30.0, accuracy:0.2, cumul_delta=18.409, eps=0.83941
# episode 115: cumul_reward=12.0, accuracy:0.066667, cumul_delta=5.4668, eps=0.83812
# episode 116: cumul_reward=23.0, accuracy:0.13333, cumul_delta=4.7504, eps=0.83684
# episode 117: cumul_reward=22.0, accuracy:0.13333, cumul_delta=1.5841, eps=0.83555
# episode 118: cumul_reward=19.0, accuracy:0.13333, cumul_delta=2.8415, eps=0.83427
# episode 119: cumul_reward=20.0, accuracy:0.13333, cumul_delta=6.6588, eps=0.83299
# episode 120: cumul_reward=16.0, accuracy:0.13333, cumul_delta=4.477, eps=0.83171
# episode 121: cumul_reward=24.0, accuracy:0.13333, cumul_delta=6.0912, eps=0.83044
# episode 122: cumul_reward=12.0, accuracy:0.066667, cumul_delta=-0.074822, eps=0.82916
# episode 123: cumul_reward=16.0, accuracy:0.13333, cumul_delta=8.4398, eps=0.82789
# episode 124: cumul_reward=22.0, accuracy:0.13333, cumul_delta=2.0725, eps=0.82662
# episode 125: cumul_reward=24.0, accuracy:0.066667, cumul_delta=8.5315, eps=0.82535
# episode 126: cumul_reward=29.0, accuracy:0.2, cumul_delta=12.489, eps=0.82408
# episode 127: cumul_reward=23.0, accuracy:0.13333, cumul_delta=4.9256, eps=0.82282
# episode 128: cumul_reward=8.0, accuracy:0.066667, cumul_delta=1.4458, eps=0.82156
# episode 129: cumul_reward=14.0, accuracy:0.066667, cumul_delta=-0.7101, eps=0.8203
# episode 130: cumul_reward=44.0, accuracy:0.26667, cumul_delta=13.772, eps=0.81904
# episode 131: cumul_reward=16.0, accuracy:0.13333, cumul_delta=4.2754, eps=0.81778
# episode 132: cumul_reward=19.0, accuracy:0.13333, cumul_delta=4.4763, eps=0.81653
# episode 133: cumul_reward=11.0, accuracy:0.066667, cumul_delta=0.9182, eps=0.81527
# episode 134: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.81402
# episode 135: cumul_reward=42.0, accuracy:0.26667, cumul_delta=8.9732, eps=0.81277
# episode 136: cumul_reward=28.0, accuracy:0.2, cumul_delta=3.0972, eps=0.81153
# episode 137: cumul_reward=40.0, accuracy:0.33333, cumul_delta=13.308, eps=0.81028
# episode 138: cumul_reward=8.0, accuracy:0.066667, cumul_delta=2.4438, eps=0.80904
# episode 139: cumul_reward=27.0, accuracy:0.066667, cumul_delta=-1.723, eps=0.8078
# episode 140: cumul_reward=21.0, accuracy:0.13333, cumul_delta=3.894, eps=0.80656
# episode 141: cumul_reward=18.0, accuracy:0.13333, cumul_delta=3.1589, eps=0.80532
# episode 142: cumul_reward=42.0, accuracy:0.2, cumul_delta=12.658, eps=0.80408
# episode 143: cumul_reward=31.0, accuracy:0.2, cumul_delta=8.2881, eps=0.80285
# episode 144: cumul_reward=25.0, accuracy:0.2, cumul_delta=6.8938, eps=0.80162
# episode 145: cumul_reward=28.0, accuracy:0.13333, cumul_delta=6.8001, eps=0.80039
# episode 146: cumul_reward=10.0, accuracy:0.066667, cumul_delta=0.39935, eps=0.79916
# episode 147: cumul_reward=23.0, accuracy:0.13333, cumul_delta=4.1929, eps=0.79793
# episode 148: cumul_reward=16.0, accuracy:0.13333, cumul_delta=4.9103, eps=0.79671
# episode 149: cumul_reward=18.0, accuracy:0.13333, cumul_delta=3.282, eps=0.79549
# episode 150: cumul_reward=18.0, accuracy:0.13333, cumul_delta=3.6867, eps=0.79427
# episode 151: cumul_reward=32.0, accuracy:0.2, cumul_delta=1.4194, eps=0.79305
# episode 152: cumul_reward=30.0, accuracy:0.13333, cumul_delta=7.3569, eps=0.79183
# episode 153: cumul_reward=30.0, accuracy:0.2, cumul_delta=-0.2935, eps=0.79062
# episode 154: cumul_reward=44.0, accuracy:0.26667, cumul_delta=14.475, eps=0.7894
# episode 155: cumul_reward=32.0, accuracy:0.26667, cumul_delta=6.0192, eps=0.78819
# episode 156: cumul_reward=32.0, accuracy:0.13333, cumul_delta=12.237, eps=0.78698
# episode 157: cumul_reward=32.0, accuracy:0.26667, cumul_delta=6.357, eps=0.78578
# episode 158: cumul_reward=32.0, accuracy:0.26667, cumul_delta=5.2425, eps=0.78457
# episode 159: cumul_reward=8.0, accuracy:0.066667, cumul_delta=1.056, eps=0.78337
# episode 160: cumul_reward=20.0, accuracy:0.13333, cumul_delta=0.18562, eps=0.78216
# episode 161: cumul_reward=22.0, accuracy:0.13333, cumul_delta=2.176, eps=0.78096
# episode 162: cumul_reward=12.0, accuracy:0.066667, cumul_delta=-0.76619, eps=0.77977
# episode 163: cumul_reward=28.0, accuracy:0.13333, cumul_delta=2.3586, eps=0.77857
# episode 164: cumul_reward=33.0, accuracy:0.26667, cumul_delta=3.095, eps=0.77737
# episode 165: cumul_reward=24.0, accuracy:0.13333, cumul_delta=3.3721, eps=0.77618
# episode 166: cumul_reward=33.0, accuracy:0.2, cumul_delta=6.8108, eps=0.77499
# episode 167: cumul_reward=34.0, accuracy:0.26667, cumul_delta=1.6562, eps=0.7738
# episode 168: cumul_reward=32.0, accuracy:0.26667, cumul_delta=3.9887, eps=0.77261
# episode 169: cumul_reward=23.0, accuracy:0.13333, cumul_delta=5.6604, eps=0.77143
# episode 170: cumul_reward=13.0, accuracy:0.066667, cumul_delta=-0.90853, eps=0.77024
# episode 171: cumul_reward=8.0, accuracy:0.066667, cumul_delta=0.95102, eps=0.76906
# episode 172: cumul_reward=32.0, accuracy:0.26667, cumul_delta=5.6871, eps=0.76788
# episode 173: cumul_reward=16.0, accuracy:0.13333, cumul_delta=2.2413, eps=0.7667
# episode 174: cumul_reward=10.0, accuracy:0.066667, cumul_delta=-1.0122, eps=0.76553
# episode 175: cumul_reward=24.0, accuracy:0.2, cumul_delta=3.4036, eps=0.76435
# episode 176: cumul_reward=11.0, accuracy:0.066667, cumul_delta=-0.58727, eps=0.76318
# episode 177: cumul_reward=22.0, accuracy:0.066667, cumul_delta=6.909, eps=0.76201
# episode 178: cumul_reward=30.0, accuracy:0.13333, cumul_delta=0.50067, eps=0.76084
# episode 179: cumul_reward=10.0, accuracy:0.066667, cumul_delta=-0.69718, eps=0.75967
# episode 180: cumul_reward=17.0, accuracy:0.13333, cumul_delta=1.8813, eps=0.75851
# episode 181: cumul_reward=8.0, accuracy:0.066667, cumul_delta=1.1452, eps=0.75734
# episode 182: cumul_reward=21.0, accuracy:0.13333, cumul_delta=5.5283, eps=0.75618
# episode 183: cumul_reward=41.0, accuracy:0.26667, cumul_delta=6.0216, eps=0.75502
# episode 184: cumul_reward=20.0, accuracy:0.13333, cumul_delta=-0.52121, eps=0.75386
# episode 185: cumul_reward=22.0, accuracy:0.13333, cumul_delta=4.8426, eps=0.75271
# episode 186: cumul_reward=34.0, accuracy:0.26667, cumul_delta=1.9102, eps=0.75155
# episode 187: cumul_reward=33.0, accuracy:0.2, cumul_delta=-2.9842, eps=0.7504
# episode 188: cumul_reward=26.0, accuracy:0.2, cumul_delta=1.3487, eps=0.74925
# episode 189: cumul_reward=44.0, accuracy:0.26667, cumul_delta=14.576, eps=0.7481
# episode 190: cumul_reward=9.0, accuracy:0.066667, cumul_delta=-0.26944, eps=0.74695
# episode 191: cumul_reward=16.0, accuracy:0.13333, cumul_delta=3.9656, eps=0.7458
# episode 192: cumul_reward=41.0, accuracy:0.26667, cumul_delta=5.7634, eps=0.74466
# episode 193: cumul_reward=36.0, accuracy:0.26667, cumul_delta=4.7963, eps=0.74352
# episode 194: cumul_reward=45.0, accuracy:0.2, cumul_delta=5.7579, eps=0.74238
# episode 195: cumul_reward=22.0, accuracy:0.13333, cumul_delta=-0.88577, eps=0.74124
# episode 196: cumul_reward=14.0, accuracy:0.066667, cumul_delta=1.753, eps=0.7401
# episode 197: cumul_reward=44.0, accuracy:0.33333, cumul_delta=5.1723, eps=0.73896
# episode 198: cumul_reward=39.0, accuracy:0.26667, cumul_delta=3.5932, eps=0.73783
# episode 199: cumul_reward=38.0, accuracy:0.26667, cumul_delta=10.709, eps=0.7367
# episode 200: cumul_reward=16.0, accuracy:0.13333, cumul_delta=1.4103, eps=0.73557
# episode 201: cumul_reward=54.0, accuracy:0.33333, cumul_delta=10.7, eps=0.73444
# episode 202: cumul_reward=32.0, accuracy:0.26667, cumul_delta=2.6209, eps=0.73331
# episode 203: cumul_reward=28.0, accuracy:0.2, cumul_delta=0.8932, eps=0.73219
# episode 204: cumul_reward=11.0, accuracy:0.066667, cumul_delta=-1.4696, eps=0.73106
# episode 205: cumul_reward=40.0, accuracy:0.33333, cumul_delta=4.1946, eps=0.72994
# episode 206: cumul_reward=24.0, accuracy:0.2, cumul_delta=1.8286, eps=0.72882
# episode 207: cumul_reward=21.0, accuracy:0.13333, cumul_delta=2.4245, eps=0.7277
# episode 208: cumul_reward=21.0, accuracy:0.13333, cumul_delta=-0.051903, eps=0.72659
# episode 209: cumul_reward=15.0, accuracy:0.066667, cumul_delta=0.73534, eps=0.72547
# episode 210: cumul_reward=41.0, accuracy:0.33333, cumul_delta=3.6444, eps=0.72436
# episode 211: cumul_reward=26.0, accuracy:0.13333, cumul_delta=0.013501, eps=0.72325
# episode 212: cumul_reward=34.0, accuracy:0.2, cumul_delta=7.0513, eps=0.72214
# episode 213: cumul_reward=32.0, accuracy:0.2, cumul_delta=3.5286, eps=0.72103
# episode 214: cumul_reward=32.0, accuracy:0.2, cumul_delta=11.528, eps=0.71992
# episode 215: cumul_reward=40.0, accuracy:0.26667, cumul_delta=5.9814, eps=0.71882
# episode 216: cumul_reward=55.0, accuracy:0.33333, cumul_delta=10.98, eps=0.71771
# episode 217: cumul_reward=32.0, accuracy:0.26667, cumul_delta=2.2642, eps=0.71661
# episode 218: cumul_reward=45.0, accuracy:0.26667, cumul_delta=5.5053, eps=0.71551
# episode 219: cumul_reward=53.0, accuracy:0.4, cumul_delta=9.477, eps=0.71442
# episode 220: cumul_reward=33.0, accuracy:0.13333, cumul_delta=-3.6583, eps=0.71332
# episode 221: cumul_reward=34.0, accuracy:0.2, cumul_delta=1.8954, eps=0.71223
# episode 222: cumul_reward=37.0, accuracy:0.26667, cumul_delta=6.1381, eps=0.71113
# episode 223: cumul_reward=45.0, accuracy:0.2, cumul_delta=11.529, eps=0.71004
# episode 224: cumul_reward=26.0, accuracy:0.2, cumul_delta=0.25628, eps=0.70895
# episode 225: cumul_reward=27.0, accuracy:0.2, cumul_delta=-0.48642, eps=0.70786
# episode 226: cumul_reward=22.0, accuracy:0.13333, cumul_delta=-2.2991, eps=0.70678
# episode 227: cumul_reward=22.0, accuracy:0.13333, cumul_delta=3.5306, eps=0.70569
# episode 228: cumul_reward=32.0, accuracy:0.26667, cumul_delta=2.0698, eps=0.70461
# episode 229: cumul_reward=8.0, accuracy:0.066667, cumul_delta=0.58489, eps=0.70353
# episode 230: cumul_reward=43.0, accuracy:0.33333, cumul_delta=1.2479, eps=0.70245
# episode 231: cumul_reward=24.0, accuracy:0.13333, cumul_delta=2.8692, eps=0.70137
# episode 232: cumul_reward=39.0, accuracy:0.26667, cumul_delta=3.6604, eps=0.7003
# episode 233: cumul_reward=26.0, accuracy:0.2, cumul_delta=-0.38285, eps=0.69922
# episode 234: cumul_reward=43.0, accuracy:0.33333, cumul_delta=6.4841, eps=0.69815
# episode 235: cumul_reward=38.0, accuracy:0.26667, cumul_delta=2.9285, eps=0.69708
# episode 236: cumul_reward=32.0, accuracy:0.2, cumul_delta=2.1615, eps=0.69601
# episode 237: cumul_reward=41.0, accuracy:0.26667, cumul_delta=4.4122, eps=0.69494
# episode 238: cumul_reward=29.0, accuracy:0.13333, cumul_delta=0.58622, eps=0.69387
# episode 239: cumul_reward=40.0, accuracy:0.26667, cumul_delta=0.59836, eps=0.69281
# episode 240: cumul_reward=29.0, accuracy:0.2, cumul_delta=12.183, eps=0.69175
# episode 241: cumul_reward=24.0, accuracy:0.2, cumul_delta=0.86355, eps=0.69068
# episode 242: cumul_reward=25.0, accuracy:0.066667, cumul_delta=8.0004, eps=0.68962
# episode 243: cumul_reward=61.0, accuracy:0.4, cumul_delta=7.8698, eps=0.68857
# episode 244: cumul_reward=41.0, accuracy:0.26667, cumul_delta=3.5944, eps=0.68751
# episode 245: cumul_reward=37.0, accuracy:0.2, cumul_delta=1.1865, eps=0.68646
# episode 246: cumul_reward=57.0, accuracy:0.4, cumul_delta=11.535, eps=0.6854
# episode 247: cumul_reward=31.0, accuracy:0.2, cumul_delta=3.4827, eps=0.68435
# episode 248: cumul_reward=20.0, accuracy:0.066667, cumul_delta=1.8953, eps=0.6833
# episode 249: cumul_reward=8.0, accuracy:0.066667, cumul_delta=0.57576, eps=0.68225
# episode 250: cumul_reward=37.0, accuracy:0.2, cumul_delta=6.0958, eps=0.6812
# episode 251: cumul_reward=28.0, accuracy:0.2, cumul_delta=-0.62398, eps=0.68016
# episode 252: cumul_reward=41.0, accuracy:0.26667, cumul_delta=-1.4187, eps=0.67912
# episode 253: cumul_reward=48.0, accuracy:0.4, cumul_delta=8.2129, eps=0.67807
# episode 254: cumul_reward=39.0, accuracy:0.26667, cumul_delta=1.9862, eps=0.67703
# episode 255: cumul_reward=46.0, accuracy:0.33333, cumul_delta=9.4645, eps=0.67599
# episode 256: cumul_reward=35.0, accuracy:0.26667, cumul_delta=2.5249, eps=0.67496
# episode 257: cumul_reward=48.0, accuracy:0.4, cumul_delta=2.9788, eps=0.67392
# episode 258: cumul_reward=29.0, accuracy:0.2, cumul_delta=3.309, eps=0.67289
# episode 259: cumul_reward=24.0, accuracy:0.2, cumul_delta=1.6123, eps=0.67186
# episode 260: cumul_reward=36.0, accuracy:0.26667, cumul_delta=-0.15899, eps=0.67082
# episode 261: cumul_reward=24.0, accuracy:0.2, cumul_delta=0.45838, eps=0.6698
# episode 262: cumul_reward=27.0, accuracy:0.2, cumul_delta=0.95493, eps=0.66877
# episode 263: cumul_reward=29.0, accuracy:0.2, cumul_delta=0.39178, eps=0.66774
# episode 264: cumul_reward=40.0, accuracy:0.26667, cumul_delta=1.3784, eps=0.66672
# episode 265: cumul_reward=40.0, accuracy:0.33333, cumul_delta=5.0248, eps=0.66569
# episode 266: cumul_reward=37.0, accuracy:0.26667, cumul_delta=0.63572, eps=0.66467
# episode 267: cumul_reward=39.0, accuracy:0.26667, cumul_delta=5.4986, eps=0.66365
# episode 268: cumul_reward=35.0, accuracy:0.2, cumul_delta=0.017742, eps=0.66263
# episode 269: cumul_reward=33.0, accuracy:0.2, cumul_delta=1.4163, eps=0.66162
# episode 270: cumul_reward=32.0, accuracy:0.26667, cumul_delta=4.2477, eps=0.6606
# episode 271: cumul_reward=46.0, accuracy:0.26667, cumul_delta=5.1818, eps=0.65959
# episode 272: cumul_reward=33.0, accuracy:0.26667, cumul_delta=1.6488, eps=0.65858
# episode 273: cumul_reward=36.0, accuracy:0.2, cumul_delta=4.4755, eps=0.65757
# episode 274: cumul_reward=17.0, accuracy:0.0, cumul_delta=-2.8437, eps=0.65656
# episode 275: cumul_reward=48.0, accuracy:0.33333, cumul_delta=3.8181, eps=0.65555
# episode 276: cumul_reward=17.0, accuracy:0.066667, cumul_delta=-5.2048, eps=0.65454
# episode 277: cumul_reward=42.0, accuracy:0.2, cumul_delta=5.9834, eps=0.65354
# episode 278: cumul_reward=40.0, accuracy:0.26667, cumul_delta=4.2929, eps=0.65254
# episode 279: cumul_reward=48.0, accuracy:0.4, cumul_delta=4.3493, eps=0.65154
# episode 280: cumul_reward=35.0, accuracy:0.2, cumul_delta=4.5793, eps=0.65054
# episode 281: cumul_reward=36.0, accuracy:0.2, cumul_delta=4.3201, eps=0.64954
# episode 282: cumul_reward=32.0, accuracy:0.2, cumul_delta=3.8326, eps=0.64854
# episode 283: cumul_reward=38.0, accuracy:0.26667, cumul_delta=1.9704, eps=0.64755
# episode 284: cumul_reward=21.0, accuracy:0.13333, cumul_delta=-3.5233, eps=0.64655
# episode 285: cumul_reward=14.0, accuracy:0.066667, cumul_delta=-0.064188, eps=0.64556
# episode 286: cumul_reward=55.0, accuracy:0.4, cumul_delta=8.74, eps=0.64457
# episode 287: cumul_reward=59.0, accuracy:0.26667, cumul_delta=15.48, eps=0.64358
# episode 288: cumul_reward=47.0, accuracy:0.26667, cumul_delta=7.9776, eps=0.64259
# episode 289: cumul_reward=46.0, accuracy:0.33333, cumul_delta=5.3389, eps=0.64161
# episode 290: cumul_reward=41.0, accuracy:0.2, cumul_delta=3.9026, eps=0.64062
# episode 291: cumul_reward=47.0, accuracy:0.33333, cumul_delta=8.6903, eps=0.63964
# episode 292: cumul_reward=48.0, accuracy:0.4, cumul_delta=5.5164, eps=0.63866
# episode 293: cumul_reward=20.0, accuracy:0.066667, cumul_delta=1.9498, eps=0.63768
# episode 294: cumul_reward=37.0, accuracy:0.26667, cumul_delta=-1.9067, eps=0.6367
# episode 295: cumul_reward=29.0, accuracy:0.13333, cumul_delta=-6.8681, eps=0.63572
# episode 296: cumul_reward=43.0, accuracy:0.2, cumul_delta=10.929, eps=0.63475
# episode 297: cumul_reward=42.0, accuracy:0.26667, cumul_delta=5.243, eps=0.63377
# episode 298: cumul_reward=55.0, accuracy:0.26667, cumul_delta=10.436, eps=0.6328
# episode 299: cumul_reward=40.0, accuracy:0.33333, cumul_delta=5.5182, eps=0.63183
# episode 300: cumul_reward=43.0, accuracy:0.26667, cumul_delta=8.2106, eps=0.63086
# episode 301: cumul_reward=30.0, accuracy:0.2, cumul_delta=2.5254, eps=0.62989
# episode 302: cumul_reward=56.0, accuracy:0.26667, cumul_delta=12.903, eps=0.62893
# episode 303: cumul_reward=44.0, accuracy:0.26667, cumul_delta=7.1113, eps=0.62796
# episode 304: cumul_reward=42.0, accuracy:0.2, cumul_delta=7.0629, eps=0.627
# episode 305: cumul_reward=31.0, accuracy:0.2, cumul_delta=0.46906, eps=0.62604
# episode 306: cumul_reward=54.0, accuracy:0.4, cumul_delta=5.781, eps=0.62507
# episode 307: cumul_reward=34.0, accuracy:0.26667, cumul_delta=1.8465, eps=0.62412
# episode 308: cumul_reward=45.0, accuracy:0.26667, cumul_delta=4.4293, eps=0.62316
# episode 309: cumul_reward=47.0, accuracy:0.33333, cumul_delta=9.1385, eps=0.6222
# episode 310: cumul_reward=40.0, accuracy:0.26667, cumul_delta=2.5699, eps=0.62125
# episode 311: cumul_reward=30.0, accuracy:0.2, cumul_delta=3.1399, eps=0.62029
# episode 312: cumul_reward=47.0, accuracy:0.2, cumul_delta=8.4433, eps=0.61934
# episode 313: cumul_reward=47.0, accuracy:0.33333, cumul_delta=7.1624, eps=0.61839
# episode 314: cumul_reward=46.0, accuracy:0.26667, cumul_delta=6.1857, eps=0.61744
# episode 315: cumul_reward=38.0, accuracy:0.26667, cumul_delta=2.2503, eps=0.6165
# episode 316: cumul_reward=24.0, accuracy:0.2, cumul_delta=1.4145, eps=0.61555
# episode 317: cumul_reward=65.0, accuracy:0.46667, cumul_delta=5.5908, eps=0.61461
# episode 318: cumul_reward=22.0, accuracy:0.13333, cumul_delta=1.3465, eps=0.61366
# episode 319: cumul_reward=51.0, accuracy:0.26667, cumul_delta=14.133, eps=0.61272
# episode 320: cumul_reward=31.0, accuracy:0.2, cumul_delta=1.0389, eps=0.61178
# episode 321: cumul_reward=46.0, accuracy:0.33333, cumul_delta=4.0329, eps=0.61084
# episode 322: cumul_reward=37.0, accuracy:0.26667, cumul_delta=2.9192, eps=0.6099
# episode 323: cumul_reward=43.0, accuracy:0.33333, cumul_delta=5.9646, eps=0.60897
# episode 324: cumul_reward=41.0, accuracy:0.2, cumul_delta=3.535, eps=0.60803
# episode 325: cumul_reward=40.0, accuracy:0.2, cumul_delta=-0.15759, eps=0.6071
# episode 326: cumul_reward=25.0, accuracy:0.13333, cumul_delta=-1.4599, eps=0.60617
# episode 327: cumul_reward=51.0, accuracy:0.33333, cumul_delta=2.6912, eps=0.60524
# episode 328: cumul_reward=47.0, accuracy:0.26667, cumul_delta=5.7756, eps=0.60431
# episode 329: cumul_reward=35.0, accuracy:0.2, cumul_delta=0.67425, eps=0.60338
# episode 330: cumul_reward=26.0, accuracy:0.2, cumul_delta=-0.69617, eps=0.60246
# episode 331: cumul_reward=40.0, accuracy:0.33333, cumul_delta=2.0434, eps=0.60153
# episode 332: cumul_reward=46.0, accuracy:0.33333, cumul_delta=7.2846, eps=0.60061
# episode 333: cumul_reward=50.0, accuracy:0.26667, cumul_delta=8.4628, eps=0.59969
# episode 334: cumul_reward=31.0, accuracy:0.13333, cumul_delta=1.5238, eps=0.59877
# episode 335: cumul_reward=46.0, accuracy:0.33333, cumul_delta=7.2998, eps=0.59785
# episode 336: cumul_reward=20.0, accuracy:0.13333, cumul_delta=-2.7952, eps=0.59693
# episode 337: cumul_reward=40.0, accuracy:0.33333, cumul_delta=10.09, eps=0.59602
# episode 338: cumul_reward=43.0, accuracy:0.13333, cumul_delta=1.1291, eps=0.5951
# episode 339: cumul_reward=47.0, accuracy:0.33333, cumul_delta=5.5579, eps=0.59419
# episode 340: cumul_reward=40.0, accuracy:0.33333, cumul_delta=2.7528, eps=0.59328
# episode 341: cumul_reward=32.0, accuracy:0.26667, cumul_delta=3.4665, eps=0.59237
# episode 342: cumul_reward=38.0, accuracy:0.26667, cumul_delta=-1.9823, eps=0.59146
# episode 343: cumul_reward=45.0, accuracy:0.33333, cumul_delta=4.4288, eps=0.59055
# episode 344: cumul_reward=51.0, accuracy:0.26667, cumul_delta=4.2064, eps=0.58964
# episode 345: cumul_reward=49.0, accuracy:0.4, cumul_delta=2.5718, eps=0.58874
# episode 346: cumul_reward=57.0, accuracy:0.33333, cumul_delta=4.9459, eps=0.58784
# episode 347: cumul_reward=65.0, accuracy:0.46667, cumul_delta=7.4364, eps=0.58693
# episode 348: cumul_reward=51.0, accuracy:0.26667, cumul_delta=4.5714, eps=0.58603
# episode 349: cumul_reward=28.0, accuracy:0.2, cumul_delta=-2.0186, eps=0.58513
# episode 350: cumul_reward=65.0, accuracy:0.46667, cumul_delta=4.9584, eps=0.58424
# episode 351: cumul_reward=50.0, accuracy:0.33333, cumul_delta=10.546, eps=0.58334
# episode 352: cumul_reward=42.0, accuracy:0.33333, cumul_delta=1.0501, eps=0.58245
# episode 353: cumul_reward=47.0, accuracy:0.33333, cumul_delta=2.7944, eps=0.58155
# episode 354: cumul_reward=48.0, accuracy:0.4, cumul_delta=9.92, eps=0.58066
# episode 355: cumul_reward=51.0, accuracy:0.2, cumul_delta=11.203, eps=0.57977
# episode 356: cumul_reward=62.0, accuracy:0.4, cumul_delta=6.1794, eps=0.57888
# episode 357: cumul_reward=55.0, accuracy:0.4, cumul_delta=4.8163, eps=0.57799
# episode 358: cumul_reward=54.0, accuracy:0.26667, cumul_delta=3.769, eps=0.5771
# episode 359: cumul_reward=47.0, accuracy:0.26667, cumul_delta=5.3245, eps=0.57622
# episode 360: cumul_reward=35.0, accuracy:0.26667, cumul_delta=3.2368, eps=0.57533
# episode 361: cumul_reward=42.0, accuracy:0.2, cumul_delta=4.6775, eps=0.57445
# episode 362: cumul_reward=17.0, accuracy:0.13333, cumul_delta=2.6419, eps=0.57357
# episode 363: cumul_reward=46.0, accuracy:0.33333, cumul_delta=2.4099, eps=0.57269
# episode 364: cumul_reward=59.0, accuracy:0.33333, cumul_delta=7.2342, eps=0.57181
# episode 365: cumul_reward=34.0, accuracy:0.26667, cumul_delta=-0.33651, eps=0.57093
# episode 366: cumul_reward=53.0, accuracy:0.33333, cumul_delta=3.5129, eps=0.57006
# episode 367: cumul_reward=58.0, accuracy:0.33333, cumul_delta=4.2427, eps=0.56918
# episode 368: cumul_reward=24.0, accuracy:0.2, cumul_delta=1.0331, eps=0.56831
# episode 369: cumul_reward=45.0, accuracy:0.26667, cumul_delta=1.198, eps=0.56744
# episode 370: cumul_reward=50.0, accuracy:0.26667, cumul_delta=3.5223, eps=0.56657
# episode 371: cumul_reward=66.0, accuracy:0.4, cumul_delta=7.1834, eps=0.5657
# episode 372: cumul_reward=24.0, accuracy:0.2, cumul_delta=0.88679, eps=0.56483
# episode 373: cumul_reward=24.0, accuracy:0.2, cumul_delta=0.28856, eps=0.56396
# episode 374: cumul_reward=38.0, accuracy:0.13333, cumul_delta=5.4176, eps=0.5631
# episode 375: cumul_reward=61.0, accuracy:0.26667, cumul_delta=6.4092, eps=0.56223
# episode 376: cumul_reward=43.0, accuracy:0.2, cumul_delta=8.5247, eps=0.56137
# episode 377: cumul_reward=52.0, accuracy:0.33333, cumul_delta=3.3245, eps=0.56051
# episode 378: cumul_reward=64.0, accuracy:0.46667, cumul_delta=1.906, eps=0.55965
# episode 379: cumul_reward=38.0, accuracy:0.26667, cumul_delta=2.4985, eps=0.55879
# episode 380: cumul_reward=44.0, accuracy:0.2, cumul_delta=5.4057, eps=0.55793
# episode 381: cumul_reward=53.0, accuracy:0.33333, cumul_delta=5.2663, eps=0.55708
# episode 382: cumul_reward=21.0, accuracy:0.13333, cumul_delta=-2.0174, eps=0.55622
# episode 383: cumul_reward=50.0, accuracy:0.4, cumul_delta=3.3645, eps=0.55537
# episode 384: cumul_reward=55.0, accuracy:0.4, cumul_delta=7.0562, eps=0.55452
# episode 385: cumul_reward=58.0, accuracy:0.4, cumul_delta=2.4955, eps=0.55367
# episode 386: cumul_reward=54.0, accuracy:0.4, cumul_delta=4.9011, eps=0.55282
# episode 387: cumul_reward=34.0, accuracy:0.2, cumul_delta=0.37397, eps=0.55197
# episode 388: cumul_reward=25.0, accuracy:0.2, cumul_delta=-0.70647, eps=0.55112
# episode 389: cumul_reward=30.0, accuracy:0.2, cumul_delta=2.1887, eps=0.55028
# episode 390: cumul_reward=53.0, accuracy:0.4, cumul_delta=1.8298, eps=0.54943
# episode 391: cumul_reward=43.0, accuracy:0.33333, cumul_delta=0.47861, eps=0.54859
# episode 392: cumul_reward=45.0, accuracy:0.26667, cumul_delta=3.9702, eps=0.54775
# episode 393: cumul_reward=58.0, accuracy:0.4, cumul_delta=5.2563, eps=0.54691
# episode 394: cumul_reward=61.0, accuracy:0.4, cumul_delta=13.887, eps=0.54607
# episode 395: cumul_reward=32.0, accuracy:0.26667, cumul_delta=0.67467, eps=0.54523
# episode 396: cumul_reward=41.0, accuracy:0.33333, cumul_delta=-0.21917, eps=0.54439
# episode 397: cumul_reward=56.0, accuracy:0.33333, cumul_delta=-0.23582, eps=0.54356
# episode 398: cumul_reward=78.0, accuracy:0.46667, cumul_delta=8.1397, eps=0.54272
# episode 399: cumul_reward=29.0, accuracy:0.2, cumul_delta=-2.5222, eps=0.54189
# episode 400: cumul_reward=67.0, accuracy:0.46667, cumul_delta=7.7105, eps=0.54106
# episode 401: cumul_reward=75.0, accuracy:0.53333, cumul_delta=5.8185, eps=0.54023
# episode 402: cumul_reward=61.0, accuracy:0.46667, cumul_delta=4.7251, eps=0.5394
# episode 403: cumul_reward=34.0, accuracy:0.26667, cumul_delta=1.202, eps=0.53857
# episode 404: cumul_reward=56.0, accuracy:0.4, cumul_delta=0.0092192, eps=0.53775
# episode 405: cumul_reward=58.0, accuracy:0.4, cumul_delta=1.807, eps=0.53692
# episode 406: cumul_reward=56.0, accuracy:0.46667, cumul_delta=1.6712, eps=0.5361
# episode 407: cumul_reward=30.0, accuracy:0.066667, cumul_delta=5.0879, eps=0.53527
# episode 408: cumul_reward=54.0, accuracy:0.4, cumul_delta=4.7034, eps=0.53445
# episode 409: cumul_reward=37.0, accuracy:0.26667, cumul_delta=1.0776, eps=0.53363
# episode 410: cumul_reward=50.0, accuracy:0.26667, cumul_delta=3.3765, eps=0.53281
# episode 411: cumul_reward=73.0, accuracy:0.6, cumul_delta=5.4673, eps=0.532
# episode 412: cumul_reward=62.0, accuracy:0.4, cumul_delta=1.3984, eps=0.53118
# episode 413: cumul_reward=65.0, accuracy:0.4, cumul_delta=1.4199, eps=0.53036
# episode 414: cumul_reward=46.0, accuracy:0.33333, cumul_delta=2.8933, eps=0.52955
# episode 415: cumul_reward=58.0, accuracy:0.33333, cumul_delta=2.7759, eps=0.52874
# episode 416: cumul_reward=46.0, accuracy:0.33333, cumul_delta=-3.2882, eps=0.52793
# episode 417: cumul_reward=27.0, accuracy:0.2, cumul_delta=-1.8645, eps=0.52712
# episode 418: cumul_reward=59.0, accuracy:0.4, cumul_delta=-0.96211, eps=0.52631
# episode 419: cumul_reward=63.0, accuracy:0.46667, cumul_delta=2.269, eps=0.5255
# episode 420: cumul_reward=77.0, accuracy:0.53333, cumul_delta=11.036, eps=0.52469
# episode 421: cumul_reward=54.0, accuracy:0.4, cumul_delta=1.6876, eps=0.52389
# episode 422: cumul_reward=68.0, accuracy:0.46667, cumul_delta=5.3384, eps=0.52309
# episode 423: cumul_reward=72.0, accuracy:0.6, cumul_delta=6.2981, eps=0.52228
# episode 424: cumul_reward=56.0, accuracy:0.46667, cumul_delta=1.9232, eps=0.52148
# episode 425: cumul_reward=44.0, accuracy:0.26667, cumul_delta=-0.46968, eps=0.52068
# episode 426: cumul_reward=46.0, accuracy:0.2, cumul_delta=0.20996, eps=0.51988
# episode 427: cumul_reward=55.0, accuracy:0.4, cumul_delta=0.5223, eps=0.51908
# episode 428: cumul_reward=40.0, accuracy:0.33333, cumul_delta=1.2582, eps=0.51829
# episode 429: cumul_reward=49.0, accuracy:0.26667, cumul_delta=10.996, eps=0.51749
# episode 430: cumul_reward=77.0, accuracy:0.53333, cumul_delta=8.5075, eps=0.5167
# episode 431: cumul_reward=53.0, accuracy:0.4, cumul_delta=5.1809, eps=0.51591
# episode 432: cumul_reward=42.0, accuracy:0.33333, cumul_delta=-0.97758, eps=0.51511
# episode 433: cumul_reward=64.0, accuracy:0.53333, cumul_delta=1.7412, eps=0.51432
# episode 434: cumul_reward=28.0, accuracy:0.2, cumul_delta=1.1386, eps=0.51354
# episode 435: cumul_reward=64.0, accuracy:0.46667, cumul_delta=2.8478, eps=0.51275
# episode 436: cumul_reward=35.0, accuracy:0.26667, cumul_delta=-1.3771, eps=0.51196
# episode 437: cumul_reward=69.0, accuracy:0.46667, cumul_delta=6.7498, eps=0.51117
# episode 438: cumul_reward=79.0, accuracy:0.6, cumul_delta=9.4619, eps=0.51039
# episode 439: cumul_reward=49.0, accuracy:0.33333, cumul_delta=-0.40889, eps=0.50961
# episode 440: cumul_reward=47.0, accuracy:0.33333, cumul_delta=0.90841, eps=0.50883
# episode 441: cumul_reward=60.0, accuracy:0.4, cumul_delta=0.50469, eps=0.50804
# episode 442: cumul_reward=63.0, accuracy:0.46667, cumul_delta=3.5512, eps=0.50727
# episode 443: cumul_reward=61.0, accuracy:0.4, cumul_delta=3.5175, eps=0.50649
# episode 444: cumul_reward=53.0, accuracy:0.33333, cumul_delta=4.3193, eps=0.50571
# episode 445: cumul_reward=63.0, accuracy:0.46667, cumul_delta=3.0477, eps=0.50493
# episode 446: cumul_reward=54.0, accuracy:0.4, cumul_delta=3.8548, eps=0.50416
# episode 447: cumul_reward=53.0, accuracy:0.33333, cumul_delta=-2.8844, eps=0.50339
# episode 448: cumul_reward=65.0, accuracy:0.46667, cumul_delta=1.1553, eps=0.50261
# episode 449: cumul_reward=86.0, accuracy:0.66667, cumul_delta=5.2668, eps=0.50184
# episode 450: cumul_reward=48.0, accuracy:0.4, cumul_delta=2.0267, eps=0.50107
# episode 451: cumul_reward=80.0, accuracy:0.66667, cumul_delta=3.1466, eps=0.5003
# episode 452: cumul_reward=27.0, accuracy:0.2, cumul_delta=-1.6896, eps=0.49954
# episode 453: cumul_reward=62.0, accuracy:0.46667, cumul_delta=0.34015, eps=0.49877
# episode 454: cumul_reward=64.0, accuracy:0.46667, cumul_delta=-1.908, eps=0.498
# episode 455: cumul_reward=44.0, accuracy:0.2, cumul_delta=2.6278, eps=0.49724
# episode 456: cumul_reward=63.0, accuracy:0.46667, cumul_delta=3.4853, eps=0.49648
# episode 457: cumul_reward=56.0, accuracy:0.46667, cumul_delta=2.2569, eps=0.49571
# episode 458: cumul_reward=35.0, accuracy:0.2, cumul_delta=-0.98874, eps=0.49495
# episode 459: cumul_reward=43.0, accuracy:0.26667, cumul_delta=-0.092789, eps=0.49419
# episode 460: cumul_reward=40.0, accuracy:0.26667, cumul_delta=-4.4247, eps=0.49344
# episode 461: cumul_reward=69.0, accuracy:0.46667, cumul_delta=6.29, eps=0.49268
# episode 462: cumul_reward=85.0, accuracy:0.6, cumul_delta=4.9969, eps=0.49192
# episode 463: cumul_reward=64.0, accuracy:0.4, cumul_delta=4.0374, eps=0.49117
# episode 464: cumul_reward=32.0, accuracy:0.26667, cumul_delta=0.82284, eps=0.49041
# episode 465: cumul_reward=54.0, accuracy:0.4, cumul_delta=2.2595, eps=0.48966
# episode 466: cumul_reward=47.0, accuracy:0.33333, cumul_delta=2.3551, eps=0.48891
# episode 467: cumul_reward=47.0, accuracy:0.33333, cumul_delta=4.0295, eps=0.48816
# episode 468: cumul_reward=54.0, accuracy:0.4, cumul_delta=1.7323, eps=0.48741
# episode 469: cumul_reward=46.0, accuracy:0.33333, cumul_delta=-1.496, eps=0.48666
# episode 470: cumul_reward=47.0, accuracy:0.26667, cumul_delta=6.6943, eps=0.48592
# episode 471: cumul_reward=54.0, accuracy:0.4, cumul_delta=2.7433, eps=0.48517
# episode 472: cumul_reward=56.0, accuracy:0.46667, cumul_delta=1.8355, eps=0.48443
# episode 473: cumul_reward=81.0, accuracy:0.6, cumul_delta=2.4972, eps=0.48368
# episode 474: cumul_reward=56.0, accuracy:0.46667, cumul_delta=1.8073, eps=0.48294
# episode 475: cumul_reward=45.0, accuracy:0.26667, cumul_delta=-4.126, eps=0.4822
# episode 476: cumul_reward=38.0, accuracy:0.26667, cumul_delta=0.87533, eps=0.48146
# episode 477: cumul_reward=64.0, accuracy:0.53333, cumul_delta=2.9894, eps=0.48072
# episode 478: cumul_reward=88.0, accuracy:0.73333, cumul_delta=6.1098, eps=0.47998
# episode 479: cumul_reward=62.0, accuracy:0.46667, cumul_delta=4.0958, eps=0.47925
# episode 480: cumul_reward=53.0, accuracy:0.4, cumul_delta=-0.20447, eps=0.47851
# episode 481: cumul_reward=62.0, accuracy:0.46667, cumul_delta=1.814, eps=0.47778
# episode 482: cumul_reward=33.0, accuracy:0.2, cumul_delta=-1.6179, eps=0.47705
# episode 483: cumul_reward=38.0, accuracy:0.2, cumul_delta=6.3719, eps=0.47631
# episode 484: cumul_reward=48.0, accuracy:0.4, cumul_delta=2.7999, eps=0.47558
# episode 485: cumul_reward=53.0, accuracy:0.33333, cumul_delta=7.8964, eps=0.47485
# episode 486: cumul_reward=61.0, accuracy:0.4, cumul_delta=6.7813, eps=0.47412
# episode 487: cumul_reward=85.0, accuracy:0.6, cumul_delta=6.9096, eps=0.4734
# episode 488: cumul_reward=34.0, accuracy:0.2, cumul_delta=-1.4444, eps=0.47267
# episode 489: cumul_reward=89.0, accuracy:0.66667, cumul_delta=1.3474, eps=0.47194
# episode 490: cumul_reward=61.0, accuracy:0.4, cumul_delta=6.117, eps=0.47122
# episode 491: cumul_reward=41.0, accuracy:0.33333, cumul_delta=0.72065, eps=0.4705
# episode 492: cumul_reward=32.0, accuracy:0.2, cumul_delta=-1.3211, eps=0.46978
# episode 493: cumul_reward=69.0, accuracy:0.46667, cumul_delta=4.6079, eps=0.46905
# episode 494: cumul_reward=24.0, accuracy:0.2, cumul_delta=0.8854, eps=0.46834
# episode 495: cumul_reward=69.0, accuracy:0.46667, cumul_delta=5.1674, eps=0.46762
# episode 496: cumul_reward=74.0, accuracy:0.53333, cumul_delta=-0.14274, eps=0.4669
# episode 497: cumul_reward=73.0, accuracy:0.53333, cumul_delta=2.3995, eps=0.46618
# episode 498: cumul_reward=80.0, accuracy:0.66667, cumul_delta=2.978, eps=0.46547
# episode 499: cumul_reward=96.0, accuracy:0.8, cumul_delta=6.7748, eps=0.46475
# episode 500: cumul_reward=72.0, accuracy:0.6, cumul_delta=1.8886, eps=0.46404
# episode 501: cumul_reward=51.0, accuracy:0.4, cumul_delta=-1.6813, eps=0.46333
# episode 502: cumul_reward=57.0, accuracy:0.46667, cumul_delta=0.83885, eps=0.46262
# episode 503: cumul_reward=80.0, accuracy:0.66667, cumul_delta=1.4547, eps=0.46191
# episode 504: cumul_reward=57.0, accuracy:0.46667, cumul_delta=-0.023507, eps=0.4612
# episode 505: cumul_reward=48.0, accuracy:0.26667, cumul_delta=0.6492, eps=0.46049
# episode 506: cumul_reward=70.0, accuracy:0.53333, cumul_delta=2.1941, eps=0.45978
# episode 507: cumul_reward=52.0, accuracy:0.4, cumul_delta=-1.6468, eps=0.45908
# episode 508: cumul_reward=57.0, accuracy:0.4, cumul_delta=0.40661, eps=0.45837
# episode 509: cumul_reward=58.0, accuracy:0.33333, cumul_delta=6.3879, eps=0.45767
# episode 510: cumul_reward=96.0, accuracy:0.8, cumul_delta=3.3257, eps=0.45697
# episode 511: cumul_reward=70.0, accuracy:0.53333, cumul_delta=1.0208, eps=0.45627
# episode 512: cumul_reward=56.0, accuracy:0.46667, cumul_delta=4.5562, eps=0.45557
# episode 513: cumul_reward=64.0, accuracy:0.53333, cumul_delta=1.4679, eps=0.45487
# episode 514: cumul_reward=81.0, accuracy:0.6, cumul_delta=0.97834, eps=0.45417
# episode 515: cumul_reward=49.0, accuracy:0.26667, cumul_delta=-0.9915, eps=0.45347
# episode 516: cumul_reward=78.0, accuracy:0.6, cumul_delta=4.8202, eps=0.45278
# episode 517: cumul_reward=66.0, accuracy:0.46667, cumul_delta=0.97408, eps=0.45208
# episode 518: cumul_reward=64.0, accuracy:0.53333, cumul_delta=1.2772, eps=0.45139
# episode 519: cumul_reward=78.0, accuracy:0.6, cumul_delta=7.2636, eps=0.4507
# episode 520: cumul_reward=78.0, accuracy:0.6, cumul_delta=5.7919, eps=0.45001
# episode 521: cumul_reward=57.0, accuracy:0.46667, cumul_delta=-0.079043, eps=0.44931
# episode 522: cumul_reward=75.0, accuracy:0.53333, cumul_delta=0.019277, eps=0.44863
# episode 523: cumul_reward=86.0, accuracy:0.66667, cumul_delta=3.8231, eps=0.44794
# episode 524: cumul_reward=86.0, accuracy:0.66667, cumul_delta=4.8968, eps=0.44725
# episode 525: cumul_reward=66.0, accuracy:0.46667, cumul_delta=-0.63059, eps=0.44656
# episode 526: cumul_reward=74.0, accuracy:0.53333, cumul_delta=1.9653, eps=0.44588
# episode 527: cumul_reward=79.0, accuracy:0.6, cumul_delta=2.0149, eps=0.44519
# episode 528: cumul_reward=84.0, accuracy:0.6, cumul_delta=6.5151, eps=0.44451
# episode 529: cumul_reward=56.0, accuracy:0.46667, cumul_delta=1.0215, eps=0.44383
# episode 530: cumul_reward=70.0, accuracy:0.53333, cumul_delta=4.9572, eps=0.44315
# episode 531: cumul_reward=86.0, accuracy:0.66667, cumul_delta=3.7103, eps=0.44247
# episode 532: cumul_reward=66.0, accuracy:0.46667, cumul_delta=-1.0412, eps=0.44179
# episode 533: cumul_reward=36.0, accuracy:0.26667, cumul_delta=-3.3867, eps=0.44111
# episode 534: cumul_reward=78.0, accuracy:0.6, cumul_delta=2.3707, eps=0.44043
# episode 535: cumul_reward=56.0, accuracy:0.46667, cumul_delta=1.7623, eps=0.43976
# episode 536: cumul_reward=48.0, accuracy:0.33333, cumul_delta=-1.0435, eps=0.43908
# episode 537: cumul_reward=50.0, accuracy:0.4, cumul_delta=-0.82781, eps=0.43841
# episode 538: cumul_reward=80.0, accuracy:0.66667, cumul_delta=1.8008, eps=0.43774
# episode 539: cumul_reward=47.0, accuracy:0.33333, cumul_delta=1.0198, eps=0.43707
# episode 540: cumul_reward=72.0, accuracy:0.6, cumul_delta=1.2432, eps=0.4364
# episode 541: cumul_reward=55.0, accuracy:0.4, cumul_delta=0.75839, eps=0.43573
# episode 542: cumul_reward=69.0, accuracy:0.46667, cumul_delta=-3.4673, eps=0.43506
# episode 543: cumul_reward=81.0, accuracy:0.6, cumul_delta=0.091949, eps=0.43439
# episode 544: cumul_reward=64.0, accuracy:0.53333, cumul_delta=1.7936, eps=0.43372
# episode 545: cumul_reward=68.0, accuracy:0.53333, cumul_delta=-1.0568, eps=0.43306
# episode 546: cumul_reward=54.0, accuracy:0.4, cumul_delta=0.77305, eps=0.43239
# episode 547: cumul_reward=64.0, accuracy:0.46667, cumul_delta=0.69322, eps=0.43173
# episode 548: cumul_reward=59.0, accuracy:0.46667, cumul_delta=-1.3404, eps=0.43107
# episode 549: cumul_reward=80.0, accuracy:0.66667, cumul_delta=1.7419, eps=0.43041
# episode 550: cumul_reward=73.0, accuracy:0.6, cumul_delta=0.39498, eps=0.42975
# episode 551: cumul_reward=46.0, accuracy:0.33333, cumul_delta=0.97116, eps=0.42909
# episode 552: cumul_reward=40.0, accuracy:0.26667, cumul_delta=-0.026231, eps=0.42843
# episode 553: cumul_reward=62.0, accuracy:0.46667, cumul_delta=1.5927, eps=0.42777
# episode 554: cumul_reward=62.0, accuracy:0.46667, cumul_delta=1.8307, eps=0.42711
# episode 555: cumul_reward=86.0, accuracy:0.66667, cumul_delta=2.32, eps=0.42646
# episode 556: cumul_reward=72.0, accuracy:0.6, cumul_delta=0.78993, eps=0.4258
# episode 557: cumul_reward=87.0, accuracy:0.66667, cumul_delta=2.0815, eps=0.42515
# episode 558: cumul_reward=64.0, accuracy:0.53333, cumul_delta=1.1725, eps=0.4245
# episode 559: cumul_reward=82.0, accuracy:0.66667, cumul_delta=-0.70676, eps=0.42385
# episode 560: cumul_reward=51.0, accuracy:0.4, cumul_delta=-1.7834, eps=0.4232
# episode 561: cumul_reward=57.0, accuracy:0.46667, cumul_delta=0.66925, eps=0.42255
# episode 562: cumul_reward=65.0, accuracy:0.53333, cumul_delta=0.032856, eps=0.4219
# episode 563: cumul_reward=64.0, accuracy:0.53333, cumul_delta=1.2523, eps=0.42125
# episode 564: cumul_reward=80.0, accuracy:0.66667, cumul_delta=1.0856, eps=0.42061
# episode 565: cumul_reward=64.0, accuracy:0.53333, cumul_delta=0.65254, eps=0.41996
# episode 566: cumul_reward=81.0, accuracy:0.6, cumul_delta=1.2667, eps=0.41932
# episode 567: cumul_reward=56.0, accuracy:0.46667, cumul_delta=0.49456, eps=0.41867
# episode 568: cumul_reward=63.0, accuracy:0.46667, cumul_delta=1.0739, eps=0.41803
# episode 569: cumul_reward=73.0, accuracy:0.53333, cumul_delta=0.65515, eps=0.41739
# episode 570: cumul_reward=72.0, accuracy:0.6, cumul_delta=1.1698, eps=0.41675
# episode 571: cumul_reward=71.0, accuracy:0.53333, cumul_delta=1.3076, eps=0.41611
# episode 572: cumul_reward=63.0, accuracy:0.46667, cumul_delta=1.4646, eps=0.41547
# episode 573: cumul_reward=58.0, accuracy:0.46667, cumul_delta=-1.0875, eps=0.41483
# episode 574: cumul_reward=79.0, accuracy:0.6, cumul_delta=1.3706, eps=0.4142
# episode 575: cumul_reward=63.0, accuracy:0.46667, cumul_delta=1.8705, eps=0.41356
# episode 576: cumul_reward=56.0, accuracy:0.46667, cumul_delta=0.82069, eps=0.41293
# episode 577: cumul_reward=103.0, accuracy:0.8, cumul_delta=2.5261, eps=0.41229
# episode 578: cumul_reward=52.0, accuracy:0.4, cumul_delta=-1.8172, eps=0.41166
# episode 579: cumul_reward=72.0, accuracy:0.6, cumul_delta=0.63122, eps=0.41103
# episode 580: cumul_reward=43.0, accuracy:0.33333, cumul_delta=-1.918, eps=0.4104
# episode 581: cumul_reward=63.0, accuracy:0.46667, cumul_delta=2.0461, eps=0.40977
# episode 582: cumul_reward=63.0, accuracy:0.46667, cumul_delta=0.58319, eps=0.40914
# episode 583: cumul_reward=64.0, accuracy:0.53333, cumul_delta=1.1258, eps=0.40851
# episode 584: cumul_reward=59.0, accuracy:0.46667, cumul_delta=-1.2281, eps=0.40788
# episode 585: cumul_reward=87.0, accuracy:0.66667, cumul_delta=2.0304, eps=0.40726
# episode 586: cumul_reward=83.0, accuracy:0.66667, cumul_delta=-0.49348, eps=0.40663
# episode 587: cumul_reward=56.0, accuracy:0.33333, cumul_delta=-0.20255, eps=0.40601
# episode 588: cumul_reward=72.0, accuracy:0.6, cumul_delta=1.2928, eps=0.40539
# episode 589: cumul_reward=73.0, accuracy:0.53333, cumul_delta=0.043329, eps=0.40476
# episode 590: cumul_reward=43.0, accuracy:0.33333, cumul_delta=-1.9519, eps=0.40414
# episode 591: cumul_reward=95.0, accuracy:0.73333, cumul_delta=2.0766, eps=0.40352
# episode 592: cumul_reward=63.0, accuracy:0.46667, cumul_delta=1.4811, eps=0.4029
# episode 593: cumul_reward=71.0, accuracy:0.53333, cumul_delta=1.5139, eps=0.40229
# episode 594: cumul_reward=71.0, accuracy:0.53333, cumul_delta=1.3179, eps=0.40167
# episode 595: cumul_reward=24.0, accuracy:0.2, cumul_delta=0.094904, eps=0.40105
# ...
# episode 1038: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.7854, eps=0.20313
# episode 1039: cumul_reward=90.0, accuracy:0.73333, cumul_delta=-0.67967, eps=0.20282
# episode 1040: cumul_reward=106.0, accuracy:0.86667, cumul_delta=-0.72713, eps=0.2025
# episode 1041: cumul_reward=66.0, accuracy:0.53333, cumul_delta=-1.2346, eps=0.20219
# episode 1042: cumul_reward=112.0, accuracy:0.93333, cumul_delta=1.1763, eps=0.20188
# episode 1043: cumul_reward=96.0, accuracy:0.8, cumul_delta=1.4256, eps=0.20157
# episode 1044: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.88497, eps=0.20126
# episode 1045: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.48242, eps=0.20096
# episode 1046: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.44602, eps=0.20065
# episode 1047: cumul_reward=72.0, accuracy:0.6, cumul_delta=0.45001, eps=0.20034
# episode 1048: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.46482, eps=0.20003
# episode 1049: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.70136, eps=0.19973
# episode 1050: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.69966, eps=0.19942
# episode 1051: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.51161, eps=0.19911
# episode 1052: cumul_reward=85.0, accuracy:0.66667, cumul_delta=-1.8366, eps=0.19881
# episode 1053: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.41714, eps=0.1985
# episode 1054: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.85671, eps=0.1982
# episode 1055: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.36171, eps=0.19789
# episode 1056: cumul_reward=82.0, accuracy:0.6, cumul_delta=5.0327, eps=0.19759
# episode 1057: cumul_reward=87.0, accuracy:0.66667, cumul_delta=2.1822, eps=0.19729
# episode 1058: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.45941, eps=0.19698
# episode 1059: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.28417, eps=0.19668
# episode 1060: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.31048, eps=0.19638
# episode 1061: cumul_reward=80.0, accuracy:0.66667, cumul_delta=0.59145, eps=0.19608
# episode 1062: cumul_reward=72.0, accuracy:0.6, cumul_delta=0.48821, eps=0.19578
# episode 1063: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.28338, eps=0.19548
# episode 1064: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.15453, eps=0.19518
# episode 1065: cumul_reward=80.0, accuracy:0.66667, cumul_delta=0.33488, eps=0.19488
# episode 1066: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.10805, eps=0.19458
# episode 1067: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.063268, eps=0.19428
# episode 1068: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.11105, eps=0.19398
# episode 1069: cumul_reward=85.0, accuracy:0.66667, cumul_delta=1.7769, eps=0.19368
# episode 1070: cumul_reward=80.0, accuracy:0.66667, cumul_delta=0.48157, eps=0.19339
# episode 1071: cumul_reward=80.0, accuracy:0.66667, cumul_delta=0.32265, eps=0.19309
# episode 1072: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.24632, eps=0.19279
# episode 1073: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.38577, eps=0.1925
# episode 1074: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.061786, eps=0.1922
# episode 1075: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.14293, eps=0.19191
# episode 1076: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.059786, eps=0.19161
# episode 1077: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.13675, eps=0.19132
# episode 1078: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.1131, eps=0.19103
# episode 1079: cumul_reward=64.0, accuracy:0.53333, cumul_delta=0.17714, eps=0.19073
# episode 1080: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.040874, eps=0.19044
# episode 1081: cumul_reward=99.0, accuracy:0.8, cumul_delta=-1.9128, eps=0.19015
# episode 1082: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.41906, eps=0.18986
# episode 1083: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.29783, eps=0.18957
# episode 1084: cumul_reward=80.0, accuracy:0.66667, cumul_delta=0.55294, eps=0.18927
# episode 1085: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.26068, eps=0.18898
# episode 1086: cumul_reward=120.0, accuracy:1.0, cumul_delta=0.25981, eps=0.18869
# episode 1087: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.041313, eps=0.1884
# episode 1088: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.19002, eps=0.18812
# episode 1089: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.18415, eps=0.18783
# episode 1090: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.014873, eps=0.18754
# episode 1091: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.03503, eps=0.18725
# episode 1092: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.31154, eps=0.18696
# episode 1093: cumul_reward=65.0, accuracy:0.33333, cumul_delta=11.075, eps=0.18668
# episode 1094: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.2927, eps=0.18639
# episode 1095: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.14521, eps=0.1861
# episode 1096: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.45317, eps=0.18582
# episode 1097: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.024461, eps=0.18553
# episode 1098: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.21279, eps=0.18525
# episode 1099: cumul_reward=120.0, accuracy:1.0, cumul_delta=0.070753, eps=0.18496
# episode 1100: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.01216, eps=0.18468
# episode 1101: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.051484, eps=0.1844
# episode 1102: cumul_reward=84.0, accuracy:0.66667, cumul_delta=-2.3699, eps=0.18411
# episode 1103: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.41051, eps=0.18383
# episode 1104: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.21369, eps=0.18355
# episode 1105: cumul_reward=93.0, accuracy:0.73333, cumul_delta=-1.8794, eps=0.18327
# episode 1106: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.26834, eps=0.18299
# episode 1107: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.35367, eps=0.18271
# episode 1108: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.22717, eps=0.18243
# episode 1109: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.49177, eps=0.18215
# episode 1110: cumul_reward=90.0, accuracy:0.73333, cumul_delta=-1.6291, eps=0.18187
# episode 1111: cumul_reward=98.0, accuracy:0.8, cumul_delta=-1.4874, eps=0.18159
# episode 1112: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.67604, eps=0.18131
# episode 1113: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.83401, eps=0.18103
# episode 1114: cumul_reward=80.0, accuracy:0.66667, cumul_delta=0.1449, eps=0.18075
# episode 1115: cumul_reward=120.0, accuracy:1.0, cumul_delta=0.70855, eps=0.18048
# episode 1116: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.1215, eps=0.1802
# episode 1117: cumul_reward=77.0, accuracy:0.6, cumul_delta=-1.5366, eps=0.17992
# episode 1118: cumul_reward=72.0, accuracy:0.53333, cumul_delta=3.2038, eps=0.17965
# episode 1119: cumul_reward=104.0, accuracy:0.8, cumul_delta=-3.8957, eps=0.17937
# episode 1120: cumul_reward=104.0, accuracy:0.86667, cumul_delta=1.5197, eps=0.1791
# episode 1121: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.54142, eps=0.17882
# episode 1122: cumul_reward=104.0, accuracy:0.86667, cumul_delta=1.0717, eps=0.17855
# episode 1123: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.98708, eps=0.17827
# episode 1124: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.75792, eps=0.178
# episode 1125: cumul_reward=120.0, accuracy:1.0, cumul_delta=0.72647, eps=0.17773
# episode 1126: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.54673, eps=0.17745
# episode 1127: cumul_reward=120.0, accuracy:1.0, cumul_delta=0.54771, eps=0.17718
# episode 1128: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.33648, eps=0.17691
# episode 1129: cumul_reward=120.0, accuracy:1.0, cumul_delta=0.41513, eps=0.17664
# episode 1130: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.36754, eps=0.17637
# episode 1131: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.56971, eps=0.1761
# episode 1132: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.21691, eps=0.17583
# episode 1133: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.24419, eps=0.17556
# episode 1134: cumul_reward=98.0, accuracy:0.8, cumul_delta=-1.6608, eps=0.17529
# episode 1135: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.68106, eps=0.17502
# episode 1136: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.65067, eps=0.17475
# episode 1137: cumul_reward=76.0, accuracy:0.53333, cumul_delta=1.3491, eps=0.17448
# episode 1138: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.48148, eps=0.17421
# episode 1139: cumul_reward=57.0, accuracy:0.4, cumul_delta=-6.9945, eps=0.17395
# episode 1140: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.79158, eps=0.17368
# episode 1141: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.70663, eps=0.17341
# episode 1142: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.62047, eps=0.17315
# episode 1143: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.26834, eps=0.17288
# episode 1144: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.5876, eps=0.17262
# episode 1145: cumul_reward=96.0, accuracy:0.73333, cumul_delta=0.23027, eps=0.17235
# episode 1146: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.62674, eps=0.17209
# episode 1147: cumul_reward=82.0, accuracy:0.66667, cumul_delta=-0.71996, eps=0.17182
# episode 1148: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.54073, eps=0.17156
# episode 1149: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.56947, eps=0.17129
# episode 1150: cumul_reward=75.0, accuracy:0.6, cumul_delta=-1.452, eps=0.17103
# episode 1151: cumul_reward=75.0, accuracy:0.6, cumul_delta=-1.5026, eps=0.17077
# episode 1152: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.9142, eps=0.17051
# episode 1153: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.59453, eps=0.17025
# episode 1154: cumul_reward=91.0, accuracy:0.73333, cumul_delta=-1.6503, eps=0.16998
# episode 1155: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.85044, eps=0.16972
# episode 1156: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.36366, eps=0.16946
# episode 1157: cumul_reward=120.0, accuracy:1.0, cumul_delta=0.59631, eps=0.1692
# episode 1158: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.79669, eps=0.16894
# episode 1159: cumul_reward=91.0, accuracy:0.6, cumul_delta=5.2043, eps=0.16868
# episode 1160: cumul_reward=90.0, accuracy:0.73333, cumul_delta=-1.1687, eps=0.16843
# episode 1161: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.65051, eps=0.16817
# episode 1162: cumul_reward=72.0, accuracy:0.6, cumul_delta=0.75207, eps=0.16791
# episode 1163: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.70814, eps=0.16765
# episode 1164: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.60192, eps=0.16739
# episode 1165: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.63959, eps=0.16714
# episode 1166: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.51266, eps=0.16688
# episode 1167: cumul_reward=120.0, accuracy:1.0, cumul_delta=0.39646, eps=0.16663
# episode 1168: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.51487, eps=0.16637
# episode 1169: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.15535, eps=0.16611
# episode 1170: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.2969, eps=0.16586
# episode 1171: cumul_reward=95.0, accuracy:0.73333, cumul_delta=-4.4522, eps=0.1656
# episode 1172: cumul_reward=104.0, accuracy:0.86667, cumul_delta=1.2755, eps=0.16535
# episode 1173: cumul_reward=101.0, accuracy:0.8, cumul_delta=-1.425, eps=0.1651
# episode 1174: cumul_reward=96.0, accuracy:0.8, cumul_delta=1.0915, eps=0.16484
# episode 1175: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.90284, eps=0.16459
# episode 1176: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.84878, eps=0.16434
# episode 1177: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.52828, eps=0.16409
# episode 1178: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.55978, eps=0.16383
# episode 1179: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.62661, eps=0.16358
# episode 1180: cumul_reward=120.0, accuracy:1.0, cumul_delta=0.47651, eps=0.16333
# episode 1181: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.38958, eps=0.16308
# episode 1182: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.3788, eps=0.16283
# episode 1183: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.31129, eps=0.16258
# episode 1184: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.30203, eps=0.16233
# episode 1185: cumul_reward=97.0, accuracy:0.8, cumul_delta=-0.81449, eps=0.16208
# episode 1186: cumul_reward=106.0, accuracy:0.86667, cumul_delta=-1.4911, eps=0.16183
# episode 1187: cumul_reward=84.0, accuracy:0.66667, cumul_delta=-2.0225, eps=0.16159
# episode 1188: cumul_reward=91.0, accuracy:0.73333, cumul_delta=-1.5559, eps=0.16134
# episode 1189: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.86946, eps=0.16109
# episode 1190: cumul_reward=112.0, accuracy:0.93333, cumul_delta=1.0766, eps=0.16084
# episode 1191: cumul_reward=120.0, accuracy:1.0, cumul_delta=0.90967, eps=0.1606
# episode 1192: cumul_reward=83.0, accuracy:0.66667, cumul_delta=-1.9605, eps=0.16035
# episode 1193: cumul_reward=96.0, accuracy:0.8, cumul_delta=1.0111, eps=0.1601
# episode 1194: cumul_reward=77.0, accuracy:0.6, cumul_delta=1.8419, eps=0.15986
# episode 1195: cumul_reward=120.0, accuracy:1.0, cumul_delta=0.86349, eps=0.15961
# episode 1196: cumul_reward=100.0, accuracy:0.8, cumul_delta=-1.6676, eps=0.15937
# episode 1197: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.81958, eps=0.15912
# episode 1198: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.7646, eps=0.15888
# episode 1199: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.94638, eps=0.15864
# episode 1200: cumul_reward=120.0, accuracy:1.0, cumul_delta=0.67113, eps=0.15839
# episode 1201: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.22185, eps=0.15815
# episode 1202: cumul_reward=91.0, accuracy:0.73333, cumul_delta=-1.6676, eps=0.15791
# episode 1203: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.88431, eps=0.15766
# episode 1204: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.67352, eps=0.15742
# episode 1205: cumul_reward=79.0, accuracy:0.6, cumul_delta=0.66095, eps=0.15718
# episode 1206: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.64414, eps=0.15694
# episode 1207: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.93946, eps=0.1567
# episode 1208: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.63169, eps=0.15646
# episode 1209: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.58651, eps=0.15622
# episode 1210: cumul_reward=80.0, accuracy:0.66667, cumul_delta=0.37844, eps=0.15598
# episode 1211: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.43073, eps=0.15574
# episode 1212: cumul_reward=99.0, accuracy:0.8, cumul_delta=-1.5158, eps=0.1555
# episode 1213: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.7016, eps=0.15526
# episode 1214: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.37281, eps=0.15502
# episode 1215: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.49053, eps=0.15479
# episode 1216: cumul_reward=98.0, accuracy:0.8, cumul_delta=-1.3212, eps=0.15455
# episode 1217: cumul_reward=82.0, accuracy:0.66667, cumul_delta=-1.5116, eps=0.15431
# episode 1218: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.52496, eps=0.15407
# episode 1219: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.71586, eps=0.15384
# episode 1220: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.8767, eps=0.1536
# episode 1221: cumul_reward=96.0, accuracy:0.8, cumul_delta=0.49239, eps=0.15337
# episode 1222: cumul_reward=112.0, accuracy:0.93333, cumul_delta=0.60155, eps=0.15313
# episode 1223: cumul_reward=83.0, accuracy:0.66667, cumul_delta=-1.9316, eps=0.1529
# episode 1224: cumul_reward=107.0, accuracy:0.86667, cumul_delta=-1.4763, eps=0.15266
# episode 1225: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.88738, eps=0.15243
# episode 1226: cumul_reward=104.0, accuracy:0.86667, cumul_delta=0.63301, eps=0.15219
# episode 1227: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.50196, eps=0.15196
# episode 1228: cumul_reward=89.0, accuracy:0.73333, cumul_delta=-0.90725, eps=0.15173
# episode 1229: cumul_reward=88.0, accuracy:0.73333, cumul_delta=0.67493, eps=0.15149
# episode 1230: cumul_reward=99.0, accuracy:0.8, cumul_delta=-1.6015, eps=0.15126
