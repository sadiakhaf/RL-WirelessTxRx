# %%
#   ____                            _____     _____                   __          __        _        _                 
#  / __ \                     /\   |_   _|   / ____|                  \ \        / /       | |      | |                
# | |  | |_ __   ___ _ __    /  \    | |    | |  __ _   _ _ __ ___     \ \  /\  / /__  _ __| | _____| |__   ___  _ __  
# | |  | | '_ \ / _ \ '_ \  / /\ \   | |    | | |_ | | | | '_ ` _ \     \ \/  \/ / _ \| '__| |/ / __| '_ \ / _ \| '_ \ 
# | |__| | |_) |  __/ | | |/ ____ \ _| |_   | |__| | |_| | | | | | |     \  /\  / (_) | |  |   <\__ \ | | | (_) | |_) |
#  \____/| .__/ \___|_| |_/_/    \_\_____|   \_____|\__, |_| |_| |_|      \/  \/ \___/|_|  |_|\_\___/_| |_|\___/| .__/ 
#        | |                                         __/ |                                                      | |    
#        |_|                                        |___/                                                       |_|

# %%
# !pip install gym
#!pip install torch==1.5.0+cpu -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (0.17.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym) (1.18.5)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)

# %%
import json
from itertools import count

import gym
from gym import spaces

import torch
from torch import Tensor

import random
from random import randint

from typing import Dict, List, Optional, Callable, Any, Tuple, Union, Type

import pathlib
import collections

# %% [markdown]
# ![alt text](https://www.taitradioacademy.com/wp-content/uploads/2014/10/Image-25-800x450.png)

# %%
# <START> ------ CODE BLOCK 1
# <END> -------- CODE BLOCK 1

class TDMAGym(gym.Env):
  NO_ACTION = 0  # no action on sub-frame
  UPLINK_ACTION = 1  # use sub-frame as up-link role (user [Tx] --> base-station [Rx])
  DOWNLINK_ACTION = 2  # use sub-frame as down-link role (base-station [Tx] --> user [Rx])

  def __init__(self, n_freqs: int, n_subframes: int, horizon: int):
    super(TDMAGym, self).__init__()  # initialize gym.Env base class
    if n_subframes % 2 != 0:  # since a link is separated in up and down link we need even number of subframe
      raise ValueError('n_subframes must be an even number')

    # action space dict includes frequency and sub-frames action
    self.action_space = spaces.Dict(
      {
        'freq': spaces.Discrete(n_freqs),  # frequency used
        'subframes': spaces.MultiDiscrete([3] * n_subframes)  # sub-frames role actions
      }
    )
    # observation space dict includes the time-step, last action and its sub-frames successes
    self.observation_space = spaces.Dict(
      {
        'time_step': spaces.Discrete(horizon + 1),  # include terminal state
        'last_a': self.action_space,  # last action done by the agent
        'last_success': spaces.MultiDiscrete([2] * n_subframes)  # what sub-frames received an acknowledgement
      }
    )
    self.reward_range = 0.0, float(n_subframes)  # action-reward range between 0 and the number of sub-frames

    self.freq_sf: Dict[int, Tuple[int, Tensor]] = dict()  # frequency and sub-frames role assignation w.r.t. to time-step
    for t in range(horizon):  # do not include terminal state
      freq = randint(0, n_freqs - 1)  # choose random frequency to do Tx
      ul_subframes = random.sample(range(n_subframes), k=n_subframes // 2)  # choose which sub-frames will be used as up-link
      dl_subframes = [
        sf for sf in range(n_subframes) if sf not in ul_subframes  # choose the rest of sub-frames as down-link
      ]
      sf = torch.zeros(n_subframes, dtype=torch.int)  # initialize sub-frames roles
      sf.fill_(self.NO_ACTION)  # set all sub-frames to no-action
      sf[ul_subframes] = self.UPLINK_ACTION  # set all up-link sub-frames to uplink-action value
      sf[dl_subframes] = self.DOWNLINK_ACTION  # set all down-link sub-frames to downlink-action value
      self.freq_sf[t] = freq, sf  # set sub-frames role w.r.t. time-step

    self.hor = horizon  # gym horizon to know when we are DONE
    self.t = 0  # initial time-step / observation

  def step(self, action: Dict) -> Tuple[  # step function to interact with the gym
    Dict, float, bool, Dict[str, Any]
  ]:
    if self.t >= self.hor:  # terminal state reached
      return collections.OrderedDict(), 0.0, True, {}  # return empty interaction

    assert self.action_space.contains(action)  # action is within gym action-space assertion

    freq, sf = self.freq_sf[self.t]  # get frequency and sub-frames role for current time-step
    a_freq, a_sf = action['freq'], action['subframes']  # fetch frequency and sub-frames role from the action

    if freq == a_freq:  # gym and action frequency are the same
      sf_success = [
        int(gym_sf == act_sf) for gym_sf, act_sf in zip(sf, a_sf)  # action sub-frames role is correct w.r.t. the gym's sub-frames
      ]
    else:
      sf_success = [0] * len(self.action_space['subframes'].nvec)  # wrong frequency, no sub-frames successes

    self.t += 1  # increment our time-step / observation
    o = collections.OrderedDict(
      time_step=self.t, last_a=action,   # observation that we will return, time-step, last action
      last_success=[int(sf_s) for sf_s in sf_success]  # and successes from last action
    )
    r = float(sum(sf_success))  # sum successes to give the reward
    return o, r, False, {}   # gyms always returns <obs, reward, if terminal obs reached, debug/info dictionary>

  def reset(self) -> Dict:  # reset our gym for a new episode
    self.t = 0  # initial time-step
    obs = collections.OrderedDict(time_step=self.t)  # initial observation
    return obs

  def render(self, mode='human'):  # gym visual rendering (e.g. text, image, plot, 3D frame, etc.)
    if self.t < self.hor:  # terminal gym state not reached
      # show current time-step, frequency and sub-frames role
      print(
        'rendering={{time_step={time_step}, freq={freq}, sf={sf}}}'
          .format(
          time_step=self.t, freq=self.freq_sf[self.t][0],
          sf=str(self.freq_sf[self.t][1].tolist()).replace(' ', '')
        )
      )
    else:  # terminal gym state reached and out of horizon
      print('rendering={terminal state reached, out of horizon}')

# %%
def build_epsilon_fn(steps: int) -> Callable[[int], float]:  # epsilon function builder
  log_epsilon_space = torch.logspace(1.0, -1.0, steps=steps, base=10.0) / 10.0  # epsilon log-space {1.0, ..., 0.0}

  def epsilon_fn(episode_i: int):  # epsilon function
    if episode_i >= steps:  # max step reached
      return 0.0
    return log_epsilon_space[episode_i].item()  # return epsilon value

  return epsilon_fn  # return our function as an callable object

# %%
class TDMAQLearningAgent:

  def __init__(
      self, lr: float, gamma: float, act_space: spaces.Dict,
      obs_space: spaces.Dict, eps_fn_steps: int
  ):
    self.act_space = act_space  # action-space from the gym environment
    self.obs_space = obs_space  # observation-space from the gym environment

    self.lr = lr  # learning rate
    self.gamma = gamma  # gamma parameter

    # <START> ------ CODE BLOCK 2.A
    self.qtable: Dict[str, Tensor] = dict()  # Q-table with observation encoded as text string as keys for a 3D Q-table
    self.qtable_dims: Tuple[int, int, int] = (
      act_space['freq'].n, act_space['subframes'].nvec.size,  # 3D Q-table dimensions (n_freqs X n_subframes x n_roles)
      act_space['subframes'].nvec.max()
    )
    # <END> -------- CODE BLOCK 2.A

    self.eps_fn_steps = eps_fn_steps  # number of steps (episodes) in epsilon log-space
    self.eps_fn: Callable[[int], float] = build_epsilon_fn(eps_fn_steps)  # build our epsilon function
    self.episode_i: Optional[int] = None  # keep track of the episode number (e.g. for epsilon)
    self.eps: Optional[float] = None  # epsilon value as a property of our agent

  def act(self, o: Dict, eps: Optional[float] = None) -> Dict:  # choose action
    if eps is None:
      eps = self.eps  # not epsilon as argument, use agent's current epsilon value

    o_enc = self.encode_obs(o)  # encode obs to a string "{time_step}:{freq}:{subframes}:{successes}"

    # <START> ------ CODE BLOCK 2.B 
    if o_enc not in self.qtable:
      self.qtable[o_enc] = torch.zeros(self.qtable_dims)  # add new Q-table for new obs, Q-values are zero

    if random.uniform(1.0, 0.0) < eps:  # epsilon-greedy condition for exploration
      return self.explore(o)  # exploring random action

    max_sf_values, max_sf_indices = self.qtable[o_enc].max(dim=2)  # get values and index of best actions for all sub-frame Q-values
    max_freq = max_sf_values.sum(dim=1).argmax()  # get frequency with the best Q-values for all sub-frames

    if max_sf_indices.ndimension() > 1:  # multiple equal maximums
      max_sf_indices = max_sf_indices[max_freq]  # if Q-value equality occurs, take random one

    # ------- same algorithm but using python loops instead of pytorch -------
    # max_sf_values2 = []
    # max_sf_indices2 = []
    # for i in range(self.qtable[o_enc].shape[0]):
    #     j_vals = []
    #     j_inds = []
    #     for j in range(self.qtable[o_enc].shape[1]):
    #         max_k = float(max(self.qtable[o_enc][i, j]))
    #         for k in range(self.qtable[o_enc].shape[2]):
    #             if self.qtable[o_enc][i, j, k] == max_k:
    #                 j_inds.append(k)
    #                 break
    #         j_vals.append(max_k)
    #     max_sf_values2.append(j_vals)
    #     max_sf_indices2.append(j_inds)

    # max_freq_values2 = []
    # for i in range(self.qtable[o_enc].shape[0]):
    #     max_freq_values2.append(sum(max_sf_values2[i]))

    # max_freq2 = float('-inf')
    # for i in range(self.qtable[o_enc].shape[0]):
    #     if max_freq_values2[i] == max(max_freq_values2):
    #         max_freq2 = i
    #         break

    # assert torch.all(max_sf_values == torch.tensor(max_sf_values2))
    # assert torch.all(max_sf_indices == torch.tensor(max_sf_indices2))
    # assert torch.all(max_freq == torch.tensor(max_freq2))
    # -----------------------------------------------------------------------

    a = collections.OrderedDict(
      freq=int(max_freq), subframes=max_sf_indices.tolist()  # create and return action with best Q-values
    )
    # <END> -------- CODE BLOCK 2.B

    assert (
      isinstance(a, collections.OrderedDict) and
      self.act_space.contains(a)
    )
    return a

  def explore(self, o: Dict) -> Dict:  # action-space exploration
    # <START> ------ CODE BLOCK 2.C
    a = collections.OrderedDict(
      freq=randint(0, self.act_space['freq'].n - 1),  # random frequency
      subframes=[
        randint(0, n - 1) for n in self.act_space['subframes'].nvec  # random role action for each sub-frame
      ]
    )
    # <END> ------ CODE BLOCK 2.C
    assert (
      isinstance(a, collections.OrderedDict) and
      self.act_space.contains(a)
    )
    return a  # random action

  def update(
      self, o: Dict, a: Dict, r: float, o_prime: Dict  # agent update function (e.g. Q-learning update)
  ) -> float:
    o_enc = self.encode_obs(o)  # encode obs to a string "{time_step}:{freq}:{subframes}:{successes}"
    o_prime_enc = self.encode_obs(o_prime)  # encode obs to a string "{time_step}:{freq}:{subframes}:{successes}"

    # <START> ------ CODE BLOCK 2.D
    
    if o_enc not in self.qtable:
      self.qtable[o_enc] = torch.zeros(self.qtable_dims)  # add new Q-table for new obs, Q-values are zero

    if o_prime_enc not in self.qtable:
      self.qtable[o_prime_enc] = torch.zeros(self.qtable_dims)  # add new Q-table for new obs, Q-values are zero

    a_inds = a['freq'], range(len(a['subframes'])), a['subframes']  # get Q-table indices of action
    a_vals = self.qtable[o_enc][a_inds]  # TD-source (e.i. TD-error = [TD-target - TD-source]), also old Q-values to compute delta update

    max_prime_sf_vals, _ = self.qtable[o_prime_enc].max(dim=2)  # get values and index of best actions for all sub-frame Q-values
    a_prime_val = max_prime_sf_vals[max_prime_sf_vals.sum(dim=1).argmax()]  # get frequency with the best Q-values for all sub-frames

    # ------- same algorithm but using python loops instead of pytorch -------
    # a_vals2 = []
    # for i in range(len(a['subframes'])):
    #     a_vals2.append(
    #         self.qtable[o_enc][a['freq'], i, a['subframes'][i]]
    #     )
    # assert torch.all(a_vals == torch.tensor(a_vals2))

    # max_prime_sf_values2 = []
    # for i in range(self.qtable[o_prime_enc].shape[0]):
    #     j_vals = []
    #     for j in range(self.qtable[o_prime_enc].shape[1]):
    #         max_k = float(max(aa[i, j]))
    #         j_vals.append(max_k)
    #     max_prime_sf_values2.append(j_vals)

    # max_prime_freq2 = max([sum(sf) for sf in max_prime_sf_values2])
    # for i in range(self.qtable[o_prime_enc].shape[0]):
    #     if sum(max_prime_sf_values2[i]) == max_prime_freq2:
    #         max_prime_freq2 = i
    #         break

    # a_prime_val2 = max_prime_sf_values2[max_prime_freq2]
    # assert torch.all(a_prime_val == torch.tensor(a_prime_val2))
    # -----------------------------------------------------------------------

    last_success = torch.tensor(o_prime['last_success'])  # last success for credit assignment of the update

    td_target = (r + self.gamma * a_prime_val) * last_success  # compute Temporal-Difference target (e.i [r + gamma * Q(o', a_max)])
    self.qtable[o_enc][a_inds] += (
        self.lr * (td_target - a_vals) * last_success  # update Q-table (e.i. Q(o, s) <- Q(o, s) + lr * [TD-target - Q(o, a)])
    )

    delta_update = float(sum(self.qtable[o_enc][a_inds] - a_vals))  # compute delta update
    # <END> -------- CODE BLOCK 2.D
    assert isinstance(delta_update, float)
    return delta_update  # return delta update to training loop

  def episode_reset(self, o: Dict, episode_i: int) -> Dict:  # reset agent for a new episode
    self.episode_i = episode_i  # current episode number
    self.eps = self.eps_fn(episode_i)  # epsilon w.r.t. episode number
    return self.act(o, self.eps)  # act upon initial observation

  def save_to_file(self, path: str, overwrite: bool):  # save agent state to file
    file = pathlib.Path(path)  # file path
    if not overwrite and file.exists():  # exception if file exist and overwrite is false
      raise FileExistsError()

    # agent state as a python dictionary
    agent_state: Dict[str, Any] = {
      'gamma': self.gamma,
      'act_space': {
        'n_freq': self.act_space['freq'].n,
        'subframes_nvec': [
          int(n) for n in self.act_space['subframes'].nvec
        ]
      },
      'obs_space': {
        'n_time_step': self.obs_space['time_step'].n
      },
      'qtable': {k: v.tolist() for k, v in self.qtable.items()}
    }

    with file.open('w') as f:  # open file to write in it
      json.dump(agent_state, f)  # write agent state in file

  def load_from_file(self, path: str):  # load agent state from compatible saved state
    file = pathlib.Path(path)  # file path
    if not file.exists():
      return  # file does not exists

    with file.open('r') as f:  # open file to read it
      agent_state = json.load(f)  # load agent state from file

    self.gamma = agent_state['gamma']  # set gamma to loaded value
    self.qtable = {
      k: torch.tensor(v) for k, v in agent_state['qtable'].items()  # set number of actions from loaded value
    }

    assert self.act_space['freq'].n == agent_state['act_space']['n_freq']  # assert compatiblity
    assert [int(n) for n in self.act_space['subframes'].nvec] == (
      agent_state['act_space']['subframes_nvec']    # assert compatiblity
    )
    assert self.obs_space['time_step'].n == (
      agent_state['obs_space']['n_time_step']    # assert compatiblity
    )

  @staticmethod
  def encode_obs(o: Dict) -> str:  # encoding observation to a string to use it as Q-table key
    encoded = '{time_step}:{last_a}:{last_success}'.format(
      time_step=o['time_step'] if 'time_step' in o else '',
      last_a=(
        TDMAQLearningAgent.encode_act(o['last_a'])
        if 'last_a' in o else ''
      ),
      last_success=o['last_success'] if 'last_success' in o else ''
    ).replace(' ', '')
    return encoded  # return encoded observation as string

  @staticmethod
  def encode_act(a: Dict) -> str:  # encoding action to a string to use it as part of Q-table key
    encoded = '{freq}:{sf}'.format(
      freq=a['freq'], sf=a['subframes']
    ).replace(' ', '')
    return encoded  # return encoded action as string

# %%
random.seed(1234)  # python random number generator seed
torch.manual_seed(1234)  # pytorch random number generator seed

n_freqs = 4  # number of frequencies
n_subframes = 4  # number of sub-frames within a time-step frame
horizon = 15  # horizon of our gym (episodes)

gym_env = TDMAGym(n_freqs, n_subframes, horizon)  # our gym environment

lr = 0.55  # learning rate
gamma = 0.0  # gamma parameter
eps_fn_steps = 1500  # number of steps (episodes) in epsilon log-space

# initialize our Rx agent with learning parameters and gym parameters
agent = TDMAQLearningAgent(
  lr, gamma, gym_env.action_space, gym_env.observation_space, eps_fn_steps
)
#agent.load_from_file('tdma_agent_1.json')    # load previously saved agent

show_verbose = False  # print information for debugging
render_gym = False  # render gym

# print simulation parameters
print(
  'model: {{n_freqs={n_freqs}, n_subframes:{n_subframes},'
  ' horizon={horizon}}}, '
  'agent: {{lr={lr}, gamma={gamma}, eps_fn_steps={eps_fn_steps}}}'.format(
    n_freqs=n_freqs, n_subframes=n_subframes, horizon=horizon, lr=lr,
    gamma=gamma, eps_fn_steps=eps_fn_steps
  )
)

running_len = 5  # length of our running training data
running_delta = []  # running delta (e.g. the last running_len delta update)
running_acc = []  # running accuracy (e.g. the last running_len accuracy)

for episode_i in count():  # training loop
  if show_verbose:
    print('starting episode {episode_i}...'.format(episode_i=episode_i))

  delta_update: List[float] = []  # delta update of our Q-table
  n_successes: int = 0  # number of optimal actions (actions with maximum reward)
  cumul_r: float = 0.0  # cumulative reward

  # <START> ------ CODE BLOCK 3.A
  o = gym_env.reset()  # reset gym for new episode
  a = agent.episode_reset(o, episode_i)  # reset agent with initial gym observation and episode number
  # <END> -------- CODE BLOCK 3.A

  print(a)

  for t in count():  # episode loop
    if render_gym:
      gym_env.render()  # show gym rendering
    o_prime, r, done, _ = gym_env.step(a)  # interact with the gym, get environment transition
    if done:
      break  # terminal gym observation reached, out of horizon

    # <START> ------ CODE BLOCK 3.B
    delta_update.append(agent.update(o, a, r, o_prime))  # update agent with transition, get delta update
    cumul_r += r  # add reward to cumulative reward
    n_successes += int(r == 1.0 * n_subframes)  # success if optimal action-reward of 1.0 * number of sub-frames
    # <END> -------- CODE BLOCK 3.B

    if show_verbose:  # show transition of our model (e.i. <o, a, r, o'>)
      print(
        'transition={{o={o}, a={a}, r={r}, o_prime={o_prime}}},'
        ' delta_update={delta}'.format(
          o=agent.encode_obs(o), a=agent.encode_act(a),
          r=r, o_prime=agent.encode_obs(o_prime),
          delta=delta_update[-1]
        )
      )
    # <START> ------ CODE BLOCK 3.C
    o = o_prime  # increment to next observation (e.g. next observation)
    a = agent.act(o)  #  act upon next observation
    # <END> -------- CODE BLOCK 3.C

  # strip running data because we reached running length
  if len(running_acc) >= running_len or len(running_delta) >= running_len:
    running_acc.pop(0)  # delete oldest running accuracy
    running_delta.pop(0)  # delete oldest running update delta

  # <START> ------ CODE BLOCK 3.D
  running_acc.append(n_successes / horizon)  # add latest accuracy to running data
  running_delta.append(sum(delta_update))  # add latest update delta to running data
  # <END> -------- CODE BLOCK 3.D

  # show episode results
  print(
    'episode {episode_i}: cumul_reward={cumul_r}, accuracy:{acc:0.5}, '
    'cumul_delta={cumul_delta:0.5}, eps={eps:0.5}'.format(
      episode_i=episode_i, cumul_r=cumul_r, acc=running_acc[-1],
      cumul_delta=running_delta[-1], eps=agent.eps
    )
  )

  # training stop conditions
  if (
      all([acc == 1.0 for acc in running_acc])  # all running accuracy are maximized
      and all([delta < 0.0001 for delta in running_delta])  # all running delta update a lower than 0.0001
      and episode_i >= running_len  # running data have reached running length
  ) or episode_i >= eps_fn_steps + running_len:  # epsilon was 0 for all running data (nothing will change)
    break  # exit training loop

agent.save_to_file('tdma_agent_1.json', overwrite=True)  # save agent state to file
gym_env.close()  # close gym environment
# Out:
# model: {n_freqs=4, n_subframes:4, horizon=15}, agent: {lr=0.55, gamma=0.0, eps_fn_steps=1500}
# OrderedDict([('freq', 3), ('subframes', [2, 1, 0, 0])])
# episode 0: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=1.0
# OrderedDict([('freq', 3), ('subframes', [0, 2, 0, 1])])
# episode 1: cumul_reward=5.0, accuracy:0.0, cumul_delta=4.95, eps=0.99693
# OrderedDict([('freq', 3), ('subframes', [0, 0, 2, 1])])
# episode 2: cumul_reward=8.0, accuracy:0.0, cumul_delta=9.295, eps=0.99387
# OrderedDict([('freq', 0), ('subframes', [0, 1, 0, 1])])
# episode 3: cumul_reward=2.0, accuracy:0.0, cumul_delta=2.2, eps=0.99083
# OrderedDict([('freq', 1), ('subframes', [1, 0, 2, 0])])
# episode 4: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.98779
# OrderedDict([('freq', 0), ('subframes', [2, 1, 0, 2])])
# episode 5: cumul_reward=5.0, accuracy:0.0, cumul_delta=7.15, eps=0.98476
# OrderedDict([('freq', 0), ('subframes', [1, 2, 0, 1])])
# episode 6: cumul_reward=6.0, accuracy:0.0, cumul_delta=4.4, eps=0.98174
# OrderedDict([('freq', 0), ('subframes', [1, 0, 1, 2])])
# episode 7: cumul_reward=8.0, accuracy:0.0, cumul_delta=11.0, eps=0.97872
# OrderedDict([('freq', 3), ('subframes', [0, 2, 1, 2])])
# episode 8: cumul_reward=7.0, accuracy:0.0, cumul_delta=5.445, eps=0.97572
# OrderedDict([('freq', 2), ('subframes', [0, 1, 2, 1])])
# episode 9: cumul_reward=6.0, accuracy:0.0, cumul_delta=5.5, eps=0.97273
# OrderedDict([('freq', 3), ('subframes', [0, 1, 0, 2])])
# episode 10: cumul_reward=4.0, accuracy:0.0, cumul_delta=3.3, eps=0.96975
# OrderedDict([('freq', 0), ('subframes', [1, 0, 2, 0])])
# episode 11: cumul_reward=6.0, accuracy:0.0, cumul_delta=6.6, eps=0.96677
# OrderedDict([('freq', 0), ('subframes', [1, 2, 2, 0])])
# episode 12: cumul_reward=5.0, accuracy:0.0, cumul_delta=3.85, eps=0.96381
# OrderedDict([('freq', 1), ('subframes', [0, 2, 1, 1])])
# episode 13: cumul_reward=4.0, accuracy:0.0, cumul_delta=3.3, eps=0.96085
# OrderedDict([('freq', 1), ('subframes', [0, 0, 2, 2])])
# episode 14: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.9579
# OrderedDict([('freq', 3), ('subframes', [0, 1, 0, 2])])
# episode 15: cumul_reward=2.0, accuracy:0.0, cumul_delta=1.1, eps=0.95496
# OrderedDict([('freq', 1), ('subframes', [0, 2, 2, 2])])
# episode 16: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.95203
# OrderedDict([('freq', 3), ('subframes', [2, 2, 1, 0])])
# episode 17: cumul_reward=6.0, accuracy:0.0, cumul_delta=4.9253, eps=0.94911
# OrderedDict([('freq', 1), ('subframes', [1, 1, 0, 2])])
# episode 18: cumul_reward=7.0, accuracy:0.0, cumul_delta=8.25, eps=0.9462
# OrderedDict([('freq', 0), ('subframes', [0, 0, 2, 2])])
# episode 19: cumul_reward=5.0, accuracy:0.0, cumul_delta=3.85, eps=0.9433
# OrderedDict([('freq', 2), ('subframes', [0, 2, 2, 2])])
# episode 20: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.94041
# OrderedDict([('freq', 3), ('subframes', [0, 2, 2, 1])])
# episode 21: cumul_reward=10.0, accuracy:0.0, cumul_delta=10.057, eps=0.93752
# OrderedDict([('freq', 1), ('subframes', [0, 1, 0, 1])])
# episode 22: cumul_reward=5.0, accuracy:0.0, cumul_delta=4.95, eps=0.93465
# OrderedDict([('freq', 0), ('subframes', [1, 2, 1, 2])])
# episode 23: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.93178
# OrderedDict([('freq', 3), ('subframes', [2, 0, 1, 2])])
# episode 24: cumul_reward=2.0, accuracy:0.0, cumul_delta=2.2, eps=0.92892
# OrderedDict([('freq', 2), ('subframes', [1, 2, 2, 1])])
# episode 25: cumul_reward=8.0, accuracy:0.0, cumul_delta=8.8, eps=0.92607
# OrderedDict([('freq', 1), ('subframes', [0, 2, 1, 2])])
# episode 26: cumul_reward=4.0, accuracy:0.0, cumul_delta=5.5, eps=0.92323
# OrderedDict([('freq', 3), ('subframes', [2, 1, 1, 1])])
# episode 27: cumul_reward=7.0, accuracy:0.0, cumul_delta=6.9477, eps=0.9204
# OrderedDict([('freq', 0), ('subframes', [1, 2, 1, 1])])
# episode 28: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.91758
# OrderedDict([('freq', 3), ('subframes', [0, 2, 2, 1])])
# episode 29: cumul_reward=6.0, accuracy:0.0, cumul_delta=3.3717, eps=0.91476
# OrderedDict([('freq', 2), ('subframes', [2, 0, 2, 0])])
# episode 30: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.91195
# OrderedDict([('freq', 0), ('subframes', [1, 1, 0, 1])])
# episode 31: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.90916
# OrderedDict([('freq', 3), ('subframes', [2, 1, 1, 2])])
# episode 32: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.90637
# OrderedDict([('freq', 3), ('subframes', [2, 0, 2, 0])])
# episode 33: cumul_reward=9.0, accuracy:0.0, cumul_delta=11.212, eps=0.90359
# OrderedDict([('freq', 2), ('subframes', [0, 0, 1, 1])])
# episode 34: cumul_reward=6.0, accuracy:0.0, cumul_delta=6.6, eps=0.90082
# OrderedDict([('freq', 3), ('subframes', [0, 2, 0, 2])])
# episode 35: cumul_reward=9.0, accuracy:0.0, cumul_delta=6.408, eps=0.89805
# OrderedDict([('freq', 3), ('subframes', [1, 0, 0, 1])])
# episode 36: cumul_reward=3.0, accuracy:0.0, cumul_delta=1.4427, eps=0.8953
# OrderedDict([('freq', 1), ('subframes', [0, 1, 0, 2])])
# episode 37: cumul_reward=2.0, accuracy:0.0, cumul_delta=2.2, eps=0.89255
# OrderedDict([('freq', 3), ('subframes', [0, 0, 2, 2])])
# episode 38: cumul_reward=4.0, accuracy:0.0, cumul_delta=1.2502, eps=0.88981
# OrderedDict([('freq', 1), ('subframes', [1, 2, 1, 0])])
# episode 39: cumul_reward=5.0, accuracy:0.0, cumul_delta=4.95, eps=0.88709
# OrderedDict([('freq', 1), ('subframes', [0, 2, 2, 0])])
# episode 40: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.55, eps=0.88436
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 41: cumul_reward=5.0, accuracy:0.066667, cumul_delta=5.5735, eps=0.88165
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 42: cumul_reward=4.0, accuracy:0.066667, cumul_delta=2.3967, eps=0.87895
# OrderedDict([('freq', 0), ('subframes', [2, 1, 0, 2])])
# episode 43: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.55, eps=0.87625
# OrderedDict([('freq', 3), ('subframes', [1, 2, 0, 2])])
# episode 44: cumul_reward=7.0, accuracy:0.0, cumul_delta=2.117, eps=0.87356
# OrderedDict([('freq', 1), ('subframes', [1, 0, 0, 2])])
# episode 45: cumul_reward=11.0, accuracy:0.0, cumul_delta=14.85, eps=0.87088
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 46: cumul_reward=8.0, accuracy:0.066667, cumul_delta=4.9687, eps=0.86821
# OrderedDict([('freq', 0), ('subframes', [2, 0, 2, 0])])
# episode 47: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.55, eps=0.86555
# OrderedDict([('freq', 3), ('subframes', [2, 1, 1, 2])])
# episode 48: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.86289
# OrderedDict([('freq', 0), ('subframes', [1, 0, 2, 2])])
# episode 49: cumul_reward=2.0, accuracy:0.0, cumul_delta=0.7975, eps=0.86025
# OrderedDict([('freq', 3), ('subframes', [2, 0, 0, 0])])
# episode 50: cumul_reward=9.0, accuracy:0.0, cumul_delta=11.55, eps=0.85761
# OrderedDict([('freq', 0), ('subframes', [1, 2, 1, 2])])
# episode 51: cumul_reward=6.0, accuracy:0.0, cumul_delta=8.1455, eps=0.85498
# OrderedDict([('freq', 3), ('subframes', [0, 2, 1, 2])])
# episode 52: cumul_reward=2.0, accuracy:0.0, cumul_delta=-0.77632, eps=0.85235
# OrderedDict([('freq', 2), ('subframes', [2, 1, 1, 0])])
# episode 53: cumul_reward=10.0, accuracy:0.0, cumul_delta=12.1, eps=0.84974
# OrderedDict([('freq', 2), ('subframes', [2, 1, 0, 1])])
# episode 54: cumul_reward=2.0, accuracy:0.0, cumul_delta=1.1, eps=0.84713
# OrderedDict([('freq', 1), ('subframes', [1, 1, 2, 1])])
# episode 55: cumul_reward=7.0, accuracy:0.0, cumul_delta=10.45, eps=0.84454
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 56: cumul_reward=12.0, accuracy:0.066667, cumul_delta=10.417, eps=0.84194
# OrderedDict([('freq', 3), ('subframes', [1, 0, 2, 1])])
# episode 57: cumul_reward=7.0, accuracy:0.0, cumul_delta=0.50101, eps=0.83936
# OrderedDict([('freq', 3), ('subframes', [1, 1, 2, 0])])
# episode 58: cumul_reward=5.0, accuracy:0.0, cumul_delta=1.2505, eps=0.83679
# OrderedDict([('freq', 0), ('subframes', [1, 1, 0, 1])])
# episode 59: cumul_reward=2.0, accuracy:0.0, cumul_delta=1.1, eps=0.83422
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 60: cumul_reward=9.0, accuracy:0.066667, cumul_delta=7.2702, eps=0.83166
# OrderedDict([('freq', 2), ('subframes', [2, 1, 2, 1])])
# episode 61: cumul_reward=2.0, accuracy:0.0, cumul_delta=1.1, eps=0.82911
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 62: cumul_reward=17.0, accuracy:0.066667, cumul_delta=14.355, eps=0.82657
# OrderedDict([('freq', 3), ('subframes', [2, 1, 1, 1])])
# episode 63: cumul_reward=3.0, accuracy:0.0, cumul_delta=-0.48498, eps=0.82403
# OrderedDict([('freq', 2), ('subframes', [2, 0, 1, 1])])
# episode 64: cumul_reward=7.0, accuracy:0.0, cumul_delta=8.25, eps=0.8215
# OrderedDict([('freq', 0), ('subframes', [2, 2, 2, 1])])
# episode 65: cumul_reward=5.0, accuracy:0.0, cumul_delta=5.7475, eps=0.81898
# OrderedDict([('freq', 2), ('subframes', [0, 0, 0, 1])])
# episode 66: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.55, eps=0.81647
# OrderedDict([('freq', 2), ('subframes', [2, 0, 1, 0])])
# episode 67: cumul_reward=6.0, accuracy:0.0, cumul_delta=6.6, eps=0.81397
# OrderedDict([('freq', 3), ('subframes', [1, 0, 1, 2])])
# episode 68: cumul_reward=5.0, accuracy:0.0, cumul_delta=1.8063, eps=0.81147
# OrderedDict([('freq', 2), ('subframes', [1, 2, 0, 2])])
# episode 69: cumul_reward=7.0, accuracy:0.0, cumul_delta=8.14, eps=0.80898
# OrderedDict([('freq', 2), ('subframes', [0, 2, 2, 1])])
# episode 70: cumul_reward=9.0, accuracy:0.066667, cumul_delta=13.75, eps=0.8065
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 71: cumul_reward=9.0, accuracy:0.066667, cumul_delta=4.1981, eps=0.80403
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 72: cumul_reward=9.0, accuracy:0.066667, cumul_delta=4.1689, eps=0.80156
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 73: cumul_reward=10.0, accuracy:0.066667, cumul_delta=3.526, eps=0.7991
# OrderedDict([('freq', 0), ('subframes', [0, 0, 1, 0])])
# episode 74: cumul_reward=6.0, accuracy:0.0, cumul_delta=5.5, eps=0.79665
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 75: cumul_reward=13.0, accuracy:0.066667, cumul_delta=9.5471, eps=0.79421
# OrderedDict([('freq', 0), ('subframes', [2, 1, 1, 0])])
# episode 76: cumul_reward=6.0, accuracy:0.0, cumul_delta=5.5, eps=0.79177
# OrderedDict([('freq', 2), ('subframes', [1, 2, 0, 0])])
# episode 77: cumul_reward=3.0, accuracy:0.0, cumul_delta=0.9955, eps=0.78934
# OrderedDict([('freq', 3), ('subframes', [0, 1, 1, 0])])
# episode 78: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.78692
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 79: cumul_reward=12.0, accuracy:0.13333, cumul_delta=12.189, eps=0.78451
# OrderedDict([('freq', 2), ('subframes', [2, 1, 0, 2])])
# episode 80: cumul_reward=3.0, accuracy:0.0, cumul_delta=1.0401, eps=0.7821
# OrderedDict([('freq', 1), ('subframes', [2, 1, 1, 0])])
# episode 81: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.7797
# OrderedDict([('freq', 0), ('subframes', [0, 2, 2, 0])])
# episode 82: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.55, eps=0.77731
# OrderedDict([('freq', 2), ('subframes', [0, 1, 2, 2])])
# episode 83: cumul_reward=6.0, accuracy:0.0, cumul_delta=9.9, eps=0.77492
# OrderedDict([('freq', 3), ('subframes', [1, 2, 0, 2])])
# episode 84: cumul_reward=3.0, accuracy:0.0, cumul_delta=-2.0688, eps=0.77255
# OrderedDict([('freq', 2), ('subframes', [1, 1, 1, 0])])
# episode 85: cumul_reward=4.0, accuracy:0.0, cumul_delta=3.3, eps=0.77018
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 86: cumul_reward=8.0, accuracy:0.066667, cumul_delta=3.7366, eps=0.76782
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 87: cumul_reward=5.0, accuracy:0.066667, cumul_delta=0.80506, eps=0.76546
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 88: cumul_reward=9.0, accuracy:0.066667, cumul_delta=4.5959, eps=0.76311
# OrderedDict([('freq', 2), ('subframes', [2, 2, 2, 1])])
# episode 89: cumul_reward=7.0, accuracy:0.0, cumul_delta=9.35, eps=0.76077
# OrderedDict([('freq', 3), ('subframes', [2, 1, 1, 1])])
# episode 90: cumul_reward=11.0, accuracy:0.066667, cumul_delta=12.812, eps=0.75844
# OrderedDict([('freq', 1), ('subframes', [0, 1, 0, 0])])
# episode 91: cumul_reward=4.0, accuracy:0.0, cumul_delta=1.7875, eps=0.75611
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 92: cumul_reward=16.0, accuracy:0.13333, cumul_delta=10.775, eps=0.75379
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 93: cumul_reward=7.0, accuracy:0.066667, cumul_delta=2.1088, eps=0.75148
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 94: cumul_reward=11.0, accuracy:0.13333, cumul_delta=4.8835, eps=0.74917
# OrderedDict([('freq', 0), ('subframes', [2, 1, 0, 2])])
# episode 95: cumul_reward=11.0, accuracy:0.0, cumul_delta=7.639, eps=0.74688
# OrderedDict([('freq', 1), ('subframes', [1, 0, 2, 0])])
# episode 96: cumul_reward=4.0, accuracy:0.0, cumul_delta=2.5657, eps=0.74459
# OrderedDict([('freq', 0), ('subframes', [0, 2, 1, 1])])
# episode 97: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.7423
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 98: cumul_reward=16.0, accuracy:0.13333, cumul_delta=5.9663, eps=0.74002
# OrderedDict([('freq', 1), ('subframes', [2, 0, 0, 2])])
# episode 99: cumul_reward=7.0, accuracy:0.0, cumul_delta=2.5585, eps=0.73775
# OrderedDict([('freq', 0), ('subframes', [0, 1, 2, 2])])
# episode 100: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.55, eps=0.73549
# OrderedDict([('freq', 2), ('subframes', [2, 0, 0, 1])])
# episode 101: cumul_reward=3.0, accuracy:0.0, cumul_delta=0.5703, eps=0.73324
# OrderedDict([('freq', 1), ('subframes', [2, 2, 0, 1])])
# episode 102: cumul_reward=9.0, accuracy:0.0, cumul_delta=6.212, eps=0.73099
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 103: cumul_reward=8.0, accuracy:0.13333, cumul_delta=3.8418, eps=0.72874
# OrderedDict([('freq', 2), ('subframes', [2, 0, 0, 2])])
# episode 104: cumul_reward=5.0, accuracy:0.0, cumul_delta=1.6362, eps=0.72651
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 105: cumul_reward=11.0, accuracy:0.13333, cumul_delta=1.8633, eps=0.72428
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 106: cumul_reward=6.0, accuracy:0.066667, cumul_delta=1.1085, eps=0.72206
# OrderedDict([('freq', 0), ('subframes', [1, 1, 2, 0])])
# episode 107: cumul_reward=5.0, accuracy:0.0, cumul_delta=4.5114, eps=0.71984
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 108: cumul_reward=7.0, accuracy:0.066667, cumul_delta=2.2313, eps=0.71764
# OrderedDict([('freq', 2), ('subframes', [2, 0, 0, 1])])
# episode 109: cumul_reward=7.0, accuracy:0.0, cumul_delta=2.2243, eps=0.71543
# OrderedDict([('freq', 2), ('subframes', [0, 2, 1, 2])])
# episode 110: cumul_reward=4.0, accuracy:0.0, cumul_delta=3.3, eps=0.71324
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 111: cumul_reward=11.0, accuracy:0.13333, cumul_delta=2.9754, eps=0.71105
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 112: cumul_reward=12.0, accuracy:0.066667, cumul_delta=2.9309, eps=0.70887
# OrderedDict([('freq', 3), ('subframes', [1, 2, 0, 2])])
# episode 113: cumul_reward=15.0, accuracy:0.066667, cumul_delta=8.6698, eps=0.7067
# OrderedDict([('freq', 1), ('subframes', [1, 0, 1, 1])])
# episode 114: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.55, eps=0.70453
# OrderedDict([('freq', 2), ('subframes', [0, 2, 2, 1])])
# episode 115: cumul_reward=9.0, accuracy:0.0, cumul_delta=4.7079, eps=0.70237
# OrderedDict([('freq', 0), ('subframes', [1, 1, 1, 2])])
# episode 116: cumul_reward=10.0, accuracy:0.0, cumul_delta=7.8328, eps=0.70021
# OrderedDict([('freq', 0), ('subframes', [1, 0, 1, 0])])
# episode 117: cumul_reward=5.0, accuracy:0.0, cumul_delta=2.2106, eps=0.69807
# OrderedDict([('freq', 2), ('subframes', [2, 1, 1, 2])])
# episode 118: cumul_reward=5.0, accuracy:0.0, cumul_delta=3.0476, eps=0.69592
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 119: cumul_reward=16.0, accuracy:0.13333, cumul_delta=4.4906, eps=0.69379
# OrderedDict([('freq', 3), ('subframes', [0, 1, 1, 1])])
# episode 120: cumul_reward=11.0, accuracy:0.0, cumul_delta=2.4857, eps=0.69166
# OrderedDict([('freq', 1), ('subframes', [2, 2, 1, 0])])
# episode 121: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.55, eps=0.68954
# OrderedDict([('freq', 3), ('subframes', [0, 1, 2, 1])])
# episode 122: cumul_reward=7.0, accuracy:0.0, cumul_delta=4.6476, eps=0.68742
# OrderedDict([('freq', 2), ('subframes', [0, 2, 1, 2])])
# episode 123: cumul_reward=6.0, accuracy:0.066667, cumul_delta=3.418, eps=0.68532
# OrderedDict([('freq', 2), ('subframes', [0, 2, 1, 0])])
# episode 124: cumul_reward=5.0, accuracy:0.0, cumul_delta=7.15, eps=0.68321
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 125: cumul_reward=7.0, accuracy:0.066667, cumul_delta=2.2001, eps=0.68112
# OrderedDict([('freq', 2), ('subframes', [0, 1, 2, 2])])
# episode 126: cumul_reward=5.0, accuracy:0.0, cumul_delta=1.5569, eps=0.67903
# OrderedDict([('freq', 2), ('subframes', [1, 0, 1, 0])])
# episode 127: cumul_reward=3.0, accuracy:0.0, cumul_delta=0.34898, eps=0.67695
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 128: cumul_reward=16.0, accuracy:0.066667, cumul_delta=11.211, eps=0.67487
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 129: cumul_reward=10.0, accuracy:0.066667, cumul_delta=0.71193, eps=0.6728
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 130: cumul_reward=10.0, accuracy:0.066667, cumul_delta=2.9638, eps=0.67074
# OrderedDict([('freq', 2), ('subframes', [2, 2, 2, 1])])
# episode 131: cumul_reward=3.0, accuracy:0.0, cumul_delta=0.79988, eps=0.66868
# OrderedDict([('freq', 2), ('subframes', [1, 2, 0, 2])])
# episode 132: cumul_reward=7.0, accuracy:0.0, cumul_delta=2.9116, eps=0.66663
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 133: cumul_reward=12.0, accuracy:0.13333, cumul_delta=3.5936, eps=0.66458
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 134: cumul_reward=9.0, accuracy:0.066667, cumul_delta=1.0677, eps=0.66254
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 135: cumul_reward=9.0, accuracy:0.066667, cumul_delta=0.84999, eps=0.66051
# OrderedDict([('freq', 0), ('subframes', [0, 1, 0, 1])])
# episode 136: cumul_reward=4.0, accuracy:0.0, cumul_delta=1.1543, eps=0.65848
# OrderedDict([('freq', 0), ('subframes', [1, 2, 0, 0])])
# episode 137: cumul_reward=2.0, accuracy:0.0, cumul_delta=1.3496, eps=0.65646
# OrderedDict([('freq', 1), ('subframes', [0, 0, 1, 1])])
# episode 138: cumul_reward=4.0, accuracy:0.0, cumul_delta=5.5, eps=0.65445
# OrderedDict([('freq', 2), ('subframes', [2, 2, 2, 0])])
# episode 139: cumul_reward=7.0, accuracy:0.0, cumul_delta=7.7009, eps=0.65244
# OrderedDict([('freq', 3), ('subframes', [0, 1, 1, 2])])
# episode 140: cumul_reward=8.0, accuracy:0.0, cumul_delta=3.3121, eps=0.65044
# OrderedDict([('freq', 0), ('subframes', [1, 0, 0, 1])])
# episode 141: cumul_reward=7.0, accuracy:0.0, cumul_delta=5.9584, eps=0.64845
# OrderedDict([('freq', 3), ('subframes', [2, 1, 2, 2])])
# episode 142: cumul_reward=7.0, accuracy:0.0, cumul_delta=-0.9239, eps=0.64646
# OrderedDict([('freq', 1), ('subframes', [0, 0, 0, 1])])
# episode 143: cumul_reward=8.0, accuracy:0.0, cumul_delta=2.1882, eps=0.64448
# OrderedDict([('freq', 2), ('subframes', [0, 0, 1, 0])])
# episode 144: cumul_reward=11.0, accuracy:0.066667, cumul_delta=8.5777, eps=0.6425
# OrderedDict([('freq', 0), ('subframes', [0, 1, 1, 0])])
# episode 145: cumul_reward=11.0, accuracy:0.066667, cumul_delta=1.6106, eps=0.64053
# OrderedDict([('freq', 3), ('subframes', [0, 0, 1, 1])])
# episode 146: cumul_reward=7.0, accuracy:0.0, cumul_delta=-0.73653, eps=0.63856
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 147: cumul_reward=13.0, accuracy:0.13333, cumul_delta=10.768, eps=0.6366
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 148: cumul_reward=7.0, accuracy:0.066667, cumul_delta=5.1639, eps=0.63465
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 149: cumul_reward=13.0, accuracy:0.13333, cumul_delta=7.7723, eps=0.6327
# OrderedDict([('freq', 3), ('subframes', [1, 0, 2, 0])])
# episode 150: cumul_reward=9.0, accuracy:0.0, cumul_delta=2.4009, eps=0.63076
# OrderedDict([('freq', 1), ('subframes', [0, 1, 1, 2])])
# episode 151: cumul_reward=5.0, accuracy:0.066667, cumul_delta=1.5931, eps=0.62883
# OrderedDict([('freq', 2), ('subframes', [2, 1, 2, 2])])
# episode 152: cumul_reward=15.0, accuracy:0.066667, cumul_delta=14.315, eps=0.6269
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 153: cumul_reward=22.0, accuracy:0.26667, cumul_delta=6.2276, eps=0.62498
# OrderedDict([('freq', 3), ('subframes', [2, 2, 2, 2])])
# episode 154: cumul_reward=8.0, accuracy:0.0, cumul_delta=-1.2856, eps=0.62306
# OrderedDict([('freq', 1), ('subframes', [2, 0, 2, 2])])
# episode 155: cumul_reward=10.0, accuracy:0.13333, cumul_delta=4.4588, eps=0.62115
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 156: cumul_reward=9.0, accuracy:0.066667, cumul_delta=4.2343, eps=0.61924
# OrderedDict([('freq', 1), ('subframes', [1, 1, 2, 1])])
# episode 157: cumul_reward=2.0, accuracy:0.0, cumul_delta=0.4455, eps=0.61734
# OrderedDict([('freq', 1), ('subframes', [1, 0, 0, 0])])
# episode 158: cumul_reward=10.0, accuracy:0.0, cumul_delta=6.4665, eps=0.61545
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 159: cumul_reward=7.0, accuracy:0.066667, cumul_delta=1.8988, eps=0.61356
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 160: cumul_reward=6.0, accuracy:0.066667, cumul_delta=0.60696, eps=0.61168
# OrderedDict([('freq', 0), ('subframes', [2, 1, 0, 1])])
# episode 161: cumul_reward=7.0, accuracy:0.066667, cumul_delta=0.8992, eps=0.6098
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 162: cumul_reward=17.0, accuracy:0.2, cumul_delta=6.4083, eps=0.60793
# OrderedDict([('freq', 3), ('subframes', [2, 0, 1, 0])])
# episode 163: cumul_reward=8.0, accuracy:0.066667, cumul_delta=4.4888, eps=0.60607
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 164: cumul_reward=10.0, accuracy:0.13333, cumul_delta=1.8933, eps=0.60421
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 165: cumul_reward=11.0, accuracy:0.13333, cumul_delta=0.63713, eps=0.60236
# OrderedDict([('freq', 1), ('subframes', [0, 0, 0, 0])])
# episode 166: cumul_reward=9.0, accuracy:0.066667, cumul_delta=-0.1147, eps=0.60051
# OrderedDict([('freq', 1), ('subframes', [2, 0, 1, 0])])
# episode 167: cumul_reward=3.0, accuracy:0.0, cumul_delta=0.10546, eps=0.59867
# OrderedDict([('freq', 1), ('subframes', [1, 1, 2, 2])])
# episode 168: cumul_reward=16.0, accuracy:0.2, cumul_delta=4.3937, eps=0.59683
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 169: cumul_reward=17.0, accuracy:0.13333, cumul_delta=6.6949, eps=0.595
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 170: cumul_reward=6.0, accuracy:0.066667, cumul_delta=0.061428, eps=0.59317
# OrderedDict([('freq', 0), ('subframes', [2, 1, 0, 0])])
# episode 171: cumul_reward=10.0, accuracy:0.066667, cumul_delta=-2.1493, eps=0.59135
# OrderedDict([('freq', 3), ('subframes', [2, 1, 0, 0])])
# episode 172: cumul_reward=5.0, accuracy:0.0, cumul_delta=0.27293, eps=0.58954
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 173: cumul_reward=11.0, accuracy:0.066667, cumul_delta=0.46865, eps=0.58773
# OrderedDict([('freq', 2), ('subframes', [0, 2, 0, 0])])
# episode 174: cumul_reward=11.0, accuracy:0.13333, cumul_delta=5.9787, eps=0.58593
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 175: cumul_reward=11.0, accuracy:0.13333, cumul_delta=2.0984, eps=0.58413
# OrderedDict([('freq', 2), ('subframes', [1, 0, 2, 0])])
# episode 176: cumul_reward=9.0, accuracy:0.066667, cumul_delta=0.49054, eps=0.58234
# OrderedDict([('freq', 3), ('subframes', [0, 1, 2, 1])])
# episode 177: cumul_reward=11.0, accuracy:0.066667, cumul_delta=-4.5857, eps=0.58055
# OrderedDict([('freq', 2), ('subframes', [0, 1, 0, 0])])
# episode 178: cumul_reward=18.0, accuracy:0.2, cumul_delta=2.193, eps=0.57877
# OrderedDict([('freq', 2), ('subframes', [2, 1, 0, 2])])
# episode 179: cumul_reward=20.0, accuracy:0.2, cumul_delta=3.4118, eps=0.577
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 180: cumul_reward=17.0, accuracy:0.13333, cumul_delta=4.2009, eps=0.57523
# OrderedDict([('freq', 0), ('subframes', [0, 1, 2, 0])])
# episode 181: cumul_reward=13.0, accuracy:0.13333, cumul_delta=2.5788, eps=0.57346
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 182: cumul_reward=15.0, accuracy:0.066667, cumul_delta=5.0511, eps=0.5717
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 183: cumul_reward=17.0, accuracy:0.13333, cumul_delta=1.18, eps=0.56995
# OrderedDict([('freq', 1), ('subframes', [2, 1, 1, 1])])
# episode 184: cumul_reward=12.0, accuracy:0.0, cumul_delta=4.4493, eps=0.5682
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 185: cumul_reward=11.0, accuracy:0.13333, cumul_delta=2.9753, eps=0.56646
# OrderedDict([('freq', 0), ('subframes', [1, 0, 2, 1])])
# episode 186: cumul_reward=8.0, accuracy:0.0, cumul_delta=3.0259, eps=0.56472
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 187: cumul_reward=18.0, accuracy:0.26667, cumul_delta=2.6924, eps=0.56299
# OrderedDict([('freq', 3), ('subframes', [2, 0, 0, 1])])
# episode 188: cumul_reward=2.0, accuracy:0.0, cumul_delta=-1.0888, eps=0.56126
# OrderedDict([('freq', 0), ('subframes', [0, 2, 0, 1])])
# episode 189: cumul_reward=5.0, accuracy:0.0, cumul_delta=6.7114, eps=0.55954
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 190: cumul_reward=18.0, accuracy:0.066667, cumul_delta=6.3396, eps=0.55782
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 191: cumul_reward=11.0, accuracy:0.066667, cumul_delta=5.9206, eps=0.55611
# OrderedDict([('freq', 0), ('subframes', [0, 1, 0, 0])])
# episode 192: cumul_reward=8.0, accuracy:0.0, cumul_delta=4.7852, eps=0.55441
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 193: cumul_reward=12.0, accuracy:0.066667, cumul_delta=8.877, eps=0.55271
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 194: cumul_reward=10.0, accuracy:0.13333, cumul_delta=1.5624, eps=0.55101
# OrderedDict([('freq', 1), ('subframes', [2, 2, 0, 0])])
# episode 195: cumul_reward=10.0, accuracy:0.066667, cumul_delta=2.2862, eps=0.54932
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 196: cumul_reward=19.0, accuracy:0.066667, cumul_delta=13.983, eps=0.54764
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 197: cumul_reward=24.0, accuracy:0.26667, cumul_delta=4.8344, eps=0.54596
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 198: cumul_reward=14.0, accuracy:0.13333, cumul_delta=2.2881, eps=0.54428
# OrderedDict([('freq', 2), ('subframes', [1, 0, 0, 0])])
# episode 199: cumul_reward=5.0, accuracy:0.0, cumul_delta=1.2086, eps=0.54261
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 200: cumul_reward=8.0, accuracy:0.066667, cumul_delta=0.013942, eps=0.54095
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 201: cumul_reward=12.0, accuracy:0.066667, cumul_delta=-1.3587, eps=0.53929
# OrderedDict([('freq', 2), ('subframes', [0, 2, 1, 0])])
# episode 202: cumul_reward=10.0, accuracy:0.13333, cumul_delta=0.65259, eps=0.53763
# OrderedDict([('freq', 1), ('subframes', [2, 2, 0, 1])])
# episode 203: cumul_reward=7.0, accuracy:0.0, cumul_delta=3.7166, eps=0.53599
# OrderedDict([('freq', 0), ('subframes', [2, 2, 0, 1])])
# episode 204: cumul_reward=16.0, accuracy:0.066667, cumul_delta=3.6593, eps=0.53434
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 205: cumul_reward=13.0, accuracy:0.13333, cumul_delta=1.0892, eps=0.5327
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 206: cumul_reward=9.0, accuracy:0.066667, cumul_delta=2.4497, eps=0.53107
# OrderedDict([('freq', 1), ('subframes', [1, 0, 0, 2])])
# episode 207: cumul_reward=7.0, accuracy:0.0, cumul_delta=7.1507, eps=0.52944
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 208: cumul_reward=15.0, accuracy:0.066667, cumul_delta=1.8373, eps=0.52781
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 209: cumul_reward=15.0, accuracy:0.066667, cumul_delta=0.039998, eps=0.5262
# OrderedDict([('freq', 2), ('subframes', [2, 1, 0, 0])])
# episode 210: cumul_reward=7.0, accuracy:0.066667, cumul_delta=0.63403, eps=0.52458
# OrderedDict([('freq', 2), ('subframes', [2, 0, 1, 2])])
# episode 211: cumul_reward=11.0, accuracy:0.13333, cumul_delta=0.2431, eps=0.52297
# OrderedDict([('freq', 3), ('subframes', [1, 2, 1, 2])])
# episode 212: cumul_reward=4.0, accuracy:0.0, cumul_delta=-1.7545, eps=0.52137
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 213: cumul_reward=19.0, accuracy:0.26667, cumul_delta=1.0055, eps=0.51977
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 214: cumul_reward=17.0, accuracy:0.13333, cumul_delta=2.2531, eps=0.51817
# OrderedDict([('freq', 1), ('subframes', [0, 1, 0, 1])])
# episode 215: cumul_reward=6.0, accuracy:0.0, cumul_delta=2.9741, eps=0.51659
# OrderedDict([('freq', 3), ('subframes', [1, 2, 1, 1])])
# episode 216: cumul_reward=11.0, accuracy:0.066667, cumul_delta=2.4047, eps=0.515
# OrderedDict([('freq', 2), ('subframes', [2, 1, 1, 1])])
# episode 217: cumul_reward=6.0, accuracy:0.0, cumul_delta=3.4282, eps=0.51342
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 218: cumul_reward=21.0, accuracy:0.2, cumul_delta=6.5934, eps=0.51185
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 219: cumul_reward=13.0, accuracy:0.066667, cumul_delta=6.0318, eps=0.51028
# OrderedDict([('freq', 0), ('subframes', [1, 2, 1, 2])])
# episode 220: cumul_reward=8.0, accuracy:0.0, cumul_delta=1.8967, eps=0.50871
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 221: cumul_reward=24.0, accuracy:0.26667, cumul_delta=7.621, eps=0.50715
# OrderedDict([('freq', 0), ('subframes', [2, 1, 1, 0])])
# episode 222: cumul_reward=15.0, accuracy:0.13333, cumul_delta=3.9727, eps=0.50559
# OrderedDict([('freq', 1), ('subframes', [0, 1, 2, 1])])
# episode 223: cumul_reward=8.0, accuracy:0.066667, cumul_delta=1.9258, eps=0.50404
# OrderedDict([('freq', 1), ('subframes', [0, 1, 2, 0])])
# episode 224: cumul_reward=11.0, accuracy:0.066667, cumul_delta=1.2228, eps=0.5025
# OrderedDict([('freq', 0), ('subframes', [2, 1, 0, 1])])
# episode 225: cumul_reward=14.0, accuracy:0.066667, cumul_delta=4.8412, eps=0.50096
# OrderedDict([('freq', 2), ('subframes', [1, 0, 2, 0])])
# episode 226: cumul_reward=13.0, accuracy:0.0, cumul_delta=-1.7335, eps=0.49942
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 227: cumul_reward=22.0, accuracy:0.2, cumul_delta=8.6818, eps=0.49789
# OrderedDict([('freq', 1), ('subframes', [1, 1, 0, 1])])
# episode 228: cumul_reward=11.0, accuracy:0.13333, cumul_delta=0.61322, eps=0.49636
# OrderedDict([('freq', 0), ('subframes', [2, 2, 2, 1])])
# episode 229: cumul_reward=8.0, accuracy:0.066667, cumul_delta=0.020555, eps=0.49484
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 230: cumul_reward=19.0, accuracy:0.26667, cumul_delta=4.095, eps=0.49332
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 231: cumul_reward=20.0, accuracy:0.066667, cumul_delta=2.9742, eps=0.49181
# OrderedDict([('freq', 2), ('subframes', [1, 0, 2, 0])])
# episode 232: cumul_reward=17.0, accuracy:0.066667, cumul_delta=2.7765, eps=0.4903
# OrderedDict([('freq', 3), ('subframes', [2, 1, 2, 2])])
# episode 233: cumul_reward=8.0, accuracy:0.066667, cumul_delta=5.2647, eps=0.48879
# OrderedDict([('freq', 2), ('subframes', [0, 0, 0, 1])])
# episode 234: cumul_reward=12.0, accuracy:0.13333, cumul_delta=0.55255, eps=0.48729
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 235: cumul_reward=16.0, accuracy:0.2, cumul_delta=3.9202, eps=0.4858
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 236: cumul_reward=15.0, accuracy:0.066667, cumul_delta=3.0383, eps=0.48431
# OrderedDict([('freq', 3), ('subframes', [1, 0, 0, 0])])
# episode 237: cumul_reward=15.0, accuracy:0.13333, cumul_delta=1.74, eps=0.48282
# OrderedDict([('freq', 1), ('subframes', [0, 1, 0, 0])])
# episode 238: cumul_reward=17.0, accuracy:0.2, cumul_delta=4.7309, eps=0.48134
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 239: cumul_reward=17.0, accuracy:0.2, cumul_delta=-0.55416, eps=0.47987
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 240: cumul_reward=18.0, accuracy:0.13333, cumul_delta=3.3227, eps=0.47839
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 241: cumul_reward=21.0, accuracy:0.26667, cumul_delta=2.5856, eps=0.47693
# OrderedDict([('freq', 0), ('subframes', [0, 1, 1, 2])])
# episode 242: cumul_reward=10.0, accuracy:0.066667, cumul_delta=8.3887, eps=0.47546
# OrderedDict([('freq', 3), ('subframes', [0, 0, 2, 2])])
# episode 243: cumul_reward=9.0, accuracy:0.066667, cumul_delta=-0.10641, eps=0.47401
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 244: cumul_reward=16.0, accuracy:0.13333, cumul_delta=0.45494, eps=0.47255
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 245: cumul_reward=17.0, accuracy:0.13333, cumul_delta=2.8306, eps=0.4711
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 246: cumul_reward=15.0, accuracy:0.2, cumul_delta=-1.8767, eps=0.46966
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 247: cumul_reward=18.0, accuracy:0.26667, cumul_delta=4.0062, eps=0.46822
# OrderedDict([('freq', 0), ('subframes', [1, 0, 2, 2])])
# episode 248: cumul_reward=12.0, accuracy:0.066667, cumul_delta=0.67215, eps=0.46678
# OrderedDict([('freq', 3), ('subframes', [0, 0, 0, 0])])
# episode 249: cumul_reward=7.0, accuracy:0.0, cumul_delta=3.7503, eps=0.46535
# OrderedDict([('freq', 0), ('subframes', [2, 2, 1, 1])])
# episode 250: cumul_reward=11.0, accuracy:0.066667, cumul_delta=3.256, eps=0.46392
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 251: cumul_reward=21.0, accuracy:0.13333, cumul_delta=6.2612, eps=0.4625
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 252: cumul_reward=18.0, accuracy:0.13333, cumul_delta=1.8943, eps=0.46108
# OrderedDict([('freq', 2), ('subframes', [1, 1, 1, 1])])
# episode 253: cumul_reward=12.0, accuracy:0.2, cumul_delta=2.7003, eps=0.45967
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 254: cumul_reward=19.0, accuracy:0.26667, cumul_delta=2.9334, eps=0.45826
# OrderedDict([('freq', 2), ('subframes', [1, 0, 1, 0])])
# episode 255: cumul_reward=8.0, accuracy:0.066667, cumul_delta=0.94427, eps=0.45685
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 256: cumul_reward=15.0, accuracy:0.2, cumul_delta=4.3187, eps=0.45545
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 257: cumul_reward=20.0, accuracy:0.2, cumul_delta=1.7453, eps=0.45405
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 258: cumul_reward=20.0, accuracy:0.26667, cumul_delta=1.4603, eps=0.45266
# OrderedDict([('freq', 1), ('subframes', [2, 1, 2, 0])])
# episode 259: cumul_reward=15.0, accuracy:0.13333, cumul_delta=2.3331, eps=0.45127
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 260: cumul_reward=21.0, accuracy:0.13333, cumul_delta=7.457, eps=0.44989
# OrderedDict([('freq', 2), ('subframes', [0, 2, 0, 0])])
# episode 261: cumul_reward=13.0, accuracy:0.13333, cumul_delta=1.6565, eps=0.44851
# OrderedDict([('freq', 3), ('subframes', [2, 0, 1, 1])])
# episode 262: cumul_reward=9.0, accuracy:0.066667, cumul_delta=-0.97929, eps=0.44713
# OrderedDict([('freq', 1), ('subframes', [0, 1, 1, 1])])
# episode 263: cumul_reward=11.0, accuracy:0.066667, cumul_delta=1.6119, eps=0.44576
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 264: cumul_reward=14.0, accuracy:0.13333, cumul_delta=2.139, eps=0.44439
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 265: cumul_reward=14.0, accuracy:0.2, cumul_delta=4.1063, eps=0.44303
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 266: cumul_reward=19.0, accuracy:0.13333, cumul_delta=8.0085, eps=0.44167
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 267: cumul_reward=29.0, accuracy:0.2, cumul_delta=11.322, eps=0.44031
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 268: cumul_reward=20.0, accuracy:0.26667, cumul_delta=0.029954, eps=0.43896
# OrderedDict([('freq', 1), ('subframes', [1, 0, 0, 1])])
# episode 269: cumul_reward=11.0, accuracy:0.13333, cumul_delta=2.6899, eps=0.43762
# OrderedDict([('freq', 2), ('subframes', [0, 0, 2, 1])])
# episode 270: cumul_reward=12.0, accuracy:0.066667, cumul_delta=-0.22065, eps=0.43627
# OrderedDict([('freq', 2), ('subframes', [1, 1, 2, 1])])
# episode 271: cumul_reward=23.0, accuracy:0.13333, cumul_delta=6.3873, eps=0.43494
# OrderedDict([('freq', 0), ('subframes', [2, 1, 0, 0])])
# episode 272: cumul_reward=7.0, accuracy:0.066667, cumul_delta=0.18469, eps=0.4336
# OrderedDict([('freq', 1), ('subframes', [1, 1, 1, 2])])
# episode 273: cumul_reward=13.0, accuracy:0.13333, cumul_delta=-0.114, eps=0.43227
# OrderedDict([('freq', 1), ('subframes', [2, 1, 0, 2])])
# episode 274: cumul_reward=14.0, accuracy:0.13333, cumul_delta=6.2688, eps=0.43095
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 275: cumul_reward=21.0, accuracy:0.2, cumul_delta=7.8378, eps=0.42962
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 276: cumul_reward=24.0, accuracy:0.33333, cumul_delta=0.078877, eps=0.42831
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 277: cumul_reward=30.0, accuracy:0.4, cumul_delta=1.3354, eps=0.42699
# OrderedDict([('freq', 0), ('subframes', [1, 2, 1, 1])])
# episode 278: cumul_reward=12.0, accuracy:0.13333, cumul_delta=12.085, eps=0.42568
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 279: cumul_reward=16.0, accuracy:0.26667, cumul_delta=0.8189, eps=0.42438
# OrderedDict([('freq', 0), ('subframes', [2, 0, 0, 2])])
# episode 280: cumul_reward=7.0, accuracy:0.066667, cumul_delta=2.3167, eps=0.42308
# OrderedDict([('freq', 0), ('subframes', [2, 2, 0, 2])])
# episode 281: cumul_reward=6.0, accuracy:0.0, cumul_delta=4.95, eps=0.42178
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 282: cumul_reward=21.0, accuracy:0.33333, cumul_delta=0.97492, eps=0.42048
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 283: cumul_reward=17.0, accuracy:0.2, cumul_delta=1.5584, eps=0.41919
# OrderedDict([('freq', 1), ('subframes', [0, 1, 1, 2])])
# episode 284: cumul_reward=21.0, accuracy:0.066667, cumul_delta=0.14514, eps=0.41791
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 285: cumul_reward=17.0, accuracy:0.13333, cumul_delta=7.3981, eps=0.41663
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 286: cumul_reward=26.0, accuracy:0.26667, cumul_delta=3.7043, eps=0.41535
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 287: cumul_reward=18.0, accuracy:0.2, cumul_delta=1.5973, eps=0.41407
# OrderedDict([('freq', 0), ('subframes', [0, 2, 1, 0])])
# episode 288: cumul_reward=21.0, accuracy:0.26667, cumul_delta=0.14034, eps=0.4128
# OrderedDict([('freq', 2), ('subframes', [2, 1, 1, 0])])
# episode 289: cumul_reward=11.0, accuracy:0.13333, cumul_delta=0.13349, eps=0.41154
# OrderedDict([('freq', 3), ('subframes', [0, 0, 0, 0])])
# episode 290: cumul_reward=17.0, accuracy:0.13333, cumul_delta=0.33085, eps=0.41028
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 291: cumul_reward=22.0, accuracy:0.2, cumul_delta=-1.4517, eps=0.40902
# OrderedDict([('freq', 1), ('subframes', [0, 0, 0, 2])])
# episode 292: cumul_reward=20.0, accuracy:0.26667, cumul_delta=5.213, eps=0.40776
# OrderedDict([('freq', 3), ('subframes', [2, 1, 2, 1])])
# episode 293: cumul_reward=27.0, accuracy:0.2, cumul_delta=0.50489, eps=0.40651
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 294: cumul_reward=13.0, accuracy:0.2, cumul_delta=2.0874, eps=0.40526
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 295: cumul_reward=11.0, accuracy:0.13333, cumul_delta=0.7451, eps=0.40402
# OrderedDict([('freq', 2), ('subframes', [1, 0, 1, 2])])
# episode 296: cumul_reward=16.0, accuracy:0.13333, cumul_delta=0.7778, eps=0.40278
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 297: cumul_reward=23.0, accuracy:0.33333, cumul_delta=0.46235, eps=0.40155
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 298: cumul_reward=19.0, accuracy:0.13333, cumul_delta=1.5557, eps=0.40031
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 299: cumul_reward=14.0, accuracy:0.066667, cumul_delta=1.6731, eps=0.39909
# OrderedDict([('freq', 0), ('subframes', [1, 2, 2, 2])])
# episode 300: cumul_reward=13.0, accuracy:0.066667, cumul_delta=2.0308, eps=0.39786
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 301: cumul_reward=25.0, accuracy:0.26667, cumul_delta=2.9963, eps=0.39664
# OrderedDict([('freq', 1), ('subframes', [2, 0, 0, 0])])
# episode 302: cumul_reward=23.0, accuracy:0.33333, cumul_delta=9.7914, eps=0.39543
# OrderedDict([('freq', 1), ('subframes', [2, 2, 2, 0])])
# episode 303: cumul_reward=20.0, accuracy:0.2, cumul_delta=1.3789, eps=0.39421
# OrderedDict([('freq', 3), ('subframes', [0, 0, 2, 0])])
# episode 304: cumul_reward=15.0, accuracy:0.13333, cumul_delta=-0.87938, eps=0.393
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 305: cumul_reward=19.0, accuracy:0.13333, cumul_delta=1.4943, eps=0.3918
# OrderedDict([('freq', 1), ('subframes', [1, 1, 1, 2])])
# episode 306: cumul_reward=16.0, accuracy:0.26667, cumul_delta=0.037641, eps=0.3906
# OrderedDict([('freq', 2), ('subframes', [1, 0, 1, 2])])
# episode 307: cumul_reward=20.0, accuracy:0.26667, cumul_delta=-0.65831, eps=0.3894
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 308: cumul_reward=24.0, accuracy:0.13333, cumul_delta=-2.7981, eps=0.3882
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 309: cumul_reward=11.0, accuracy:0.066667, cumul_delta=-0.36465, eps=0.38701
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 310: cumul_reward=9.0, accuracy:0.13333, cumul_delta=1.9435, eps=0.38583
# OrderedDict([('freq', 1), ('subframes', [2, 1, 0, 2])])
# episode 311: cumul_reward=10.0, accuracy:0.066667, cumul_delta=2.6995, eps=0.38464
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 312: cumul_reward=20.0, accuracy:0.13333, cumul_delta=10.195, eps=0.38346
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 313: cumul_reward=21.0, accuracy:0.2, cumul_delta=-5.8501, eps=0.38229
# OrderedDict([('freq', 3), ('subframes', [1, 2, 0, 2])])
# episode 314: cumul_reward=12.0, accuracy:0.066667, cumul_delta=-0.54949, eps=0.38111
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 315: cumul_reward=20.0, accuracy:0.26667, cumul_delta=2.9851, eps=0.37994
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 316: cumul_reward=24.0, accuracy:0.26667, cumul_delta=3.824, eps=0.37878
# OrderedDict([('freq', 0), ('subframes', [1, 0, 0, 1])])
# episode 317: cumul_reward=16.0, accuracy:0.066667, cumul_delta=2.1962, eps=0.37762
# OrderedDict([('freq', 3), ('subframes', [2, 1, 1, 2])])
# episode 318: cumul_reward=10.0, accuracy:0.066667, cumul_delta=3.0736, eps=0.37646
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 319: cumul_reward=30.0, accuracy:0.2, cumul_delta=3.9835, eps=0.3753
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 320: cumul_reward=26.0, accuracy:0.26667, cumul_delta=1.7568, eps=0.37415
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 321: cumul_reward=24.0, accuracy:0.33333, cumul_delta=-0.89257, eps=0.373
# OrderedDict([('freq', 1), ('subframes', [1, 2, 2, 1])])
# episode 322: cumul_reward=4.0, accuracy:0.0, cumul_delta=-0.4274, eps=0.37186
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 323: cumul_reward=20.0, accuracy:0.2, cumul_delta=3.6353, eps=0.37072
# OrderedDict([('freq', 2), ('subframes', [0, 0, 1, 0])])
# episode 324: cumul_reward=9.0, accuracy:0.13333, cumul_delta=0.66095, eps=0.36958
# OrderedDict([('freq', 1), ('subframes', [2, 2, 2, 0])])
# episode 325: cumul_reward=17.0, accuracy:0.2, cumul_delta=6.9379, eps=0.36845
# OrderedDict([('freq', 3), ('subframes', [2, 1, 1, 0])])
# episode 326: cumul_reward=12.0, accuracy:0.13333, cumul_delta=1.33, eps=0.36732
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 327: cumul_reward=19.0, accuracy:0.26667, cumul_delta=2.5076, eps=0.36619
# OrderedDict([('freq', 2), ('subframes', [0, 1, 2, 1])])
# episode 328: cumul_reward=11.0, accuracy:0.13333, cumul_delta=0.077597, eps=0.36507
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 329: cumul_reward=20.0, accuracy:0.33333, cumul_delta=0.028057, eps=0.36395
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 330: cumul_reward=34.0, accuracy:0.4, cumul_delta=3.8217, eps=0.36283
# OrderedDict([('freq', 1), ('subframes', [0, 0, 2, 0])])
# episode 331: cumul_reward=27.0, accuracy:0.26667, cumul_delta=3.3462, eps=0.36172
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 332: cumul_reward=20.0, accuracy:0.2, cumul_delta=5.0348, eps=0.36061
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 333: cumul_reward=12.0, accuracy:0.13333, cumul_delta=-1.642, eps=0.3595
# OrderedDict([('freq', 3), ('subframes', [2, 2, 0, 2])])
# episode 334: cumul_reward=12.0, accuracy:0.066667, cumul_delta=0.46824, eps=0.3584
# OrderedDict([('freq', 0), ('subframes', [2, 1, 2, 2])])
# episode 335: cumul_reward=25.0, accuracy:0.4, cumul_delta=3.6919, eps=0.3573
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 336: cumul_reward=33.0, accuracy:0.4, cumul_delta=5.6163, eps=0.35621
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 337: cumul_reward=20.0, accuracy:0.33333, cumul_delta=0.81755, eps=0.35511
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 338: cumul_reward=32.0, accuracy:0.4, cumul_delta=6.1941, eps=0.35402
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 339: cumul_reward=10.0, accuracy:0.13333, cumul_delta=1.8534, eps=0.35294
# OrderedDict([('freq', 1), ('subframes', [1, 2, 1, 2])])
# episode 340: cumul_reward=17.0, accuracy:0.26667, cumul_delta=0.55078, eps=0.35186
# OrderedDict([('freq', 2), ('subframes', [1, 0, 0, 1])])
# episode 341: cumul_reward=29.0, accuracy:0.26667, cumul_delta=6.4832, eps=0.35078
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 342: cumul_reward=16.0, accuracy:0.066667, cumul_delta=0.27265, eps=0.3497
# OrderedDict([('freq', 1), ('subframes', [0, 1, 1, 2])])
# episode 343: cumul_reward=23.0, accuracy:0.26667, cumul_delta=3.3953, eps=0.34863
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 344: cumul_reward=25.0, accuracy:0.26667, cumul_delta=3.9045, eps=0.34756
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 345: cumul_reward=11.0, accuracy:0.066667, cumul_delta=-5.1254, eps=0.34649
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 346: cumul_reward=31.0, accuracy:0.4, cumul_delta=2.0582, eps=0.34543
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 347: cumul_reward=24.0, accuracy:0.13333, cumul_delta=2.6603, eps=0.34437
# OrderedDict([('freq', 3), ('subframes', [0, 2, 2, 2])])
# episode 348: cumul_reward=25.0, accuracy:0.2, cumul_delta=2.2505, eps=0.34331
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 349: cumul_reward=27.0, accuracy:0.33333, cumul_delta=0.15979, eps=0.34226
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 350: cumul_reward=24.0, accuracy:0.26667, cumul_delta=3.2075, eps=0.34121
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 351: cumul_reward=27.0, accuracy:0.33333, cumul_delta=5.4921, eps=0.34016
# OrderedDict([('freq', 1), ('subframes', [1, 0, 2, 1])])
# episode 352: cumul_reward=22.0, accuracy:0.26667, cumul_delta=7.1503, eps=0.33912
# OrderedDict([('freq', 3), ('subframes', [2, 0, 1, 2])])
# episode 353: cumul_reward=23.0, accuracy:0.33333, cumul_delta=4.3285, eps=0.33808
# ...
# episode 1390: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.9075, eps=0.013978
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1391: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.40838, eps=0.013935
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1392: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.18377, eps=0.013892
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1393: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.082696, eps=0.013849
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1394: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.037213, eps=0.013807
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1395: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.016746, eps=0.013764
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1396: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0075359, eps=0.013722
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1397: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.003391, eps=0.01368
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1398: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0015256, eps=0.013638
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1399: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.00068665, eps=0.013596
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1400: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.00030899, eps=0.013555
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1401: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.00013947, eps=0.013513
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1402: cumul_reward=59.0, accuracy:0.93333, cumul_delta=6.2227e-05, eps=0.013472
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1403: cumul_reward=59.0, accuracy:0.93333, cumul_delta=2.861e-05, eps=0.01343
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1404: cumul_reward=59.0, accuracy:0.93333, cumul_delta=1.2875e-05, eps=0.013389
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1405: cumul_reward=59.0, accuracy:0.93333, cumul_delta=5.722e-06, eps=0.013348
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1406: cumul_reward=51.0, accuracy:0.8, cumul_delta=2.1458e-06, eps=0.013307
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1407: cumul_reward=59.0, accuracy:0.93333, cumul_delta=1.4305e-06, eps=0.013266
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1408: cumul_reward=59.0, accuracy:0.93333, cumul_delta=7.1526e-07, eps=0.013226
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1409: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.013185
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1410: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.013145
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1411: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.013104
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1412: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.013064
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1413: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.013024
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1414: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.012984
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1415: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.012944
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1416: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.012904
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1417: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.012865
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1418: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.012825
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1419: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.012786
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1420: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.012747
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1421: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.012708
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1422: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.012669
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1423: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.01263
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1424: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.012591
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1425: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.012553
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1426: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.012514
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1427: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.012476
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1428: cumul_reward=51.0, accuracy:0.8, cumul_delta=0.0, eps=0.012437
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1429: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.012399
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1430: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.012361
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1431: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.012323
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1432: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.012286
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1433: cumul_reward=51.0, accuracy:0.66667, cumul_delta=-2.1993, eps=0.012248
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1434: cumul_reward=59.0, accuracy:0.93333, cumul_delta=1.21, eps=0.01221
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1435: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.5445, eps=0.012173
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1436: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.24503, eps=0.012135
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1437: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.11026, eps=0.012098
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1438: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.049618, eps=0.012061
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1439: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.022328, eps=0.012024
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1440: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.010047, eps=0.011987
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1441: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0045214, eps=0.01195
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1442: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0020347, eps=0.011914
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1443: cumul_reward=51.0, accuracy:0.8, cumul_delta=0.00091553, eps=0.011877
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1444: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.00041199, eps=0.011841
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1445: cumul_reward=51.0, accuracy:0.8, cumul_delta=0.00018549, eps=0.011805
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1446: cumul_reward=59.0, accuracy:0.93333, cumul_delta=8.3447e-05, eps=0.011768
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1447: cumul_reward=59.0, accuracy:0.93333, cumul_delta=3.767e-05, eps=0.011732
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1448: cumul_reward=59.0, accuracy:0.93333, cumul_delta=1.6689e-05, eps=0.011696
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1449: cumul_reward=59.0, accuracy:0.93333, cumul_delta=7.6294e-06, eps=0.01166
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1450: cumul_reward=51.0, accuracy:0.8, cumul_delta=3.3379e-06, eps=0.011625
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1451: cumul_reward=59.0, accuracy:0.93333, cumul_delta=1.4305e-06, eps=0.011589
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1452: cumul_reward=51.0, accuracy:0.8, cumul_delta=9.5367e-07, eps=0.011553
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1453: cumul_reward=59.0, accuracy:0.93333, cumul_delta=4.7684e-07, eps=0.011518
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1454: cumul_reward=44.0, accuracy:0.6, cumul_delta=0.80444, eps=0.011483
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1455: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.011447
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1456: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.011412
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1457: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.011377
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1458: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.011342
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1459: cumul_reward=50.0, accuracy:0.73333, cumul_delta=2.2275, eps=0.011308
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1460: cumul_reward=50.0, accuracy:0.73333, cumul_delta=2.2275, eps=0.011273
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1461: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.011238
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1462: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.011204
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1463: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.011169
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1464: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.011135
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1465: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.011101
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1466: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.011067
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1467: cumul_reward=40.0, accuracy:0.6, cumul_delta=0.35776, eps=0.011033
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1468: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010999
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1469: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010965
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1470: cumul_reward=51.0, accuracy:0.8, cumul_delta=0.049618, eps=0.010932
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1471: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010898
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1472: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010865
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1473: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010832
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1474: cumul_reward=51.0, accuracy:0.8, cumul_delta=0.0, eps=0.010798
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1475: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010765
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1476: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010732
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1477: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010699
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1478: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010666
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1479: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010634
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1480: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010601
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1481: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010569
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1482: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010536
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1483: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010504
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1484: cumul_reward=51.0, accuracy:0.8, cumul_delta=0.0, eps=0.010472
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1485: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010439
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1486: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010407
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1487: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010376
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1488: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010344
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1489: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010312
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1490: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.01028
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1491: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010249
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1492: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010217
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1493: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010186
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1494: cumul_reward=48.0, accuracy:0.73333, cumul_delta=0.2475, eps=0.010155
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1495: cumul_reward=51.0, accuracy:0.8, cumul_delta=0.0, eps=0.010124
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1496: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010093
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1497: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010062
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1498: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.010031
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1499: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.01
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1500: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.0
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1501: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.0
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1502: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.0
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1503: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.0
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1504: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.0
# OrderedDict([('freq', 3), ('subframes', [1, 2, 2, 1])])
# episode 1505: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.0, eps=0.0
