# %%
#   ____                            _____     _____                   __          __        _        _                 
#  / __ \                     /\   |_   _|   / ____|                  \ \        / /       | |      | |                
# | |  | |_ __   ___ _ __    /  \    | |    | |  __ _   _ _ __ ___     \ \  /\  / /__  _ __| | _____| |__   ___  _ __  
# | |  | | '_ \ / _ \ '_ \  / /\ \   | |    | | |_ | | | | '_ ` _ \     \ \/  \/ / _ \| '__| |/ / __| '_ \ / _ \| '_ \ 
# | |__| | |_) |  __/ | | |/ ____ \ _| |_   | |__| | |_| | | | | | |     \  /\  / (_) | |  |   <\__ \ | | | (_) | |_) |
#  \____/| .__/ \___|_| |_/_/    \_\_____|   \_____|\__, |_| |_| |_|      \/  \/ \___/|_|  |_|\_\___/_| |_|\___/| .__/ 
#        | |                                         __/ |                                                      | |    
#        |_|                                        |___/                                                       |_|

# %%
# !pip install gym
#!pip install torch==1.5.0+cpu -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (0.17.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)

# %%
import json
from itertools import count

import gym
from gym import spaces

import torch
from torch import Tensor

import random
from random import randint

from typing import Dict, List, Optional, Callable, Any, Tuple, Union, Type

import pathlib
import collections
import numpy as np
import pdb

# %% [markdown]
# ![alt text](https://www.taitradioacademy.com/wp-content/uploads/2014/10/Image-25-800x450.png)

# %%
# <START> ------ CODE BLOCK 1

# insert TDMA gym here
class TDMAGym(gym.Env):
  NO_ACTION = 0  # no action on sub-frame
  UPLINK_ACTION = 1  # use sub-frame as up-link role (user [Tx] --> base-station [Rx])
  DOWNLINK_ACTION = 2  # use sub-frame as down-link role (base-station [Tx] --> user [Rx])

  def __init__(self, n_freqs: int, n_subframes: int, horizon: int):
    super(TDMAGym, self).__init__()  # initialize gym.Env base class
    if n_subframes % 2 != 0:  # since a link is separated in up and down link we need even number of subframe
      raise ValueError('n_subframes must be an even number')

    # action-space dict includes frequency and sub-frames action
    self.action_space = spaces.Dict(
      {
        'freq': spaces.Discrete(n_freqs),  # frequency used
        'subframes': spaces.MultiDiscrete([3] * n_subframes)  # sub-frames role actions
      }
    )
    # observation-space dict includes the time-step, last action and its sub-frames successes
    self.observation_space = spaces.Dict(
      {
        'time_step': spaces.Discrete(horizon + 1),  # include terminal state
        'last_a': self.action_space,  # last action done by the agent
        'last_success': spaces.MultiDiscrete([2] * n_subframes)  # what sub-frames received an acknowledgement
      }
    )
    self.reward_range = 0.0, float(n_subframes)  # action-reward range between 0 and the number of sub-frames

    self.freq_sf: Dict[int, Tuple[int, Tensor]] = dict()  # frequency and sub-frames role assignation w.r.t. to time-step
    for t in range(horizon):  # do not include terminal state
      freq = randint(0, n_freqs - 1)  # choose random frequency to do Tx
      ul_subframes = random.sample(range(n_subframes), k=n_subframes // 2)  # choose which sub-frames will be used as up-link
      dl_subframes = [
        sf for sf in range(n_subframes) if sf not in ul_subframes  # choose the rest of sub-frames as down-link
      ]
      sf = torch.zeros(n_subframes, dtype=torch.int)  # initialize sub-frames roles
      sf.fill_(self.NO_ACTION)  # set all sub-frames to no-action
      sf[ul_subframes] = self.UPLINK_ACTION  # set all up-link sub-frames to uplink-action value
      sf[dl_subframes] = self.DOWNLINK_ACTION  # set all down-link sub-frames to downlink-action value
      self.freq_sf[t] = freq, sf  # set sub-frames role w.r.t. time-step

    self.hor = horizon  # gym horizon to know when we are DONE
    self.t = 0  # initial time-step / observation

  def step(self, action: Dict) -> Tuple[  # step function to interact with the gym
    Dict, float, bool, Dict[str, Any]
  ]:
    if self.t >= self.hor:  # terminal state reached
      return collections.OrderedDict(), 0.0, True, {}  # return empty interaction

    assert self.action_space.contains(action)  # action is within gym action-space assertion

    # <START> ------ CODE BLOCK 1

    # fetch current frequency and sub-frames role from self.freq_sf[self.t]
    # compute sub-frame successes, increment time-step
    # create observation with successes and last action using OrderedDict 
    # compute reward based on successful sub-frames
    freq, sf = self.freq_sf[self.t]
    if freq == action['freq']: 
      sf_success = torch.eq(torch.from_numpy(action['subframes']),sf)*1.0
    else:
      sf_success = [0.0]*n_subframes
    sf_success = np.array(sf_success)

    # print('freq ={f}, sf = {s}, action = {a} , success = {su}'.format(f=freq,s=sf, su=sf_success, a=action))
    self.t += 1
    o = collections.OrderedDict()
    o['time_step'] = self.t
    o['last_a'] = action
    o['last_success'] = sf_success
    r = sum(sf_success)
    # <END> ------ CODE BLOCK 1

    assert (
        isinstance(o, collections.OrderedDict) and
        self.observation_space.contains(o) and
        isinstance(r, float) and
        self.reward_range[0] <= r <= self.reward_range[1]
    )
    return o, r, False, {}   # gyms always returns <obs, reward, if terminal obs reached, debug/info dictionary>

  def reset(self) -> Dict:  # reset our gym for a new episode
    
    # <START> ------ CODE BLOCK 2
    
    # reset gym for new episode and create initial observation
    # with empty last action and last successed (all values are zero)
    self.t = 0 #restting time to zero
    o = collections.OrderedDict()
    #Note that you cannot update an orderd dict as o = {'key':value}, this will create a new dict and change type
    #To update an existing ordered dict, use dict_name['key'] = value 
    last_success =[0,0,0,0]
    last_a = {'freq': 0, 'subframes':[0,0,0,0]}
    o['time_step'] = 0
    o['last_a']=last_a
    o['last_success']=last_success  
    # <END> ------ CODE BLOCK 2

    assert (
        isinstance(o, collections.OrderedDict) and
        self.observation_space.contains(o))
    return o

  def render(self, mode='human'):  # gym visual rendering (e.g. text, image, plot, 3D frame, etc.)
    if self.t < self.hor:  # terminal gym state not reached
      # show current time-step, frequency and sub-frames role
      print(
        'rendering={{time_step={time_step}, freq={freq}, sf={sf}}}'
          .format(
          time_step=self.t, freq=self.freq_sf[self.t][0],
          sf=str(self.freq_sf[self.t][1].tolist()).replace(' ', '')
        )
      )
    else:  # terminal gym state reached and out of horizon
      print('rendering={terminal state reached, out of horizon}')

# <END> -------- CODE BLOCK 1

# %%
def build_epsilon_fn(steps: int) -> Callable[[int], float]:  # epsilon function builder
  log_epsilon_space = torch.logspace(1.0, -1.0, steps=steps, base=10.0) / 10.0  # epsilon log-space {1.0, ..., 0.0}

  def epsilon_fn(episode_i: int):  # epsilon function
    if episode_i >= steps:  # max step reached
      return 0.0
    return log_epsilon_space[episode_i].item()  # return epsilon value

  return epsilon_fn  # return our function as an callable object

# %%
class TDMAQLearningAgent:

  def __init__(
      self, lr: float, gamma: float, act_space: spaces.Dict,
      obs_space: spaces.Dict, eps_fn_steps: int
  ):
    self.act_space = act_space  # action-space from the gym environment
    self.obs_space = obs_space  # observation-space from the gym environment

    self.lr = lr  # learning rate
    self.gamma = gamma  # gamma parameter

    # <START> ------ CODE BLOCK 2.A
    
    # initialize the q-table where dictionary keys are string from encoded obs
    # and values are 3 dimensional tensors (3D Q-Table) 
    # The initialization of the Q-table must be implemented using observation 
    # as key and a 3D Q-table as value (code block 2.A module 6), e.i. Q-table 
    # dimensions are [n_frequencies X n_subframes X n_subframe_actions]
    self.qtable : Dict[str,Tensor] = dict()
    self.qtable_dims : Tuple[int, int, int] = (
        self.act_space['freq'].n, self.act_space['subframes'].nvec.size, self.act_space['subframes'].nvec.max()
    )
    # <END> -------- CODE BLOCK 2.A

    self.eps_fn_steps = eps_fn_steps  # number of steps (episodes) in epsilon log-space
    self.eps_fn: Callable[[int], float] = build_epsilon_fn(eps_fn_steps)  # build our epsilon function
    self.episode_i: Optional[int] = None  # keep track of the episode number (e.g. for epsilon)
    self.eps: Optional[float] = None  # epsilon value as a property of our agent

  def act(self, o: Dict, eps: Optional[float] = None) -> Dict:  # choose action
    if eps is None:
      eps = self.eps  # not epsilon as argument, use agent's current epsilon value

    o_enc = self.encode_obs(o)  # encode obs to a string "{time_step}:{freq}:{subframes}:{successes}"

    # <START> ------ CODE BLOCK 2.B 
    
    # choose exploration with epsilon greedy condition and choose action with
    # highest Q-value for exploitation
    # The act function must be implemented using epsilon-greedy for exploration 
    # and the high sub-frame action value for each sub-frames (code block 2.B module 6)
    if o_enc not in self.qtable:
      self.qtable[o_enc] = torch.zeros(self.qtable_dims)

    if random.random() < eps:
      a  = self.explore(o)
    else:

      vals, inds = self.qtable[o_enc].max(dim=2)
      vv, _ = vals.max(dim=1)
      freq = vv.argmax()
      #assert (freq.ndimention() == 1)
      a = collections.OrderedDict()
      a['freq'] = freq.item()
      a['subframes'] = np.array(inds[freq])

    # <END> -------- CODE BLOCK 2.B
    #pdb.set_trace()
    assert (
      isinstance(a, collections.OrderedDict) and
      self.act_space.contains(a)

    )
    return a

  def explore(self, o: Dict) -> Dict:  # action-space exploration
    # <START> ------ CODE BLOCK 2.C
    
    # choose random action as exploration mechanism
    a = collections.OrderedDict(
        freq=self.act_space['freq'].sample(),
        subframes = self.act_space['subframes'].sample()
    )

    # <END> ------ CODE BLOCK 2.C
    assert (
      isinstance(a, collections.OrderedDict) and
      self.act_space.contains(a)
    )
    return a  # random action

  def update(
      self, o: Dict, a: Dict, r: float, o_prime: Dict  # agent update function (e.g. Q-learning update)
  ) -> float:
    o_enc = self.encode_obs(o)  # encode obs to a string "{time_step}:{freq}:{subframes}:{successes}"
    o_prime_enc = self.encode_obs(o_prime)  # encode obs to a string "{time_step}:{freq}:{subframes}:{successes}"

    # <START> ------ CODE BLOCK 2.D
    
    # update the Q-table with TD-error and compute delta-update
    if o_enc not in self.qtable:
      self.qtable[o_enc] = torch.zeros(self.qtable_dims)  

    if o_prime_enc not in self.qtable:
      self.qtable[o_prime_enc] = torch.zeros(self.qtable_dims) 

    old_q_value_3d = self.qtable[o_enc]
    q_ind = a['freq'], range(len(a['subframes'])), a['subframes']
    old_q_val = old_q_value_3d[q_ind]
    
    q_prime_val, _ = self.qtable[o_prime_enc].max(dim=2) 
    action_prime  = q_prime_val[q_prime_val.sum(dim=1).argmax()]

    last_success = torch.Tensor(o_prime['last_success'])


    td_target = (r + self.gamma * action_prime) * last_success  
    
    self.qtable[o_enc][q_ind] += self.lr * (td_target - old_q_val) * last_success      

    delta_update = float(sum(self.qtable[o_enc][q_ind] - old_q_val))




    # <END> -------- CODE BLOCK 2.D
    assert isinstance(delta_update, float)
    return delta_update  # return delta update to training loop

  def episode_reset(self, o: Dict, episode_i: int) -> Dict:  # reset agent for a new episode
    self.episode_i = episode_i  # current episode number
    self.eps = self.eps_fn(episode_i)  # epsilon w.r.t. episode number
    return self.act(o, self.eps)  # act upon initial observation

  def save_to_file(self, path: str, overwrite: bool):  # save agent state to file
    file = pathlib.Path(path)  # file path
    if not overwrite and file.exists():  # exception if file exist and overwrite is false
      raise FileExistsError()

    # agent state as a python dictionary
    agent_state: Dict[str, Any] = {
      'gamma': self.gamma,
      'act_space': {
        'n_freq': self.act_space['freq'].n,
        'subframes_nvec': [
          int(n) for n in self.act_space['subframes'].nvec
        ]
      },
      'obs_space': {
        'n_time_step': self.obs_space['time_step'].n
      },
      'qtable': {k: v.tolist() for k, v in self.qtable.items()}
    }

    with file.open('w') as f:  # open file to write in it
      json.dump(agent_state, f)  # write agent state in file

  def load_from_file(self, path: str):  # load agent state from compatible saved state
    file = pathlib.Path(path)  # file path
    if not file.exists():
      return  # file does not exists

    with file.open('r') as f:  # open file to read it
      agent_state = json.load(f)  # load agent state from file

    self.gamma = agent_state['gamma']  # set gamma to loaded value
    self.qtable = {
      k: torch.tensor(v) for k, v in agent_state['qtable'].items()  # set number of actions from loaded value
    }

    assert self.act_space['freq'].n == agent_state['act_space']['n_freq']  # assert compatiblity
    assert [int(n) for n in self.act_space['subframes'].nvec] == (
      agent_state['act_space']['subframes_nvec']    # assert compatiblity
    )
    assert self.obs_space['time_step'].n == (
      agent_state['obs_space']['n_time_step']    # assert compatiblity
    )

  @staticmethod
  def encode_obs(o: Dict) -> str:  # encoding observation to a string to use it as Q-table key
    encoded = '{time_step}:{last_a}:{last_success}'.format(
      time_step=o['time_step'] if 'time_step' in o else '',
      last_a=(
        TDMAQLearningAgent.encode_act(o['last_a'])
        if 'last_a' in o else ''
      ),
      last_success=o['last_success'] if 'last_success' in o else ''
    ).replace(' ', '')
    return encoded  # return encoded observation as string

  @staticmethod
  def encode_act(a: Dict) -> str:  # encoding action to a string to use it as part of Q-table key
    encoded = '{freq}:{sf}'.format(
      freq=a['freq'], sf=a['subframes']
    ).replace(' ', '')
    return encoded  # return encoded action as string

# %%
random.seed(1234)  # python random number generator seed
torch.manual_seed(1234)  # pytorch random number generator seed

n_freqs = 4  # number of frequencies
n_subframes = 4  # number of sub-frames within a time-step frame
horizon = 15  # horizon of our gym (episodes)

gym_env = TDMAGym(n_freqs, n_subframes, horizon)  # our gym environment

lr = 0.55  # learning rate
gamma = 0.0  # gamma parameter
eps_fn_steps = 1500  # number of steps (episodes) in epsilon log-space

# initialize our Rx agent with learning parameters and gym parameters
agent = TDMAQLearningAgent(
  lr, gamma, gym_env.action_space, gym_env.observation_space, eps_fn_steps
)
#agent.load_from_file('tdma_agent_1.json')    # load previously saved agent

show_verbose = False  # print information for debugging
render_gym = False  # render gym

# print simulation parameters
print(
  'model: {{n_freqs={n_freqs}, n_subframes:{n_subframes},'
  ' horizon={horizon}}}, '
  'agent: {{lr={lr}, gamma={gamma}, eps_fn_steps={eps_fn_steps}}}'.format(
    n_freqs=n_freqs, n_subframes=n_subframes, horizon=horizon, lr=lr,
    gamma=gamma, eps_fn_steps=eps_fn_steps
  )
)

running_len = 5  # length of our running training data
running_delta = []  # running delta (e.g. the last running_len delta update)
running_acc = []  # running accuracy (e.g. the last running_len accuracy)

for episode_i in count():  # training loop
  if show_verbose:
    print('starting episode {episode_i}...'.format(episode_i=episode_i))

  delta_update: List[float] = []  # delta update of our Q-table
  n_successes: int = 0  # number of optimal actions (actions with maximum reward)
  cumul_r: float = 0.0  # cumulative reward

  # <START> ------ CODE BLOCK 3.A
  
  # reset gym and agent
  o = gym_env.reset()
  a= agent.episode_reset( o, episode_i)

  # <END> -------- CODE BLOCK 3.A

  for t in count():  # episode loop
    if render_gym:
      gym_env.render()  # show gym rendering
    o_prime, r, done, _ = gym_env.step(a)  # interact with the gym, get environment transition
    if done:
      break  # terminal gym observation reached, out of horizon

    # <START> ------ CODE BLOCK 3.B
    delta_update.append(agent.update(o, a, r, o_prime))

    
    # update agent, delta_update to list, add reward to cumul_r,

    cumul_r += r 
    # increment n_successes if success
    n_successes += int(r == 1.0 * n_subframes )
    # <END> -------- CODE BLOCK 3.B

    if show_verbose:  # show transition of our model (e.i. <o, a, r, o'>)
      print(
        'transition={{o={o}, a={a}, r={r}, o_prime={o_prime}}},'
        ' delta_update={delta}'.format(
          o=agent.encode_obs(o), a=agent.encode_act(a),
          r=r, o_prime=agent.encode_obs(o_prime),
          delta=delta_update[-1]
        )
      )
    # <START> ------ CODE BLOCK 3.C

    # next observation becomes current observation
    o = o_prime
    # choose action based on new observation
    #print(t) 
    #if (episode_i==4 and t==0): 
     # pdb.set_trace()
    a = agent.act(o)

    # <END> -------- CODE BLOCK 3.C

  # strip running data because we reached running length
  if len(running_acc) >= running_len or len(running_delta) >= running_len:
    running_acc.pop(0)  # delete oldest running accuracy
    running_delta.pop(0)  # delete oldest running update delta

  # <START> ------ CODE BLOCK 3.D

  # add accuracy and delta-update to running data
  running_acc.append(n_successes / horizon)
  running_delta.append(sum(delta_update))
  # <END> ------- CODE BLOCK 3.D

  # show episode results
  print(
    'episode {episode_i}: cumul_reward={cumul_r}, accuracy:{acc:0.5}, '
    'cumul_delta={cumul_delta:0.5}, eps={eps:0.5}'.format(
      episode_i=episode_i, cumul_r=cumul_r, acc=running_acc[-1],
      cumul_delta=running_delta[-1], eps=agent.eps
    )
  )

  # training stop conditions
  if (
      all([acc == 1.0 for acc in running_acc])  # all running accuracy are maximized
      and all([delta < 0.0001 for delta in running_delta])  # all running delta update a lower than 0.0001
      and episode_i >= running_len  # running data have reached running length
  ) or episode_i >= eps_fn_steps + running_len:  # epsilon was 0 for all running data (nothing will change)
    break  # exit training loop

agent.save_to_file('tdma_agent_1.json', overwrite=True)  # save agent state to file
gym_env.close()  # close gym environment
# Out:
# model: {n_freqs=4, n_subframes:4, horizon=15}, agent: {lr=0.55, gamma=0.0, eps_fn_steps=1500}
# episode 0: cumul_reward=8.0, accuracy:0.066667, cumul_delta=12.1, eps=1.0
# episode 1: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.55, eps=0.99693
# episode 2: cumul_reward=4.0, accuracy:0.0, cumul_delta=3.3, eps=0.99387
# episode 3: cumul_reward=2.0, accuracy:0.0, cumul_delta=1.1, eps=0.99083
# episode 4: cumul_reward=5.0, accuracy:0.0, cumul_delta=4.95, eps=0.98779
# episode 5: cumul_reward=5.0, accuracy:0.0, cumul_delta=6.05, eps=0.98476
# episode 6: cumul_reward=5.0, accuracy:0.0, cumul_delta=3.85, eps=0.98174
# episode 7: cumul_reward=10.0, accuracy:0.0, cumul_delta=13.2, eps=0.97872
# episode 8: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.97572
# episode 9: cumul_reward=8.0, accuracy:0.0, cumul_delta=7.7, eps=0.97273
# episode 10: cumul_reward=5.0, accuracy:0.0, cumul_delta=6.05, eps=0.96975
# episode 11: cumul_reward=2.0, accuracy:0.0, cumul_delta=1.1, eps=0.96677
# episode 12: cumul_reward=9.0, accuracy:0.0, cumul_delta=9.35, eps=0.96381
# episode 13: cumul_reward=2.0, accuracy:0.0, cumul_delta=2.2, eps=0.96085
# episode 14: cumul_reward=5.0, accuracy:0.0, cumul_delta=3.85, eps=0.9579
# episode 15: cumul_reward=4.0, accuracy:0.0, cumul_delta=3.3, eps=0.95496
# episode 16: cumul_reward=11.0, accuracy:0.0, cumul_delta=11.55, eps=0.95203
# episode 17: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.94911
# episode 18: cumul_reward=9.0, accuracy:0.0, cumul_delta=7.9475, eps=0.9462
# episode 19: cumul_reward=8.0, accuracy:0.0, cumul_delta=7.7, eps=0.9433
# episode 20: cumul_reward=4.0, accuracy:0.0, cumul_delta=3.3, eps=0.94041
# episode 21: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.93752
# episode 22: cumul_reward=5.0, accuracy:0.0, cumul_delta=6.05, eps=0.93465
# episode 23: cumul_reward=2.0, accuracy:0.0, cumul_delta=1.1, eps=0.93178
# episode 24: cumul_reward=4.0, accuracy:0.0, cumul_delta=4.4, eps=0.92892
# episode 25: cumul_reward=9.0, accuracy:0.066667, cumul_delta=12.54, eps=0.92607
# episode 26: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.92323
# episode 27: cumul_reward=9.0, accuracy:0.066667, cumul_delta=14.85, eps=0.9204
# episode 28: cumul_reward=5.0, accuracy:0.0, cumul_delta=4.95, eps=0.91758
# episode 29: cumul_reward=6.0, accuracy:0.0, cumul_delta=7.7069, eps=0.91476
# episode 30: cumul_reward=2.0, accuracy:0.0, cumul_delta=1.1, eps=0.91195
# episode 31: cumul_reward=6.0, accuracy:0.0, cumul_delta=5.5, eps=0.90916
# episode 32: cumul_reward=2.0, accuracy:0.0, cumul_delta=1.1, eps=0.90637
# episode 33: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.90359
# episode 34: cumul_reward=6.0, accuracy:0.0, cumul_delta=7.3975, eps=0.90082
# episode 35: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.89805
# episode 36: cumul_reward=10.0, accuracy:0.0, cumul_delta=6.3977, eps=0.8953
# episode 37: cumul_reward=4.0, accuracy:0.0, cumul_delta=3.3092, eps=0.89255
# episode 38: cumul_reward=2.0, accuracy:0.0, cumul_delta=1.1, eps=0.88981
# episode 39: cumul_reward=7.0, accuracy:0.0, cumul_delta=10.45, eps=0.88709
# episode 40: cumul_reward=5.0, accuracy:0.0, cumul_delta=7.15, eps=0.88436
# episode 41: cumul_reward=8.0, accuracy:0.066667, cumul_delta=10.985, eps=0.88165
# episode 42: cumul_reward=7.0, accuracy:0.0, cumul_delta=7.9475, eps=0.87895
# episode 43: cumul_reward=5.0, accuracy:0.0, cumul_delta=4.95, eps=0.87625
# episode 44: cumul_reward=7.0, accuracy:0.0, cumul_delta=6.05, eps=0.87356
# episode 45: cumul_reward=6.0, accuracy:0.0, cumul_delta=6.6, eps=0.87088
# episode 46: cumul_reward=4.0, accuracy:0.0, cumul_delta=3.3, eps=0.86821
# episode 47: cumul_reward=4.0, accuracy:0.0, cumul_delta=1.8931, eps=0.86555
# episode 48: cumul_reward=12.0, accuracy:0.066667, cumul_delta=16.02, eps=0.86289
# episode 49: cumul_reward=6.0, accuracy:0.0, cumul_delta=4.895, eps=0.86025
# episode 50: cumul_reward=6.0, accuracy:0.0, cumul_delta=7.7, eps=0.85761
# episode 51: cumul_reward=7.0, accuracy:0.0, cumul_delta=10.45, eps=0.85498
# episode 52: cumul_reward=7.0, accuracy:0.0, cumul_delta=4.3175, eps=0.85235
# episode 53: cumul_reward=5.0, accuracy:0.0, cumul_delta=3.85, eps=0.84974
# episode 54: cumul_reward=7.0, accuracy:0.066667, cumul_delta=7.3136, eps=0.84713
# episode 55: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.84454
# episode 56: cumul_reward=7.0, accuracy:0.066667, cumul_delta=7.425, eps=0.84194
# episode 57: cumul_reward=8.0, accuracy:0.0, cumul_delta=11.0, eps=0.83936
# episode 58: cumul_reward=7.0, accuracy:0.0, cumul_delta=7.645, eps=0.83679
# episode 59: cumul_reward=2.0, accuracy:0.0, cumul_delta=-1.1119, eps=0.83422
# episode 60: cumul_reward=11.0, accuracy:0.0, cumul_delta=8.9423, eps=0.83166
# episode 61: cumul_reward=8.0, accuracy:0.0, cumul_delta=8.69, eps=0.82911
# episode 62: cumul_reward=6.0, accuracy:0.0, cumul_delta=5.7039, eps=0.82657
# episode 63: cumul_reward=4.0, accuracy:0.0, cumul_delta=1.9729, eps=0.82403
# episode 64: cumul_reward=6.0, accuracy:0.0, cumul_delta=3.7524, eps=0.8215
# episode 65: cumul_reward=8.0, accuracy:0.0, cumul_delta=6.1207, eps=0.81898
# episode 66: cumul_reward=7.0, accuracy:0.066667, cumul_delta=5.0537, eps=0.81647
# episode 67: cumul_reward=9.0, accuracy:0.0, cumul_delta=10.23, eps=0.81397
# episode 68: cumul_reward=5.0, accuracy:0.0, cumul_delta=2.2085, eps=0.81147
# episode 69: cumul_reward=3.0, accuracy:0.0, cumul_delta=1.3475, eps=0.80898
# episode 70: cumul_reward=2.0, accuracy:0.0, cumul_delta=0.7975, eps=0.8065
# episode 71: cumul_reward=6.0, accuracy:0.066667, cumul_delta=4.4125, eps=0.80403
# episode 72: cumul_reward=2.0, accuracy:0.0, cumul_delta=2.2, eps=0.80156
# episode 73: cumul_reward=7.0, accuracy:0.0, cumul_delta=2.2034, eps=0.7991
# episode 74: cumul_reward=6.0, accuracy:0.0, cumul_delta=0.17121, eps=0.79665
# episode 75: cumul_reward=10.0, accuracy:0.0, cumul_delta=9.9, eps=0.79421
# episode 76: cumul_reward=5.0, accuracy:0.0, cumul_delta=4.95, eps=0.79177
# episode 77: cumul_reward=2.0, accuracy:0.0, cumul_delta=2.2, eps=0.78934
# episode 78: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.78692
# episode 79: cumul_reward=7.0, accuracy:0.0, cumul_delta=4.5746, eps=0.78451
# episode 80: cumul_reward=6.0, accuracy:0.0, cumul_delta=2.441, eps=0.7821
# episode 81: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.55, eps=0.7797
# episode 82: cumul_reward=6.0, accuracy:0.066667, cumul_delta=6.1449, eps=0.77731
# episode 83: cumul_reward=5.0, accuracy:0.0, cumul_delta=6.545, eps=0.77492
# episode 84: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.55, eps=0.77255
# episode 85: cumul_reward=6.0, accuracy:0.0, cumul_delta=2.4005, eps=0.77018
# episode 86: cumul_reward=1.0, accuracy:0.0, cumul_delta=-0.38851, eps=0.76782
# episode 87: cumul_reward=3.0, accuracy:0.0, cumul_delta=0.64021, eps=0.76546
# episode 88: cumul_reward=5.0, accuracy:0.0, cumul_delta=0.14594, eps=0.76311
# episode 89: cumul_reward=8.0, accuracy:0.066667, cumul_delta=7.8511, eps=0.76077
# episode 90: cumul_reward=6.0, accuracy:0.066667, cumul_delta=3.753, eps=0.75844
# episode 91: cumul_reward=5.0, accuracy:0.066667, cumul_delta=0.64384, eps=0.75611
# episode 92: cumul_reward=4.0, accuracy:0.0, cumul_delta=0.58212, eps=0.75379
# episode 93: cumul_reward=6.0, accuracy:0.0, cumul_delta=7.9005, eps=0.75148
# episode 94: cumul_reward=7.0, accuracy:0.0, cumul_delta=4.5559, eps=0.74917
# episode 95: cumul_reward=8.0, accuracy:0.066667, cumul_delta=4.4741, eps=0.74688
# episode 96: cumul_reward=7.0, accuracy:0.0, cumul_delta=2.0877, eps=0.74459
# episode 97: cumul_reward=5.0, accuracy:0.0, cumul_delta=1.5329, eps=0.7423
# episode 98: cumul_reward=9.0, accuracy:0.0, cumul_delta=3.2847, eps=0.74002
# episode 99: cumul_reward=2.0, accuracy:0.0, cumul_delta=1.1, eps=0.73775
# episode 100: cumul_reward=8.0, accuracy:0.066667, cumul_delta=3.8283, eps=0.73549
# episode 101: cumul_reward=8.0, accuracy:0.13333, cumul_delta=4.1944, eps=0.73324
# episode 102: cumul_reward=5.0, accuracy:0.066667, cumul_delta=2.3305, eps=0.73099
# episode 103: cumul_reward=9.0, accuracy:0.0, cumul_delta=4.9567, eps=0.72874
# episode 104: cumul_reward=8.0, accuracy:0.066667, cumul_delta=6.3094, eps=0.72651
# episode 105: cumul_reward=3.0, accuracy:0.0, cumul_delta=0.87299, eps=0.72428
# episode 106: cumul_reward=4.0, accuracy:0.0, cumul_delta=0.8464, eps=0.72206
# episode 107: cumul_reward=4.0, accuracy:0.0, cumul_delta=4.4, eps=0.71984
# episode 108: cumul_reward=8.0, accuracy:0.0, cumul_delta=-0.32563, eps=0.71764
# episode 109: cumul_reward=8.0, accuracy:0.066667, cumul_delta=5.4036, eps=0.71543
# episode 110: cumul_reward=7.0, accuracy:0.0, cumul_delta=6.6316, eps=0.71324
# episode 111: cumul_reward=1.0, accuracy:0.0, cumul_delta=-0.5297, eps=0.71105
# episode 112: cumul_reward=2.0, accuracy:0.0, cumul_delta=2.2, eps=0.70887
# episode 113: cumul_reward=11.0, accuracy:0.066667, cumul_delta=5.1514, eps=0.7067
# episode 114: cumul_reward=4.0, accuracy:0.0, cumul_delta=3.5897, eps=0.70453
# episode 115: cumul_reward=6.0, accuracy:0.0, cumul_delta=0.91134, eps=0.70237
# episode 116: cumul_reward=3.0, accuracy:0.0, cumul_delta=1.65, eps=0.70021
# episode 117: cumul_reward=11.0, accuracy:0.066667, cumul_delta=4.8857, eps=0.69807
# episode 118: cumul_reward=15.0, accuracy:0.066667, cumul_delta=6.7992, eps=0.69592
# episode 119: cumul_reward=3.0, accuracy:0.0, cumul_delta=4.95, eps=0.69379
# episode 120: cumul_reward=8.0, accuracy:0.066667, cumul_delta=2.6446, eps=0.69166
# episode 121: cumul_reward=4.0, accuracy:0.0, cumul_delta=3.19, eps=0.68954
# episode 122: cumul_reward=7.0, accuracy:0.066667, cumul_delta=0.76832, eps=0.68742
# episode 123: cumul_reward=7.0, accuracy:0.066667, cumul_delta=1.6441, eps=0.68532
# episode 124: cumul_reward=9.0, accuracy:0.0, cumul_delta=1.814, eps=0.68321
# episode 125: cumul_reward=4.0, accuracy:0.0, cumul_delta=-1.9104, eps=0.68112
# episode 126: cumul_reward=12.0, accuracy:0.13333, cumul_delta=3.5217, eps=0.67903
# episode 127: cumul_reward=3.0, accuracy:0.0, cumul_delta=-0.53877, eps=0.67695
# episode 128: cumul_reward=9.0, accuracy:0.13333, cumul_delta=4.7735, eps=0.67487
# episode 129: cumul_reward=7.0, accuracy:0.066667, cumul_delta=0.85009, eps=0.6728
# episode 130: cumul_reward=15.0, accuracy:0.0, cumul_delta=9.8729, eps=0.67074
# episode 131: cumul_reward=10.0, accuracy:0.066667, cumul_delta=10.094, eps=0.66868
# episode 132: cumul_reward=11.0, accuracy:0.066667, cumul_delta=1.8021, eps=0.66663
# episode 133: cumul_reward=10.0, accuracy:0.066667, cumul_delta=3.7603, eps=0.66458
# episode 134: cumul_reward=19.0, accuracy:0.13333, cumul_delta=9.6744, eps=0.66254
# episode 135: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.55, eps=0.66051
# episode 136: cumul_reward=3.0, accuracy:0.0, cumul_delta=0.64021, eps=0.65848
# episode 137: cumul_reward=4.0, accuracy:0.066667, cumul_delta=0.26596, eps=0.65646
# episode 138: cumul_reward=2.0, accuracy:0.0, cumul_delta=2.2, eps=0.65445
# episode 139: cumul_reward=8.0, accuracy:0.066667, cumul_delta=0.8422, eps=0.65244
# episode 140: cumul_reward=10.0, accuracy:0.066667, cumul_delta=-2.6491, eps=0.65044
# episode 141: cumul_reward=5.0, accuracy:0.066667, cumul_delta=0.27174, eps=0.64845
# episode 142: cumul_reward=20.0, accuracy:0.2, cumul_delta=18.743, eps=0.64646
# episode 143: cumul_reward=5.0, accuracy:0.066667, cumul_delta=-0.029808, eps=0.64448
# episode 144: cumul_reward=9.0, accuracy:0.066667, cumul_delta=8.7347, eps=0.6425
# episode 145: cumul_reward=6.0, accuracy:0.066667, cumul_delta=2.6368, eps=0.64053
# episode 146: cumul_reward=1.0, accuracy:0.0, cumul_delta=-1.65, eps=0.63856
# episode 147: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.11137, eps=0.6366
# episode 148: cumul_reward=13.0, accuracy:0.066667, cumul_delta=-0.038614, eps=0.63465
# episode 149: cumul_reward=6.0, accuracy:0.0, cumul_delta=2.4756, eps=0.6327
# episode 150: cumul_reward=11.0, accuracy:0.066667, cumul_delta=2.6125, eps=0.63076
# episode 151: cumul_reward=16.0, accuracy:0.13333, cumul_delta=3.0465, eps=0.62883
# episode 152: cumul_reward=3.0, accuracy:0.0, cumul_delta=1.045, eps=0.6269
# episode 153: cumul_reward=7.0, accuracy:0.066667, cumul_delta=1.8396, eps=0.62498
# episode 154: cumul_reward=7.0, accuracy:0.066667, cumul_delta=3.0404, eps=0.62306
# episode 155: cumul_reward=16.0, accuracy:0.2, cumul_delta=13.2, eps=0.62115
# episode 156: cumul_reward=3.0, accuracy:0.0, cumul_delta=1.6541, eps=0.61924
# episode 157: cumul_reward=6.0, accuracy:0.066667, cumul_delta=-0.53209, eps=0.61734
# episode 158: cumul_reward=10.0, accuracy:0.066667, cumul_delta=-4.4006, eps=0.61545
# episode 159: cumul_reward=9.0, accuracy:0.066667, cumul_delta=6.3211, eps=0.61356
# episode 160: cumul_reward=7.0, accuracy:0.0, cumul_delta=0.67139, eps=0.61168
# episode 161: cumul_reward=11.0, accuracy:0.066667, cumul_delta=2.8865, eps=0.6098
# episode 162: cumul_reward=8.0, accuracy:0.13333, cumul_delta=1.5507, eps=0.60793
# episode 163: cumul_reward=10.0, accuracy:0.066667, cumul_delta=6.7868, eps=0.60607
# episode 164: cumul_reward=11.0, accuracy:0.066667, cumul_delta=-1.228, eps=0.60421
# episode 165: cumul_reward=4.0, accuracy:0.0, cumul_delta=2.2011, eps=0.60236
# episode 166: cumul_reward=11.0, accuracy:0.066667, cumul_delta=6.032, eps=0.60051
# episode 167: cumul_reward=6.0, accuracy:0.066667, cumul_delta=3.5314, eps=0.59867
# episode 168: cumul_reward=12.0, accuracy:0.066667, cumul_delta=4.9357, eps=0.59683
# episode 169: cumul_reward=8.0, accuracy:0.0, cumul_delta=3.1663, eps=0.595
# episode 170: cumul_reward=9.0, accuracy:0.066667, cumul_delta=5.8256, eps=0.59317
# episode 171: cumul_reward=9.0, accuracy:0.066667, cumul_delta=-0.25129, eps=0.59135
# episode 172: cumul_reward=14.0, accuracy:0.2, cumul_delta=2.668, eps=0.58954
# episode 173: cumul_reward=2.0, accuracy:0.0, cumul_delta=-1.7354, eps=0.58773
# episode 174: cumul_reward=10.0, accuracy:0.13333, cumul_delta=1.2921, eps=0.58593
# episode 175: cumul_reward=17.0, accuracy:0.2, cumul_delta=2.8685, eps=0.58413
# episode 176: cumul_reward=11.0, accuracy:0.066667, cumul_delta=2.3646, eps=0.58234
# episode 177: cumul_reward=7.0, accuracy:0.066667, cumul_delta=0.13448, eps=0.58055
# episode 178: cumul_reward=6.0, accuracy:0.0, cumul_delta=3.8095, eps=0.57877
# episode 179: cumul_reward=10.0, accuracy:0.13333, cumul_delta=2.562, eps=0.577
# episode 180: cumul_reward=11.0, accuracy:0.13333, cumul_delta=-1.5719, eps=0.57523
# episode 181: cumul_reward=3.0, accuracy:0.0, cumul_delta=-1.1806, eps=0.57346
# episode 182: cumul_reward=10.0, accuracy:0.066667, cumul_delta=5.8142, eps=0.5717
# episode 183: cumul_reward=12.0, accuracy:0.13333, cumul_delta=2.3612, eps=0.56995
# episode 184: cumul_reward=6.0, accuracy:0.066667, cumul_delta=3.1552, eps=0.5682
# episode 185: cumul_reward=20.0, accuracy:0.2, cumul_delta=4.6333, eps=0.56646
# episode 186: cumul_reward=11.0, accuracy:0.13333, cumul_delta=3.0753, eps=0.56472
# episode 187: cumul_reward=13.0, accuracy:0.13333, cumul_delta=-1.9974, eps=0.56299
# episode 188: cumul_reward=21.0, accuracy:0.13333, cumul_delta=8.3366, eps=0.56126
# episode 189: cumul_reward=6.0, accuracy:0.0, cumul_delta=0.23425, eps=0.55954
# episode 190: cumul_reward=16.0, accuracy:0.13333, cumul_delta=1.0138, eps=0.55782
# episode 191: cumul_reward=18.0, accuracy:0.13333, cumul_delta=2.5317, eps=0.55611
# episode 192: cumul_reward=12.0, accuracy:0.13333, cumul_delta=1.8738, eps=0.55441
# episode 193: cumul_reward=14.0, accuracy:0.066667, cumul_delta=5.4651, eps=0.55271
# episode 194: cumul_reward=17.0, accuracy:0.2, cumul_delta=6.9521, eps=0.55101
# episode 195: cumul_reward=16.0, accuracy:0.2, cumul_delta=4.7777, eps=0.54932
# episode 196: cumul_reward=16.0, accuracy:0.13333, cumul_delta=3.8675, eps=0.54764
# episode 197: cumul_reward=18.0, accuracy:0.13333, cumul_delta=1.3714, eps=0.54596
# episode 198: cumul_reward=17.0, accuracy:0.13333, cumul_delta=8.5191, eps=0.54428
# episode 199: cumul_reward=23.0, accuracy:0.33333, cumul_delta=2.9436, eps=0.54261
# episode 200: cumul_reward=6.0, accuracy:0.066667, cumul_delta=0.49537, eps=0.54095
# episode 201: cumul_reward=22.0, accuracy:0.13333, cumul_delta=3.1131, eps=0.53929
# episode 202: cumul_reward=12.0, accuracy:0.066667, cumul_delta=-0.18442, eps=0.53763
# episode 203: cumul_reward=7.0, accuracy:0.0, cumul_delta=-1.7021, eps=0.53599
# episode 204: cumul_reward=16.0, accuracy:0.2, cumul_delta=-0.15609, eps=0.53434
# episode 205: cumul_reward=4.0, accuracy:0.0, cumul_delta=0.12425, eps=0.5327
# episode 206: cumul_reward=15.0, accuracy:0.13333, cumul_delta=7.2882, eps=0.53107
# episode 207: cumul_reward=15.0, accuracy:0.2, cumul_delta=0.659, eps=0.52944
# episode 208: cumul_reward=17.0, accuracy:0.2, cumul_delta=5.2828, eps=0.52781
# episode 209: cumul_reward=24.0, accuracy:0.26667, cumul_delta=1.2523, eps=0.5262
# episode 210: cumul_reward=22.0, accuracy:0.2, cumul_delta=4.7741, eps=0.52458
# episode 211: cumul_reward=19.0, accuracy:0.2, cumul_delta=1.8025, eps=0.52297
# episode 212: cumul_reward=18.0, accuracy:0.2, cumul_delta=0.87004, eps=0.52137
# episode 213: cumul_reward=15.0, accuracy:0.13333, cumul_delta=1.1077, eps=0.51977
# episode 214: cumul_reward=11.0, accuracy:0.13333, cumul_delta=0.50959, eps=0.51817
# episode 215: cumul_reward=13.0, accuracy:0.13333, cumul_delta=7.2907, eps=0.51659
# episode 216: cumul_reward=9.0, accuracy:0.066667, cumul_delta=0.039529, eps=0.515
# episode 217: cumul_reward=17.0, accuracy:0.2, cumul_delta=-0.27743, eps=0.51342
# episode 218: cumul_reward=10.0, accuracy:0.066667, cumul_delta=3.513, eps=0.51185
# episode 219: cumul_reward=23.0, accuracy:0.13333, cumul_delta=3.683, eps=0.51028
# episode 220: cumul_reward=13.0, accuracy:0.066667, cumul_delta=7.1343, eps=0.50871
# episode 221: cumul_reward=20.0, accuracy:0.13333, cumul_delta=8.6392, eps=0.50715
# episode 222: cumul_reward=14.0, accuracy:0.2, cumul_delta=0.87007, eps=0.50559
# episode 223: cumul_reward=2.0, accuracy:0.0, cumul_delta=2.2, eps=0.50404
# episode 224: cumul_reward=14.0, accuracy:0.13333, cumul_delta=2.3848, eps=0.5025
# episode 225: cumul_reward=20.0, accuracy:0.2, cumul_delta=5.694, eps=0.50096
# episode 226: cumul_reward=20.0, accuracy:0.2, cumul_delta=2.5316, eps=0.49942
# episode 227: cumul_reward=29.0, accuracy:0.26667, cumul_delta=4.3976, eps=0.49789
# episode 228: cumul_reward=10.0, accuracy:0.066667, cumul_delta=-0.92132, eps=0.49636
# episode 229: cumul_reward=16.0, accuracy:0.13333, cumul_delta=3.534, eps=0.49484
# episode 230: cumul_reward=16.0, accuracy:0.13333, cumul_delta=2.324, eps=0.49332
# episode 231: cumul_reward=27.0, accuracy:0.26667, cumul_delta=2.0167, eps=0.49181
# episode 232: cumul_reward=24.0, accuracy:0.2, cumul_delta=4.1006, eps=0.4903
# episode 233: cumul_reward=19.0, accuracy:0.13333, cumul_delta=0.34485, eps=0.48879
# episode 234: cumul_reward=15.0, accuracy:0.13333, cumul_delta=2.2102, eps=0.48729
# episode 235: cumul_reward=22.0, accuracy:0.26667, cumul_delta=2.9322, eps=0.4858
# episode 236: cumul_reward=13.0, accuracy:0.13333, cumul_delta=-0.37852, eps=0.48431
# episode 237: cumul_reward=19.0, accuracy:0.2, cumul_delta=0.90286, eps=0.48282
# episode 238: cumul_reward=15.0, accuracy:0.2, cumul_delta=3.0555, eps=0.48134
# episode 239: cumul_reward=12.0, accuracy:0.13333, cumul_delta=-0.21215, eps=0.47987
# episode 240: cumul_reward=19.0, accuracy:0.26667, cumul_delta=-0.33492, eps=0.47839
# episode 241: cumul_reward=20.0, accuracy:0.13333, cumul_delta=2.8498, eps=0.47693
# episode 242: cumul_reward=8.0, accuracy:0.066667, cumul_delta=0.026147, eps=0.47546
# episode 243: cumul_reward=6.0, accuracy:0.0, cumul_delta=1.2624, eps=0.47401
# episode 244: cumul_reward=13.0, accuracy:0.066667, cumul_delta=2.4795, eps=0.47255
# episode 245: cumul_reward=19.0, accuracy:0.2, cumul_delta=4.0195, eps=0.4711
# episode 246: cumul_reward=19.0, accuracy:0.13333, cumul_delta=-0.61667, eps=0.46966
# episode 247: cumul_reward=17.0, accuracy:0.13333, cumul_delta=0.51557, eps=0.46822
# episode 248: cumul_reward=12.0, accuracy:0.066667, cumul_delta=1.2144, eps=0.46678
# episode 249: cumul_reward=19.0, accuracy:0.2, cumul_delta=3.2295, eps=0.46535
# episode 250: cumul_reward=11.0, accuracy:0.066667, cumul_delta=1.5549, eps=0.46392
# episode 251: cumul_reward=25.0, accuracy:0.26667, cumul_delta=3.9909, eps=0.4625
# episode 252: cumul_reward=5.0, accuracy:0.066667, cumul_delta=0.55002, eps=0.46108
# episode 253: cumul_reward=17.0, accuracy:0.26667, cumul_delta=4.0113, eps=0.45967
# episode 254: cumul_reward=18.0, accuracy:0.26667, cumul_delta=2.8104, eps=0.45826
# episode 255: cumul_reward=10.0, accuracy:0.13333, cumul_delta=-1.1169, eps=0.45685
# episode 256: cumul_reward=15.0, accuracy:0.2, cumul_delta=2.6001, eps=0.45545
# episode 257: cumul_reward=14.0, accuracy:0.066667, cumul_delta=3.7052, eps=0.45405
# episode 258: cumul_reward=10.0, accuracy:0.13333, cumul_delta=0.978, eps=0.45266
# episode 259: cumul_reward=11.0, accuracy:0.13333, cumul_delta=-1.1248, eps=0.45127
# episode 260: cumul_reward=13.0, accuracy:0.13333, cumul_delta=1.6484, eps=0.44989
# episode 261: cumul_reward=13.0, accuracy:0.13333, cumul_delta=5.5084, eps=0.44851
# episode 262: cumul_reward=26.0, accuracy:0.2, cumul_delta=7.6869, eps=0.44713
# episode 263: cumul_reward=8.0, accuracy:0.13333, cumul_delta=1.276, eps=0.44576
# episode 264: cumul_reward=16.0, accuracy:0.26667, cumul_delta=0.76292, eps=0.44439
# episode 265: cumul_reward=16.0, accuracy:0.2, cumul_delta=1.652, eps=0.44303
# episode 266: cumul_reward=16.0, accuracy:0.13333, cumul_delta=1.1633, eps=0.44167
# episode 267: cumul_reward=22.0, accuracy:0.2, cumul_delta=2.7722, eps=0.44031
# episode 268: cumul_reward=9.0, accuracy:0.13333, cumul_delta=0.60126, eps=0.43896
# episode 269: cumul_reward=17.0, accuracy:0.2, cumul_delta=0.29637, eps=0.43762
# episode 270: cumul_reward=18.0, accuracy:0.26667, cumul_delta=-0.52497, eps=0.43627
# episode 271: cumul_reward=12.0, accuracy:0.13333, cumul_delta=0.006875, eps=0.43494
# episode 272: cumul_reward=20.0, accuracy:0.2, cumul_delta=1.8108, eps=0.4336
# episode 273: cumul_reward=23.0, accuracy:0.26667, cumul_delta=5.7741, eps=0.43227
# episode 274: cumul_reward=13.0, accuracy:0.13333, cumul_delta=3.4353, eps=0.43095
# episode 275: cumul_reward=11.0, accuracy:0.13333, cumul_delta=0.67507, eps=0.42962
# episode 276: cumul_reward=21.0, accuracy:0.26667, cumul_delta=2.1252, eps=0.42831
# episode 277: cumul_reward=7.0, accuracy:0.066667, cumul_delta=-1.9513, eps=0.42699
# episode 278: cumul_reward=18.0, accuracy:0.26667, cumul_delta=3.6556, eps=0.42568
# episode 279: cumul_reward=11.0, accuracy:0.13333, cumul_delta=0.35964, eps=0.42438
# episode 280: cumul_reward=16.0, accuracy:0.2, cumul_delta=1.3461, eps=0.42308
# episode 281: cumul_reward=11.0, accuracy:0.066667, cumul_delta=1.8929, eps=0.42178
# episode 282: cumul_reward=18.0, accuracy:0.2, cumul_delta=6.5822, eps=0.42048
# episode 283: cumul_reward=22.0, accuracy:0.26667, cumul_delta=3.7138, eps=0.41919
# episode 284: cumul_reward=17.0, accuracy:0.26667, cumul_delta=4.8433, eps=0.41791
# episode 285: cumul_reward=26.0, accuracy:0.4, cumul_delta=0.87854, eps=0.41663
# episode 286: cumul_reward=25.0, accuracy:0.26667, cumul_delta=2.3261, eps=0.41535
# episode 287: cumul_reward=14.0, accuracy:0.13333, cumul_delta=-0.92224, eps=0.41407
# episode 288: cumul_reward=5.0, accuracy:0.066667, cumul_delta=-1.6485, eps=0.4128
# episode 289: cumul_reward=17.0, accuracy:0.2, cumul_delta=0.41789, eps=0.41154
# episode 290: cumul_reward=20.0, accuracy:0.2, cumul_delta=6.3595, eps=0.41028
# episode 291: cumul_reward=11.0, accuracy:0.066667, cumul_delta=-0.85149, eps=0.40902
# episode 292: cumul_reward=17.0, accuracy:0.2, cumul_delta=-1.1395, eps=0.40776
# episode 293: cumul_reward=10.0, accuracy:0.0, cumul_delta=4.3796, eps=0.40651
# episode 294: cumul_reward=16.0, accuracy:0.2, cumul_delta=1.1693, eps=0.40526
# episode 295: cumul_reward=21.0, accuracy:0.2, cumul_delta=0.54885, eps=0.40402
# episode 296: cumul_reward=26.0, accuracy:0.4, cumul_delta=2.2248, eps=0.40278
# episode 297: cumul_reward=24.0, accuracy:0.4, cumul_delta=0.59138, eps=0.40155
# episode 298: cumul_reward=16.0, accuracy:0.26667, cumul_delta=2.2126, eps=0.40031
# episode 299: cumul_reward=20.0, accuracy:0.26667, cumul_delta=-0.83326, eps=0.39909
# episode 300: cumul_reward=22.0, accuracy:0.33333, cumul_delta=0.6441, eps=0.39786
# episode 301: cumul_reward=22.0, accuracy:0.2, cumul_delta=2.4187, eps=0.39664
# episode 302: cumul_reward=24.0, accuracy:0.26667, cumul_delta=0.72494, eps=0.39543
# episode 303: cumul_reward=10.0, accuracy:0.066667, cumul_delta=3.7957, eps=0.39421
# episode 304: cumul_reward=22.0, accuracy:0.33333, cumul_delta=2.1215, eps=0.393
# episode 305: cumul_reward=25.0, accuracy:0.26667, cumul_delta=2.3832, eps=0.3918
# episode 306: cumul_reward=33.0, accuracy:0.4, cumul_delta=5.1695, eps=0.3906
# episode 307: cumul_reward=23.0, accuracy:0.26667, cumul_delta=3.2033, eps=0.3894
# episode 308: cumul_reward=22.0, accuracy:0.26667, cumul_delta=3.6922, eps=0.3882
# episode 309: cumul_reward=22.0, accuracy:0.33333, cumul_delta=1.856, eps=0.38701
# episode 310: cumul_reward=21.0, accuracy:0.33333, cumul_delta=-1.4586, eps=0.38583
# episode 311: cumul_reward=25.0, accuracy:0.33333, cumul_delta=2.3428, eps=0.38464
# episode 312: cumul_reward=12.0, accuracy:0.13333, cumul_delta=-2.1948, eps=0.38346
# episode 313: cumul_reward=22.0, accuracy:0.26667, cumul_delta=3.9629, eps=0.38229
# episode 314: cumul_reward=19.0, accuracy:0.13333, cumul_delta=1.6091, eps=0.38111
# episode 315: cumul_reward=15.0, accuracy:0.2, cumul_delta=1.9459, eps=0.37994
# episode 316: cumul_reward=24.0, accuracy:0.26667, cumul_delta=2.7214, eps=0.37878
# episode 317: cumul_reward=31.0, accuracy:0.26667, cumul_delta=5.5015, eps=0.37762
# episode 318: cumul_reward=18.0, accuracy:0.2, cumul_delta=-2.4543, eps=0.37646
# episode 319: cumul_reward=19.0, accuracy:0.2, cumul_delta=0.32096, eps=0.3753
# episode 320: cumul_reward=24.0, accuracy:0.33333, cumul_delta=2.3597, eps=0.37415
# episode 321: cumul_reward=11.0, accuracy:0.066667, cumul_delta=10.258, eps=0.373
# episode 322: cumul_reward=23.0, accuracy:0.33333, cumul_delta=1.4286, eps=0.37186
# episode 323: cumul_reward=23.0, accuracy:0.26667, cumul_delta=0.53353, eps=0.37072
# episode 324: cumul_reward=15.0, accuracy:0.2, cumul_delta=0.99858, eps=0.36958
# episode 325: cumul_reward=28.0, accuracy:0.4, cumul_delta=1.0983, eps=0.36845
# episode 326: cumul_reward=22.0, accuracy:0.26667, cumul_delta=0.19849, eps=0.36732
# episode 327: cumul_reward=15.0, accuracy:0.13333, cumul_delta=-3.6132, eps=0.36619
# episode 328: cumul_reward=32.0, accuracy:0.4, cumul_delta=10.089, eps=0.36507
# episode 329: cumul_reward=10.0, accuracy:0.13333, cumul_delta=-1.7712, eps=0.36395
# episode 330: cumul_reward=23.0, accuracy:0.26667, cumul_delta=1.9456, eps=0.36283
# episode 331: cumul_reward=34.0, accuracy:0.46667, cumul_delta=5.1336, eps=0.36172
# episode 332: cumul_reward=26.0, accuracy:0.33333, cumul_delta=-3.2663, eps=0.36061
# episode 333: cumul_reward=30.0, accuracy:0.46667, cumul_delta=2.7767, eps=0.3595
# episode 334: cumul_reward=16.0, accuracy:0.26667, cumul_delta=0.42366, eps=0.3584
# episode 335: cumul_reward=26.0, accuracy:0.4, cumul_delta=3.7836, eps=0.3573
# episode 336: cumul_reward=24.0, accuracy:0.26667, cumul_delta=-0.5256, eps=0.35621
# episode 337: cumul_reward=22.0, accuracy:0.33333, cumul_delta=2.6788, eps=0.35511
# episode 338: cumul_reward=22.0, accuracy:0.26667, cumul_delta=-2.7774, eps=0.35402
# episode 339: cumul_reward=36.0, accuracy:0.53333, cumul_delta=2.1851, eps=0.35294
# episode 340: cumul_reward=25.0, accuracy:0.33333, cumul_delta=1.0747, eps=0.35186
# episode 341: cumul_reward=9.0, accuracy:0.13333, cumul_delta=0.72852, eps=0.35078
# episode 342: cumul_reward=16.0, accuracy:0.2, cumul_delta=4.1809, eps=0.3497
# episode 343: cumul_reward=17.0, accuracy:0.2, cumul_delta=4.7816, eps=0.34863
# episode 344: cumul_reward=25.0, accuracy:0.4, cumul_delta=1.0542, eps=0.34756
# episode 345: cumul_reward=31.0, accuracy:0.46667, cumul_delta=2.1181, eps=0.34649
# episode 346: cumul_reward=29.0, accuracy:0.4, cumul_delta=4.351, eps=0.34543
# episode 347: cumul_reward=16.0, accuracy:0.26667, cumul_delta=1.9865, eps=0.34437
# episode 348: cumul_reward=28.0, accuracy:0.4, cumul_delta=3.5255, eps=0.34331
# episode 349: cumul_reward=17.0, accuracy:0.26667, cumul_delta=0.68104, eps=0.34226
# episode 350: cumul_reward=32.0, accuracy:0.33333, cumul_delta=1.8061, eps=0.34121
# episode 351: cumul_reward=41.0, accuracy:0.6, cumul_delta=0.49378, eps=0.34016
# episode 352: cumul_reward=26.0, accuracy:0.26667, cumul_delta=3.9275, eps=0.33912
# episode 353: cumul_reward=30.0, accuracy:0.4, cumul_delta=2.4084, eps=0.33808
# episode 354: cumul_reward=18.0, accuracy:0.13333, cumul_delta=6.216, eps=0.33704
# episode 355: cumul_reward=30.0, accuracy:0.4, cumul_delta=2.8572, eps=0.33601
# episode 356: cumul_reward=22.0, accuracy:0.2, cumul_delta=1.4167, eps=0.33498
# episode 357: cumul_reward=22.0, accuracy:0.26667, cumul_delta=0.18028, eps=0.33395
# episode 358: cumul_reward=19.0, accuracy:0.26667, cumul_delta=3.432, eps=0.33293
# episode 359: cumul_reward=23.0, accuracy:0.26667, cumul_delta=3.8714, eps=0.33191
# episode 360: cumul_reward=21.0, accuracy:0.26667, cumul_delta=5.5484, eps=0.33089
# episode 361: cumul_reward=16.0, accuracy:0.26667, cumul_delta=0.20985, eps=0.32987
# episode 362: cumul_reward=23.0, accuracy:0.33333, cumul_delta=4.0559, eps=0.32886
# episode 363: cumul_reward=26.0, accuracy:0.4, cumul_delta=-1.9494, eps=0.32785
# episode 364: cumul_reward=13.0, accuracy:0.13333, cumul_delta=0.8252, eps=0.32685
# episode 365: cumul_reward=19.0, accuracy:0.26667, cumul_delta=6.2188, eps=0.32584
# episode 366: cumul_reward=27.0, accuracy:0.33333, cumul_delta=-1.6537, eps=0.32484
# episode 367: cumul_reward=23.0, accuracy:0.33333, cumul_delta=1.4897, eps=0.32385
# episode 368: cumul_reward=41.0, accuracy:0.66667, cumul_delta=1.9012, eps=0.32285
# episode 369: cumul_reward=39.0, accuracy:0.53333, cumul_delta=6.2855, eps=0.32186
# episode 370: cumul_reward=26.0, accuracy:0.4, cumul_delta=-1.7282, eps=0.32088
# episode 371: cumul_reward=21.0, accuracy:0.33333, cumul_delta=1.8367, eps=0.31989
# episode 372: cumul_reward=18.0, accuracy:0.26667, cumul_delta=-1.9113, eps=0.31891
# episode 373: cumul_reward=26.0, accuracy:0.4, cumul_delta=3.5317, eps=0.31793
# episode 374: cumul_reward=5.0, accuracy:0.066667, cumul_delta=-1.6421, eps=0.31696
# episode 375: cumul_reward=19.0, accuracy:0.26667, cumul_delta=1.0679, eps=0.31598
# episode 376: cumul_reward=19.0, accuracy:0.2, cumul_delta=0.76991, eps=0.31502
# episode 377: cumul_reward=18.0, accuracy:0.2, cumul_delta=1.1246, eps=0.31405
# episode 378: cumul_reward=32.0, accuracy:0.46667, cumul_delta=0.31092, eps=0.31309
# episode 379: cumul_reward=20.0, accuracy:0.26667, cumul_delta=4.379, eps=0.31213
# episode 380: cumul_reward=31.0, accuracy:0.33333, cumul_delta=7.6987, eps=0.31117
# episode 381: cumul_reward=30.0, accuracy:0.4, cumul_delta=0.34946, eps=0.31021
# episode 382: cumul_reward=27.0, accuracy:0.4, cumul_delta=-0.49727, eps=0.30926
# episode 383: cumul_reward=37.0, accuracy:0.53333, cumul_delta=0.75358, eps=0.30831
# episode 384: cumul_reward=40.0, accuracy:0.6, cumul_delta=2.2244, eps=0.30737
# episode 385: cumul_reward=31.0, accuracy:0.4, cumul_delta=1.8861, eps=0.30643
# episode 386: cumul_reward=24.0, accuracy:0.4, cumul_delta=0.19764, eps=0.30549
# episode 387: cumul_reward=13.0, accuracy:0.2, cumul_delta=1.1648, eps=0.30455
# episode 388: cumul_reward=8.0, accuracy:0.066667, cumul_delta=1.5189, eps=0.30361
# episode 389: cumul_reward=15.0, accuracy:0.2, cumul_delta=2.2378, eps=0.30268
# episode 390: cumul_reward=29.0, accuracy:0.46667, cumul_delta=-1.0764, eps=0.30175
# episode 391: cumul_reward=29.0, accuracy:0.4, cumul_delta=-0.56742, eps=0.30083
# episode 392: cumul_reward=23.0, accuracy:0.33333, cumul_delta=-1.0428, eps=0.29991
# episode 393: cumul_reward=20.0, accuracy:0.26667, cumul_delta=1.7692, eps=0.29899
# episode 394: cumul_reward=30.0, accuracy:0.4, cumul_delta=4.4882, eps=0.29807
# episode 395: cumul_reward=30.0, accuracy:0.46667, cumul_delta=1.5384, eps=0.29715
# episode 396: cumul_reward=17.0, accuracy:0.26667, cumul_delta=1.0036, eps=0.29624
# episode 397: cumul_reward=32.0, accuracy:0.46667, cumul_delta=3.7535, eps=0.29533
# episode 398: cumul_reward=20.0, accuracy:0.26667, cumul_delta=-3.2727, eps=0.29443
# episode 399: cumul_reward=28.0, accuracy:0.33333, cumul_delta=-1.5745, eps=0.29353
# episode 400: cumul_reward=28.0, accuracy:0.4, cumul_delta=0.75241, eps=0.29262
# episode 401: cumul_reward=27.0, accuracy:0.4, cumul_delta=3.904, eps=0.29173
# episode 402: cumul_reward=25.0, accuracy:0.4, cumul_delta=1.4657, eps=0.29083
# episode 403: cumul_reward=35.0, accuracy:0.53333, cumul_delta=0.84232, eps=0.28994
# episode 404: cumul_reward=26.0, accuracy:0.33333, cumul_delta=-0.56786, eps=0.28905
# episode 405: cumul_reward=25.0, accuracy:0.33333, cumul_delta=3.9521, eps=0.28816
# episode 406: cumul_reward=9.0, accuracy:0.13333, cumul_delta=-1.65, eps=0.28728
# episode 407: cumul_reward=37.0, accuracy:0.6, cumul_delta=2.2709, eps=0.2864
# episode 408: cumul_reward=17.0, accuracy:0.2, cumul_delta=0.79679, eps=0.28552
# episode 409: cumul_reward=32.0, accuracy:0.4, cumul_delta=3.4431, eps=0.28464
# episode 410: cumul_reward=34.0, accuracy:0.46667, cumul_delta=4.2364, eps=0.28377
# episode 411: cumul_reward=33.0, accuracy:0.46667, cumul_delta=3.2237, eps=0.2829
# episode 412: cumul_reward=36.0, accuracy:0.53333, cumul_delta=2.5083, eps=0.28203
# episode 413: cumul_reward=30.0, accuracy:0.46667, cumul_delta=1.5201, eps=0.28117
# episode 414: cumul_reward=19.0, accuracy:0.26667, cumul_delta=3.4639, eps=0.28031
# episode 415: cumul_reward=21.0, accuracy:0.26667, cumul_delta=1.9049, eps=0.27945
# episode 416: cumul_reward=33.0, accuracy:0.46667, cumul_delta=-1.4782, eps=0.27859
# episode 417: cumul_reward=16.0, accuracy:0.2, cumul_delta=3.191, eps=0.27773
# episode 418: cumul_reward=29.0, accuracy:0.46667, cumul_delta=2.467, eps=0.27688
# episode 419: cumul_reward=29.0, accuracy:0.4, cumul_delta=1.9466, eps=0.27603
# episode 420: cumul_reward=38.0, accuracy:0.53333, cumul_delta=2.7306, eps=0.27519
# episode 421: cumul_reward=30.0, accuracy:0.33333, cumul_delta=0.099052, eps=0.27434
# episode 422: cumul_reward=30.0, accuracy:0.33333, cumul_delta=-2.0585, eps=0.2735
# episode 423: cumul_reward=31.0, accuracy:0.46667, cumul_delta=6.2468, eps=0.27266
# episode 424: cumul_reward=25.0, accuracy:0.26667, cumul_delta=0.74978, eps=0.27183
# episode 425: cumul_reward=25.0, accuracy:0.33333, cumul_delta=-5.5205, eps=0.27099
# episode 426: cumul_reward=24.0, accuracy:0.33333, cumul_delta=-1.0907, eps=0.27016
# episode 427: cumul_reward=33.0, accuracy:0.53333, cumul_delta=1.9088, eps=0.26933
# episode 428: cumul_reward=27.0, accuracy:0.4, cumul_delta=1.0247, eps=0.26851
# episode 429: cumul_reward=36.0, accuracy:0.53333, cumul_delta=2.5004, eps=0.26768
# episode 430: cumul_reward=22.0, accuracy:0.26667, cumul_delta=-2.5347, eps=0.26686
# episode 431: cumul_reward=11.0, accuracy:0.13333, cumul_delta=0.082479, eps=0.26604
# episode 432: cumul_reward=34.0, accuracy:0.46667, cumul_delta=4.4547, eps=0.26523
# episode 433: cumul_reward=42.0, accuracy:0.6, cumul_delta=1.0902, eps=0.26441
# episode 434: cumul_reward=15.0, accuracy:0.2, cumul_delta=1.1847, eps=0.2636
# episode 435: cumul_reward=30.0, accuracy:0.46667, cumul_delta=0.44826, eps=0.26279
# episode 436: cumul_reward=24.0, accuracy:0.33333, cumul_delta=0.42817, eps=0.26199
# episode 437: cumul_reward=26.0, accuracy:0.33333, cumul_delta=-3.3587, eps=0.26118
# episode 438: cumul_reward=24.0, accuracy:0.26667, cumul_delta=3.1972, eps=0.26038
# episode 439: cumul_reward=33.0, accuracy:0.46667, cumul_delta=1.4647, eps=0.25958
# episode 440: cumul_reward=18.0, accuracy:0.2, cumul_delta=6.71, eps=0.25879
# episode 441: cumul_reward=26.0, accuracy:0.33333, cumul_delta=-2.2366, eps=0.25799
# episode 442: cumul_reward=26.0, accuracy:0.26667, cumul_delta=-0.91072, eps=0.2572
# episode 443: cumul_reward=22.0, accuracy:0.26667, cumul_delta=1.5248, eps=0.25641
# episode 444: cumul_reward=24.0, accuracy:0.4, cumul_delta=1.4736, eps=0.25563
# episode 445: cumul_reward=22.0, accuracy:0.26667, cumul_delta=2.9879, eps=0.25484
# episode 446: cumul_reward=42.0, accuracy:0.6, cumul_delta=3.084, eps=0.25406
# episode 447: cumul_reward=25.0, accuracy:0.33333, cumul_delta=-1.9865, eps=0.25328
# episode 448: cumul_reward=24.0, accuracy:0.26667, cumul_delta=-1.8544, eps=0.2525
# episode 449: cumul_reward=36.0, accuracy:0.53333, cumul_delta=1.7019, eps=0.25173
# episode 450: cumul_reward=13.0, accuracy:0.2, cumul_delta=-1.0484, eps=0.25096
# episode 451: cumul_reward=14.0, accuracy:0.13333, cumul_delta=1.6444, eps=0.25019
# episode 452: cumul_reward=40.0, accuracy:0.53333, cumul_delta=1.6739, eps=0.24942
# episode 453: cumul_reward=40.0, accuracy:0.53333, cumul_delta=2.9164, eps=0.24865
# episode 454: cumul_reward=27.0, accuracy:0.4, cumul_delta=-1.2755, eps=0.24789
# episode 455: cumul_reward=32.0, accuracy:0.53333, cumul_delta=1.1482, eps=0.24713
# episode 456: cumul_reward=37.0, accuracy:0.53333, cumul_delta=-1.2242, eps=0.24637
# episode 457: cumul_reward=24.0, accuracy:0.33333, cumul_delta=6.5904, eps=0.24562
# episode 458: cumul_reward=26.0, accuracy:0.4, cumul_delta=-1.9899, eps=0.24486
# episode 459: cumul_reward=28.0, accuracy:0.33333, cumul_delta=0.52156, eps=0.24411
# episode 460: cumul_reward=26.0, accuracy:0.33333, cumul_delta=2.9871, eps=0.24336
# episode 461: cumul_reward=28.0, accuracy:0.4, cumul_delta=4.237, eps=0.24262
# episode 462: cumul_reward=23.0, accuracy:0.33333, cumul_delta=0.23824, eps=0.24187
# episode 463: cumul_reward=25.0, accuracy:0.33333, cumul_delta=-2.1059, eps=0.24113
# episode 464: cumul_reward=16.0, accuracy:0.26667, cumul_delta=6.1989e-06, eps=0.24039
# episode 465: cumul_reward=27.0, accuracy:0.4, cumul_delta=1.2523, eps=0.23965
# episode 466: cumul_reward=27.0, accuracy:0.4, cumul_delta=4.2972, eps=0.23892
# episode 467: cumul_reward=30.0, accuracy:0.4, cumul_delta=1.7384, eps=0.23819
# episode 468: cumul_reward=27.0, accuracy:0.4, cumul_delta=1.4736, eps=0.23746
# episode 469: cumul_reward=23.0, accuracy:0.33333, cumul_delta=0.835, eps=0.23673
# episode 470: cumul_reward=18.0, accuracy:0.2, cumul_delta=-1.2409, eps=0.236
# episode 471: cumul_reward=25.0, accuracy:0.33333, cumul_delta=3.0396, eps=0.23528
# episode 472: cumul_reward=27.0, accuracy:0.33333, cumul_delta=3.8106, eps=0.23456
# episode 473: cumul_reward=28.0, accuracy:0.4, cumul_delta=-1.541, eps=0.23384
# episode 474: cumul_reward=35.0, accuracy:0.53333, cumul_delta=2.1568, eps=0.23312
# episode 475: cumul_reward=16.0, accuracy:0.2, cumul_delta=0.79225, eps=0.2324
# episode 476: cumul_reward=27.0, accuracy:0.33333, cumul_delta=3.3088, eps=0.23169
# episode 477: cumul_reward=35.0, accuracy:0.46667, cumul_delta=2.1599, eps=0.23098
# episode 478: cumul_reward=19.0, accuracy:0.13333, cumul_delta=0.64727, eps=0.23027
# episode 479: cumul_reward=34.0, accuracy:0.46667, cumul_delta=3.7797, eps=0.22957
# episode 480: cumul_reward=28.0, accuracy:0.46667, cumul_delta=0.89212, eps=0.22886
# episode 481: cumul_reward=33.0, accuracy:0.46667, cumul_delta=2.8492, eps=0.22816
# episode 482: cumul_reward=25.0, accuracy:0.33333, cumul_delta=0.063221, eps=0.22746
# episode 483: cumul_reward=23.0, accuracy:0.26667, cumul_delta=0.26523, eps=0.22676
# episode 484: cumul_reward=31.0, accuracy:0.46667, cumul_delta=0.27979, eps=0.22607
# episode 485: cumul_reward=34.0, accuracy:0.46667, cumul_delta=1.8492, eps=0.22537
# episode 486: cumul_reward=22.0, accuracy:0.26667, cumul_delta=-5.3561, eps=0.22468
# episode 487: cumul_reward=29.0, accuracy:0.4, cumul_delta=0.20401, eps=0.22399
# episode 488: cumul_reward=29.0, accuracy:0.4, cumul_delta=5.4107, eps=0.22331
# episode 489: cumul_reward=34.0, accuracy:0.46667, cumul_delta=1.7064, eps=0.22262
# episode 490: cumul_reward=38.0, accuracy:0.53333, cumul_delta=0.57766, eps=0.22194
# episode 491: cumul_reward=29.0, accuracy:0.4, cumul_delta=-0.18697, eps=0.22126
# episode 492: cumul_reward=35.0, accuracy:0.53333, cumul_delta=0.44196, eps=0.22058
# episode 493: cumul_reward=32.0, accuracy:0.46667, cumul_delta=-1.5824, eps=0.2199
# episode 494: cumul_reward=34.0, accuracy:0.46667, cumul_delta=1.8283, eps=0.21923
# episode 495: cumul_reward=39.0, accuracy:0.6, cumul_delta=0.14218, eps=0.21855
# episode 496: cumul_reward=16.0, accuracy:0.2, cumul_delta=1.2118, eps=0.21788
# episode 497: cumul_reward=44.0, accuracy:0.6, cumul_delta=1.952, eps=0.21722
# episode 498: cumul_reward=37.0, accuracy:0.53333, cumul_delta=2.2142, eps=0.21655
# episode 499: cumul_reward=38.0, accuracy:0.53333, cumul_delta=0.25059, eps=0.21589
# episode 500: cumul_reward=35.0, accuracy:0.53333, cumul_delta=0.068515, eps=0.21522
# episode 501: cumul_reward=25.0, accuracy:0.33333, cumul_delta=-2.1955, eps=0.21456
# episode 502: cumul_reward=33.0, accuracy:0.46667, cumul_delta=3.8227, eps=0.2139
# episode 503: cumul_reward=36.0, accuracy:0.53333, cumul_delta=3.1964, eps=0.21325
# episode 504: cumul_reward=36.0, accuracy:0.53333, cumul_delta=0.2767, eps=0.21259
# episode 505: cumul_reward=35.0, accuracy:0.53333, cumul_delta=0.098933, eps=0.21194
# episode 506: cumul_reward=18.0, accuracy:0.26667, cumul_delta=0.99005, eps=0.21129
# episode 507: cumul_reward=19.0, accuracy:0.2, cumul_delta=3.0626, eps=0.21064
# episode 508: cumul_reward=21.0, accuracy:0.13333, cumul_delta=1.733, eps=0.21
# episode 509: cumul_reward=27.0, accuracy:0.4, cumul_delta=0.90874, eps=0.20935
# episode 510: cumul_reward=19.0, accuracy:0.2, cumul_delta=-0.61786, eps=0.20871
# episode 511: cumul_reward=32.0, accuracy:0.46667, cumul_delta=2.531, eps=0.20807
# episode 512: cumul_reward=20.0, accuracy:0.2, cumul_delta=1.6484, eps=0.20743
# episode 513: cumul_reward=40.0, accuracy:0.46667, cumul_delta=1.5564, eps=0.2068
# episode 514: cumul_reward=30.0, accuracy:0.46667, cumul_delta=0.62313, eps=0.20616
# episode 515: cumul_reward=36.0, accuracy:0.6, cumul_delta=0.13987, eps=0.20553
# episode 516: cumul_reward=39.0, accuracy:0.6, cumul_delta=0.063071, eps=0.2049
# episode 517: cumul_reward=36.0, accuracy:0.53333, cumul_delta=-1.9086, eps=0.20427
# episode 518: cumul_reward=38.0, accuracy:0.53333, cumul_delta=1.3261, eps=0.20364
# episode 519: cumul_reward=32.0, accuracy:0.4, cumul_delta=1.4034, eps=0.20302
# episode 520: cumul_reward=37.0, accuracy:0.53333, cumul_delta=0.34654, eps=0.2024
# episode 521: cumul_reward=21.0, accuracy:0.33333, cumul_delta=0.13611, eps=0.20178
# episode 522: cumul_reward=30.0, accuracy:0.4, cumul_delta=0.057376, eps=0.20116
# episode 523: cumul_reward=39.0, accuracy:0.6, cumul_delta=0.072186, eps=0.20054
# episode 524: cumul_reward=31.0, accuracy:0.4, cumul_delta=0.5767, eps=0.19993
# episode 525: cumul_reward=34.0, accuracy:0.53333, cumul_delta=1.9097, eps=0.19931
# episode 526: cumul_reward=24.0, accuracy:0.4, cumul_delta=0.01794, eps=0.1987
# episode 527: cumul_reward=25.0, accuracy:0.4, cumul_delta=0.65727, eps=0.19809
# episode 528: cumul_reward=22.0, accuracy:0.26667, cumul_delta=0.18793, eps=0.19748
# episode 529: cumul_reward=29.0, accuracy:0.46667, cumul_delta=-1.6464, eps=0.19688
# episode 530: cumul_reward=20.0, accuracy:0.26667, cumul_delta=-0.3009, eps=0.19627
# episode 531: cumul_reward=26.0, accuracy:0.26667, cumul_delta=-0.79719, eps=0.19567
# episode 532: cumul_reward=37.0, accuracy:0.53333, cumul_delta=1.6236, eps=0.19507
# episode 533: cumul_reward=26.0, accuracy:0.33333, cumul_delta=1.2887, eps=0.19447
# episode 534: cumul_reward=27.0, accuracy:0.4, cumul_delta=1.6366, eps=0.19388
# episode 535: cumul_reward=43.0, accuracy:0.6, cumul_delta=0.37795, eps=0.19328
# episode 536: cumul_reward=40.0, accuracy:0.53333, cumul_delta=0.64887, eps=0.19269
# episode 537: cumul_reward=36.0, accuracy:0.6, cumul_delta=0.08686, eps=0.1921
# episode 538: cumul_reward=24.0, accuracy:0.33333, cumul_delta=0.061641, eps=0.19151
# episode 539: cumul_reward=37.0, accuracy:0.53333, cumul_delta=0.019667, eps=0.19092
# episode 540: cumul_reward=32.0, accuracy:0.4, cumul_delta=-0.51677, eps=0.19034
# episode 541: cumul_reward=28.0, accuracy:0.33333, cumul_delta=-0.42644, eps=0.18975
# episode 542: cumul_reward=41.0, accuracy:0.6, cumul_delta=0.54806, eps=0.18917
# episode 543: cumul_reward=32.0, accuracy:0.4, cumul_delta=0.20688, eps=0.18859
# episode 544: cumul_reward=24.0, accuracy:0.26667, cumul_delta=2.2036, eps=0.18801
# episode 545: cumul_reward=35.0, accuracy:0.53333, cumul_delta=-3.4041, eps=0.18743
# episode 546: cumul_reward=28.0, accuracy:0.33333, cumul_delta=-0.64771, eps=0.18686
# episode 547: cumul_reward=27.0, accuracy:0.4, cumul_delta=0.9075, eps=0.18629
# episode 548: cumul_reward=41.0, accuracy:0.66667, cumul_delta=-0.48065, eps=0.18571
# episode 549: cumul_reward=27.0, accuracy:0.33333, cumul_delta=1.3255, eps=0.18514
# episode 550: cumul_reward=38.0, accuracy:0.46667, cumul_delta=-0.64513, eps=0.18458
# episode 551: cumul_reward=30.0, accuracy:0.4, cumul_delta=2.2319, eps=0.18401
# episode 552: cumul_reward=27.0, accuracy:0.4, cumul_delta=0.40853, eps=0.18345
# episode 553: cumul_reward=33.0, accuracy:0.33333, cumul_delta=7.8928, eps=0.18288
# episode 554: cumul_reward=39.0, accuracy:0.53333, cumul_delta=0.73665, eps=0.18232
# episode 555: cumul_reward=27.0, accuracy:0.33333, cumul_delta=0.00057352, eps=0.18176
# episode 556: cumul_reward=31.0, accuracy:0.4, cumul_delta=0.2211, eps=0.18121
# episode 557: cumul_reward=21.0, accuracy:0.26667, cumul_delta=-0.58602, eps=0.18065
# episode 558: cumul_reward=41.0, accuracy:0.53333, cumul_delta=2.3643, eps=0.1801
# episode 559: cumul_reward=27.0, accuracy:0.33333, cumul_delta=3.3739, eps=0.17954
# episode 560: cumul_reward=35.0, accuracy:0.46667, cumul_delta=0.4954, eps=0.17899
# episode 561: cumul_reward=27.0, accuracy:0.26667, cumul_delta=0.66832, eps=0.17844
# episode 562: cumul_reward=41.0, accuracy:0.53333, cumul_delta=2.3895, eps=0.1779
# episode 563: cumul_reward=33.0, accuracy:0.4, cumul_delta=2.05, eps=0.17735
# episode 564: cumul_reward=42.0, accuracy:0.53333, cumul_delta=3.3724, eps=0.17681
# episode 565: cumul_reward=42.0, accuracy:0.53333, cumul_delta=2.5076, eps=0.17626
# episode 566: cumul_reward=34.0, accuracy:0.4, cumul_delta=0.68194, eps=0.17572
# episode 567: cumul_reward=26.0, accuracy:0.26667, cumul_delta=1.2657, eps=0.17518
# episode 568: cumul_reward=36.0, accuracy:0.46667, cumul_delta=2.1095, eps=0.17465
# episode 569: cumul_reward=31.0, accuracy:0.46667, cumul_delta=0.18849, eps=0.17411
# episode 570: cumul_reward=32.0, accuracy:0.46667, cumul_delta=-1.1994, eps=0.17358
# episode 571: cumul_reward=34.0, accuracy:0.4, cumul_delta=1.1744, eps=0.17304
# episode 572: cumul_reward=22.0, accuracy:0.2, cumul_delta=0.040792, eps=0.17251
# episode 573: cumul_reward=21.0, accuracy:0.33333, cumul_delta=0.29728, eps=0.17198
# episode 574: cumul_reward=38.0, accuracy:0.53333, cumul_delta=0.076642, eps=0.17146
# episode 575: cumul_reward=36.0, accuracy:0.46667, cumul_delta=1.4128, eps=0.17093
# episode 576: cumul_reward=38.0, accuracy:0.46667, cumul_delta=-1.5321, eps=0.17041
# episode 577: cumul_reward=31.0, accuracy:0.33333, cumul_delta=1.4613, eps=0.16988
# episode 578: cumul_reward=26.0, accuracy:0.4, cumul_delta=-0.47918, eps=0.16936
# episode 579: cumul_reward=42.0, accuracy:0.53333, cumul_delta=0.41915, eps=0.16884
# episode 580: cumul_reward=32.0, accuracy:0.4, cumul_delta=2.2189, eps=0.16833
# episode 581: cumul_reward=24.0, accuracy:0.2, cumul_delta=0.57575, eps=0.16781
# episode 582: cumul_reward=31.0, accuracy:0.4, cumul_delta=-0.43595, eps=0.16729
# episode 583: cumul_reward=34.0, accuracy:0.4, cumul_delta=0.72843, eps=0.16678
# episode 584: cumul_reward=41.0, accuracy:0.53333, cumul_delta=-1.5425, eps=0.16627
# episode 585: cumul_reward=43.0, accuracy:0.6, cumul_delta=0.49768, eps=0.16576
# episode 586: cumul_reward=23.0, accuracy:0.2, cumul_delta=2.2397, eps=0.16525
# episode 587: cumul_reward=28.0, accuracy:0.33333, cumul_delta=-1.2314, eps=0.16474
# episode 588: cumul_reward=30.0, accuracy:0.33333, cumul_delta=0.022652, eps=0.16424
# episode 589: cumul_reward=32.0, accuracy:0.46667, cumul_delta=1.8351, eps=0.16374
# episode 590: cumul_reward=38.0, accuracy:0.46667, cumul_delta=7.6919, eps=0.16323
# episode 591: cumul_reward=23.0, accuracy:0.26667, cumul_delta=-1.648, eps=0.16273
# episode 592: cumul_reward=22.0, accuracy:0.33333, cumul_delta=-0.30879, eps=0.16223
# episode 593: cumul_reward=42.0, accuracy:0.53333, cumul_delta=1.4315, eps=0.16174
# episode 594: cumul_reward=36.0, accuracy:0.46667, cumul_delta=5.6433, eps=0.16124
# episode 595: cumul_reward=42.0, accuracy:0.6, cumul_delta=0.18421, eps=0.16074
# episode 596: cumul_reward=31.0, accuracy:0.4, cumul_delta=0.65148, eps=0.16025
# episode 597: cumul_reward=30.0, accuracy:0.33333, cumul_delta=0.0033937, eps=0.15976
# episode 598: cumul_reward=35.0, accuracy:0.4, cumul_delta=-1.3602, eps=0.15927
# ...
# episode 1315: cumul_reward=44.0, accuracy:0.6, cumul_delta=-2.1997, eps=0.017599
# episode 1316: cumul_reward=58.0, accuracy:0.86667, cumul_delta=1.2101, eps=0.017545
# episode 1317: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.54456, eps=0.017492
# episode 1318: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.24505, eps=0.017438
# episode 1319: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.11027, eps=0.017384
# episode 1320: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.049623, eps=0.017331
# episode 1321: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.02233, eps=0.017278
# episode 1322: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.010048, eps=0.017225
# episode 1323: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0045218, eps=0.017172
# episode 1324: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.0020351, eps=0.017119
# episode 1325: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.00091553, eps=0.017067
# episode 1326: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.00041199, eps=0.017015
# episode 1327: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.00018549, eps=0.016962
# episode 1328: cumul_reward=50.0, accuracy:0.73333, cumul_delta=8.3447e-05, eps=0.01691
# episode 1329: cumul_reward=58.0, accuracy:0.86667, cumul_delta=3.767e-05, eps=0.016858
# episode 1330: cumul_reward=58.0, accuracy:0.86667, cumul_delta=1.6689e-05, eps=0.016807
# episode 1331: cumul_reward=58.0, accuracy:0.86667, cumul_delta=7.6294e-06, eps=0.016755
# episode 1332: cumul_reward=58.0, accuracy:0.86667, cumul_delta=3.3379e-06, eps=0.016704
# episode 1333: cumul_reward=58.0, accuracy:0.86667, cumul_delta=1.4305e-06, eps=0.016653
# episode 1334: cumul_reward=58.0, accuracy:0.86667, cumul_delta=9.5367e-07, eps=0.016601
# episode 1335: cumul_reward=58.0, accuracy:0.86667, cumul_delta=4.7684e-07, eps=0.016551
# episode 1336: cumul_reward=51.0, accuracy:0.8, cumul_delta=0.0, eps=0.0165
# episode 1337: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.016449
# episode 1338: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.016399
# episode 1339: cumul_reward=50.0, accuracy:0.73333, cumul_delta=0.0, eps=0.016348
# episode 1340: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.016298
# episode 1341: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.0, eps=0.016248
# episode 1342: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.016198
# episode 1343: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.016149
# episode 1344: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.016099
# episode 1345: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.01605
# episode 1346: cumul_reward=50.0, accuracy:0.73333, cumul_delta=0.0, eps=0.016001
# episode 1347: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.015952
# episode 1348: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.015903
# episode 1349: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.015854
# episode 1350: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.015805
# episode 1351: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.015757
# episode 1352: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.015708
# episode 1353: cumul_reward=47.0, accuracy:0.66667, cumul_delta=0.2475, eps=0.01566
# episode 1354: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.015612
# episode 1355: cumul_reward=47.0, accuracy:0.66667, cumul_delta=0.11137, eps=0.015564
# episode 1356: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.015517
# episode 1357: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.015469
# episode 1358: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.015421
# episode 1359: cumul_reward=52.0, accuracy:0.86667, cumul_delta=5.4272, eps=0.015374
# episode 1360: cumul_reward=50.0, accuracy:0.73333, cumul_delta=0.0, eps=0.015327
# episode 1361: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.01528
# episode 1362: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.015233
# episode 1363: cumul_reward=51.0, accuracy:0.73333, cumul_delta=-1.65, eps=0.015186
# episode 1364: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.9075, eps=0.01514
# episode 1365: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.40838, eps=0.015093
# episode 1366: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.18377, eps=0.015047
# episode 1367: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.082696, eps=0.015001
# episode 1368: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.037213, eps=0.014955
# episode 1369: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.016746, eps=0.014909
# episode 1370: cumul_reward=52.0, accuracy:0.73333, cumul_delta=0.99003, eps=0.014863
# episode 1371: cumul_reward=51.0, accuracy:0.73333, cumul_delta=0.050119, eps=0.014818
# episode 1372: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0075357, eps=0.014772
# episode 1373: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.003391, eps=0.014727
# episode 1374: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0015259, eps=0.014682
# episode 1375: cumul_reward=52.0, accuracy:0.86667, cumul_delta=2.4422, eps=0.014637
# episode 1376: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.00068665, eps=0.014592
# episode 1377: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.00030899, eps=0.014547
# episode 1378: cumul_reward=48.0, accuracy:0.73333, cumul_delta=-3.2922, eps=0.014502
# episode 1379: cumul_reward=50.0, accuracy:0.73333, cumul_delta=1.8151, eps=0.014458
# episode 1380: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.81681, eps=0.014414
# episode 1381: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.36757, eps=0.014369
# episode 1382: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.1654, eps=0.014325
# episode 1383: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.074426, eps=0.014281
# episode 1384: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.033497, eps=0.014238
# episode 1385: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.015074, eps=0.014194
# episode 1386: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0067832, eps=0.01415
# episode 1387: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.003052, eps=0.014107
# episode 1388: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0013735, eps=0.014064
# episode 1389: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.00061822, eps=0.014021
# episode 1390: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.00027871, eps=0.013978
# episode 1391: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.00012469, eps=0.013935
# episode 1392: cumul_reward=58.0, accuracy:0.86667, cumul_delta=5.6744e-05, eps=0.013892
# episode 1393: cumul_reward=50.0, accuracy:0.73333, cumul_delta=1.2636e-05, eps=0.013849
# episode 1394: cumul_reward=50.0, accuracy:0.73333, cumul_delta=1.8597e-05, eps=0.013807
# episode 1395: cumul_reward=58.0, accuracy:0.86667, cumul_delta=8.3447e-06, eps=0.013764
# episode 1396: cumul_reward=58.0, accuracy:0.86667, cumul_delta=3.3379e-06, eps=0.013722
# episode 1397: cumul_reward=58.0, accuracy:0.86667, cumul_delta=1.9073e-06, eps=0.01368
# episode 1398: cumul_reward=58.0, accuracy:0.86667, cumul_delta=9.5367e-07, eps=0.013638
# episode 1399: cumul_reward=58.0, accuracy:0.86667, cumul_delta=2.3842e-07, eps=0.013596
# episode 1400: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.013555
# episode 1401: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.013513
# episode 1402: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.013472
# episode 1403: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.01343
# episode 1404: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.013389
# episode 1405: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.013348
# episode 1406: cumul_reward=50.0, accuracy:0.73333, cumul_delta=0.0, eps=0.013307
# episode 1407: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.013266
# episode 1408: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.013226
# episode 1409: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.013185
# episode 1410: cumul_reward=52.0, accuracy:0.86667, cumul_delta=1.0949, eps=0.013145
# episode 1411: cumul_reward=48.0, accuracy:0.66667, cumul_delta=0.99, eps=0.013104
# episode 1412: cumul_reward=50.0, accuracy:0.73333, cumul_delta=0.0, eps=0.013064
# episode 1413: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.013024
# episode 1414: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012984
# episode 1415: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012944
# episode 1416: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012904
# episode 1417: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012865
# episode 1418: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012825
# episode 1419: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012786
# episode 1420: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012747
# episode 1421: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012708
# episode 1422: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012669
# episode 1423: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.01263
# episode 1424: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012591
# episode 1425: cumul_reward=50.0, accuracy:0.73333, cumul_delta=0.0, eps=0.012553
# episode 1426: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012514
# episode 1427: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012476
# episode 1428: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012437
# episode 1429: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012399
# episode 1430: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012361
# episode 1431: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012323
# episode 1432: cumul_reward=54.0, accuracy:0.8, cumul_delta=0.0, eps=0.012286
# episode 1433: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012248
# episode 1434: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.01221
# episode 1435: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012173
# episode 1436: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012135
# episode 1437: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012098
# episode 1438: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012061
# episode 1439: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.012024
# episode 1440: cumul_reward=51.0, accuracy:0.8, cumul_delta=0.0, eps=0.011987
# episode 1441: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.01195
# episode 1442: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011914
# episode 1443: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011877
# episode 1444: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011841
# episode 1445: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011805
# episode 1446: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011768
# episode 1447: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011732
# episode 1448: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011696
# episode 1449: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.01166
# episode 1450: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011625
# episode 1451: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011589
# episode 1452: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011553
# episode 1453: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011518
# episode 1454: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011483
# episode 1455: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011447
# episode 1456: cumul_reward=50.0, accuracy:0.73333, cumul_delta=0.0, eps=0.011412
# episode 1457: cumul_reward=50.0, accuracy:0.73333, cumul_delta=0.0, eps=0.011377
# episode 1458: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011342
# episode 1459: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011308
# episode 1460: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011273
# episode 1461: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011238
# episode 1462: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011204
# episode 1463: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011169
# episode 1464: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0, eps=0.011135
# episode 1465: cumul_reward=48.0, accuracy:0.66667, cumul_delta=-1.5386, eps=0.011101
# episode 1466: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.9075, eps=0.011067
# episode 1467: cumul_reward=50.0, accuracy:0.73333, cumul_delta=0.40838, eps=0.011033
# episode 1468: cumul_reward=53.0, accuracy:0.73333, cumul_delta=-1.4662, eps=0.010999
# episode 1469: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.9902, eps=0.010965
# episode 1470: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.44559, eps=0.010932
# episode 1471: cumul_reward=48.0, accuracy:0.66667, cumul_delta=1.1905, eps=0.010898
# episode 1472: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.090231, eps=0.010865
# episode 1473: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.040604, eps=0.010832
# episode 1474: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.018271, eps=0.010798
# episode 1475: cumul_reward=55.0, accuracy:0.8, cumul_delta=-1.6418, eps=0.010765
# episode 1476: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.90781, eps=0.010732
# episode 1477: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.41191, eps=0.010699
# episode 1478: cumul_reward=45.0, accuracy:0.73333, cumul_delta=-0.91617, eps=0.010666
# episode 1479: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.68925, eps=0.010634
# episode 1480: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.31016, eps=0.010601
# episode 1481: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.13957, eps=0.010569
# episode 1482: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.062808, eps=0.010536
# episode 1483: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.028263, eps=0.010504
# episode 1484: cumul_reward=50.0, accuracy:0.73333, cumul_delta=0.012718, eps=0.010472
# episode 1485: cumul_reward=50.0, accuracy:0.73333, cumul_delta=0.0057237, eps=0.010439
# episode 1486: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0025756, eps=0.010407
# episode 1487: cumul_reward=50.0, accuracy:0.73333, cumul_delta=0.0011587, eps=0.010376
# episode 1488: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.0005219, eps=0.010344
# episode 1489: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.00023484, eps=0.010312
# episode 1490: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.00010538, eps=0.01028
# episode 1491: cumul_reward=51.0, accuracy:0.8, cumul_delta=4.1723e-05, eps=0.010249
# episode 1492: cumul_reward=58.0, accuracy:0.86667, cumul_delta=2.4557e-05, eps=0.010217
# episode 1493: cumul_reward=58.0, accuracy:0.86667, cumul_delta=1.0967e-05, eps=0.010186
# episode 1494: cumul_reward=58.0, accuracy:0.86667, cumul_delta=5.0068e-06, eps=0.010155
# episode 1495: cumul_reward=58.0, accuracy:0.86667, cumul_delta=2.1458e-06, eps=0.010124
# episode 1496: cumul_reward=58.0, accuracy:0.86667, cumul_delta=9.5367e-07, eps=0.010093
# episode 1497: cumul_reward=58.0, accuracy:0.86667, cumul_delta=7.1526e-07, eps=0.010062
# episode 1498: cumul_reward=58.0, accuracy:0.86667, cumul_delta=2.3842e-07, eps=0.010031
# episode 1499: cumul_reward=54.0, accuracy:0.86667, cumul_delta=-1.7073, eps=0.01
# episode 1500: cumul_reward=58.0, accuracy:0.86667, cumul_delta=1.21, eps=0.0
# episode 1501: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.5445, eps=0.0
# episode 1502: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.24503, eps=0.0
# episode 1503: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.11026, eps=0.0
# episode 1504: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.049618, eps=0.0
# episode 1505: cumul_reward=58.0, accuracy:0.86667, cumul_delta=0.022328, eps=0.0

# %%
episode_i
# Out:
# 1505
