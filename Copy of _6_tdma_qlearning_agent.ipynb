# %%
#   ____                            _____     _____                   __          __        _        _                 
#  / __ \                     /\   |_   _|   / ____|                  \ \        / /       | |      | |                
# | |  | |_ __   ___ _ __    /  \    | |    | |  __ _   _ _ __ ___     \ \  /\  / /__  _ __| | _____| |__   ___  _ __  
# | |  | | '_ \ / _ \ '_ \  / /\ \   | |    | | |_ | | | | '_ ` _ \     \ \/  \/ / _ \| '__| |/ / __| '_ \ / _ \| '_ \ 
# | |__| | |_) |  __/ | | |/ ____ \ _| |_   | |__| | |_| | | | | | |     \  /\  / (_) | |  |   <\__ \ | | | (_) | |_) |
#  \____/| .__/ \___|_| |_/_/    \_\_____|   \_____|\__, |_| |_| |_|      \/  \/ \___/|_|  |_|\_\___/_| |_|\___/| .__/ 
#        | |                                         __/ |                                                      | |    
#        |_|                                        |___/                                                       |_|

# %%
# !pip install gym
#!pip install torch==1.5.0+cpu -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (0.17.2)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym) (1.18.5)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)

# %%
import json
from itertools import count

import gym
from gym import spaces

import torch
from torch import Tensor

import random
from random import randint

from typing import Dict, List, Optional, Callable, Any, Tuple, Union, Type

import pathlib
import collections

# %% [markdown]
# ![alt text](https://www.taitradioacademy.com/wp-content/uploads/2014/10/Image-25-800x450.png)

# %%
class TDMAGym(gym.Env):
  NO_ACTION = 0  # no action on sub-frame
  UPLINK_ACTION = 1  # use sub-frame as up-link role (user [Tx] --> base-station [Rx])
  DOWNLINK_ACTION = 2  # use sub-frame as down-link role (base-station [Tx] --> user [Rx])

  def __init__(self, n_freqs: int, n_subframes: int, horizon: int):
    super(TDMAGym, self).__init__()  # initialize gym.Env base class
    if n_subframes % 2 != 0:  # since a link is separated in up and down link we need even number of subframe
      raise ValueError('n_subframes must be an even number')

    # action space dict includes frequency and sub-frames action
    self.action_space = spaces.Dict(
      {
        'freq': spaces.Discrete(n_freqs),  # frequency used
        'subframes': spaces.MultiDiscrete([3] * n_subframes)  # sub-frames role actions
      }
    )
    # observation space dict includes the time-step, last action and its sub-frames successes
    self.observation_space = spaces.Dict(
      {
        'time_step': spaces.Discrete(horizon + 1),  # include terminal state
        'last_a': self.action_space,  # last action done by the agent
        'last_success': spaces.MultiDiscrete([2] * n_subframes)  # what sub-frames received an acknowledgement
      }
    )
    self.reward_range = 0.0, float(n_subframes)  # action-reward range between 0 and the number of sub-frames

    self.freq_sf: Dict[int, Tuple[int, Tensor]] = dict()  # frequency and sub-frames role assignation w.r.t. to time-step
    for t in range(horizon):  # do not include terminal state
      freq = randint(0, n_freqs - 1)  # choose random frequency to do Tx
      ul_subframes = random.sample(range(n_subframes), k=n_subframes // 2)  # choose which sub-frames will be used as up-link
      dl_subframes = [
        sf for sf in range(n_subframes) if sf not in ul_subframes  # choose the rest of sub-frames as down-link
      ]
      sf = torch.zeros(n_subframes, dtype=torch.int)  # initialize sub-frames roles
      sf.fill_(self.NO_ACTION)  # set all sub-frames to no-action
      sf[ul_subframes] = self.UPLINK_ACTION  # set all up-link sub-frames to uplink-action value
      sf[dl_subframes] = self.DOWNLINK_ACTION  # set all down-link sub-frames to downlink-action value
      self.freq_sf[t] = freq, sf  # set sub-frames role w.r.t. time-step

    self.hor = horizon  # gym horizon to know when we are DONE
    self.t = 0  # initial time-step / observation

  def step(self, action: Dict) -> Tuple[  # step function to interact with the gym
    Dict, float, bool, Dict[str, Any]
  ]:
    if self.t >= self.hor:  # terminal state reached
      return collections.OrderedDict(), 0.0, True, {}  # return empty interaction

    assert self.action_space.contains(action)  # action is within gym action-space assertion

    freq, sf = self.freq_sf[self.t]  # get frequency and sub-frames role for current time-step
    a_freq, a_sf = action['freq'], action['subframes']  # fetch frequency and sub-frames role from the action

    if freq == a_freq:  # gym and action frequency are the same
      sf_success = [
        int(gym_sf == act_sf) for gym_sf, act_sf in zip(sf, a_sf)  # action sub-frames role is correct w.r.t. the gym's sub-frames
      ]
    else:
      sf_success = [0] * len(self.action_space['subframes'].nvec)  # wrong frequency, no sub-frames successes

    self.t += 1  # increment our time-step / observation
    o = collections.OrderedDict(
      time_step=self.t, last_a=action,   # observation that we will return, time-step, last action
      last_success=[int(sf_s) for sf_s in sf_success]  # and successes from last action
    )
    r = float(sum(sf_success))  # sum successes to give the reward
    return o, r, False, {}   # gyms always returns <obs, reward, if terminal obs reached, debug/info dictionary>

  def reset(self) -> Dict:  # reset our gym for a new episode
    self.t = 0  # initial time-step
    obs = collections.OrderedDict(time_step=self.t)  # initial observation
    return obs

  def render(self, mode='human'):  # gym visual rendering (e.g. text, image, plot, 3D frame, etc.)
    if self.t < self.hor:  # terminal gym state not reached
      # show current time-step, frequency and sub-frames role
      print(
        'rendering={{time_step={time_step}, freq={freq}, sf={sf}}}'
          .format(
          time_step=self.t, freq=self.freq_sf[self.t][0],
          sf=str(self.freq_sf[self.t][1].tolist()).replace(' ', '')
        )
      )
    else:  # terminal gym state reached and out of horizon
      print('rendering={terminal state reached, out of horizon}')

# %%
def build_epsilon_fn(steps: int) -> Callable[[int], float]:  # epsilon function builder
  log_epsilon_space = torch.logspace(1.0, -1.0, steps=steps, base=10.0) / 10.0  # epsilon log-space {1.0, ..., 0.0}

  def epsilon_fn(episode_i: int):  # epsilon function
    if episode_i >= steps:  # max step reached
      return 0.0
    return log_epsilon_space[episode_i].item()  # return epsilon value

  return epsilon_fn  # return our function as an callable object

# %%
class TDMAQLearningAgent:

  def __init__(
      self, lr: float, gamma: float, act_space: spaces.Dict,
      obs_space: spaces.Dict, eps_fn_steps: int
  ):
    self.act_space = act_space  # action-space from the gym environment
    self.obs_space = obs_space  # observation-space from the gym environment

    self.lr = lr  # learning rate
    self.gamma = gamma  # gamma parameter
    self.qtable: Dict[str, Tensor] = dict()  # Q-table with observation encoded as text string as keys for a 3D Q-table
    self.qtable_dims: Tuple[int, int, int] = (
      act_space['freq'].n, act_space['subframes'].nvec.size,  # 3D Q-table dimensions (n_freqs X n_subframes x n_roles)
      act_space['subframes'].nvec.max()
    )

    self.eps_fn_steps = eps_fn_steps  # number of steps (episodes) in epsilon log-space
    self.eps_fn: Callable[[int], float] = build_epsilon_fn(eps_fn_steps)  # build our epsilon function
    self.episode_i: Optional[int] = None  # keep track of the episode number (e.g. for epsilon)
    self.eps: Optional[float] = None  # epsilon value as a property of our agent

  def act(self, o: Dict, eps: Optional[float] = None) -> Dict:  # choose action
    if eps is None:
      eps = self.eps  # not epsilon as argument, use agent's current epsilon value

    o_enc = self.encode_obs(o)  # encode obs to a string "{time_step}:{freq}:{subframes}:{successes}"
    if o_enc not in self.qtable:
      self.qtable[o_enc] = torch.zeros(self.qtable_dims)  # add new Q-table for new obs, Q-values are zero

    if random.uniform(1.0, 0.0) < eps:  # epsilon-greedy condition for exploration
      return self.explore(o)  # exploring random action

    max_sf_values, max_sf_indices = self.qtable[o_enc].max(dim=2)  # get values and index of best actions for all sub-frame Q-values
    max_freq = max_sf_values.sum(dim=1).argmax()  # get frequency with the best Q-values for all sub-frames

    if max_sf_indices.ndimension() > 1:  # multiple equal maximums
      max_sf_indices = max_sf_indices[max_freq]  # if Q-value equality occurs, take random one

    # ------- same algorithm but using python loops instead of pytorch -------
    # max_sf_values2 = []
    # max_sf_indices2 = []
    # for i in range(self.qtable[o_enc].shape[0]):
    #     j_vals = []
    #     j_inds = []
    #     for j in range(self.qtable[o_enc].shape[1]):
    #         max_k = float(max(self.qtable[o_enc][i, j]))
    #         for k in range(self.qtable[o_enc].shape[2]):
    #             if self.qtable[o_enc][i, j, k] == max_k:
    #                 j_inds.append(k)
    #                 break
    #         j_vals.append(max_k)
    #     max_sf_values2.append(j_vals)
    #     max_sf_indices2.append(j_inds)

    # max_freq_values2 = []
    # for i in range(self.qtable[o_enc].shape[0]):
    #     max_freq_values2.append(sum(max_sf_values2[i]))

    # max_freq2 = float('-inf')
    # for i in range(self.qtable[o_enc].shape[0]):
    #     if max_freq_values2[i] == max(max_freq_values2):
    #         max_freq2 = i
    #         break

    # assert torch.all(max_sf_values == torch.tensor(max_sf_values2))
    # assert torch.all(max_sf_indices == torch.tensor(max_sf_indices2))
    # assert torch.all(max_freq == torch.tensor(max_freq2))
    # -----------------------------------------------------------------------

    return collections.OrderedDict(
      freq=int(max_freq), subframes=max_sf_indices.tolist()  # create and return action with best Q-values
    )

  def explore(self, o: Dict) -> Dict:  # action-space exploration
    rand_a = collections.OrderedDict(
      freq=randint(0, self.act_space['freq'].n - 1),  # random frequency
      subframes=[
        randint(0, n - 1) for n in self.act_space['subframes'].nvec  # random role action for each sub-frame
      ]
    )
    return rand_a  # random action

  def update(
      self, o: Dict, a: Dict, r: float, o_prime: Dict  # agent update function (e.g. Q-learning update)
  ) -> float:
    o_enc = self.encode_obs(o)  # encode obs to a string "{time_step}:{freq}:{subframes}:{successes}"
    o_prime_enc = self.encode_obs(o_prime)  # encode obs to a string "{time_step}:{freq}:{subframes}:{successes}"

    if o_enc not in self.qtable:
      self.qtable[o_enc] = torch.zeros(self.qtable_dims)  # add new Q-table for new obs, Q-values are zero

    if o_prime_enc not in self.qtable:
      self.qtable[o_prime_enc] = torch.zeros(self.qtable_dims)  # add new Q-table for new obs, Q-values are zero

    a_inds = a['freq'], range(len(a['subframes'])), a['subframes']  # get Q-table indices of action
    a_vals = self.qtable[o_enc][a_inds]  # TD-source (e.i. TD-error = [TD-target - TD-source]), also old Q-values to compute delta update

    max_prime_sf_vals, _ = self.qtable[o_prime_enc].max(dim=2)  # get values and index of best actions for all sub-frame Q-values
    a_prime_val = max_prime_sf_vals[max_prime_sf_vals.sum(dim=1).argmax()]  # get frequency with the best Q-values for all sub-frames

    # ------- same algorithm but using python loops instead of pytorch -------
    # a_vals2 = []
    # for i in range(len(a['subframes'])):
    #     a_vals2.append(
    #         self.qtable[o_enc][a['freq'], i, a['subframes'][i]]
    #     )
    # assert torch.all(a_vals == torch.tensor(a_vals2))

    # max_prime_sf_values2 = []
    # for i in range(self.qtable[o_prime_enc].shape[0]):
    #     j_vals = []
    #     for j in range(self.qtable[o_prime_enc].shape[1]):
    #         max_k = float(max(aa[i, j]))
    #         j_vals.append(max_k)
    #     max_prime_sf_values2.append(j_vals)

    # max_prime_freq2 = max([sum(sf) for sf in max_prime_sf_values2])
    # for i in range(self.qtable[o_prime_enc].shape[0]):
    #     if sum(max_prime_sf_values2[i]) == max_prime_freq2:
    #         max_prime_freq2 = i
    #         break

    # a_prime_val2 = max_prime_sf_values2[max_prime_freq2]
    # assert torch.all(a_prime_val == torch.tensor(a_prime_val2))
    # -----------------------------------------------------------------------

    last_success = torch.tensor(o_prime['last_success'])  # last success for credit assignment of the update

    td_target = (r + self.gamma * a_prime_val) * last_success  # compute Temporal-Difference target (e.i [r + gamma * Q(o', a_max)])
    self.qtable[o_enc][a_inds] += (
        self.lr * (td_target - a_vals) * last_success  # update Q-table (e.i. Q(o, s) <- Q(o, s) + lr * [TD-target - Q(o, a)])
    )

    delta_update = float(sum(self.qtable[o_enc][a_inds] - a_vals))  # compute delta update
    return delta_update  # return delta update to training loop

  def episode_reset(self, o: Dict, episode_i: int) -> Dict:  # reset agent for a new episode
    self.episode_i = episode_i  # current episode number
    self.eps = self.eps_fn(episode_i)  # epsilon w.r.t. episode number
    return self.act(o, self.eps)  # act upon initial observation

  def save_to_file(self, path: str, overwrite: bool):  # save agent state to file
    file = pathlib.Path(path)  # file path
    if not overwrite and file.exists():  # exception if file exist and overwrite is false
      raise FileExistsError()

    # agent state as a python dictionary
    agent_state: Dict[str, Any] = {
      'gamma': self.gamma,
      'act_space': {
        'n_freq': self.act_space['freq'].n,
        'subframes_nvec': [
          int(n) for n in self.act_space['subframes'].nvec
        ]
      },
      'obs_space': {
        'n_time_step': self.obs_space['time_step'].n
      },
      'qtable': {k: v.tolist() for k, v in self.qtable.items()}
    }

    with file.open('w') as f:  # open file to write in it
      json.dump(agent_state, f)  # write agent state in file

  def load_from_file(self, path: str):  # load agent state from compatible saved state
    file = pathlib.Path(path)  # file path
    if not file.exists():
      return  # file does not exists

    with file.open('r') as f:  # open file to read it
      agent_state = json.load(f)  # load agent state from file

    self.gamma = agent_state['gamma']  # set gamma to loaded value
    self.qtable = {
      k: torch.tensor(v) for k, v in agent_state['qtable'].items()  # set number of actions from loaded value
    }

    assert self.act_space['freq'].n == agent_state['act_space']['n_freq']  # assert compatiblity
    assert [int(n) for n in self.act_space['subframes'].nvec] == (
      agent_state['act_space']['subframes_nvec']    # assert compatiblity
    )
    assert self.obs_space['time_step'].n == (
      agent_state['obs_space']['n_time_step']    # assert compatiblity
    )

  @staticmethod
  def encode_obs(o: Dict) -> str:  # encoding observation to a string to use it as Q-table key
    encoded = '{time_step}:{last_a}:{last_success}'.format(
      time_step=o['time_step'] if 'time_step' in o else '',
      last_a=(
        TDMAQLearningAgent.encode_act(o['last_a'])
        if 'last_a' in o else ''
      ),
      last_success=o['last_success'] if 'last_success' in o else ''
    ).replace(' ', '')
    return encoded  # return encoded observation as string

  @staticmethod
  def encode_act(a: Dict) -> str:  # encoding action to a string to use it as part of Q-table key
    encoded = '{freq}:{sf}'.format(
      freq=a['freq'], sf=a['subframes']
    ).replace(' ', '')
    return encoded  # return encoded action as string

# %%
random.seed(1234)  # python random number generator seed
torch.manual_seed(1234)  # pytorch random number generator seed

n_freqs = 4  # number of frequencies
n_subframes = 4  # number of sub-frames within a time-step frame
horizon = 15  # horizon of our gym (episodes)

gym_env = TDMAGym(n_freqs, n_subframes, horizon)  # our gym environment

lr = 0.55  # learning rate
gamma = 0.0  # gamma parameter
eps_fn_steps = 1500  # number of steps (episodes) in epsilon log-space

# initialize our Rx agent with learning parameters and gym parameters
agent = TDMAQLearningAgent(
  lr, gamma, gym_env.action_space, gym_env.observation_space, eps_fn_steps
)
#agent.load_from_file('tdma_agent_1.json')    # load previously saved agent

show_verbose = False  # print information for debugging
render_gym = False  # render gym

# print simulation parameters
print(
  'model: {{n_freqs={n_freqs}, n_subframes:{n_subframes},'
  ' horizon={horizon}}}, '
  'agent: {{lr={lr}, gamma={gamma}, eps_fn_steps={eps_fn_steps}}}'.format(
    n_freqs=n_freqs, n_subframes=n_subframes, horizon=horizon, lr=lr,
    gamma=gamma, eps_fn_steps=eps_fn_steps
  )
)

running_len = 5  # length of our running training data
running_delta = []  # running delta (e.g. the last running_len delta update)
running_acc = []  # running accuracy (e.g. the last running_len accuracy)

for episode_i in count():  # training loop
  if show_verbose:
    print('starting episode {episode_i}...'.format(episode_i=episode_i))

  delta_update: List[float] = []  # delta update of our Q-table
  n_successes: int = 0  # number of optimal actions (actions with maximum reward)
  cumul_r: float = 0.0  # cumulative reward

  o = gym_env.reset()  # reset gym for new episode
  a = agent.episode_reset(o, episode_i)  # reset agent with initial gym observation and episode number

  for t in count():  # episode loop
    if render_gym:
      gym_env.render()  # show gym rendering
    o_prime, r, done, _ = gym_env.step(a)  # interact with the gym, get environment transition
    if done:
      break  # terminal gym observation reached, out of horizon

    delta_update.append(agent.update(o, a, r, o_prime))  # update agent with transition, get delta update
    cumul_r += r  # add reward to cumulative reward
    n_successes += int(r == 1.0 * n_subframes)  # success if optimal action-reward of 1.0 * number of sub-frames

    if show_verbose:  # show transition of our model (e.i. <o, a, r, o'>)
      print(
        'transition={{o={o}, a={a}, r={r}, o_prime={o_prime}}},'
        ' delta_update={delta}'.format(
          o=agent.encode_obs(o), a=agent.encode_act(a),
          r=r, o_prime=agent.encode_obs(o_prime),
          delta=delta_update[-1]
        )
      )

    o = o_prime  # increment to next observation (e.g. next observation)
    a = agent.act(o)  #  act upon next observation

  # strip running data because we reached running length
  if len(running_acc) >= running_len or len(running_delta) >= running_len:
    running_acc.pop(0)  # delete oldest running accuracy
    running_delta.pop(0)  # delete oldest running update delta

  running_acc.append(n_successes / horizon)  # add latest accuracy to running data
  running_delta.append(sum(delta_update))  # add latest update delta to running data

  # show episode results
  print(
    'episode {episode_i}: cumul_reward={cumul_r}, accuracy:{acc:0.5}, '
    'cumul_delta={cumul_delta:0.5}, eps={eps:0.5}'.format(
      episode_i=episode_i, cumul_r=cumul_r, acc=running_acc[-1],
      cumul_delta=running_delta[-1], eps=agent.eps
    )
  )

  # training stop conditions
  if (
      all([acc == 1.0 for acc in running_acc])  # all running accuracy are maximized
      and all([delta < 0.0001 for delta in running_delta])  # all running delta update a lower than 0.0001
      and episode_i >= running_len  # running data have reached running length
  ) or episode_i >= eps_fn_steps + running_len:  # epsilon was 0 for all running data (nothing will change)
    break  # exit training loop

agent.save_to_file('tdma_agent_1.json', overwrite=True)  # save agent state to file
gym_env.close()  # close gym environment
# Out:
# model: {n_freqs=4, n_subframes:4, horizon=15}, agent: {lr=0.55, gamma=0.0, eps_fn_steps=1500}
# episode 0: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=1.0
# episode 1: cumul_reward=5.0, accuracy:0.0, cumul_delta=4.95, eps=0.99693
# episode 2: cumul_reward=8.0, accuracy:0.0, cumul_delta=9.295, eps=0.99387
# episode 3: cumul_reward=2.0, accuracy:0.0, cumul_delta=2.2, eps=0.99083
# episode 4: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.98779
# episode 5: cumul_reward=5.0, accuracy:0.0, cumul_delta=7.15, eps=0.98476
# episode 6: cumul_reward=6.0, accuracy:0.0, cumul_delta=4.4, eps=0.98174
# episode 7: cumul_reward=8.0, accuracy:0.0, cumul_delta=11.0, eps=0.97872
# episode 8: cumul_reward=7.0, accuracy:0.0, cumul_delta=5.445, eps=0.97572
# episode 9: cumul_reward=6.0, accuracy:0.0, cumul_delta=5.5, eps=0.97273
# episode 10: cumul_reward=4.0, accuracy:0.0, cumul_delta=3.3, eps=0.96975
# episode 11: cumul_reward=6.0, accuracy:0.0, cumul_delta=6.6, eps=0.96677
# episode 12: cumul_reward=7.0, accuracy:0.0, cumul_delta=6.05, eps=0.96381
# episode 13: cumul_reward=4.0, accuracy:0.0, cumul_delta=3.3, eps=0.96085
# episode 14: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.9579
# episode 15: cumul_reward=2.0, accuracy:0.0, cumul_delta=1.1, eps=0.95496
# episode 16: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.95203
# episode 17: cumul_reward=6.0, accuracy:0.0, cumul_delta=4.9253, eps=0.94911
# episode 18: cumul_reward=7.0, accuracy:0.0, cumul_delta=8.25, eps=0.9462
# episode 19: cumul_reward=5.0, accuracy:0.0, cumul_delta=3.85, eps=0.9433
# episode 20: cumul_reward=5.0, accuracy:0.0, cumul_delta=4.95, eps=0.94041
# episode 21: cumul_reward=10.0, accuracy:0.0, cumul_delta=10.057, eps=0.93752
# episode 22: cumul_reward=5.0, accuracy:0.0, cumul_delta=4.95, eps=0.93465
# episode 23: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.93178
# episode 24: cumul_reward=2.0, accuracy:0.0, cumul_delta=2.2, eps=0.92892
# episode 25: cumul_reward=8.0, accuracy:0.0, cumul_delta=8.8, eps=0.92607
# episode 26: cumul_reward=4.0, accuracy:0.0, cumul_delta=5.5, eps=0.92323
# episode 27: cumul_reward=7.0, accuracy:0.0, cumul_delta=6.9477, eps=0.9204
# episode 28: cumul_reward=5.0, accuracy:0.0, cumul_delta=4.95, eps=0.91758
# episode 29: cumul_reward=6.0, accuracy:0.0, cumul_delta=3.3717, eps=0.91476
# episode 30: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.91195
# episode 31: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.90916
# episode 32: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.90637
# episode 33: cumul_reward=9.0, accuracy:0.0, cumul_delta=11.212, eps=0.90359
# episode 34: cumul_reward=6.0, accuracy:0.0, cumul_delta=6.6, eps=0.90082
# episode 35: cumul_reward=12.0, accuracy:0.0, cumul_delta=11.358, eps=0.89805
# episode 36: cumul_reward=3.0, accuracy:0.0, cumul_delta=1.4427, eps=0.8953
# episode 37: cumul_reward=2.0, accuracy:0.0, cumul_delta=2.2, eps=0.89255
# episode 38: cumul_reward=4.0, accuracy:0.0, cumul_delta=1.2502, eps=0.88981
# episode 39: cumul_reward=5.0, accuracy:0.0, cumul_delta=4.95, eps=0.88709
# episode 40: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.55, eps=0.88436
# episode 41: cumul_reward=9.0, accuracy:0.066667, cumul_delta=12.174, eps=0.88165
# episode 42: cumul_reward=4.0, accuracy:0.066667, cumul_delta=2.3967, eps=0.87895
# episode 43: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.55, eps=0.87625
# episode 44: cumul_reward=9.0, accuracy:0.066667, cumul_delta=8.717, eps=0.87356
# episode 45: cumul_reward=11.0, accuracy:0.0, cumul_delta=14.85, eps=0.87088
# episode 46: cumul_reward=10.0, accuracy:0.066667, cumul_delta=9.3687, eps=0.86821
# episode 47: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.55, eps=0.86555
# episode 48: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.86289
# episode 49: cumul_reward=8.0, accuracy:0.0, cumul_delta=9.5975, eps=0.86025
# episode 50: cumul_reward=9.0, accuracy:0.0, cumul_delta=11.55, eps=0.85761
# episode 51: cumul_reward=10.0, accuracy:0.0, cumul_delta=11.033, eps=0.85498
# episode 52: cumul_reward=2.0, accuracy:0.0, cumul_delta=-0.77632, eps=0.85235
# episode 53: cumul_reward=10.0, accuracy:0.0, cumul_delta=12.1, eps=0.84974
# episode 54: cumul_reward=2.0, accuracy:0.0, cumul_delta=1.1, eps=0.84713
# episode 55: cumul_reward=7.0, accuracy:0.0, cumul_delta=10.45, eps=0.84454
# episode 56: cumul_reward=12.0, accuracy:0.066667, cumul_delta=10.417, eps=0.84194
# episode 57: cumul_reward=13.0, accuracy:0.0, cumul_delta=8.091, eps=0.83936
# episode 58: cumul_reward=5.0, accuracy:0.0, cumul_delta=1.2505, eps=0.83679
# episode 59: cumul_reward=2.0, accuracy:0.0, cumul_delta=1.1, eps=0.83422
# episode 60: cumul_reward=9.0, accuracy:0.066667, cumul_delta=7.2702, eps=0.83166
# episode 61: cumul_reward=4.0, accuracy:0.0, cumul_delta=3.3, eps=0.82911
# episode 62: cumul_reward=16.0, accuracy:0.066667, cumul_delta=14.244, eps=0.82657
# episode 63: cumul_reward=7.0, accuracy:0.0, cumul_delta=3.915, eps=0.82403
# episode 64: cumul_reward=7.0, accuracy:0.0, cumul_delta=8.25, eps=0.8215
# episode 65: cumul_reward=8.0, accuracy:0.0, cumul_delta=9.5975, eps=0.81898
# episode 66: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.55, eps=0.81647
# episode 67: cumul_reward=6.0, accuracy:0.0, cumul_delta=6.6, eps=0.81397
# episode 68: cumul_reward=5.0, accuracy:0.0, cumul_delta=1.8063, eps=0.81147
# episode 69: cumul_reward=8.0, accuracy:0.0, cumul_delta=10.89, eps=0.80898
# episode 70: cumul_reward=11.0, accuracy:0.066667, cumul_delta=15.95, eps=0.8065
# episode 71: cumul_reward=14.0, accuracy:0.066667, cumul_delta=11.953, eps=0.80403
# episode 72: cumul_reward=10.0, accuracy:0.066667, cumul_delta=5.4064, eps=0.80156
# episode 73: cumul_reward=12.0, accuracy:0.066667, cumul_delta=4.4404, eps=0.7991
# episode 74: cumul_reward=6.0, accuracy:0.0, cumul_delta=5.5, eps=0.79665
# episode 75: cumul_reward=13.0, accuracy:0.066667, cumul_delta=9.5471, eps=0.79421
# episode 76: cumul_reward=6.0, accuracy:0.0, cumul_delta=5.5, eps=0.79177
# episode 77: cumul_reward=7.0, accuracy:0.066667, cumul_delta=6.1655, eps=0.78934
# episode 78: cumul_reward=5.0, accuracy:0.0, cumul_delta=4.95, eps=0.78692
# episode 79: cumul_reward=14.0, accuracy:0.13333, cumul_delta=14.389, eps=0.78451
# episode 80: cumul_reward=6.0, accuracy:0.0, cumul_delta=5.4464, eps=0.7821
# episode 81: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.7797
# episode 82: cumul_reward=3.0, accuracy:0.0, cumul_delta=0.9955, eps=0.77731
# episode 83: cumul_reward=6.0, accuracy:0.0, cumul_delta=9.9, eps=0.77492
# episode 84: cumul_reward=5.0, accuracy:0.0, cumul_delta=-0.088811, eps=0.77255
# episode 85: cumul_reward=4.0, accuracy:0.0, cumul_delta=3.3, eps=0.77018
# episode 86: cumul_reward=10.0, accuracy:0.066667, cumul_delta=3.3118, eps=0.76782
# episode 87: cumul_reward=9.0, accuracy:0.066667, cumul_delta=7.4051, eps=0.76546
# episode 88: cumul_reward=10.0, accuracy:0.066667, cumul_delta=7.3459, eps=0.76311
# episode 89: cumul_reward=9.0, accuracy:0.0, cumul_delta=11.55, eps=0.76077
# episode 90: cumul_reward=14.0, accuracy:0.13333, cumul_delta=19.002, eps=0.75844
# episode 91: cumul_reward=10.0, accuracy:0.0, cumul_delta=10.588, eps=0.75611
# episode 92: cumul_reward=20.0, accuracy:0.2, cumul_delta=12.294, eps=0.75379
# episode 93: cumul_reward=9.0, accuracy:0.066667, cumul_delta=4.3088, eps=0.75148
# episode 94: cumul_reward=15.0, accuracy:0.13333, cumul_delta=6.8232, eps=0.74917
# episode 95: cumul_reward=16.0, accuracy:0.13333, cumul_delta=18.965, eps=0.74688
# episode 96: cumul_reward=6.0, accuracy:0.0, cumul_delta=4.7657, eps=0.74459
# episode 97: cumul_reward=0.0, accuracy:0.0, cumul_delta=0.0, eps=0.7423
# episode 98: cumul_reward=21.0, accuracy:0.2, cumul_delta=10.546, eps=0.74002
# episode 99: cumul_reward=10.0, accuracy:0.066667, cumul_delta=9.901, eps=0.73775
# episode 100: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.73549
# episode 101: cumul_reward=7.0, accuracy:0.0, cumul_delta=1.8039, eps=0.73324
# episode 102: cumul_reward=12.0, accuracy:0.066667, cumul_delta=6.534, eps=0.73099
# episode 103: cumul_reward=10.0, accuracy:0.13333, cumul_delta=4.5722, eps=0.72874
# episode 104: cumul_reward=8.0, accuracy:0.066667, cumul_delta=2.127, eps=0.72651
# episode 105: cumul_reward=13.0, accuracy:0.13333, cumul_delta=6.1294, eps=0.72428
# episode 106: cumul_reward=6.0, accuracy:0.066667, cumul_delta=1.1085, eps=0.72206
# episode 107: cumul_reward=9.0, accuracy:0.0, cumul_delta=8.6914, eps=0.71984
# episode 108: cumul_reward=8.0, accuracy:0.13333, cumul_delta=6.0813, eps=0.71764
# episode 109: cumul_reward=11.0, accuracy:0.0, cumul_delta=4.0668, eps=0.71543
# episode 110: cumul_reward=4.0, accuracy:0.0, cumul_delta=1.9841, eps=0.71324
# episode 111: cumul_reward=13.0, accuracy:0.13333, cumul_delta=3.1156, eps=0.71105
# episode 112: cumul_reward=16.0, accuracy:0.13333, cumul_delta=10.377, eps=0.70887
# episode 113: cumul_reward=18.0, accuracy:0.066667, cumul_delta=8.2151, eps=0.7067
# episode 114: cumul_reward=3.0, accuracy:0.0, cumul_delta=2.75, eps=0.70453
# episode 115: cumul_reward=10.0, accuracy:0.0, cumul_delta=6.2297, eps=0.70237
# episode 116: cumul_reward=10.0, accuracy:0.0, cumul_delta=6.5169, eps=0.70021
# episode 117: cumul_reward=10.0, accuracy:0.066667, cumul_delta=6.4215, eps=0.69807
# episode 118: cumul_reward=10.0, accuracy:0.0, cumul_delta=7.4124, eps=0.69592
# episode 119: cumul_reward=21.0, accuracy:0.13333, cumul_delta=10.465, eps=0.69379
# episode 120: cumul_reward=14.0, accuracy:0.066667, cumul_delta=6.5544, eps=0.69166
# episode 121: cumul_reward=1.0, accuracy:0.0, cumul_delta=0.55, eps=0.68954
# episode 122: cumul_reward=9.0, accuracy:0.0, cumul_delta=6.8476, eps=0.68742
# episode 123: cumul_reward=8.0, accuracy:0.066667, cumul_delta=3.9576, eps=0.68532
# episode 124: cumul_reward=7.0, accuracy:0.0, cumul_delta=9.35, eps=0.68321
# episode 125: cumul_reward=9.0, accuracy:0.066667, cumul_delta=4.4001, eps=0.68112
# episode 126: cumul_reward=8.0, accuracy:0.066667, cumul_delta=3.7634, eps=0.67903
# episode 127: cumul_reward=4.0, accuracy:0.0, cumul_delta=-0.36415, eps=0.67695
# episode 128: cumul_reward=18.0, accuracy:0.066667, cumul_delta=13.398, eps=0.67487
# episode 129: cumul_reward=11.0, accuracy:0.13333, cumul_delta=0.6919, eps=0.6728
# episode 130: cumul_reward=15.0, accuracy:0.066667, cumul_delta=5.755, eps=0.67074
# episode 131: cumul_reward=6.0, accuracy:0.0, cumul_delta=6.2975, eps=0.66868
# episode 132: cumul_reward=10.0, accuracy:0.066667, cumul_delta=5.3409, eps=0.66663
# episode 133: cumul_reward=13.0, accuracy:0.2, cumul_delta=3.5788, eps=0.66458
# episode 134: cumul_reward=9.0, accuracy:0.066667, cumul_delta=1.0667, eps=0.66254
# episode 135: cumul_reward=13.0, accuracy:0.066667, cumul_delta=3.2613, eps=0.66051
# episode 136: cumul_reward=4.0, accuracy:0.0, cumul_delta=0.90559, eps=0.65848
# episode 137: cumul_reward=10.0, accuracy:0.0, cumul_delta=8.7761, eps=0.65646
# episode 138: cumul_reward=4.0, accuracy:0.0, cumul_delta=5.5, eps=0.65445
# episode 139: cumul_reward=11.0, accuracy:0.0, cumul_delta=8.7869, eps=0.65244
# episode 140: cumul_reward=9.0, accuracy:0.0, cumul_delta=4.5949, eps=0.65044
# episode 141: cumul_reward=10.0, accuracy:0.066667, cumul_delta=8.5103, eps=0.64845
# episode 142: cumul_reward=12.0, accuracy:0.066667, cumul_delta=3.4371, eps=0.64646
# episode 143: cumul_reward=14.0, accuracy:0.066667, cumul_delta=8.8568, eps=0.64448
# episode 144: cumul_reward=13.0, accuracy:0.066667, cumul_delta=6.6546, eps=0.6425
# episode 145: cumul_reward=15.0, accuracy:0.066667, cumul_delta=6.0692, eps=0.64053
# episode 146: cumul_reward=13.0, accuracy:0.066667, cumul_delta=1.9351, eps=0.63856
# episode 147: cumul_reward=16.0, accuracy:0.13333, cumul_delta=15.717, eps=0.6366
# episode 148: cumul_reward=9.0, accuracy:0.066667, cumul_delta=7.3639, eps=0.63465
# episode 149: cumul_reward=13.0, accuracy:0.13333, cumul_delta=7.7717, eps=0.6327
# episode 150: cumul_reward=15.0, accuracy:0.066667, cumul_delta=6.8764, eps=0.63076
# episode 151: cumul_reward=7.0, accuracy:0.066667, cumul_delta=3.0459, eps=0.62883
# episode 152: cumul_reward=19.0, accuracy:0.13333, cumul_delta=15.785, eps=0.6269
# episode 153: cumul_reward=24.0, accuracy:0.26667, cumul_delta=8.7806, eps=0.62498
# episode 154: cumul_reward=13.0, accuracy:0.066667, cumul_delta=2.7422, eps=0.62306
# episode 155: cumul_reward=14.0, accuracy:0.2, cumul_delta=8.3243, eps=0.62115
# episode 156: cumul_reward=14.0, accuracy:0.066667, cumul_delta=6.7222, eps=0.61924
# episode 157: cumul_reward=5.0, accuracy:0.0, cumul_delta=3.883, eps=0.61734
# episode 158: cumul_reward=17.0, accuracy:0.13333, cumul_delta=12.964, eps=0.61545
# episode 159: cumul_reward=9.0, accuracy:0.066667, cumul_delta=2.397, eps=0.61356
# episode 160: cumul_reward=10.0, accuracy:0.13333, cumul_delta=3.5317, eps=0.61168
# episode 161: cumul_reward=10.0, accuracy:0.13333, cumul_delta=3.1866, eps=0.6098
# episode 162: cumul_reward=19.0, accuracy:0.2, cumul_delta=4.5583, eps=0.60793
# episode 163: cumul_reward=8.0, accuracy:0.066667, cumul_delta=4.3908, eps=0.60607
# episode 164: cumul_reward=11.0, accuracy:0.13333, cumul_delta=1.8792, eps=0.60421
# episode 165: cumul_reward=15.0, accuracy:0.066667, cumul_delta=6.4222, eps=0.60236
# episode 166: cumul_reward=12.0, accuracy:0.066667, cumul_delta=0.86733, eps=0.60051
# episode 167: cumul_reward=8.0, accuracy:0.0, cumul_delta=2.4205, eps=0.59867
# episode 168: cumul_reward=17.0, accuracy:0.2, cumul_delta=5.0361, eps=0.59683
# episode 169: cumul_reward=26.0, accuracy:0.2, cumul_delta=17.392, eps=0.595
# episode 170: cumul_reward=10.0, accuracy:0.13333, cumul_delta=3.1996, eps=0.59317
# episode 171: cumul_reward=11.0, accuracy:0.13333, cumul_delta=-1.6831, eps=0.59135
# episode 172: cumul_reward=10.0, accuracy:0.0, cumul_delta=3.4995, eps=0.58954
# episode 173: cumul_reward=17.0, accuracy:0.13333, cumul_delta=8.1522, eps=0.58773
# episode 174: cumul_reward=14.0, accuracy:0.13333, cumul_delta=5.4005, eps=0.58593
# episode 175: cumul_reward=15.0, accuracy:0.13333, cumul_delta=4.8206, eps=0.58413
# episode 176: cumul_reward=12.0, accuracy:0.13333, cumul_delta=3.5523, eps=0.58234
# episode 177: cumul_reward=16.0, accuracy:0.066667, cumul_delta=0.3352, eps=0.58055
# episode 178: cumul_reward=26.0, accuracy:0.33333, cumul_delta=10.046, eps=0.57877
# episode 179: cumul_reward=28.0, accuracy:0.33333, cumul_delta=10.865, eps=0.577
# episode 180: cumul_reward=25.0, accuracy:0.2, cumul_delta=8.9408, eps=0.57523
# episode 181: cumul_reward=20.0, accuracy:0.2, cumul_delta=7.7176, eps=0.57346
# episode 182: cumul_reward=20.0, accuracy:0.26667, cumul_delta=11.143, eps=0.5717
# episode 183: cumul_reward=21.0, accuracy:0.13333, cumul_delta=-0.35715, eps=0.56995
# episode 184: cumul_reward=17.0, accuracy:0.0, cumul_delta=3.9827, eps=0.5682
# episode 185: cumul_reward=14.0, accuracy:0.13333, cumul_delta=5.9178, eps=0.56646
# episode 186: cumul_reward=13.0, accuracy:0.0, cumul_delta=7.667, eps=0.56472
# episode 187: cumul_reward=22.0, accuracy:0.33333, cumul_delta=3.2853, eps=0.56299
# episode 188: cumul_reward=4.0, accuracy:0.0, cumul_delta=1.1112, eps=0.56126
# episode 189: cumul_reward=7.0, accuracy:0.0, cumul_delta=6.949, eps=0.55954
# episode 190: cumul_reward=24.0, accuracy:0.066667, cumul_delta=7.2436, eps=0.55782
# episode 191: cumul_reward=15.0, accuracy:0.066667, cumul_delta=8.1357, eps=0.55611
# episode 192: cumul_reward=13.0, accuracy:0.13333, cumul_delta=6.6807, eps=0.55441
# episode 193: cumul_reward=15.0, accuracy:0.066667, cumul_delta=13.827, eps=0.55271
# episode 194: cumul_reward=13.0, accuracy:0.13333, cumul_delta=3.6141, eps=0.55101
# episode 195: cumul_reward=14.0, accuracy:0.13333, cumul_delta=2.4126, eps=0.54932
# episode 196: cumul_reward=19.0, accuracy:0.066667, cumul_delta=13.217, eps=0.54764
# episode 197: cumul_reward=31.0, accuracy:0.33333, cumul_delta=11.03, eps=0.54596
# episode 198: cumul_reward=15.0, accuracy:0.2, cumul_delta=3.012, eps=0.54428
# episode 199: cumul_reward=11.0, accuracy:0.13333, cumul_delta=3.3698, eps=0.54261
# episode 200: cumul_reward=14.0, accuracy:0.066667, cumul_delta=4.4373, eps=0.54095
# episode 201: cumul_reward=18.0, accuracy:0.13333, cumul_delta=0.86113, eps=0.53929
# episode 202: cumul_reward=12.0, accuracy:0.066667, cumul_delta=2.557, eps=0.53763
# episode 203: cumul_reward=7.0, accuracy:0.0, cumul_delta=2.0644, eps=0.53599
# episode 204: cumul_reward=19.0, accuracy:0.26667, cumul_delta=7.5557, eps=0.53434
# episode 205: cumul_reward=17.0, accuracy:0.13333, cumul_delta=2.7997, eps=0.5327
# episode 206: cumul_reward=12.0, accuracy:0.066667, cumul_delta=2.812, eps=0.53107
# episode 207: cumul_reward=12.0, accuracy:0.0, cumul_delta=11.553, eps=0.52944
# episode 208: cumul_reward=21.0, accuracy:0.13333, cumul_delta=1.6767, eps=0.52781
# episode 209: cumul_reward=24.0, accuracy:0.2, cumul_delta=11.449, eps=0.5262
# episode 210: cumul_reward=11.0, accuracy:0.13333, cumul_delta=0.63635, eps=0.52458
# episode 211: cumul_reward=16.0, accuracy:0.2, cumul_delta=2.4866, eps=0.52297
# episode 212: cumul_reward=4.0, accuracy:0.0, cumul_delta=-1.7545, eps=0.52137
# episode 213: cumul_reward=25.0, accuracy:0.33333, cumul_delta=5.9448, eps=0.51977
# episode 214: cumul_reward=22.0, accuracy:0.13333, cumul_delta=7.859, eps=0.51817
# episode 215: cumul_reward=9.0, accuracy:0.0, cumul_delta=6.7141, eps=0.51659
# episode 216: cumul_reward=15.0, accuracy:0.066667, cumul_delta=5.4182, eps=0.515
# episode 217: cumul_reward=9.0, accuracy:0.0, cumul_delta=4.4149, eps=0.51342
# episode 218: cumul_reward=24.0, accuracy:0.26667, cumul_delta=8.4559, eps=0.51185
# episode 219: cumul_reward=15.0, accuracy:0.2, cumul_delta=13.33, eps=0.51028
# episode 220: cumul_reward=15.0, accuracy:0.066667, cumul_delta=11.189, eps=0.50871
# episode 221: cumul_reward=33.0, accuracy:0.4, cumul_delta=10.072, eps=0.50715
# episode 222: cumul_reward=19.0, accuracy:0.2, cumul_delta=6.1742, eps=0.50559
# episode 223: cumul_reward=11.0, accuracy:0.0, cumul_delta=3.5176, eps=0.50404
# episode 224: cumul_reward=15.0, accuracy:0.13333, cumul_delta=0.28044, eps=0.5025
# episode 225: cumul_reward=20.0, accuracy:0.26667, cumul_delta=8.6682, eps=0.50096
# episode 226: cumul_reward=19.0, accuracy:0.2, cumul_delta=0.93661, eps=0.49942
# episode 227: cumul_reward=28.0, accuracy:0.26667, cumul_delta=15.34, eps=0.49789
# episode 228: cumul_reward=15.0, accuracy:0.2, cumul_delta=5.4659, eps=0.49636
# episode 229: cumul_reward=10.0, accuracy:0.066667, cumul_delta=-0.0036806, eps=0.49484
# episode 230: cumul_reward=24.0, accuracy:0.26667, cumul_delta=7.5836, eps=0.49332
# episode 231: cumul_reward=24.0, accuracy:0.2, cumul_delta=-0.24009, eps=0.49181
# episode 232: cumul_reward=21.0, accuracy:0.2, cumul_delta=5.0942, eps=0.4903
# episode 233: cumul_reward=14.0, accuracy:0.066667, cumul_delta=7.4981, eps=0.48879
# episode 234: cumul_reward=16.0, accuracy:0.13333, cumul_delta=1.8196, eps=0.48729
# episode 235: cumul_reward=19.0, accuracy:0.2, cumul_delta=6.5312, eps=0.4858
# episode 236: cumul_reward=18.0, accuracy:0.13333, cumul_delta=7.408, eps=0.48431
# episode 237: cumul_reward=17.0, accuracy:0.26667, cumul_delta=3.5589, eps=0.48282
# episode 238: cumul_reward=22.0, accuracy:0.26667, cumul_delta=4.3073, eps=0.48134
# episode 239: cumul_reward=24.0, accuracy:0.26667, cumul_delta=5.5456, eps=0.47987
# episode 240: cumul_reward=23.0, accuracy:0.33333, cumul_delta=4.6887, eps=0.47839
# episode 241: cumul_reward=24.0, accuracy:0.2, cumul_delta=7.1869, eps=0.47693
# episode 242: cumul_reward=13.0, accuracy:0.066667, cumul_delta=15.11, eps=0.47546
# episode 243: cumul_reward=11.0, accuracy:0.066667, cumul_delta=-1.3477, eps=0.47401
# episode 244: cumul_reward=19.0, accuracy:0.13333, cumul_delta=4.8549, eps=0.47255
# episode 245: cumul_reward=23.0, accuracy:0.33333, cumul_delta=5.7301, eps=0.4711
# episode 246: cumul_reward=19.0, accuracy:0.2, cumul_delta=2.2265, eps=0.46966
# episode 247: cumul_reward=24.0, accuracy:0.33333, cumul_delta=6.5493, eps=0.46822
# episode 248: cumul_reward=21.0, accuracy:0.2, cumul_delta=2.8461, eps=0.46678
# episode 249: cumul_reward=14.0, accuracy:0.066667, cumul_delta=8.085, eps=0.46535
# episode 250: cumul_reward=17.0, accuracy:0.13333, cumul_delta=9.1907, eps=0.46392
# episode 251: cumul_reward=30.0, accuracy:0.4, cumul_delta=8.2104, eps=0.4625
# episode 252: cumul_reward=20.0, accuracy:0.26667, cumul_delta=1.3556, eps=0.46108
# episode 253: cumul_reward=16.0, accuracy:0.2, cumul_delta=4.815, eps=0.45967
# episode 254: cumul_reward=24.0, accuracy:0.26667, cumul_delta=10.177, eps=0.45826
# episode 255: cumul_reward=9.0, accuracy:0.13333, cumul_delta=0.92864, eps=0.45685
# episode 256: cumul_reward=19.0, accuracy:0.26667, cumul_delta=2.2924, eps=0.45545
# episode 257: cumul_reward=31.0, accuracy:0.46667, cumul_delta=3.2815, eps=0.45405
# episode 258: cumul_reward=25.0, accuracy:0.33333, cumul_delta=2.3872, eps=0.45266
# episode 259: cumul_reward=19.0, accuracy:0.13333, cumul_delta=8.8615, eps=0.45127
# episode 260: cumul_reward=27.0, accuracy:0.4, cumul_delta=15.398, eps=0.44989
# episode 261: cumul_reward=14.0, accuracy:0.13333, cumul_delta=2.9563, eps=0.44851
# episode 262: cumul_reward=13.0, accuracy:0.066667, cumul_delta=5.3938, eps=0.44713
# episode 263: cumul_reward=14.0, accuracy:0.13333, cumul_delta=5.0128, eps=0.44576
# episode 264: cumul_reward=20.0, accuracy:0.2, cumul_delta=4.2077, eps=0.44439
# episode 265: cumul_reward=17.0, accuracy:0.2, cumul_delta=4.2784, eps=0.44303
# episode 266: cumul_reward=24.0, accuracy:0.2, cumul_delta=8.3218, eps=0.44167
# episode 267: cumul_reward=33.0, accuracy:0.33333, cumul_delta=8.206, eps=0.44031
# episode 268: cumul_reward=21.0, accuracy:0.33333, cumul_delta=-1.0127, eps=0.43896
# episode 269: cumul_reward=12.0, accuracy:0.2, cumul_delta=0.942, eps=0.43762
# episode 270: cumul_reward=18.0, accuracy:0.2, cumul_delta=0.21928, eps=0.43627
# episode 271: cumul_reward=30.0, accuracy:0.4, cumul_delta=0.20637, eps=0.43494
# episode 272: cumul_reward=12.0, accuracy:0.13333, cumul_delta=4.4831, eps=0.4336
# episode 273: cumul_reward=14.0, accuracy:0.13333, cumul_delta=1.3659, eps=0.43227
# episode 274: cumul_reward=11.0, accuracy:0.066667, cumul_delta=6.7399, eps=0.43095
# episode 275: cumul_reward=26.0, accuracy:0.4, cumul_delta=3.4891, eps=0.42962
# episode 276: cumul_reward=25.0, accuracy:0.4, cumul_delta=-0.38331, eps=0.42831
# episode 277: cumul_reward=32.0, accuracy:0.46667, cumul_delta=1.1859, eps=0.42699
# episode 278: cumul_reward=14.0, accuracy:0.13333, cumul_delta=11.328, eps=0.42568
# episode 279: cumul_reward=18.0, accuracy:0.26667, cumul_delta=2.9344, eps=0.42438
# episode 280: cumul_reward=12.0, accuracy:0.13333, cumul_delta=10.515, eps=0.42308
# episode 281: cumul_reward=9.0, accuracy:0.066667, cumul_delta=7.15, eps=0.42178
# episode 282: cumul_reward=25.0, accuracy:0.33333, cumul_delta=4.5258, eps=0.42048
# episode 283: cumul_reward=24.0, accuracy:0.33333, cumul_delta=5.0195, eps=0.41919
# episode 284: cumul_reward=30.0, accuracy:0.4, cumul_delta=4.1448, eps=0.41791
# episode 285: cumul_reward=20.0, accuracy:0.2, cumul_delta=11.8, eps=0.41663
# episode 286: cumul_reward=28.0, accuracy:0.4, cumul_delta=6.0018, eps=0.41535
# episode 287: cumul_reward=22.0, accuracy:0.26667, cumul_delta=2.1718, eps=0.41407
# episode 288: cumul_reward=24.0, accuracy:0.4, cumul_delta=1.1549, eps=0.4128
# episode 289: cumul_reward=14.0, accuracy:0.2, cumul_delta=2.3834, eps=0.41154
# episode 290: cumul_reward=22.0, accuracy:0.26667, cumul_delta=2.0481, eps=0.41028
# episode 291: cumul_reward=25.0, accuracy:0.33333, cumul_delta=1.0257, eps=0.40902
# episode 292: cumul_reward=22.0, accuracy:0.33333, cumul_delta=12.202, eps=0.40776
# episode 293: cumul_reward=34.0, accuracy:0.53333, cumul_delta=2.1364, eps=0.40651
# episode 294: cumul_reward=15.0, accuracy:0.2, cumul_delta=6.715, eps=0.40526
# episode 295: cumul_reward=14.0, accuracy:0.2, cumul_delta=2.9451, eps=0.40402
# episode 296: cumul_reward=24.0, accuracy:0.33333, cumul_delta=7.1077, eps=0.40278
# episode 297: cumul_reward=30.0, accuracy:0.4, cumul_delta=3.1583, eps=0.40155
# episode 298: cumul_reward=23.0, accuracy:0.33333, cumul_delta=-3.2941, eps=0.40031
# episode 299: cumul_reward=20.0, accuracy:0.33333, cumul_delta=3.2485, eps=0.39909
# episode 300: cumul_reward=19.0, accuracy:0.26667, cumul_delta=4.1906, eps=0.39786
# episode 301: cumul_reward=30.0, accuracy:0.4, cumul_delta=9.0531, eps=0.39664
# episode 302: cumul_reward=26.0, accuracy:0.4, cumul_delta=10.474, eps=0.39543
# episode 303: cumul_reward=28.0, accuracy:0.4, cumul_delta=0.51923, eps=0.39421
# episode 304: cumul_reward=18.0, accuracy:0.13333, cumul_delta=1.7998, eps=0.393
# episode 305: cumul_reward=23.0, accuracy:0.2, cumul_delta=3.7722, eps=0.3918
# episode 306: cumul_reward=16.0, accuracy:0.26667, cumul_delta=0.10656, eps=0.3906
# episode 307: cumul_reward=26.0, accuracy:0.33333, cumul_delta=2.711, eps=0.3894
# episode 308: cumul_reward=30.0, accuracy:0.4, cumul_delta=-3.3329, eps=0.3882
# episode 309: cumul_reward=13.0, accuracy:0.2, cumul_delta=-1.3992, eps=0.38701
# episode 310: cumul_reward=13.0, accuracy:0.13333, cumul_delta=8.5435, eps=0.38583
# episode 311: cumul_reward=11.0, accuracy:0.13333, cumul_delta=2.7076, eps=0.38464
# episode 312: cumul_reward=28.0, accuracy:0.33333, cumul_delta=15.46, eps=0.38346
# episode 313: cumul_reward=26.0, accuracy:0.26667, cumul_delta=-3.6005, eps=0.38229
# episode 314: cumul_reward=14.0, accuracy:0.066667, cumul_delta=0.041454, eps=0.38111
# episode 315: cumul_reward=21.0, accuracy:0.33333, cumul_delta=1.8127, eps=0.37994
# episode 316: cumul_reward=38.0, accuracy:0.53333, cumul_delta=14.629, eps=0.37878
# episode 317: cumul_reward=19.0, accuracy:0.2, cumul_delta=4.6186, eps=0.37762
# episode 318: cumul_reward=15.0, accuracy:0.13333, cumul_delta=3.4851, eps=0.37646
# episode 319: cumul_reward=36.0, accuracy:0.6, cumul_delta=4.2054, eps=0.3753
# episode 320: cumul_reward=33.0, accuracy:0.4, cumul_delta=5.6617, eps=0.37415
# episode 321: cumul_reward=29.0, accuracy:0.4, cumul_delta=2.6803, eps=0.373
# episode 322: cumul_reward=8.0, accuracy:0.066667, cumul_delta=0.19629, eps=0.37186
# episode 323: cumul_reward=24.0, accuracy:0.33333, cumul_delta=5.0145, eps=0.37072
# episode 324: cumul_reward=13.0, accuracy:0.2, cumul_delta=0.55887, eps=0.36958
# episode 325: cumul_reward=20.0, accuracy:0.26667, cumul_delta=8.9327, eps=0.36845
# episode 326: cumul_reward=18.0, accuracy:0.26667, cumul_delta=2.3753, eps=0.36732
# episode 327: cumul_reward=29.0, accuracy:0.33333, cumul_delta=9.3192, eps=0.36619
# episode 328: cumul_reward=14.0, accuracy:0.2, cumul_delta=2.3137, eps=0.36507
# episode 329: cumul_reward=24.0, accuracy:0.33333, cumul_delta=2.5211, eps=0.36395
# episode 330: cumul_reward=39.0, accuracy:0.6, cumul_delta=2.514, eps=0.36283
# episode 331: cumul_reward=32.0, accuracy:0.46667, cumul_delta=-1.2096, eps=0.36172
# episode 332: cumul_reward=21.0, accuracy:0.2, cumul_delta=2.6875, eps=0.36061
# episode 333: cumul_reward=15.0, accuracy:0.2, cumul_delta=-1.1959, eps=0.3595
# episode 334: cumul_reward=13.0, accuracy:0.066667, cumul_delta=-0.71243, eps=0.3584
# episode 335: cumul_reward=29.0, accuracy:0.4, cumul_delta=5.2064, eps=0.3573
# episode 336: cumul_reward=40.0, accuracy:0.6, cumul_delta=2.7912, eps=0.35621
# episode 337: cumul_reward=24.0, accuracy:0.33333, cumul_delta=3.29, eps=0.35511
# episode 338: cumul_reward=39.0, accuracy:0.53333, cumul_delta=7.8432, eps=0.35402
# episode 339: cumul_reward=12.0, accuracy:0.2, cumul_delta=3.9086, eps=0.35294
# episode 340: cumul_reward=21.0, accuracy:0.26667, cumul_delta=2.8734, eps=0.35186
# episode 341: cumul_reward=32.0, accuracy:0.33333, cumul_delta=6.3992, eps=0.35078
# episode 342: cumul_reward=18.0, accuracy:0.2, cumul_delta=-0.96346, eps=0.3497
# episode 343: cumul_reward=26.0, accuracy:0.26667, cumul_delta=5.8962, eps=0.34863
# episode 344: cumul_reward=28.0, accuracy:0.33333, cumul_delta=4.7364, eps=0.34756
# episode 345: cumul_reward=13.0, accuracy:0.066667, cumul_delta=-2.8339, eps=0.34649
# episode 346: cumul_reward=39.0, accuracy:0.53333, cumul_delta=5.5605, eps=0.34543
# episode 347: cumul_reward=26.0, accuracy:0.4, cumul_delta=5.1186, eps=0.34437
# episode 348: cumul_reward=32.0, accuracy:0.33333, cumul_delta=7.807, eps=0.34331
# episode 349: cumul_reward=32.0, accuracy:0.33333, cumul_delta=6.0995, eps=0.34226
# episode 350: cumul_reward=28.0, accuracy:0.33333, cumul_delta=4.9186, eps=0.34121
# episode 351: cumul_reward=31.0, accuracy:0.26667, cumul_delta=12.503, eps=0.34016
# episode 352: cumul_reward=26.0, accuracy:0.26667, cumul_delta=4.5818, eps=0.33912
# episode 353: cumul_reward=27.0, accuracy:0.33333, cumul_delta=4.8416, eps=0.33808
# episode 354: cumul_reward=41.0, accuracy:0.6, cumul_delta=2.1, eps=0.33704
# episode 355: cumul_reward=39.0, accuracy:0.33333, cumul_delta=8.7046, eps=0.33601
# episode 356: cumul_reward=30.0, accuracy:0.4, cumul_delta=8.0989, eps=0.33498
# episode 357: cumul_reward=32.0, accuracy:0.4, cumul_delta=0.35909, eps=0.33395
# episode 358: cumul_reward=28.0, accuracy:0.26667, cumul_delta=1.1252, eps=0.33293
# episode 359: cumul_reward=38.0, accuracy:0.4, cumul_delta=4.4234, eps=0.33191
# episode 360: cumul_reward=34.0, accuracy:0.33333, cumul_delta=7.7075, eps=0.33089
# episode 361: cumul_reward=31.0, accuracy:0.4, cumul_delta=4.0654, eps=0.32987
# episode 362: cumul_reward=30.0, accuracy:0.4, cumul_delta=1.5505, eps=0.32886
# episode 363: cumul_reward=31.0, accuracy:0.26667, cumul_delta=3.8839, eps=0.32785
# episode 364: cumul_reward=24.0, accuracy:0.2, cumul_delta=9.6805, eps=0.32685
# episode 365: cumul_reward=22.0, accuracy:0.26667, cumul_delta=4.2182, eps=0.32584
# episode 366: cumul_reward=37.0, accuracy:0.33333, cumul_delta=1.9936, eps=0.32484
# episode 367: cumul_reward=36.0, accuracy:0.53333, cumul_delta=5.8412, eps=0.32385
# episode 368: cumul_reward=27.0, accuracy:0.4, cumul_delta=4.3556, eps=0.32285
# episode 369: cumul_reward=23.0, accuracy:0.33333, cumul_delta=0.62376, eps=0.32186
# episode 370: cumul_reward=36.0, accuracy:0.4, cumul_delta=2.2322, eps=0.32088
# episode 371: cumul_reward=30.0, accuracy:0.46667, cumul_delta=5.0412, eps=0.31989
# episode 372: cumul_reward=20.0, accuracy:0.26667, cumul_delta=4.1688, eps=0.31891
# episode 373: cumul_reward=24.0, accuracy:0.33333, cumul_delta=7.6135, eps=0.31793
# episode 374: cumul_reward=36.0, accuracy:0.4, cumul_delta=0.32312, eps=0.31696
# episode 375: cumul_reward=39.0, accuracy:0.46667, cumul_delta=6.4318, eps=0.31598
# episode 376: cumul_reward=20.0, accuracy:0.26667, cumul_delta=8.691, eps=0.31502
# episode 377: cumul_reward=37.0, accuracy:0.46667, cumul_delta=2.3166, eps=0.31405
# episode 378: cumul_reward=31.0, accuracy:0.46667, cumul_delta=5.3442, eps=0.31309
# episode 379: cumul_reward=41.0, accuracy:0.6, cumul_delta=1.4611, eps=0.31213
# episode 380: cumul_reward=27.0, accuracy:0.26667, cumul_delta=4.566, eps=0.31117
# episode 381: cumul_reward=28.0, accuracy:0.33333, cumul_delta=8.3163, eps=0.31021
# episode 382: cumul_reward=20.0, accuracy:0.2, cumul_delta=2.2144, eps=0.30926
# episode 383: cumul_reward=33.0, accuracy:0.53333, cumul_delta=2.9516, eps=0.30831
# episode 384: cumul_reward=37.0, accuracy:0.4, cumul_delta=-0.10656, eps=0.30737
# episode 385: cumul_reward=25.0, accuracy:0.26667, cumul_delta=5.7238, eps=0.30643
# episode 386: cumul_reward=46.0, accuracy:0.46667, cumul_delta=2.0079, eps=0.30549
# episode 387: cumul_reward=14.0, accuracy:0.2, cumul_delta=-3.0273, eps=0.30455
# episode 388: cumul_reward=34.0, accuracy:0.46667, cumul_delta=3.7578, eps=0.30361
# episode 389: cumul_reward=26.0, accuracy:0.33333, cumul_delta=5.5882, eps=0.30268
# episode 390: cumul_reward=29.0, accuracy:0.4, cumul_delta=2.6652, eps=0.30175
# episode 391: cumul_reward=30.0, accuracy:0.46667, cumul_delta=4.3776, eps=0.30083
# episode 392: cumul_reward=29.0, accuracy:0.4, cumul_delta=0.26685, eps=0.29991
# episode 393: cumul_reward=49.0, accuracy:0.73333, cumul_delta=7.0399, eps=0.29899
# episode 394: cumul_reward=47.0, accuracy:0.6, cumul_delta=4.8718, eps=0.29807
# episode 395: cumul_reward=26.0, accuracy:0.26667, cumul_delta=5.2464, eps=0.29715
# episode 396: cumul_reward=20.0, accuracy:0.33333, cumul_delta=0.91867, eps=0.29624
# episode 397: cumul_reward=39.0, accuracy:0.53333, cumul_delta=0.48706, eps=0.29533
# episode 398: cumul_reward=29.0, accuracy:0.4, cumul_delta=-0.54033, eps=0.29443
# episode 399: cumul_reward=30.0, accuracy:0.46667, cumul_delta=3.8089, eps=0.29353
# episode 400: cumul_reward=31.0, accuracy:0.4, cumul_delta=0.21461, eps=0.29262
# episode 401: cumul_reward=40.0, accuracy:0.6, cumul_delta=5.77, eps=0.29173
# episode 402: cumul_reward=23.0, accuracy:0.33333, cumul_delta=0.74904, eps=0.29083
# episode 403: cumul_reward=40.0, accuracy:0.53333, cumul_delta=1.7223, eps=0.28994
# episode 404: cumul_reward=32.0, accuracy:0.4, cumul_delta=-0.86043, eps=0.28905
# episode 405: cumul_reward=46.0, accuracy:0.6, cumul_delta=0.47699, eps=0.28816
# episode 406: cumul_reward=29.0, accuracy:0.33333, cumul_delta=-3.8463, eps=0.28728
# episode 407: cumul_reward=32.0, accuracy:0.4, cumul_delta=9.9269, eps=0.2864
# episode 408: cumul_reward=22.0, accuracy:0.26667, cumul_delta=4.5758, eps=0.28552
# episode 409: cumul_reward=23.0, accuracy:0.33333, cumul_delta=0.75573, eps=0.28464
# episode 410: cumul_reward=48.0, accuracy:0.73333, cumul_delta=1.8005, eps=0.28377
# episode 411: cumul_reward=44.0, accuracy:0.73333, cumul_delta=2.3913, eps=0.2829
# episode 412: cumul_reward=22.0, accuracy:0.33333, cumul_delta=2.206, eps=0.28203
# episode 413: cumul_reward=23.0, accuracy:0.26667, cumul_delta=1.2798, eps=0.28117
# episode 414: cumul_reward=23.0, accuracy:0.26667, cumul_delta=5.4238, eps=0.28031
# episode 415: cumul_reward=35.0, accuracy:0.26667, cumul_delta=-0.84885, eps=0.27945
# episode 416: cumul_reward=38.0, accuracy:0.53333, cumul_delta=1.4153, eps=0.27859
# episode 417: cumul_reward=23.0, accuracy:0.33333, cumul_delta=1.1513, eps=0.27773
# episode 418: cumul_reward=28.0, accuracy:0.33333, cumul_delta=2.2616, eps=0.27688
# episode 419: cumul_reward=32.0, accuracy:0.4, cumul_delta=1.2022, eps=0.27603
# episode 420: cumul_reward=36.0, accuracy:0.6, cumul_delta=8.0181, eps=0.27519
# episode 421: cumul_reward=41.0, accuracy:0.53333, cumul_delta=-1.1953, eps=0.27434
# episode 422: cumul_reward=30.0, accuracy:0.4, cumul_delta=8.2212, eps=0.2735
# episode 423: cumul_reward=16.0, accuracy:0.2, cumul_delta=4.4003, eps=0.27266
# episode 424: cumul_reward=36.0, accuracy:0.53333, cumul_delta=0.55412, eps=0.27183
# episode 425: cumul_reward=44.0, accuracy:0.66667, cumul_delta=0.0021708, eps=0.27099
# episode 426: cumul_reward=36.0, accuracy:0.6, cumul_delta=0.41171, eps=0.27016
# episode 427: cumul_reward=37.0, accuracy:0.6, cumul_delta=-1.502, eps=0.26933
# episode 428: cumul_reward=28.0, accuracy:0.33333, cumul_delta=4.9008, eps=0.26851
# episode 429: cumul_reward=21.0, accuracy:0.2, cumul_delta=14.072, eps=0.26768
# episode 430: cumul_reward=50.0, accuracy:0.73333, cumul_delta=5.7843, eps=0.26686
# episode 431: cumul_reward=18.0, accuracy:0.2, cumul_delta=0.99779, eps=0.26604
# episode 432: cumul_reward=41.0, accuracy:0.6, cumul_delta=3.8121, eps=0.26523
# episode 433: cumul_reward=32.0, accuracy:0.46667, cumul_delta=2.8222, eps=0.26441
# episode 434: cumul_reward=45.0, accuracy:0.66667, cumul_delta=2.4358, eps=0.2636
# episode 435: cumul_reward=54.0, accuracy:0.8, cumul_delta=7.1553, eps=0.26279
# episode 436: cumul_reward=35.0, accuracy:0.53333, cumul_delta=1.6461, eps=0.26199
# episode 437: cumul_reward=20.0, accuracy:0.26667, cumul_delta=0.54453, eps=0.26118
# episode 438: cumul_reward=39.0, accuracy:0.6, cumul_delta=1.7267, eps=0.26038
# episode 439: cumul_reward=53.0, accuracy:0.8, cumul_delta=2.8337, eps=0.25958
# episode 440: cumul_reward=38.0, accuracy:0.53333, cumul_delta=1.7311, eps=0.25879
# episode 441: cumul_reward=43.0, accuracy:0.6, cumul_delta=0.27747, eps=0.25799
# episode 442: cumul_reward=45.0, accuracy:0.66667, cumul_delta=4.4475, eps=0.2572
# episode 443: cumul_reward=46.0, accuracy:0.66667, cumul_delta=1.1072, eps=0.25641
# episode 444: cumul_reward=33.0, accuracy:0.46667, cumul_delta=3.5721, eps=0.25563
# episode 445: cumul_reward=33.0, accuracy:0.46667, cumul_delta=3.3959, eps=0.25484
# episode 446: cumul_reward=47.0, accuracy:0.66667, cumul_delta=-0.85817, eps=0.25406
# episode 447: cumul_reward=23.0, accuracy:0.33333, cumul_delta=0.037004, eps=0.25328
# episode 448: cumul_reward=32.0, accuracy:0.4, cumul_delta=-2.0783, eps=0.2525
# episode 449: cumul_reward=33.0, accuracy:0.46667, cumul_delta=2.5931, eps=0.25173
# episode 450: cumul_reward=31.0, accuracy:0.4, cumul_delta=-1.6134, eps=0.25096
# episode 451: cumul_reward=44.0, accuracy:0.6, cumul_delta=2.7811, eps=0.25019
# episode 452: cumul_reward=49.0, accuracy:0.73333, cumul_delta=2.5392, eps=0.24942
# episode 453: cumul_reward=34.0, accuracy:0.53333, cumul_delta=3.374, eps=0.24865
# episode 454: cumul_reward=35.0, accuracy:0.53333, cumul_delta=0.96085, eps=0.24789
# episode 455: cumul_reward=37.0, accuracy:0.53333, cumul_delta=-1.8943, eps=0.24713
# episode 456: cumul_reward=47.0, accuracy:0.66667, cumul_delta=-1.4719, eps=0.24637
# episode 457: cumul_reward=43.0, accuracy:0.66667, cumul_delta=0.11803, eps=0.24562
# episode 458: cumul_reward=35.0, accuracy:0.46667, cumul_delta=2.8012, eps=0.24486
# episode 459: cumul_reward=22.0, accuracy:0.33333, cumul_delta=-2.1921, eps=0.24411
# episode 460: cumul_reward=51.0, accuracy:0.8, cumul_delta=5.7608, eps=0.24336
# episode 461: cumul_reward=50.0, accuracy:0.73333, cumul_delta=0.57043, eps=0.24262
# episode 462: cumul_reward=29.0, accuracy:0.4, cumul_delta=2.6936, eps=0.24187
# episode 463: cumul_reward=40.0, accuracy:0.6, cumul_delta=3.187, eps=0.24113
# episode 464: cumul_reward=41.0, accuracy:0.6, cumul_delta=2.5115, eps=0.24039
# episode 465: cumul_reward=44.0, accuracy:0.6, cumul_delta=0.9778, eps=0.23965
# episode 466: cumul_reward=26.0, accuracy:0.4, cumul_delta=3.1492, eps=0.23892
# episode 467: cumul_reward=39.0, accuracy:0.6, cumul_delta=0.85771, eps=0.23819
# episode 468: cumul_reward=27.0, accuracy:0.4, cumul_delta=1.0573, eps=0.23746
# episode 469: cumul_reward=43.0, accuracy:0.66667, cumul_delta=0.4165, eps=0.23673
# episode 470: cumul_reward=51.0, accuracy:0.8, cumul_delta=0.19571, eps=0.236
# episode 471: cumul_reward=43.0, accuracy:0.6, cumul_delta=7.8702, eps=0.23528
# episode 472: cumul_reward=20.0, accuracy:0.2, cumul_delta=-2.5978, eps=0.23456
# episode 473: cumul_reward=45.0, accuracy:0.66667, cumul_delta=1.4319, eps=0.23384
# episode 474: cumul_reward=36.0, accuracy:0.6, cumul_delta=0.26184, eps=0.23312
# episode 475: cumul_reward=38.0, accuracy:0.46667, cumul_delta=2.2567, eps=0.2324
# episode 476: cumul_reward=34.0, accuracy:0.46667, cumul_delta=3.7506, eps=0.23169
# episode 477: cumul_reward=37.0, accuracy:0.53333, cumul_delta=4.6096, eps=0.23098
# episode 478: cumul_reward=39.0, accuracy:0.6, cumul_delta=0.033442, eps=0.23027
# episode 479: cumul_reward=35.0, accuracy:0.53333, cumul_delta=-0.032746, eps=0.22957
# episode 480: cumul_reward=43.0, accuracy:0.66667, cumul_delta=0.064916, eps=0.22886
# episode 481: cumul_reward=45.0, accuracy:0.66667, cumul_delta=2.6328, eps=0.22816
# episode 482: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.19587, eps=0.22746
# episode 483: cumul_reward=28.0, accuracy:0.4, cumul_delta=0.00099969, eps=0.22676
# episode 484: cumul_reward=34.0, accuracy:0.46667, cumul_delta=1.7999, eps=0.22607
# episode 485: cumul_reward=43.0, accuracy:0.66667, cumul_delta=3.2268, eps=0.22537
# episode 486: cumul_reward=40.0, accuracy:0.6, cumul_delta=1.7, eps=0.22468
# episode 487: cumul_reward=51.0, accuracy:0.8, cumul_delta=1.2119, eps=0.22399
# episode 488: cumul_reward=37.0, accuracy:0.53333, cumul_delta=2.9263, eps=0.22331
# episode 489: cumul_reward=37.0, accuracy:0.53333, cumul_delta=8.7088, eps=0.22262
# episode 490: cumul_reward=34.0, accuracy:0.46667, cumul_delta=1.6806, eps=0.22194
# episode 491: cumul_reward=31.0, accuracy:0.46667, cumul_delta=0.74359, eps=0.22126
# episode 492: cumul_reward=39.0, accuracy:0.53333, cumul_delta=4.8931, eps=0.22058
# episode 493: cumul_reward=46.0, accuracy:0.66667, cumul_delta=0.38978, eps=0.2199
# episode 494: cumul_reward=22.0, accuracy:0.33333, cumul_delta=2.3103, eps=0.21923
# episode 495: cumul_reward=48.0, accuracy:0.73333, cumul_delta=0.44697, eps=0.21855
# episode 496: cumul_reward=51.0, accuracy:0.8, cumul_delta=0.22593, eps=0.21788
# episode 497: cumul_reward=41.0, accuracy:0.6, cumul_delta=5.7326, eps=0.21722
# episode 498: cumul_reward=29.0, accuracy:0.4, cumul_delta=4.4275, eps=0.21655
# episode 499: cumul_reward=30.0, accuracy:0.46667, cumul_delta=1.6447, eps=0.21589
# episode 500: cumul_reward=18.0, accuracy:0.2, cumul_delta=4.3185, eps=0.21522
# episode 501: cumul_reward=49.0, accuracy:0.73333, cumul_delta=0.48575, eps=0.21456
# episode 502: cumul_reward=31.0, accuracy:0.46667, cumul_delta=0.55, eps=0.2139
# episode 503: cumul_reward=36.0, accuracy:0.53333, cumul_delta=4.2091, eps=0.21325
# episode 504: cumul_reward=50.0, accuracy:0.8, cumul_delta=2.1947, eps=0.21259
# episode 505: cumul_reward=53.0, accuracy:0.8, cumul_delta=1.9874, eps=0.21194
# episode 506: cumul_reward=53.0, accuracy:0.8, cumul_delta=1.6025, eps=0.21129
# episode 507: cumul_reward=22.0, accuracy:0.26667, cumul_delta=4.1102, eps=0.21064
# episode 508: cumul_reward=50.0, accuracy:0.8, cumul_delta=-1.8677, eps=0.21
# episode 509: cumul_reward=42.0, accuracy:0.66667, cumul_delta=0.13846, eps=0.20935
# episode 510: cumul_reward=40.0, accuracy:0.66667, cumul_delta=1.2865, eps=0.20871
# episode 511: cumul_reward=26.0, accuracy:0.33333, cumul_delta=6.123, eps=0.20807
# episode 512: cumul_reward=44.0, accuracy:0.73333, cumul_delta=0.277, eps=0.20743
# episode 513: cumul_reward=25.0, accuracy:0.33333, cumul_delta=1.2856, eps=0.2068
# episode 514: cumul_reward=51.0, accuracy:0.8, cumul_delta=0.016373, eps=0.20616
# episode 515: cumul_reward=45.0, accuracy:0.66667, cumul_delta=2.2876, eps=0.20553
# episode 516: cumul_reward=26.0, accuracy:0.33333, cumul_delta=6.5275, eps=0.2049
# episode 517: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.11596, eps=0.20427
# episode 518: cumul_reward=46.0, accuracy:0.66667, cumul_delta=0.6392, eps=0.20364
# episode 519: cumul_reward=55.0, accuracy:0.8, cumul_delta=-0.27787, eps=0.20302
# episode 520: cumul_reward=45.0, accuracy:0.66667, cumul_delta=3.4177, eps=0.2024
# episode 521: cumul_reward=51.0, accuracy:0.8, cumul_delta=1.463, eps=0.20178
# episode 522: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.65838, eps=0.20116
# episode 523: cumul_reward=43.0, accuracy:0.6, cumul_delta=3.4331, eps=0.20054
# episode 524: cumul_reward=43.0, accuracy:0.66667, cumul_delta=0.18469, eps=0.19993
# episode 525: cumul_reward=45.0, accuracy:0.66667, cumul_delta=0.0014737, eps=0.19931
# episode 526: cumul_reward=48.0, accuracy:0.8, cumul_delta=4.9549, eps=0.1987
# episode 527: cumul_reward=45.0, accuracy:0.66667, cumul_delta=2.6675, eps=0.19809
# episode 528: cumul_reward=36.0, accuracy:0.46667, cumul_delta=-2.2716, eps=0.19748
# episode 529: cumul_reward=41.0, accuracy:0.6, cumul_delta=4.2003, eps=0.19688
# episode 530: cumul_reward=39.0, accuracy:0.6, cumul_delta=0.83357, eps=0.19627
# episode 531: cumul_reward=45.0, accuracy:0.66667, cumul_delta=1.6756, eps=0.19567
# episode 532: cumul_reward=34.0, accuracy:0.33333, cumul_delta=6.624, eps=0.19507
# episode 533: cumul_reward=44.0, accuracy:0.6, cumul_delta=2.953, eps=0.19447
# episode 534: cumul_reward=37.0, accuracy:0.53333, cumul_delta=-0.99224, eps=0.19388
# episode 535: cumul_reward=35.0, accuracy:0.53333, cumul_delta=4.0794, eps=0.19328
# episode 536: cumul_reward=40.0, accuracy:0.66667, cumul_delta=0.042825, eps=0.19269
# episode 537: cumul_reward=30.0, accuracy:0.4, cumul_delta=5.2257, eps=0.1921
# episode 538: cumul_reward=51.0, accuracy:0.8, cumul_delta=0.3959, eps=0.19151
# episode 539: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.18661, eps=0.19092
# episode 540: cumul_reward=38.0, accuracy:0.6, cumul_delta=0.4493, eps=0.19034
# episode 541: cumul_reward=46.0, accuracy:0.73333, cumul_delta=1.0685, eps=0.18975
# episode 542: cumul_reward=49.0, accuracy:0.73333, cumul_delta=-3.2692, eps=0.18917
# episode 543: cumul_reward=39.0, accuracy:0.53333, cumul_delta=0.94352, eps=0.18859
# episode 544: cumul_reward=32.0, accuracy:0.33333, cumul_delta=1.4749, eps=0.18801
# episode 545: cumul_reward=46.0, accuracy:0.73333, cumul_delta=3.2291, eps=0.18743
# episode 546: cumul_reward=49.0, accuracy:0.73333, cumul_delta=1.8349, eps=0.18686
# episode 547: cumul_reward=39.0, accuracy:0.53333, cumul_delta=-0.98925, eps=0.18629
# episode 548: cumul_reward=34.0, accuracy:0.53333, cumul_delta=3.7833, eps=0.18571
# episode 549: cumul_reward=34.0, accuracy:0.53333, cumul_delta=0.055523, eps=0.18514
# episode 550: cumul_reward=41.0, accuracy:0.53333, cumul_delta=7.5422, eps=0.18458
# episode 551: cumul_reward=44.0, accuracy:0.6, cumul_delta=0.61415, eps=0.18401
# episode 552: cumul_reward=45.0, accuracy:0.66667, cumul_delta=1.9052, eps=0.18345
# episode 553: cumul_reward=39.0, accuracy:0.53333, cumul_delta=7.2214, eps=0.18288
# episode 554: cumul_reward=37.0, accuracy:0.53333, cumul_delta=5.5468, eps=0.18232
# episode 555: cumul_reward=43.0, accuracy:0.53333, cumul_delta=8.2518, eps=0.18176
# episode 556: cumul_reward=53.0, accuracy:0.8, cumul_delta=-0.83078, eps=0.18121
# episode 557: cumul_reward=38.0, accuracy:0.53333, cumul_delta=1.9493, eps=0.18065
# episode 558: cumul_reward=45.0, accuracy:0.66667, cumul_delta=2.9104, eps=0.1801
# episode 559: cumul_reward=46.0, accuracy:0.66667, cumul_delta=-0.34033, eps=0.17954
# episode 560: cumul_reward=39.0, accuracy:0.6, cumul_delta=-0.27067, eps=0.17899
# episode 561: cumul_reward=44.0, accuracy:0.73333, cumul_delta=2.447, eps=0.17844
# episode 562: cumul_reward=51.0, accuracy:0.8, cumul_delta=3.8587, eps=0.1779
# episode 563: cumul_reward=38.0, accuracy:0.53333, cumul_delta=-0.67865, eps=0.17735
# episode 564: cumul_reward=42.0, accuracy:0.66667, cumul_delta=3.1705, eps=0.17681
# episode 565: cumul_reward=46.0, accuracy:0.66667, cumul_delta=5.6608, eps=0.17626
# episode 566: cumul_reward=44.0, accuracy:0.73333, cumul_delta=0.47469, eps=0.17572
# episode 567: cumul_reward=45.0, accuracy:0.66667, cumul_delta=-2.0689, eps=0.17518
# episode 568: cumul_reward=27.0, accuracy:0.33333, cumul_delta=3.8238, eps=0.17465
# episode 569: cumul_reward=41.0, accuracy:0.4, cumul_delta=2.8779, eps=0.17411
# episode 570: cumul_reward=33.0, accuracy:0.46667, cumul_delta=3.1078, eps=0.17358
# episode 571: cumul_reward=51.0, accuracy:0.8, cumul_delta=1.0114, eps=0.17304
# episode 572: cumul_reward=43.0, accuracy:0.66667, cumul_delta=0.43081, eps=0.17251
# episode 573: cumul_reward=43.0, accuracy:0.66667, cumul_delta=-1.4225, eps=0.17198
# episode 574: cumul_reward=33.0, accuracy:0.46667, cumul_delta=5.6747, eps=0.17146
# episode 575: cumul_reward=23.0, accuracy:0.26667, cumul_delta=7.1929, eps=0.17093
# episode 576: cumul_reward=35.0, accuracy:0.46667, cumul_delta=-1.0182, eps=0.17041
# episode 577: cumul_reward=36.0, accuracy:0.46667, cumul_delta=0.55758, eps=0.16988
# episode 578: cumul_reward=22.0, accuracy:0.26667, cumul_delta=3.836, eps=0.16936
# episode 579: cumul_reward=37.0, accuracy:0.53333, cumul_delta=4.4112, eps=0.16884
# episode 580: cumul_reward=43.0, accuracy:0.66667, cumul_delta=0.88548, eps=0.16833
# episode 581: cumul_reward=37.0, accuracy:0.53333, cumul_delta=2.6292, eps=0.16781
# episode 582: cumul_reward=23.0, accuracy:0.33333, cumul_delta=5.0064, eps=0.16729
# episode 583: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.14725, eps=0.16678
# episode 584: cumul_reward=58.0, accuracy:0.86667, cumul_delta=-1.5837, eps=0.16627
# episode 585: cumul_reward=45.0, accuracy:0.66667, cumul_delta=7.0558, eps=0.16576
# episode 586: cumul_reward=39.0, accuracy:0.6, cumul_delta=0.4138, eps=0.16525
# episode 587: cumul_reward=51.0, accuracy:0.8, cumul_delta=0.01314, eps=0.16474
# episode 588: cumul_reward=50.0, accuracy:0.8, cumul_delta=0.63538, eps=0.16424
# episode 589: cumul_reward=46.0, accuracy:0.73333, cumul_delta=2.2853, eps=0.16374
# episode 590: cumul_reward=44.0, accuracy:0.66667, cumul_delta=-1.6496, eps=0.16323
# episode 591: cumul_reward=59.0, accuracy:0.93333, cumul_delta=0.038332, eps=0.16273
# episode 592: cumul_reward=43.0, accuracy:0.66667, cumul_delta=-1.6326, eps=0.16223
# episode 593: cumul_reward=53.0, accuracy:0.8, cumul_delta=3.1152, eps=0.16174
# episode 594: cumul_reward=42.0, accuracy:0.46667, cumul_delta=5.6753, eps=0.16124
# episode 595: cumul_reward=30.0, accuracy:0.33333, cumul_delta=4.8941, eps=0.16074
# episode 596: cumul_reward=33.0, accuracy:0.4, cumul_delta=-1.0999, eps=0.16025
# episode 597: cumul_reward=33.0, accuracy:0.33333, cumul_delta=4.5979, eps=0.15976
# episode 598: cumul_reward=38.0, accuracy:0.6, cumul_delta=3.2588, eps=0.15927
# ...
# episode 849: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.024363, eps=0.073662
# episode 850: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.010963, eps=0.073436
# episode 851: cumul_reward=46.0, accuracy:0.73333, cumul_delta=0.99041, eps=0.073211
# episode 852: cumul_reward=49.0, accuracy:0.73333, cumul_delta=-3.8453, eps=0.072986
# episode 853: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.90962, eps=0.072763
# episode 854: cumul_reward=44.0, accuracy:0.73333, cumul_delta=0.0011053, eps=0.072539
# episode 855: cumul_reward=36.0, accuracy:0.6, cumul_delta=0.0, eps=0.072317
# episode 856: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.4088, eps=0.072095
# episode 857: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.18396, eps=0.071874
# episode 858: cumul_reward=54.0, accuracy:0.86667, cumul_delta=1.0727, eps=0.071653
# episode 859: cumul_reward=54.0, accuracy:0.86667, cumul_delta=2.2376, eps=0.071434
# episode 860: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.00010157, eps=0.071214
# episode 861: cumul_reward=48.0, accuracy:0.8, cumul_delta=1.21, eps=0.070996
# episode 862: cumul_reward=48.0, accuracy:0.73333, cumul_delta=0.5445, eps=0.070778
# episode 863: cumul_reward=48.0, accuracy:0.8, cumul_delta=1.2267, eps=0.070561
# episode 864: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.55204, eps=0.070345
# episode 865: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.24842, eps=0.070129
# episode 866: cumul_reward=47.0, accuracy:0.73333, cumul_delta=-0.65847, eps=0.069914
# episode 867: cumul_reward=51.0, accuracy:0.8, cumul_delta=3.1098, eps=0.069699
# episode 868: cumul_reward=54.0, accuracy:0.86667, cumul_delta=2.2501, eps=0.069486
# episode 869: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.40851, eps=0.069272
# episode 870: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.20616, eps=0.06906
# episode 871: cumul_reward=50.0, accuracy:0.73333, cumul_delta=2.3451, eps=0.068848
# episode 872: cumul_reward=52.0, accuracy:0.86667, cumul_delta=1.0223, eps=0.068637
# episode 873: cumul_reward=44.0, accuracy:0.73333, cumul_delta=0.4911, eps=0.068426
# episode 874: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.22303, eps=0.068216
# episode 875: cumul_reward=54.0, accuracy:0.86667, cumul_delta=-2.1164, eps=0.068007
# episode 876: cumul_reward=60.0, accuracy:1.0, cumul_delta=1.2644, eps=0.067799
# episode 877: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.024467, eps=0.067591
# episode 878: cumul_reward=53.0, accuracy:0.8, cumul_delta=4.296, eps=0.067383
# episode 879: cumul_reward=51.0, accuracy:0.8, cumul_delta=5.0428, eps=0.067177
# episode 880: cumul_reward=44.0, accuracy:0.66667, cumul_delta=3.4366, eps=0.066971
# episode 881: cumul_reward=53.0, accuracy:0.86667, cumul_delta=-0.49675, eps=0.066765
# episode 882: cumul_reward=48.0, accuracy:0.8, cumul_delta=1.1299, eps=0.06656
# episode 883: cumul_reward=44.0, accuracy:0.73333, cumul_delta=0.91668, eps=0.066356
# episode 884: cumul_reward=48.0, accuracy:0.73333, cumul_delta=0.4124, eps=0.066153
# episode 885: cumul_reward=60.0, accuracy:1.0, cumul_delta=1.3959, eps=0.06595
# episode 886: cumul_reward=44.0, accuracy:0.73333, cumul_delta=0.63136, eps=0.065747
# episode 887: cumul_reward=44.0, accuracy:0.73333, cumul_delta=0.26191, eps=0.065546
# episode 888: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.11787, eps=0.065345
# episode 889: cumul_reward=48.0, accuracy:0.8, cumul_delta=0.049675, eps=0.065144
# episode 890: cumul_reward=54.0, accuracy:0.86667, cumul_delta=2.2705, eps=0.064944
# episode 891: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.033226, eps=0.064745
# episode 892: cumul_reward=45.0, accuracy:0.73333, cumul_delta=-1.6458, eps=0.064547
# episode 893: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.92013, eps=0.064349
# episode 894: cumul_reward=47.0, accuracy:0.73333, cumul_delta=0.96375, eps=0.064151
# episode 895: cumul_reward=60.0, accuracy:1.0, cumul_delta=1.094, eps=0.063954
# episode 896: cumul_reward=54.0, accuracy:0.86667, cumul_delta=2.6922, eps=0.063758
# episode 897: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.22161, eps=0.063563
# episode 898: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.099725, eps=0.063368
# episode 899: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.044876, eps=0.063173
# episode 900: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.020195, eps=0.06298
# episode 901: cumul_reward=52.0, accuracy:0.86667, cumul_delta=9.2983e-06, eps=0.062786
# episode 902: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.0090878, eps=0.062594
# episode 903: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.004087, eps=0.062402
# episode 904: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.0018415, eps=0.06221
# episode 905: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.00082779, eps=0.06202
# episode 906: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.00037265, eps=0.061829
# episode 907: cumul_reward=56.0, accuracy:0.93333, cumul_delta=6.0775, eps=0.06164
# episode 908: cumul_reward=38.0, accuracy:0.6, cumul_delta=2.2, eps=0.061451
# episode 909: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.00016785, eps=0.061262
# episode 910: cumul_reward=46.0, accuracy:0.73333, cumul_delta=2.2001, eps=0.061074
# episode 911: cumul_reward=60.0, accuracy:1.0, cumul_delta=4.077e-05, eps=0.060887
# episode 912: cumul_reward=51.0, accuracy:0.8, cumul_delta=4.95, eps=0.0607
# episode 913: cumul_reward=55.0, accuracy:0.86667, cumul_delta=-1.65, eps=0.060514
# episode 914: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.90751, eps=0.060328
# episode 915: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.40838, eps=0.060143
# episode 916: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.18377, eps=0.059959
# episode 917: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.082698, eps=0.059775
# episode 918: cumul_reward=48.0, accuracy:0.73333, cumul_delta=0.037214, eps=0.059591
# episode 919: cumul_reward=56.0, accuracy:0.93333, cumul_delta=1.2267, eps=0.059409
# episode 920: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.55204, eps=0.059226
# episode 921: cumul_reward=54.0, accuracy:0.86667, cumul_delta=-1.9516, eps=0.059045
# episode 922: cumul_reward=60.0, accuracy:1.0, cumul_delta=1.3218, eps=0.058864
# episode 923: cumul_reward=55.0, accuracy:0.8, cumul_delta=2.2002, eps=0.058683
# episode 924: cumul_reward=60.0, accuracy:1.0, cumul_delta=1.4913, eps=0.058503
# episode 925: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.67109, eps=0.058324
# episode 926: cumul_reward=47.0, accuracy:0.73333, cumul_delta=0.62201, eps=0.058145
# episode 927: cumul_reward=60.0, accuracy:1.0, cumul_delta=1.1822, eps=0.057966
# episode 928: cumul_reward=55.0, accuracy:0.86667, cumul_delta=-0.12803, eps=0.057788
# episode 929: cumul_reward=60.0, accuracy:1.0, cumul_delta=1.1469, eps=0.057611
# episode 930: cumul_reward=51.0, accuracy:0.8, cumul_delta=2.6075, eps=0.057434
# episode 931: cumul_reward=54.0, accuracy:0.86667, cumul_delta=2.4323, eps=0.057258
# episode 932: cumul_reward=50.0, accuracy:0.8, cumul_delta=9.8118, eps=0.057083
# episode 933: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.092513, eps=0.056908
# episode 934: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.04163, eps=0.056733
# episode 935: cumul_reward=53.0, accuracy:0.8, cumul_delta=1.5587, eps=0.056559
# episode 936: cumul_reward=60.0, accuracy:1.0, cumul_delta=1.2184, eps=0.056385
# episode 937: cumul_reward=44.0, accuracy:0.73333, cumul_delta=0.0037858, eps=0.056213
# episode 938: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.54622, eps=0.05604
# episode 939: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.2458, eps=0.055868
# episode 940: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.12066, eps=0.055697
# episode 941: cumul_reward=46.0, accuracy:0.73333, cumul_delta=2.0574, eps=0.055526
# episode 942: cumul_reward=48.0, accuracy:0.8, cumul_delta=0.027005, eps=0.055356
# episode 943: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.010118, eps=0.055186
# episode 944: cumul_reward=51.0, accuracy:0.8, cumul_delta=1.6921, eps=0.055017
# episode 945: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.0020645, eps=0.054848
# episode 946: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.00093436, eps=0.05468
# episode 947: cumul_reward=45.0, accuracy:0.73333, cumul_delta=-1.6496, eps=0.054512
# episode 948: cumul_reward=54.0, accuracy:0.86667, cumul_delta=3.1077, eps=0.054345
# episode 949: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.40846, eps=0.054178
# episode 950: cumul_reward=44.0, accuracy:0.73333, cumul_delta=0.18377, eps=0.054012
# episode 951: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.082737, eps=0.053846
# episode 952: cumul_reward=44.0, accuracy:0.73333, cumul_delta=1.812e-05, eps=0.053681
# episode 953: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.037221, eps=0.053516
# episode 954: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.016749, eps=0.053352
# episode 955: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.0075371, eps=0.053188
# episode 956: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.003392, eps=0.053025
# episode 957: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.0015264, eps=0.052863
# episode 958: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.00068665, eps=0.0527
# episode 959: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.00030899, eps=0.052539
# episode 960: cumul_reward=46.0, accuracy:0.73333, cumul_delta=0.99014, eps=0.052378
# episode 961: cumul_reward=44.0, accuracy:0.73333, cumul_delta=0.0020347, eps=0.052217
# episode 962: cumul_reward=53.0, accuracy:0.86667, cumul_delta=-1.6499, eps=0.052057
# episode 963: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.90753, eps=0.051897
# episode 964: cumul_reward=51.0, accuracy:0.8, cumul_delta=2.6359, eps=0.051738
# episode 965: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.18377, eps=0.051579
# episode 966: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.082699, eps=0.051421
# episode 967: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.037214, eps=0.051263
# episode 968: cumul_reward=52.0, accuracy:0.86667, cumul_delta=4.7684e-07, eps=0.051106
# episode 969: cumul_reward=57.0, accuracy:0.93333, cumul_delta=5.9567, eps=0.050949
# episode 970: cumul_reward=48.0, accuracy:0.73333, cumul_delta=4.0975, eps=0.050793
# episode 971: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.41591, eps=0.050637
# episode 972: cumul_reward=50.0, accuracy:0.8, cumul_delta=2.3872, eps=0.050482
# episode 973: cumul_reward=54.0, accuracy:0.86667, cumul_delta=2.2842, eps=0.050327
# episode 974: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.0379, eps=0.050173
# episode 975: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.017055, eps=0.050019
# episode 976: cumul_reward=44.0, accuracy:0.73333, cumul_delta=0.00013924, eps=0.049865
# episode 977: cumul_reward=56.0, accuracy:0.93333, cumul_delta=0.0075982, eps=0.049712
# episode 978: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.0034192, eps=0.04956
# episode 979: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.0015385, eps=0.049408
# episode 980: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.00069237, eps=0.049256
# episode 981: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.00031209, eps=0.049105
# episode 982: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.00014043, eps=0.048955
# episode 983: cumul_reward=45.0, accuracy:0.73333, cumul_delta=-1.649, eps=0.048804
# episode 984: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.90753, eps=0.048655
# episode 985: cumul_reward=42.0, accuracy:0.66667, cumul_delta=2.6084, eps=0.048505
# episode 986: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.18377, eps=0.048357
# episode 987: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.082699, eps=0.048208
# episode 988: cumul_reward=53.0, accuracy:0.86667, cumul_delta=-1.6128, eps=0.04806
# episode 989: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.92425, eps=0.047913
# episode 990: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.41591, eps=0.047766
# episode 991: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.18716, eps=0.04762
# episode 992: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.084222, eps=0.047473
# episode 993: cumul_reward=53.0, accuracy:0.8, cumul_delta=3.7813, eps=0.047328
# episode 994: cumul_reward=44.0, accuracy:0.73333, cumul_delta=0.037213, eps=0.047183
# episode 995: cumul_reward=46.0, accuracy:0.66667, cumul_delta=6.6003, eps=0.047038
# episode 996: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.016885, eps=0.046894
# episode 997: cumul_reward=44.0, accuracy:0.73333, cumul_delta=0.00041199, eps=0.04675
# episode 998: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.0075982, eps=0.046606
# episode 999: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.0033913, eps=0.046463
# episode 1000: cumul_reward=56.0, accuracy:0.93333, cumul_delta=0.001554, eps=0.046321
# episode 1001: cumul_reward=57.0, accuracy:0.86667, cumul_delta=-0.6593, eps=0.046179
# episode 1002: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.90781, eps=0.046037
# episode 1003: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.40852, eps=0.045896
# episode 1004: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.18383, eps=0.045755
# episode 1005: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.082724, eps=0.045615
# episode 1006: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.037226, eps=0.045475
# episode 1007: cumul_reward=46.0, accuracy:0.73333, cumul_delta=2.2, eps=0.045335
# episode 1008: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.016748, eps=0.045196
# episode 1009: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.0075371, eps=0.045058
# episode 1010: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.0033915, eps=0.04492
# episode 1011: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.0015259, eps=0.044782
# episode 1012: cumul_reward=54.0, accuracy:0.86667, cumul_delta=2.2007, eps=0.044644
# episode 1013: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.00030923, eps=0.044507
# episode 1014: cumul_reward=54.0, accuracy:0.86667, cumul_delta=2.2, eps=0.044371
# episode 1015: cumul_reward=49.0, accuracy:0.73333, cumul_delta=-3.8498, eps=0.044235
# episode 1016: cumul_reward=60.0, accuracy:1.0, cumul_delta=2.1176, eps=0.044099
# episode 1017: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.95294, eps=0.043964
# episode 1018: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.42882, eps=0.043829
# episode 1019: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.19297, eps=0.043695
# episode 1020: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.086837, eps=0.04356
# episode 1021: cumul_reward=49.0, accuracy:0.8, cumul_delta=-1.6109, eps=0.043427
# episode 1022: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.92508, eps=0.043294
# episode 1023: cumul_reward=54.0, accuracy:0.86667, cumul_delta=0.61676, eps=0.043161
# episode 1024: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.18538, eps=0.043028
# episode 1025: cumul_reward=55.0, accuracy:0.86667, cumul_delta=8.5544, eps=0.042896
# episode 1026: cumul_reward=56.0, accuracy:0.93333, cumul_delta=0.039557, eps=0.042765
# episode 1027: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.001055, eps=0.042634
# episode 1028: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.01722, eps=0.042503
# episode 1029: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.0077498, eps=0.042373
# episode 1030: cumul_reward=52.0, accuracy:0.86667, cumul_delta=0.0034873, eps=0.042243
# episode 1031: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.0015693, eps=0.042113
# episode 1032: cumul_reward=60.0, accuracy:1.0, cumul_delta=0.00070548, eps=0.041984
# episode 1033: cumul_reward=52.0, accuracy:0.86667, cumul_delta=7.6294e-06, eps=0.041855
# episode 1034: cumul_reward=56.0, accuracy:0.93333, cumul_delta=0.00031376, eps=0.041727
# episode 1035: cumul_reward=48.0, accuracy:0.8, cumul_delta=0.00017762, eps=0.041599
# episode 1036: cumul_reward=52.0, accuracy:0.86667, cumul_delta=6.3896e-05, eps=0.041471
# episode 1037: cumul_reward=44.0, accuracy:0.73333, cumul_delta=2.3842e-07, eps=0.041344
# episode 1038: cumul_reward=60.0, accuracy:1.0, cumul_delta=2.9087e-05, eps=0.041217
# episode 1039: cumul_reward=60.0, accuracy:1.0, cumul_delta=1.3113e-05, eps=0.041091
# episode 1040: cumul_reward=60.0, accuracy:1.0, cumul_delta=5.722e-06, eps=0.040965
# episode 1041: cumul_reward=60.0, accuracy:1.0, cumul_delta=2.6226e-06, eps=0.040839
# episode 1042: cumul_reward=60.0, accuracy:1.0, cumul_delta=1.1921e-06, eps=0.040714
